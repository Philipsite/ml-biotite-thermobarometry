# %% [markdown]
# :warning:**IMPORTANT NOTICE**:warning:\
# *Since the initial parameterisation and gradient descent optimisation are stochastic processes, the training of a neural network is not fully reproducible.*
#
# *Therefore, it is not recommended to re-run this script as it will overwrite the original calibration of the neural network used in the work presented here.
# The purpose of this script is solely to document the training procedure and can be copied as a template to fit other new neural networks.*
#
# *To experiment with the models calibrated here, they can be loaded from the `saved_models` directory.*

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf

from pathlib import Path
from keras.models import Model, Sequential, load_model, clone_model
from keras.layers import Dense, Normalization, Input, Dropout
from keras.losses import MeanSquaredError
from keras.optimizers import Adam, schedules
from keras.metrics import MeanAbsoluteError, RootMeanSquaredError
from keras.callbacks import CSVLogger, EarlyStopping

from ml_tb.normalisation import MinMaxScaler
from ml_tb.metrics import RMSE_denormalised_P, RMSE_denormalised_T
from ml_tb.plot import plot_multiple_training_curves
# Out:
# C:\Users\ThinkPad\AppData\Local\Temp\ipykernel_15932\1129355832.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# WARNING:tensorflow:From c:\Users\ThinkPad\miniconda3\envs\masterproject\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# ## Load validation datasets

# %%
# Load the data
val_data_dir = Path("..", "01_fit_natural_biotite", "kfold_datasets")

DATA_train_0 = np.loadtxt(Path(val_data_dir, "train_data_0.csv"), delimiter=",")
DATA_val_0 = np.loadtxt(Path(val_data_dir, "test_data_0.csv"), delimiter=",")

DATA_train_1 = np.loadtxt(Path(val_data_dir, "train_data_1.csv"), delimiter=",")
DATA_val_1 = np.loadtxt(Path(val_data_dir, "test_data_1.csv"), delimiter=",")

DATA_train_2 = np.loadtxt(Path(val_data_dir, "train_data_2.csv"), delimiter=",")
DATA_val_2 = np.loadtxt(Path(val_data_dir, "test_data_2.csv"), delimiter=",")

DATA_train_3 = np.loadtxt(Path(val_data_dir, "train_data_3.csv"), delimiter=",")
DATA_val_3 = np.loadtxt(Path(val_data_dir, "test_data_3.csv"), delimiter=",")

DATA_train_4 = np.loadtxt(Path(val_data_dir, "train_data_4.csv"), delimiter=",")
DATA_val_4 = np.loadtxt(Path(val_data_dir, "test_data_4.csv"), delimiter=",")

train_data_list = [DATA_train_0, DATA_train_1, DATA_train_2, DATA_train_3, DATA_train_4]
val_data_list = [DATA_val_0, DATA_val_1, DATA_val_2, DATA_val_3, DATA_val_4]

# %% [markdown]
# ## Set-up global training parameters
#
# Define a function to calculate RMSE for pressure and temperature for unscaled values to have an interpretable metric.

# %%
scaling_pt = MinMaxScaler(min=[1500, 400], max=[10000, 900], axis=0)
inv_scaling_pt = MinMaxScaler(min=[1500, 400], max=[10000, 900], axis=0, invert=True)

def RMSE_P(y_true, y_pred):
    return RMSE_denormalised_P(y_true, y_pred, inv_scaling_pt)


def RMSE_T(y_true, y_pred):
    return RMSE_denormalised_T(y_true, y_pred, inv_scaling_pt)
# Out:
# WARNING:tensorflow:From c:\Users\ThinkPad\miniconda3\envs\masterproject\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
CALLBACKS_0 = [CSVLogger("k_ds55BtT_0.log"), EarlyStopping(monitor="val_loss", patience=50, restore_best_weights=True)]
CALLBACKS_1 = [CSVLogger("k_ds55BtT_1.log"), EarlyStopping(monitor="val_loss", patience=50, restore_best_weights=True)]
CALLBACKS_2 = [CSVLogger("k_ds55BtT_2.log"), EarlyStopping(monitor="val_loss", patience=50, restore_best_weights=True)]
CALLBACKS_3 = [CSVLogger("k_ds55BtT_3.log"), EarlyStopping(monitor="val_loss", patience=50, restore_best_weights=True)]
CALLBACKS_4 = [CSVLogger("k_ds55BtT_4.log"), EarlyStopping(monitor="val_loss", patience=50, restore_best_weights=True)]

callsbacks_list = [CALLBACKS_0, CALLBACKS_1, CALLBACKS_2, CALLBACKS_3, CALLBACKS_4]

# %% [markdown]
# ## Load pre-trained model

# %%
# load a saved model from "02_pretraining\saved_models\model_ds62White2014"
model_prior = load_model(Path("..","02_pretraining", "saved_models/model_ds55Tajcmanova2009"), compile=False)
# Out:
# WARNING:tensorflow:From c:\Users\ThinkPad\miniconda3\envs\masterproject\Lib\site-packages\keras\src\saving\legacy\saved_model\load.py:107: The name tf.gfile.Exists is deprecated. Please use tf.io.gfile.exists instead.
#
# WARNING:tensorflow:From c:\Users\ThinkPad\miniconda3\envs\masterproject\Lib\site-packages\keras\src\saving\legacy\saved_model\load.py:471: The name tf.logging.warning is deprecated. Please use tf.compat.v1.logging.warning instead.
#
# WARNING:tensorflow:Unable to restore custom metric. Please ensure that the layer implements `get_config` and `from_config` when saving. In addition, please use the `custom_objects` arg when calling `load_model()`.
# WARNING:tensorflow:Unable to restore custom metric. Please ensure that the layer implements `get_config` and `from_config` when saving. In addition, please use the `custom_objects` arg when calling `load_model()`.

# %%
# train loop

def train_model(DATA_train, DATA_val, CALLBACKS, model_name):
    # split up data
    data_train = DATA_train[:, 0:6]
    data_val = DATA_val[:, 0:6]

    pt_train = DATA_train[:, -2:]
    pt_val = DATA_val[:, -2:]

    # NORMALISATION
    normalisation_biotite_composition = Normalization(axis=-1)
    normalisation_biotite_composition.adapt(data_train)

    # SCALING of PT
    pt_train_norm = scaling_pt(pt_train)
    pt_val_norm = scaling_pt(pt_val)

    # SET TRAINING PARAMETERS
    BATCH_SIZE = 50
    STEPS_PER_EPOCH = len(DATA_train_0) // BATCH_SIZE
    MAX_EPOCHS = 5000

    lr_schedule = schedules.InverseTimeDecay(0.0005, decay_steps=STEPS_PER_EPOCH*1000, decay_rate=1, staircase=False)

    LOSS = MeanSquaredError()
    METRICS = [MeanAbsoluteError(), RootMeanSquaredError(), RMSE_P, RMSE_T]
    OPT = Adam(lr_schedule)

    # build model
    model_prior_c = clone_model(model_prior, input_tensors=Input(shape=(6,)))

    model = Sequential()
    model.add(normalisation_biotite_composition)
    model.add(model_prior_c.layers[1])
    model.add(Dropout(0.2))
    model.add(model_prior_c.layers[2])
    model.add(Dropout(0.2))
    model.add(model_prior_c.layers[3])
    model.add(Dropout(0.2))
    model.add(model_prior_c.layers[4])
    model.add(model_prior_c.layers[5])
    model.compile(optimizer=OPT, loss=LOSS, metrics=METRICS)
    model.summary()

    # train model
    history = model.fit(data_train, pt_train_norm,
                        validation_data=(data_val, pt_val_norm),
                        batch_size=BATCH_SIZE,
                        epochs=MAX_EPOCHS,
                        callbacks=CALLBACKS)

    model.save(Path("saved_models", model_name))

# %%
model_name_list = ["k_ds55BtT_0", "k_ds55BtT_1", "k_ds55BtT_2", "k_ds55BtT_3", "k_ds55BtT_4"]
for train_data, val_data, CALLBACKS, model_name in zip(train_data_list, val_data_list, callsbacks_list, model_name_list):
    train_model(train_data, val_data, CALLBACKS, model_name)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  normalization (Normalizati  (None, 6)                 13
#  on)
#
#  dense (Dense)               (None, 64)                448
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 64)                4160
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 64)                4160
#
#  dense_4 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 13071 (51.06 KB)
# Trainable params: 13058 (51.01 KB)
# Non-trainable params: 13 (56.00 Byte)
# _________________________________________________________________
# Epoch 1/5000
# WARNING:tensorflow:From c:\Users\ThinkPad\miniconda3\envs\masterproject\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\ThinkPad\miniconda3\envs\masterproject\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 35/35 [==============================] - 2s 10ms/step - loss: 0.0709 - mean_absolute_error: 0.2142 - root_mean_squared_error: 0.2663 - RMSE_P: 2312.1904 - RMSE_T: 123.7830 - val_loss: 0.0434 - val_mean_absolute_error: 0.1701 - val_root_mean_squared_error: 0.2082 - val_RMSE_P: 1979.9526 - val_RMSE_T: 88.4213
# Epoch 2/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0414 - mean_absolute_error: 0.1581 - root_mean_squared_error: 0.2036 - RMSE_P: 1867.8438 - RMSE_T: 90.9226 - val_loss: 0.0303 - val_mean_absolute_error: 0.1374 - val_root_mean_squared_error: 0.1739 - val_RMSE_P: 1680.0659 - val_RMSE_T: 72.2123
# Epoch 3/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0317 - mean_absolute_error: 0.1373 - root_mean_squared_error: 0.1781 - RMSE_P: 1653.2703 - RMSE_T: 78.6416 - val_loss: 0.0243 - val_mean_absolute_error: 0.1207 - val_root_mean_squared_error: 0.1559 - val_RMSE_P: 1491.7452 - val_RMSE_T: 66.0289
# Epoch 4/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0276 - mean_absolute_error: 0.1254 - root_mean_squared_error: 0.1662 - RMSE_P: 1588.6057 - RMSE_T: 69.6597 - val_loss: 0.0224 - val_mean_absolute_error: 0.1136 - val_root_mean_squared_error: 0.1496 - val_RMSE_P: 1439.1460 - val_RMSE_T: 62.9533
# Epoch 5/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0252 - mean_absolute_error: 0.1191 - root_mean_squared_error: 0.1588 - RMSE_P: 1507.5940 - RMSE_T: 67.0049 - val_loss: 0.0204 - val_mean_absolute_error: 0.1069 - val_root_mean_squared_error: 0.1430 - val_RMSE_P: 1376.3784 - val_RMSE_T: 60.0743
# Epoch 6/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0231 - mean_absolute_error: 0.1132 - root_mean_squared_error: 0.1520 - RMSE_P: 1439.4702 - RMSE_T: 64.9580 - val_loss: 0.0176 - val_mean_absolute_error: 0.0975 - val_root_mean_squared_error: 0.1327 - val_RMSE_P: 1282.2759 - val_RMSE_T: 55.2266
# Epoch 7/5000
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0211 - mean_absolute_error: 0.1090 - root_mean_squared_error: 0.1453 - RMSE_P: 1412.5126 - RMSE_T: 59.2227 - val_loss: 0.0171 - val_mean_absolute_error: 0.0953 - val_root_mean_squared_error: 0.1307 - val_RMSE_P: 1262.9878 - val_RMSE_T: 54.4491
# Epoch 8/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0204 - mean_absolute_error: 0.1058 - root_mean_squared_error: 0.1429 - RMSE_P: 1388.8510 - RMSE_T: 58.3768 - val_loss: 0.0162 - val_mean_absolute_error: 0.0923 - val_root_mean_squared_error: 0.1272 - val_RMSE_P: 1234.6957 - val_RMSE_T: 52.5325
# Epoch 9/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0190 - mean_absolute_error: 0.1025 - root_mean_squared_error: 0.1380 - RMSE_P: 1350.3519 - RMSE_T: 54.9278 - val_loss: 0.0162 - val_mean_absolute_error: 0.0918 - val_root_mean_squared_error: 0.1271 - val_RMSE_P: 1258.9166 - val_RMSE_T: 50.4430
# Epoch 10/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0192 - mean_absolute_error: 0.1018 - root_mean_squared_error: 0.1384 - RMSE_P: 1367.8530 - RMSE_T: 55.5539 - val_loss: 0.0158 - val_mean_absolute_error: 0.0904 - val_root_mean_squared_error: 0.1255 - val_RMSE_P: 1245.6726 - val_RMSE_T: 49.6886
# Epoch 11/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0185 - mean_absolute_error: 0.0999 - root_mean_squared_error: 0.1360 - RMSE_P: 1336.2505 - RMSE_T: 54.3590 - val_loss: 0.0151 - val_mean_absolute_error: 0.0880 - val_root_mean_squared_error: 0.1230 - val_RMSE_P: 1229.1368 - val_RMSE_T: 48.0308
# Epoch 12/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0181 - mean_absolute_error: 0.0984 - root_mean_squared_error: 0.1345 - RMSE_P: 1313.5894 - RMSE_T: 52.9643 - val_loss: 0.0150 - val_mean_absolute_error: 0.0878 - val_root_mean_squared_error: 0.1227 - val_RMSE_P: 1217.7920 - val_RMSE_T: 48.6293
# Epoch 13/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0178 - mean_absolute_error: 0.0971 - root_mean_squared_error: 0.1333 - RMSE_P: 1325.0775 - RMSE_T: 51.4513 - val_loss: 0.0150 - val_mean_absolute_error: 0.0878 - val_root_mean_squared_error: 0.1225 - val_RMSE_P: 1215.0881 - val_RMSE_T: 48.6979
# Epoch 14/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0174 - mean_absolute_error: 0.0963 - root_mean_squared_error: 0.1321 - RMSE_P: 1299.6371 - RMSE_T: 52.8176 - val_loss: 0.0149 - val_mean_absolute_error: 0.0872 - val_root_mean_squared_error: 0.1219 - val_RMSE_P: 1209.8510 - val_RMSE_T: 48.4127
# Epoch 15/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0174 - mean_absolute_error: 0.0953 - root_mean_squared_error: 0.1320 - RMSE_P: 1312.0547 - RMSE_T: 50.7032 - val_loss: 0.0146 - val_mean_absolute_error: 0.0863 - val_root_mean_squared_error: 0.1208 - val_RMSE_P: 1207.5009 - val_RMSE_T: 47.2773
# Epoch 16/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0167 - mean_absolute_error: 0.0946 - root_mean_squared_error: 0.1293 - RMSE_P: 1293.8861 - RMSE_T: 50.3205 - val_loss: 0.0145 - val_mean_absolute_error: 0.0859 - val_root_mean_squared_error: 0.1204 - val_RMSE_P: 1209.7377 - val_RMSE_T: 46.5803
# Epoch 17/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0174 - mean_absolute_error: 0.0957 - root_mean_squared_error: 0.1318 - RMSE_P: 1311.4203 - RMSE_T: 50.3824 - val_loss: 0.0145 - val_mean_absolute_error: 0.0862 - val_root_mean_squared_error: 0.1205 - val_RMSE_P: 1211.6909 - val_RMSE_T: 46.4292
# Epoch 18/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0165 - mean_absolute_error: 0.0937 - root_mean_squared_error: 0.1284 - RMSE_P: 1273.1061 - RMSE_T: 50.0447 - val_loss: 0.0144 - val_mean_absolute_error: 0.0856 - val_root_mean_squared_error: 0.1201 - val_RMSE_P: 1203.4170 - val_RMSE_T: 46.6985
# Epoch 19/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0170 - mean_absolute_error: 0.0937 - root_mean_squared_error: 0.1303 - RMSE_P: 1296.7721 - RMSE_T: 49.6107 - val_loss: 0.0143 - val_mean_absolute_error: 0.0852 - val_root_mean_squared_error: 0.1197 - val_RMSE_P: 1204.9360 - val_RMSE_T: 46.0008
# Epoch 20/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0164 - mean_absolute_error: 0.0924 - root_mean_squared_error: 0.1280 - RMSE_P: 1283.7787 - RMSE_T: 49.1117 - val_loss: 0.0146 - val_mean_absolute_error: 0.0861 - val_root_mean_squared_error: 0.1208 - val_RMSE_P: 1201.2666 - val_RMSE_T: 47.6993
# Epoch 21/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0164 - mean_absolute_error: 0.0927 - root_mean_squared_error: 0.1282 - RMSE_P: 1281.6584 - RMSE_T: 48.7969 - val_loss: 0.0143 - val_mean_absolute_error: 0.0853 - val_root_mean_squared_error: 0.1198 - val_RMSE_P: 1203.2015 - val_RMSE_T: 46.2036
# Epoch 22/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0162 - mean_absolute_error: 0.0923 - root_mean_squared_error: 0.1272 - RMSE_P: 1270.9576 - RMSE_T: 48.2738 - val_loss: 0.0145 - val_mean_absolute_error: 0.0856 - val_root_mean_squared_error: 0.1205 - val_RMSE_P: 1203.6797 - val_RMSE_T: 46.9830
# Epoch 23/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0160 - mean_absolute_error: 0.0913 - root_mean_squared_error: 0.1264 - RMSE_P: 1258.7733 - RMSE_T: 48.8572 - val_loss: 0.0144 - val_mean_absolute_error: 0.0853 - val_root_mean_squared_error: 0.1199 - val_RMSE_P: 1198.8507 - val_RMSE_T: 46.7340
# Epoch 24/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0163 - mean_absolute_error: 0.0916 - root_mean_squared_error: 0.1278 - RMSE_P: 1282.3223 - RMSE_T: 48.4791 - val_loss: 0.0144 - val_mean_absolute_error: 0.0856 - val_root_mean_squared_error: 0.1201 - val_RMSE_P: 1204.2520 - val_RMSE_T: 46.5543
# Epoch 25/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0163 - mean_absolute_error: 0.0922 - root_mean_squared_error: 0.1278 - RMSE_P: 1276.1860 - RMSE_T: 47.9064 - val_loss: 0.0145 - val_mean_absolute_error: 0.0860 - val_root_mean_squared_error: 0.1206 - val_RMSE_P: 1199.1436 - val_RMSE_T: 47.5676
# Epoch 26/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0159 - mean_absolute_error: 0.0907 - root_mean_squared_error: 0.1261 - RMSE_P: 1261.2804 - RMSE_T: 47.6145 - val_loss: 0.0143 - val_mean_absolute_error: 0.0847 - val_root_mean_squared_error: 0.1195 - val_RMSE_P: 1196.6028 - val_RMSE_T: 46.4279
# Epoch 27/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0158 - mean_absolute_error: 0.0909 - root_mean_squared_error: 0.1259 - RMSE_P: 1269.5391 - RMSE_T: 46.8429 - val_loss: 0.0140 - val_mean_absolute_error: 0.0839 - val_root_mean_squared_error: 0.1185 - val_RMSE_P: 1196.0551 - val_RMSE_T: 45.1595
# Epoch 28/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0160 - mean_absolute_error: 0.0907 - root_mean_squared_error: 0.1264 - RMSE_P: 1272.2838 - RMSE_T: 47.0635 - val_loss: 0.0142 - val_mean_absolute_error: 0.0849 - val_root_mean_squared_error: 0.1192 - val_RMSE_P: 1203.3406 - val_RMSE_T: 45.4205
# Epoch 29/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0161 - mean_absolute_error: 0.0908 - root_mean_squared_error: 0.1269 - RMSE_P: 1281.0374 - RMSE_T: 47.2750 - val_loss: 0.0143 - val_mean_absolute_error: 0.0850 - val_root_mean_squared_error: 0.1197 - val_RMSE_P: 1201.4329 - val_RMSE_T: 46.1980
# Epoch 30/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0156 - mean_absolute_error: 0.0900 - root_mean_squared_error: 0.1247 - RMSE_P: 1253.3861 - RMSE_T: 46.9575 - val_loss: 0.0141 - val_mean_absolute_error: 0.0838 - val_root_mean_squared_error: 0.1187 - val_RMSE_P: 1195.6241 - val_RMSE_T: 45.4594
# Epoch 31/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0157 - mean_absolute_error: 0.0903 - root_mean_squared_error: 0.1254 - RMSE_P: 1247.5798 - RMSE_T: 46.9181 - val_loss: 0.0142 - val_mean_absolute_error: 0.0841 - val_root_mean_squared_error: 0.1191 - val_RMSE_P: 1194.6516 - val_RMSE_T: 46.0984
# Epoch 32/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0158 - mean_absolute_error: 0.0900 - root_mean_squared_error: 0.1256 - RMSE_P: 1270.7709 - RMSE_T: 47.3636 - val_loss: 0.0143 - val_mean_absolute_error: 0.0848 - val_root_mean_squared_error: 0.1195 - val_RMSE_P: 1196.7529 - val_RMSE_T: 46.4189
# Epoch 33/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0156 - mean_absolute_error: 0.0896 - root_mean_squared_error: 0.1250 - RMSE_P: 1262.0885 - RMSE_T: 47.1416 - val_loss: 0.0140 - val_mean_absolute_error: 0.0835 - val_root_mean_squared_error: 0.1183 - val_RMSE_P: 1198.4028 - val_RMSE_T: 44.6996
# Epoch 34/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0154 - mean_absolute_error: 0.0889 - root_mean_squared_error: 0.1242 - RMSE_P: 1255.5974 - RMSE_T: 46.7253 - val_loss: 0.0139 - val_mean_absolute_error: 0.0833 - val_root_mean_squared_error: 0.1181 - val_RMSE_P: 1197.0114 - val_RMSE_T: 44.5812
# Epoch 35/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0152 - mean_absolute_error: 0.0884 - root_mean_squared_error: 0.1232 - RMSE_P: 1243.1918 - RMSE_T: 46.7383 - val_loss: 0.0138 - val_mean_absolute_error: 0.0830 - val_root_mean_squared_error: 0.1177 - val_RMSE_P: 1191.2588 - val_RMSE_T: 44.5575
# Epoch 36/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0156 - mean_absolute_error: 0.0896 - root_mean_squared_error: 0.1250 - RMSE_P: 1259.9916 - RMSE_T: 46.2909 - val_loss: 0.0140 - val_mean_absolute_error: 0.0837 - val_root_mean_squared_error: 0.1183 - val_RMSE_P: 1193.1869 - val_RMSE_T: 45.1022
# Epoch 37/5000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0152 - mean_absolute_error: 0.0885 - root_mean_squared_error: 0.1234 - RMSE_P: 1231.3385 - RMSE_T: 45.9090 - val_loss: 0.0140 - val_mean_absolute_error: 0.0835 - val_root_mean_squared_error: 0.1184 - val_RMSE_P: 1190.0293 - val_RMSE_T: 45.5610
# Epoch 38/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0152 - mean_absolute_error: 0.0879 - root_mean_squared_error: 0.1235 - RMSE_P: 1236.2328 - RMSE_T: 46.2071 - val_loss: 0.0139 - val_mean_absolute_error: 0.0834 - val_root_mean_squared_error: 0.1181 - val_RMSE_P: 1190.9381 - val_RMSE_T: 45.0711
# Epoch 39/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0156 - mean_absolute_error: 0.0896 - root_mean_squared_error: 0.1248 - RMSE_P: 1266.1554 - RMSE_T: 46.4231 - val_loss: 0.0139 - val_mean_absolute_error: 0.0833 - val_root_mean_squared_error: 0.1178 - val_RMSE_P: 1192.2645 - val_RMSE_T: 44.5558
# Epoch 40/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0153 - mean_absolute_error: 0.0883 - root_mean_squared_error: 0.1237 - RMSE_P: 1251.6763 - RMSE_T: 46.0625 - val_loss: 0.0139 - val_mean_absolute_error: 0.0832 - val_root_mean_squared_error: 0.1179 - val_RMSE_P: 1188.0969 - val_RMSE_T: 45.0412
# Epoch 41/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0150 - mean_absolute_error: 0.0880 - root_mean_squared_error: 0.1225 - RMSE_P: 1231.2286 - RMSE_T: 47.1471 - val_loss: 0.0139 - val_mean_absolute_error: 0.0830 - val_root_mean_squared_error: 0.1178 - val_RMSE_P: 1185.3939 - val_RMSE_T: 45.2049
# Epoch 42/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0151 - mean_absolute_error: 0.0879 - root_mean_squared_error: 0.1228 - RMSE_P: 1241.2665 - RMSE_T: 44.9682 - val_loss: 0.0139 - val_mean_absolute_error: 0.0832 - val_root_mean_squared_error: 0.1178 - val_RMSE_P: 1191.3136 - val_RMSE_T: 44.6177
# Epoch 43/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0152 - mean_absolute_error: 0.0885 - root_mean_squared_error: 0.1235 - RMSE_P: 1233.4629 - RMSE_T: 46.4687 - val_loss: 0.0138 - val_mean_absolute_error: 0.0834 - val_root_mean_squared_error: 0.1176 - val_RMSE_P: 1190.6079 - val_RMSE_T: 44.3653
# Epoch 44/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0149 - mean_absolute_error: 0.0876 - root_mean_squared_error: 0.1220 - RMSE_P: 1232.2281 - RMSE_T: 44.4541 - val_loss: 0.0138 - val_mean_absolute_error: 0.0831 - val_root_mean_squared_error: 0.1174 - val_RMSE_P: 1184.9232 - val_RMSE_T: 44.6934
# Epoch 45/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0150 - mean_absolute_error: 0.0877 - root_mean_squared_error: 0.1224 - RMSE_P: 1222.5845 - RMSE_T: 45.8988 - val_loss: 0.0138 - val_mean_absolute_error: 0.0831 - val_root_mean_squared_error: 0.1174 - val_RMSE_P: 1185.4670 - val_RMSE_T: 44.6478
# Epoch 46/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0152 - mean_absolute_error: 0.0886 - root_mean_squared_error: 0.1234 - RMSE_P: 1250.7441 - RMSE_T: 45.4685 - val_loss: 0.0139 - val_mean_absolute_error: 0.0839 - val_root_mean_squared_error: 0.1180 - val_RMSE_P: 1189.0951 - val_RMSE_T: 45.1202
# Epoch 47/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0149 - mean_absolute_error: 0.0873 - root_mean_squared_error: 0.1221 - RMSE_P: 1238.3955 - RMSE_T: 45.1248 - val_loss: 0.0141 - val_mean_absolute_error: 0.0844 - val_root_mean_squared_error: 0.1187 - val_RMSE_P: 1188.4395 - val_RMSE_T: 46.1029
# Epoch 48/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0149 - mean_absolute_error: 0.0872 - root_mean_squared_error: 0.1221 - RMSE_P: 1226.6218 - RMSE_T: 45.0606 - val_loss: 0.0138 - val_mean_absolute_error: 0.0831 - val_root_mean_squared_error: 0.1175 - val_RMSE_P: 1184.3657 - val_RMSE_T: 44.8591
# Epoch 49/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0151 - mean_absolute_error: 0.0875 - root_mean_squared_error: 0.1228 - RMSE_P: 1249.7207 - RMSE_T: 45.0950 - val_loss: 0.0139 - val_mean_absolute_error: 0.0842 - val_root_mean_squared_error: 0.1181 - val_RMSE_P: 1189.2932 - val_RMSE_T: 45.2056
# Epoch 50/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0150 - mean_absolute_error: 0.0872 - root_mean_squared_error: 0.1223 - RMSE_P: 1228.4750 - RMSE_T: 45.9360 - val_loss: 0.0137 - val_mean_absolute_error: 0.0828 - val_root_mean_squared_error: 0.1170 - val_RMSE_P: 1183.5737 - val_RMSE_T: 44.2743
# Epoch 51/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0147 - mean_absolute_error: 0.0872 - root_mean_squared_error: 0.1213 - RMSE_P: 1228.7155 - RMSE_T: 45.2171 - val_loss: 0.0136 - val_mean_absolute_error: 0.0823 - val_root_mean_squared_error: 0.1164 - val_RMSE_P: 1176.8888 - val_RMSE_T: 44.1207
# Epoch 52/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0149 - mean_absolute_error: 0.0864 - root_mean_squared_error: 0.1219 - RMSE_P: 1233.1129 - RMSE_T: 44.9832 - val_loss: 0.0137 - val_mean_absolute_error: 0.0826 - val_root_mean_squared_error: 0.1169 - val_RMSE_P: 1176.9073 - val_RMSE_T: 44.6864
# Epoch 53/5000
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0143 - mean_absolute_error: 0.0855 - root_mean_squared_error: 0.1197 - RMSE_P: 1215.7834 - RMSE_T: 43.9262 - val_loss: 0.0134 - val_mean_absolute_error: 0.0819 - val_root_mean_squared_error: 0.1159 - val_RMSE_P: 1174.1285 - val_RMSE_T: 43.6539
# Epoch 54/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0150 - mean_absolute_error: 0.0871 - root_mean_squared_error: 0.1227 - RMSE_P: 1235.2563 - RMSE_T: 45.0607 - val_loss: 0.0137 - val_mean_absolute_error: 0.0827 - val_root_mean_squared_error: 0.1171 - val_RMSE_P: 1179.2026 - val_RMSE_T: 44.7805
# Epoch 55/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0146 - mean_absolute_error: 0.0864 - root_mean_squared_error: 0.1207 - RMSE_P: 1218.5978 - RMSE_T: 44.9538 - val_loss: 0.0137 - val_mean_absolute_error: 0.0826 - val_root_mean_squared_error: 0.1171 - val_RMSE_P: 1174.8898 - val_RMSE_T: 45.1446
# Epoch 56/5000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0147 - mean_absolute_error: 0.0862 - root_mean_squared_error: 0.1213 - RMSE_P: 1232.2593 - RMSE_T: 44.7228 - val_loss: 0.0136 - val_mean_absolute_error: 0.0826 - val_root_mean_squared_error: 0.1168 - val_RMSE_P: 1180.4839 - val_RMSE_T: 44.3426
# Epoch 57/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0146 - mean_absolute_error: 0.0858 - root_mean_squared_error: 0.1210 - RMSE_P: 1222.9799 - RMSE_T: 44.5634 - val_loss: 0.0134 - val_mean_absolute_error: 0.0819 - val_root_mean_squared_error: 0.1159 - val_RMSE_P: 1173.9500 - val_RMSE_T: 43.7237
# Epoch 58/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0145 - mean_absolute_error: 0.0858 - root_mean_squared_error: 0.1204 - RMSE_P: 1207.4655 - RMSE_T: 44.4799 - val_loss: 0.0136 - val_mean_absolute_error: 0.0826 - val_root_mean_squared_error: 0.1165 - val_RMSE_P: 1180.4169 - val_RMSE_T: 43.9042
# Epoch 59/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0148 - mean_absolute_error: 0.0865 - root_mean_squared_error: 0.1215 - RMSE_P: 1238.4968 - RMSE_T: 44.4185 - val_loss: 0.0136 - val_mean_absolute_error: 0.0822 - val_root_mean_squared_error: 0.1164 - val_RMSE_P: 1179.5476 - val_RMSE_T: 43.8968
# Epoch 60/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0146 - mean_absolute_error: 0.0863 - root_mean_squared_error: 0.1207 - RMSE_P: 1227.1300 - RMSE_T: 44.6434 - val_loss: 0.0136 - val_mean_absolute_error: 0.0823 - val_root_mean_squared_error: 0.1166 - val_RMSE_P: 1180.5087 - val_RMSE_T: 44.0516
# Epoch 61/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0144 - mean_absolute_error: 0.0858 - root_mean_squared_error: 0.1200 - RMSE_P: 1213.1855 - RMSE_T: 44.3830 - val_loss: 0.0139 - val_mean_absolute_error: 0.0828 - val_root_mean_squared_error: 0.1177 - val_RMSE_P: 1182.1709 - val_RMSE_T: 45.2389
# Epoch 62/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0146 - mean_absolute_error: 0.0863 - root_mean_squared_error: 0.1208 - RMSE_P: 1220.4438 - RMSE_T: 44.6998 - val_loss: 0.0135 - val_mean_absolute_error: 0.0819 - val_root_mean_squared_error: 0.1163 - val_RMSE_P: 1176.8378 - val_RMSE_T: 43.9315
# Epoch 63/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0146 - mean_absolute_error: 0.0864 - root_mean_squared_error: 0.1207 - RMSE_P: 1218.0834 - RMSE_T: 44.2938 - val_loss: 0.0135 - val_mean_absolute_error: 0.0819 - val_root_mean_squared_error: 0.1163 - val_RMSE_P: 1175.3472 - val_RMSE_T: 44.1021
# Epoch 64/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0144 - mean_absolute_error: 0.0858 - root_mean_squared_error: 0.1198 - RMSE_P: 1209.4929 - RMSE_T: 44.4126 - val_loss: 0.0136 - val_mean_absolute_error: 0.0821 - val_root_mean_squared_error: 0.1166 - val_RMSE_P: 1178.2549 - val_RMSE_T: 44.1102
# Epoch 65/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0146 - mean_absolute_error: 0.0860 - root_mean_squared_error: 0.1209 - RMSE_P: 1217.3282 - RMSE_T: 45.0100 - val_loss: 0.0137 - val_mean_absolute_error: 0.0825 - val_root_mean_squared_error: 0.1170 - val_RMSE_P: 1175.0961 - val_RMSE_T: 44.9289
# Epoch 66/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0143 - mean_absolute_error: 0.0853 - root_mean_squared_error: 0.1197 - RMSE_P: 1219.2271 - RMSE_T: 43.8893 - val_loss: 0.0135 - val_mean_absolute_error: 0.0820 - val_root_mean_squared_error: 0.1162 - val_RMSE_P: 1171.9939 - val_RMSE_T: 44.1623
# Epoch 67/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0143 - mean_absolute_error: 0.0845 - root_mean_squared_error: 0.1195 - RMSE_P: 1217.0123 - RMSE_T: 43.2381 - val_loss: 0.0135 - val_mean_absolute_error: 0.0818 - val_root_mean_squared_error: 0.1162 - val_RMSE_P: 1175.4683 - val_RMSE_T: 43.8476
# Epoch 68/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0144 - mean_absolute_error: 0.0855 - root_mean_squared_error: 0.1201 - RMSE_P: 1213.2688 - RMSE_T: 44.0565 - val_loss: 0.0135 - val_mean_absolute_error: 0.0815 - val_root_mean_squared_error: 0.1160 - val_RMSE_P: 1170.2144 - val_RMSE_T: 44.1522
# Epoch 69/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0144 - mean_absolute_error: 0.0852 - root_mean_squared_error: 0.1199 - RMSE_P: 1205.6205 - RMSE_T: 45.1728 - val_loss: 0.0137 - val_mean_absolute_error: 0.0832 - val_root_mean_squared_error: 0.1170 - val_RMSE_P: 1188.8583 - val_RMSE_T: 43.7750
# Epoch 70/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0142 - mean_absolute_error: 0.0855 - root_mean_squared_error: 0.1194 - RMSE_P: 1199.7753 - RMSE_T: 44.6280 - val_loss: 0.0135 - val_mean_absolute_error: 0.0820 - val_root_mean_squared_error: 0.1162 - val_RMSE_P: 1171.5981 - val_RMSE_T: 44.1694
# Epoch 71/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0145 - mean_absolute_error: 0.0856 - root_mean_squared_error: 0.1204 - RMSE_P: 1220.1423 - RMSE_T: 44.2293 - val_loss: 0.0134 - val_mean_absolute_error: 0.0814 - val_root_mean_squared_error: 0.1157 - val_RMSE_P: 1169.0253 - val_RMSE_T: 43.8312
# Epoch 72/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0145 - mean_absolute_error: 0.0855 - root_mean_squared_error: 0.1203 - RMSE_P: 1211.5826 - RMSE_T: 44.0279 - val_loss: 0.0136 - val_mean_absolute_error: 0.0828 - val_root_mean_squared_error: 0.1166 - val_RMSE_P: 1176.9735 - val_RMSE_T: 44.3963
# Epoch 73/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0144 - mean_absolute_error: 0.0855 - root_mean_squared_error: 0.1201 - RMSE_P: 1219.0449 - RMSE_T: 43.9536 - val_loss: 0.0134 - val_mean_absolute_error: 0.0818 - val_root_mean_squared_error: 0.1160 - val_RMSE_P: 1176.9468 - val_RMSE_T: 43.4952
# Epoch 74/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0143 - mean_absolute_error: 0.0848 - root_mean_squared_error: 0.1195 - RMSE_P: 1202.4485 - RMSE_T: 43.8159 - val_loss: 0.0136 - val_mean_absolute_error: 0.0822 - val_root_mean_squared_error: 0.1166 - val_RMSE_P: 1173.2462 - val_RMSE_T: 44.6009
# Epoch 75/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0142 - mean_absolute_error: 0.0845 - root_mean_squared_error: 0.1193 - RMSE_P: 1218.2086 - RMSE_T: 43.8141 - val_loss: 0.0135 - val_mean_absolute_error: 0.0822 - val_root_mean_squared_error: 0.1162 - val_RMSE_P: 1177.2257 - val_RMSE_T: 43.8017
# Epoch 76/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0141 - mean_absolute_error: 0.0840 - root_mean_squared_error: 0.1186 - RMSE_P: 1210.6882 - RMSE_T: 43.0494 - val_loss: 0.0134 - val_mean_absolute_error: 0.0816 - val_root_mean_squared_error: 0.1157 - val_RMSE_P: 1171.2505 - val_RMSE_T: 43.7129
# Epoch 77/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0141 - mean_absolute_error: 0.0851 - root_mean_squared_error: 0.1187 - RMSE_P: 1205.5779 - RMSE_T: 43.4388 - val_loss: 0.0134 - val_mean_absolute_error: 0.0817 - val_root_mean_squared_error: 0.1158 - val_RMSE_P: 1172.4719 - val_RMSE_T: 43.6922
# Epoch 78/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0142 - mean_absolute_error: 0.0854 - root_mean_squared_error: 0.1190 - RMSE_P: 1208.1177 - RMSE_T: 43.7490 - val_loss: 0.0134 - val_mean_absolute_error: 0.0813 - val_root_mean_squared_error: 0.1159 - val_RMSE_P: 1170.4084 - val_RMSE_T: 43.8923
# Epoch 79/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0141 - mean_absolute_error: 0.0843 - root_mean_squared_error: 0.1186 - RMSE_P: 1198.9121 - RMSE_T: 43.4116 - val_loss: 0.0134 - val_mean_absolute_error: 0.0814 - val_root_mean_squared_error: 0.1156 - val_RMSE_P: 1169.8997 - val_RMSE_T: 43.6405
# Epoch 80/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0140 - mean_absolute_error: 0.0849 - root_mean_squared_error: 0.1182 - RMSE_P: 1192.0662 - RMSE_T: 44.1167 - val_loss: 0.0136 - val_mean_absolute_error: 0.0823 - val_root_mean_squared_error: 0.1167 - val_RMSE_P: 1165.3402 - val_RMSE_T: 45.4059
# Epoch 81/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0140 - mean_absolute_error: 0.0845 - root_mean_squared_error: 0.1185 - RMSE_P: 1199.5107 - RMSE_T: 43.2619 - val_loss: 0.0134 - val_mean_absolute_error: 0.0818 - val_root_mean_squared_error: 0.1157 - val_RMSE_P: 1166.2266 - val_RMSE_T: 44.0700
# Epoch 82/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0142 - mean_absolute_error: 0.0847 - root_mean_squared_error: 0.1191 - RMSE_P: 1200.4668 - RMSE_T: 43.6016 - val_loss: 0.0134 - val_mean_absolute_error: 0.0816 - val_root_mean_squared_error: 0.1159 - val_RMSE_P: 1167.9518 - val_RMSE_T: 44.1222
# Epoch 83/5000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0143 - mean_absolute_error: 0.0845 - root_mean_squared_error: 0.1194 - RMSE_P: 1209.8938 - RMSE_T: 43.1802 - val_loss: 0.0133 - val_mean_absolute_error: 0.0814 - val_root_mean_squared_error: 0.1155 - val_RMSE_P: 1165.1884 - val_RMSE_T: 43.9050
# Epoch 84/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0138 - mean_absolute_error: 0.0834 - root_mean_squared_error: 0.1174 - RMSE_P: 1189.4849 - RMSE_T: 42.9026 - val_loss: 0.0133 - val_mean_absolute_error: 0.0813 - val_root_mean_squared_error: 0.1152 - val_RMSE_P: 1166.8931 - val_RMSE_T: 43.3475
# Epoch 85/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0140 - mean_absolute_error: 0.0844 - root_mean_squared_error: 0.1184 - RMSE_P: 1191.8163 - RMSE_T: 42.7192 - val_loss: 0.0134 - val_mean_absolute_error: 0.0816 - val_root_mean_squared_error: 0.1156 - val_RMSE_P: 1162.8070 - val_RMSE_T: 44.2077
# Epoch 86/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0137 - mean_absolute_error: 0.0834 - root_mean_squared_error: 0.1170 - RMSE_P: 1181.8436 - RMSE_T: 42.9107 - val_loss: 0.0133 - val_mean_absolute_error: 0.0816 - val_root_mean_squared_error: 0.1155 - val_RMSE_P: 1163.7727 - val_RMSE_T: 43.9554
# Epoch 87/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0139 - mean_absolute_error: 0.0833 - root_mean_squared_error: 0.1179 - RMSE_P: 1195.8417 - RMSE_T: 43.7660 - val_loss: 0.0132 - val_mean_absolute_error: 0.0810 - val_root_mean_squared_error: 0.1148 - val_RMSE_P: 1161.2448 - val_RMSE_T: 43.3630
# Epoch 88/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0138 - mean_absolute_error: 0.0841 - root_mean_squared_error: 0.1176 - RMSE_P: 1189.2672 - RMSE_T: 43.5351 - val_loss: 0.0134 - val_mean_absolute_error: 0.0819 - val_root_mean_squared_error: 0.1156 - val_RMSE_P: 1162.0540 - val_RMSE_T: 44.2512
# Epoch 89/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0136 - mean_absolute_error: 0.0830 - root_mean_squared_error: 0.1167 - RMSE_P: 1177.2626 - RMSE_T: 42.7114 - val_loss: 0.0134 - val_mean_absolute_error: 0.0819 - val_root_mean_squared_error: 0.1158 - val_RMSE_P: 1165.1937 - val_RMSE_T: 44.2802
# Epoch 90/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0136 - mean_absolute_error: 0.0829 - root_mean_squared_error: 0.1164 - RMSE_P: 1168.1450 - RMSE_T: 43.2391 - val_loss: 0.0132 - val_mean_absolute_error: 0.0816 - val_root_mean_squared_error: 0.1151 - val_RMSE_P: 1162.3085 - val_RMSE_T: 43.5213
# Epoch 91/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0135 - mean_absolute_error: 0.0827 - root_mean_squared_error: 0.1160 - RMSE_P: 1189.1390 - RMSE_T: 41.9871 - val_loss: 0.0132 - val_mean_absolute_error: 0.0812 - val_root_mean_squared_error: 0.1149 - val_RMSE_P: 1158.0151 - val_RMSE_T: 43.6613
# Epoch 92/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0137 - mean_absolute_error: 0.0833 - root_mean_squared_error: 0.1171 - RMSE_P: 1187.3348 - RMSE_T: 42.7190 - val_loss: 0.0132 - val_mean_absolute_error: 0.0810 - val_root_mean_squared_error: 0.1148 - val_RMSE_P: 1161.8970 - val_RMSE_T: 43.1672
# Epoch 93/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0135 - mean_absolute_error: 0.0827 - root_mean_squared_error: 0.1163 - RMSE_P: 1193.0233 - RMSE_T: 41.7331 - val_loss: 0.0133 - val_mean_absolute_error: 0.0817 - val_root_mean_squared_error: 0.1153 - val_RMSE_P: 1161.1582 - val_RMSE_T: 43.8598
# Epoch 94/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0139 - mean_absolute_error: 0.0842 - root_mean_squared_error: 0.1178 - RMSE_P: 1190.6516 - RMSE_T: 43.3196 - val_loss: 0.0132 - val_mean_absolute_error: 0.0813 - val_root_mean_squared_error: 0.1150 - val_RMSE_P: 1158.0770 - val_RMSE_T: 43.8226
# Epoch 95/5000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0139 - mean_absolute_error: 0.0840 - root_mean_squared_error: 0.1177 - RMSE_P: 1204.4205 - RMSE_T: 43.1383 - val_loss: 0.0132 - val_mean_absolute_error: 0.0807 - val_root_mean_squared_error: 0.1149 - val_RMSE_P: 1159.7845 - val_RMSE_T: 43.5178
# Epoch 96/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0139 - mean_absolute_error: 0.0839 - root_mean_squared_error: 0.1180 - RMSE_P: 1187.8560 - RMSE_T: 43.4486 - val_loss: 0.0132 - val_mean_absolute_error: 0.0811 - val_root_mean_squared_error: 0.1150 - val_RMSE_P: 1159.5472 - val_RMSE_T: 43.6398
# Epoch 97/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0137 - mean_absolute_error: 0.0830 - root_mean_squared_error: 0.1171 - RMSE_P: 1194.5850 - RMSE_T: 42.3840 - val_loss: 0.0131 - val_mean_absolute_error: 0.0807 - val_root_mean_squared_error: 0.1147 - val_RMSE_P: 1157.5360 - val_RMSE_T: 43.4100
# Epoch 98/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0136 - mean_absolute_error: 0.0830 - root_mean_squared_error: 0.1166 - RMSE_P: 1184.6204 - RMSE_T: 43.0177 - val_loss: 0.0132 - val_mean_absolute_error: 0.0809 - val_root_mean_squared_error: 0.1150 - val_RMSE_P: 1157.4941 - val_RMSE_T: 43.8277
# Epoch 99/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0136 - mean_absolute_error: 0.0827 - root_mean_squared_error: 0.1164 - RMSE_P: 1177.3336 - RMSE_T: 42.8652 - val_loss: 0.0132 - val_mean_absolute_error: 0.0810 - val_root_mean_squared_error: 0.1148 - val_RMSE_P: 1156.7439 - val_RMSE_T: 43.6955
# Epoch 100/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0136 - mean_absolute_error: 0.0831 - root_mean_squared_error: 0.1166 - RMSE_P: 1179.6621 - RMSE_T: 43.4849 - val_loss: 0.0133 - val_mean_absolute_error: 0.0814 - val_root_mean_squared_error: 0.1152 - val_RMSE_P: 1162.6611 - val_RMSE_T: 43.6529
# Epoch 101/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0136 - mean_absolute_error: 0.0831 - root_mean_squared_error: 0.1167 - RMSE_P: 1178.0652 - RMSE_T: 42.4993 - val_loss: 0.0133 - val_mean_absolute_error: 0.0812 - val_root_mean_squared_error: 0.1152 - val_RMSE_P: 1157.4370 - val_RMSE_T: 44.0676
# Epoch 102/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0136 - mean_absolute_error: 0.0821 - root_mean_squared_error: 0.1168 - RMSE_P: 1188.0352 - RMSE_T: 42.5472 - val_loss: 0.0131 - val_mean_absolute_error: 0.0806 - val_root_mean_squared_error: 0.1144 - val_RMSE_P: 1153.3455 - val_RMSE_T: 43.4014
# Epoch 103/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0135 - mean_absolute_error: 0.0822 - root_mean_squared_error: 0.1164 - RMSE_P: 1187.2321 - RMSE_T: 42.6352 - val_loss: 0.0130 - val_mean_absolute_error: 0.0806 - val_root_mean_squared_error: 0.1141 - val_RMSE_P: 1147.3093 - val_RMSE_T: 43.5471
# Epoch 104/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0134 - mean_absolute_error: 0.0826 - root_mean_squared_error: 0.1158 - RMSE_P: 1179.1467 - RMSE_T: 42.6595 - val_loss: 0.0133 - val_mean_absolute_error: 0.0815 - val_root_mean_squared_error: 0.1154 - val_RMSE_P: 1150.2905 - val_RMSE_T: 44.9128
# Epoch 105/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0133 - mean_absolute_error: 0.0818 - root_mean_squared_error: 0.1154 - RMSE_P: 1176.3705 - RMSE_T: 42.1937 - val_loss: 0.0131 - val_mean_absolute_error: 0.0810 - val_root_mean_squared_error: 0.1143 - val_RMSE_P: 1149.0576 - val_RMSE_T: 43.7568
# Epoch 106/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0134 - mean_absolute_error: 0.0821 - root_mean_squared_error: 0.1156 - RMSE_P: 1175.2712 - RMSE_T: 42.5592 - val_loss: 0.0130 - val_mean_absolute_error: 0.0810 - val_root_mean_squared_error: 0.1140 - val_RMSE_P: 1151.6890 - val_RMSE_T: 43.2594
# Epoch 107/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0132 - mean_absolute_error: 0.0821 - root_mean_squared_error: 0.1149 - RMSE_P: 1167.3379 - RMSE_T: 41.8435 - val_loss: 0.0130 - val_mean_absolute_error: 0.0805 - val_root_mean_squared_error: 0.1140 - val_RMSE_P: 1152.8766 - val_RMSE_T: 43.0906
# Epoch 108/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0129 - mean_absolute_error: 0.0807 - root_mean_squared_error: 0.1134 - RMSE_P: 1146.3666 - RMSE_T: 41.5880 - val_loss: 0.0130 - val_mean_absolute_error: 0.0805 - val_root_mean_squared_error: 0.1142 - val_RMSE_P: 1151.0186 - val_RMSE_T: 43.3652
# Epoch 109/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0134 - mean_absolute_error: 0.0817 - root_mean_squared_error: 0.1156 - RMSE_P: 1173.4004 - RMSE_T: 42.6206 - val_loss: 0.0131 - val_mean_absolute_error: 0.0809 - val_root_mean_squared_error: 0.1146 - val_RMSE_P: 1153.3971 - val_RMSE_T: 43.6537
# Epoch 110/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0130 - mean_absolute_error: 0.0813 - root_mean_squared_error: 0.1139 - RMSE_P: 1152.3702 - RMSE_T: 42.0806 - val_loss: 0.0130 - val_mean_absolute_error: 0.0803 - val_root_mean_squared_error: 0.1142 - val_RMSE_P: 1153.5283 - val_RMSE_T: 43.1965
# Epoch 111/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0132 - mean_absolute_error: 0.0821 - root_mean_squared_error: 0.1151 - RMSE_P: 1176.2379 - RMSE_T: 41.7762 - val_loss: 0.0133 - val_mean_absolute_error: 0.0812 - val_root_mean_squared_error: 0.1152 - val_RMSE_P: 1155.8588 - val_RMSE_T: 44.1874
# Epoch 112/5000
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0135 - mean_absolute_error: 0.0822 - root_mean_squared_error: 0.1163 - RMSE_P: 1195.2845 - RMSE_T: 41.8236 - val_loss: 0.0132 - val_mean_absolute_error: 0.0811 - val_root_mean_squared_error: 0.1150 - val_RMSE_P: 1157.4359 - val_RMSE_T: 43.8437
# Epoch 113/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0131 - mean_absolute_error: 0.0818 - root_mean_squared_error: 0.1146 - RMSE_P: 1170.6372 - RMSE_T: 40.9531 - val_loss: 0.0132 - val_mean_absolute_error: 0.0810 - val_root_mean_squared_error: 0.1147 - val_RMSE_P: 1158.7560 - val_RMSE_T: 43.4103
# Epoch 114/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0132 - mean_absolute_error: 0.0816 - root_mean_squared_error: 0.1149 - RMSE_P: 1169.9738 - RMSE_T: 42.0617 - val_loss: 0.0132 - val_mean_absolute_error: 0.0811 - val_root_mean_squared_error: 0.1148 - val_RMSE_P: 1158.1134 - val_RMSE_T: 43.5458
# Epoch 115/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0131 - mean_absolute_error: 0.0811 - root_mean_squared_error: 0.1143 - RMSE_P: 1151.6554 - RMSE_T: 41.8844 - val_loss: 0.0132 - val_mean_absolute_error: 0.0810 - val_root_mean_squared_error: 0.1148 - val_RMSE_P: 1154.3132 - val_RMSE_T: 43.9223
# Epoch 116/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0130 - mean_absolute_error: 0.0799 - root_mean_squared_error: 0.1138 - RMSE_P: 1158.6505 - RMSE_T: 40.8744 - val_loss: 0.0132 - val_mean_absolute_error: 0.0812 - val_root_mean_squared_error: 0.1149 - val_RMSE_P: 1156.6642 - val_RMSE_T: 43.8243
# Epoch 117/5000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0132 - mean_absolute_error: 0.0816 - root_mean_squared_error: 0.1150 - RMSE_P: 1165.9991 - RMSE_T: 41.7547 - val_loss: 0.0132 - val_mean_absolute_error: 0.0809 - val_root_mean_squared_error: 0.1148 - val_RMSE_P: 1155.0398 - val_RMSE_T: 43.8441
# Epoch 118/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0130 - mean_absolute_error: 0.0805 - root_mean_squared_error: 0.1141 - RMSE_P: 1161.3652 - RMSE_T: 41.9688 - val_loss: 0.0131 - val_mean_absolute_error: 0.0807 - val_root_mean_squared_error: 0.1144 - val_RMSE_P: 1155.9242 - val_RMSE_T: 43.1953
# Epoch 119/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0131 - mean_absolute_error: 0.0811 - root_mean_squared_error: 0.1143 - RMSE_P: 1158.2878 - RMSE_T: 40.8568 - val_loss: 0.0131 - val_mean_absolute_error: 0.0806 - val_root_mean_squared_error: 0.1144 - val_RMSE_P: 1154.4381 - val_RMSE_T: 43.2540
# Epoch 120/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0133 - mean_absolute_error: 0.0818 - root_mean_squared_error: 0.1153 - RMSE_P: 1176.9713 - RMSE_T: 42.0462 - val_loss: 0.0131 - val_mean_absolute_error: 0.0808 - val_root_mean_squared_error: 0.1143 - val_RMSE_P: 1150.9996 - val_RMSE_T: 43.4798
# Epoch 121/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0130 - mean_absolute_error: 0.0812 - root_mean_squared_error: 0.1139 - RMSE_P: 1153.4468 - RMSE_T: 41.4436 - val_loss: 0.0131 - val_mean_absolute_error: 0.0808 - val_root_mean_squared_error: 0.1145 - val_RMSE_P: 1149.8730 - val_RMSE_T: 43.7736
# Epoch 122/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0130 - mean_absolute_error: 0.0808 - root_mean_squared_error: 0.1138 - RMSE_P: 1161.8301 - RMSE_T: 41.8197 - val_loss: 0.0131 - val_mean_absolute_error: 0.0810 - val_root_mean_squared_error: 0.1144 - val_RMSE_P: 1147.6187 - val_RMSE_T: 43.8391
# Epoch 123/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0133 - mean_absolute_error: 0.0818 - root_mean_squared_error: 0.1152 - RMSE_P: 1177.1117 - RMSE_T: 41.9269 - val_loss: 0.0131 - val_mean_absolute_error: 0.0809 - val_root_mean_squared_error: 0.1145 - val_RMSE_P: 1148.8666 - val_RMSE_T: 43.7750
# Epoch 124/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0133 - mean_absolute_error: 0.0821 - root_mean_squared_error: 0.1153 - RMSE_P: 1169.0688 - RMSE_T: 41.9606 - val_loss: 0.0131 - val_mean_absolute_error: 0.0803 - val_root_mean_squared_error: 0.1143 - val_RMSE_P: 1150.2200 - val_RMSE_T: 43.4250
# Epoch 125/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0131 - mean_absolute_error: 0.0814 - root_mean_squared_error: 0.1146 - RMSE_P: 1165.1366 - RMSE_T: 41.9640 - val_loss: 0.0130 - val_mean_absolute_error: 0.0801 - val_root_mean_squared_error: 0.1140 - val_RMSE_P: 1143.6851 - val_RMSE_T: 43.6833
# Epoch 126/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0131 - mean_absolute_error: 0.0811 - root_mean_squared_error: 0.1143 - RMSE_P: 1164.1431 - RMSE_T: 41.9363 - val_loss: 0.0130 - val_mean_absolute_error: 0.0800 - val_root_mean_squared_error: 0.1140 - val_RMSE_P: 1145.7418 - val_RMSE_T: 43.3400
# Epoch 127/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0132 - mean_absolute_error: 0.0824 - root_mean_squared_error: 0.1148 - RMSE_P: 1163.3364 - RMSE_T: 42.0876 - val_loss: 0.0131 - val_mean_absolute_error: 0.0809 - val_root_mean_squared_error: 0.1146 - val_RMSE_P: 1152.0990 - val_RMSE_T: 43.7053
# Epoch 128/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0131 - mean_absolute_error: 0.0817 - root_mean_squared_error: 0.1147 - RMSE_P: 1173.5090 - RMSE_T: 41.4630 - val_loss: 0.0130 - val_mean_absolute_error: 0.0801 - val_root_mean_squared_error: 0.1141 - val_RMSE_P: 1147.2576 - val_RMSE_T: 43.4405
# Epoch 129/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0130 - mean_absolute_error: 0.0812 - root_mean_squared_error: 0.1142 - RMSE_P: 1167.2982 - RMSE_T: 41.3997 - val_loss: 0.0130 - val_mean_absolute_error: 0.0801 - val_root_mean_squared_error: 0.1138 - val_RMSE_P: 1144.1915 - val_RMSE_T: 43.4548
# Epoch 130/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0128 - mean_absolute_error: 0.0806 - root_mean_squared_error: 0.1133 - RMSE_P: 1156.5071 - RMSE_T: 41.1180 - val_loss: 0.0132 - val_mean_absolute_error: 0.0811 - val_root_mean_squared_error: 0.1150 - val_RMSE_P: 1147.0909 - val_RMSE_T: 44.6087
# Epoch 131/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0133 - mean_absolute_error: 0.0818 - root_mean_squared_error: 0.1151 - RMSE_P: 1173.5546 - RMSE_T: 41.6887 - val_loss: 0.0129 - val_mean_absolute_error: 0.0799 - val_root_mean_squared_error: 0.1137 - val_RMSE_P: 1143.6013 - val_RMSE_T: 43.4096
# Epoch 132/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0129 - mean_absolute_error: 0.0804 - root_mean_squared_error: 0.1136 - RMSE_P: 1148.3333 - RMSE_T: 41.6950 - val_loss: 0.0130 - val_mean_absolute_error: 0.0800 - val_root_mean_squared_error: 0.1138 - val_RMSE_P: 1141.1313 - val_RMSE_T: 43.7064
# Epoch 133/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0131 - mean_absolute_error: 0.0815 - root_mean_squared_error: 0.1145 - RMSE_P: 1161.2587 - RMSE_T: 41.5872 - val_loss: 0.0129 - val_mean_absolute_error: 0.0804 - val_root_mean_squared_error: 0.1138 - val_RMSE_P: 1143.7854 - val_RMSE_T: 43.4344
# Epoch 134/5000
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0129 - mean_absolute_error: 0.0808 - root_mean_squared_error: 0.1137 - RMSE_P: 1156.7520 - RMSE_T: 41.8889 - val_loss: 0.0131 - val_mean_absolute_error: 0.0808 - val_root_mean_squared_error: 0.1145 - val_RMSE_P: 1146.0930 - val_RMSE_T: 44.1211
# Epoch 135/5000
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0127 - mean_absolute_error: 0.0801 - root_mean_squared_error: 0.1129 - RMSE_P: 1151.8098 - RMSE_T: 41.4077 - val_loss: 0.0130 - val_mean_absolute_error: 0.0805 - val_root_mean_squared_error: 0.1140 - val_RMSE_P: 1147.5123 - val_RMSE_T: 43.3612
# Epoch 136/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0131 - mean_absolute_error: 0.0809 - root_mean_squared_error: 0.1144 - RMSE_P: 1161.2798 - RMSE_T: 41.5942 - val_loss: 0.0131 - val_mean_absolute_error: 0.0807 - val_root_mean_squared_error: 0.1146 - val_RMSE_P: 1145.6108 - val_RMSE_T: 44.2799
# Epoch 137/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0130 - mean_absolute_error: 0.0810 - root_mean_squared_error: 0.1142 - RMSE_P: 1165.6837 - RMSE_T: 41.7017 - val_loss: 0.0130 - val_mean_absolute_error: 0.0807 - val_root_mean_squared_error: 0.1142 - val_RMSE_P: 1143.7531 - val_RMSE_T: 43.8944
# Epoch 138/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0133 - mean_absolute_error: 0.0812 - root_mean_squared_error: 0.1152 - RMSE_P: 1178.3420 - RMSE_T: 41.5768 - val_loss: 0.0132 - val_mean_absolute_error: 0.0809 - val_root_mean_squared_error: 0.1147 - val_RMSE_P: 1153.8644 - val_RMSE_T: 43.6894
# Epoch 139/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0128 - mean_absolute_error: 0.0802 - root_mean_squared_error: 0.1133 - RMSE_P: 1148.8859 - RMSE_T: 41.2171 - val_loss: 0.0131 - val_mean_absolute_error: 0.0809 - val_root_mean_squared_error: 0.1146 - val_RMSE_P: 1149.4670 - val_RMSE_T: 43.9548
# Epoch 140/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0129 - mean_absolute_error: 0.0803 - root_mean_squared_error: 0.1134 - RMSE_P: 1156.3229 - RMSE_T: 41.5767 - val_loss: 0.0132 - val_mean_absolute_error: 0.0815 - val_root_mean_squared_error: 0.1151 - val_RMSE_P: 1149.6537 - val_RMSE_T: 44.5575
# Epoch 141/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0131 - mean_absolute_error: 0.0811 - root_mean_squared_error: 0.1146 - RMSE_P: 1169.6406 - RMSE_T: 41.8126 - val_loss: 0.0130 - val_mean_absolute_error: 0.0804 - val_root_mean_squared_error: 0.1140 - val_RMSE_P: 1148.4291 - val_RMSE_T: 43.3617
# Epoch 142/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0130 - mean_absolute_error: 0.0814 - root_mean_squared_error: 0.1139 - RMSE_P: 1144.6268 - RMSE_T: 41.9207 - val_loss: 0.0130 - val_mean_absolute_error: 0.0805 - val_root_mean_squared_error: 0.1142 - val_RMSE_P: 1147.0284 - val_RMSE_T: 43.6940
# Epoch 143/5000
# ...
# Epoch 124/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0132 - mean_absolute_error: 0.0817 - root_mean_squared_error: 0.1148 - RMSE_P: 1166.9314 - RMSE_T: 42.1642 - val_loss: 0.0130 - val_mean_absolute_error: 0.0799 - val_root_mean_squared_error: 0.1142 - val_RMSE_P: 1151.5427 - val_RMSE_T: 42.0400
# Epoch 125/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0132 - mean_absolute_error: 0.0810 - root_mean_squared_error: 0.1149 - RMSE_P: 1164.6169 - RMSE_T: 42.1956 - val_loss: 0.0131 - val_mean_absolute_error: 0.0803 - val_root_mean_squared_error: 0.1145 - val_RMSE_P: 1154.6133 - val_RMSE_T: 42.2686
# Epoch 126/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0130 - mean_absolute_error: 0.0815 - root_mean_squared_error: 0.1139 - RMSE_P: 1148.9799 - RMSE_T: 43.0908 - val_loss: 0.0132 - val_mean_absolute_error: 0.0806 - val_root_mean_squared_error: 0.1148 - val_RMSE_P: 1154.6002 - val_RMSE_T: 42.6333
# Epoch 127/5000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0129 - mean_absolute_error: 0.0811 - root_mean_squared_error: 0.1135 - RMSE_P: 1150.9902 - RMSE_T: 42.9146 - val_loss: 0.0131 - val_mean_absolute_error: 0.0802 - val_root_mean_squared_error: 0.1144 - val_RMSE_P: 1147.5653 - val_RMSE_T: 42.4921
# Epoch 128/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0133 - mean_absolute_error: 0.0820 - root_mean_squared_error: 0.1155 - RMSE_P: 1177.1665 - RMSE_T: 42.3515 - val_loss: 0.0131 - val_mean_absolute_error: 0.0802 - val_root_mean_squared_error: 0.1147 - val_RMSE_P: 1147.8828 - val_RMSE_T: 42.9392
# Epoch 129/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0132 - mean_absolute_error: 0.0814 - root_mean_squared_error: 0.1150 - RMSE_P: 1164.3323 - RMSE_T: 42.0874 - val_loss: 0.0131 - val_mean_absolute_error: 0.0803 - val_root_mean_squared_error: 0.1146 - val_RMSE_P: 1154.9330 - val_RMSE_T: 42.3152
# Epoch 130/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0135 - mean_absolute_error: 0.0832 - root_mean_squared_error: 0.1162 - RMSE_P: 1189.6960 - RMSE_T: 42.5901 - val_loss: 0.0133 - val_mean_absolute_error: 0.0807 - val_root_mean_squared_error: 0.1152 - val_RMSE_P: 1149.9576 - val_RMSE_T: 43.3469
# Epoch 131/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0133 - mean_absolute_error: 0.0815 - root_mean_squared_error: 0.1155 - RMSE_P: 1187.6422 - RMSE_T: 42.1228 - val_loss: 0.0133 - val_mean_absolute_error: 0.0813 - val_root_mean_squared_error: 0.1154 - val_RMSE_P: 1160.4011 - val_RMSE_T: 42.8544
# Epoch 132/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0132 - mean_absolute_error: 0.0822 - root_mean_squared_error: 0.1149 - RMSE_P: 1166.6495 - RMSE_T: 42.9324 - val_loss: 0.0134 - val_mean_absolute_error: 0.0815 - val_root_mean_squared_error: 0.1159 - val_RMSE_P: 1159.5846 - val_RMSE_T: 43.5958
# Epoch 133/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0130 - mean_absolute_error: 0.0805 - root_mean_squared_error: 0.1139 - RMSE_P: 1155.2698 - RMSE_T: 41.3652 - val_loss: 0.0133 - val_mean_absolute_error: 0.0810 - val_root_mean_squared_error: 0.1153 - val_RMSE_P: 1161.9561 - val_RMSE_T: 42.7343
# Epoch 134/5000
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0130 - mean_absolute_error: 0.0811 - root_mean_squared_error: 0.1140 - RMSE_P: 1158.6600 - RMSE_T: 42.0016 - val_loss: 0.0133 - val_mean_absolute_error: 0.0809 - val_root_mean_squared_error: 0.1153 - val_RMSE_P: 1163.8784 - val_RMSE_T: 42.5570
# Epoch 135/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0128 - mean_absolute_error: 0.0806 - root_mean_squared_error: 0.1133 - RMSE_P: 1132.6243 - RMSE_T: 42.5970 - val_loss: 0.0131 - val_mean_absolute_error: 0.0804 - val_root_mean_squared_error: 0.1146 - val_RMSE_P: 1148.1354 - val_RMSE_T: 42.9442
# Epoch 136/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0131 - mean_absolute_error: 0.0814 - root_mean_squared_error: 0.1143 - RMSE_P: 1144.5923 - RMSE_T: 42.4289 - val_loss: 0.0134 - val_mean_absolute_error: 0.0815 - val_root_mean_squared_error: 0.1158 - val_RMSE_P: 1150.1685 - val_RMSE_T: 44.1179
# Epoch 137/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0131 - mean_absolute_error: 0.0815 - root_mean_squared_error: 0.1146 - RMSE_P: 1168.3744 - RMSE_T: 42.1900 - val_loss: 0.0133 - val_mean_absolute_error: 0.0803 - val_root_mean_squared_error: 0.1153 - val_RMSE_P: 1155.1187 - val_RMSE_T: 43.1008
# Epoch 138/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0130 - mean_absolute_error: 0.0807 - root_mean_squared_error: 0.1141 - RMSE_P: 1143.4784 - RMSE_T: 42.4480 - val_loss: 0.0133 - val_mean_absolute_error: 0.0802 - val_root_mean_squared_error: 0.1154 - val_RMSE_P: 1158.5952 - val_RMSE_T: 42.9334
# Epoch 139/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0129 - mean_absolute_error: 0.0813 - root_mean_squared_error: 0.1137 - RMSE_P: 1153.1643 - RMSE_T: 41.8149 - val_loss: 0.0131 - val_mean_absolute_error: 0.0801 - val_root_mean_squared_error: 0.1144 - val_RMSE_P: 1153.9347 - val_RMSE_T: 42.2027
# Epoch 140/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0129 - mean_absolute_error: 0.0807 - root_mean_squared_error: 0.1134 - RMSE_P: 1144.5477 - RMSE_T: 42.3541 - val_loss: 0.0131 - val_mean_absolute_error: 0.0804 - val_root_mean_squared_error: 0.1146 - val_RMSE_P: 1146.2068 - val_RMSE_T: 43.1147
# Epoch 141/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0130 - mean_absolute_error: 0.0804 - root_mean_squared_error: 0.1140 - RMSE_P: 1152.0254 - RMSE_T: 42.2327 - val_loss: 0.0132 - val_mean_absolute_error: 0.0805 - val_root_mean_squared_error: 0.1147 - val_RMSE_P: 1156.9001 - val_RMSE_T: 42.2595
# Epoch 142/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0126 - mean_absolute_error: 0.0798 - root_mean_squared_error: 0.1124 - RMSE_P: 1138.1625 - RMSE_T: 41.3297 - val_loss: 0.0133 - val_mean_absolute_error: 0.0806 - val_root_mean_squared_error: 0.1154 - val_RMSE_P: 1153.8063 - val_RMSE_T: 43.2996
# Epoch 143/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0130 - mean_absolute_error: 0.0813 - root_mean_squared_error: 0.1140 - RMSE_P: 1148.2117 - RMSE_T: 42.4822 - val_loss: 0.0132 - val_mean_absolute_error: 0.0797 - val_root_mean_squared_error: 0.1149 - val_RMSE_P: 1152.5625 - val_RMSE_T: 42.7153
# Epoch 144/5000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0128 - mean_absolute_error: 0.0809 - root_mean_squared_error: 0.1131 - RMSE_P: 1149.3441 - RMSE_T: 41.9871 - val_loss: 0.0132 - val_mean_absolute_error: 0.0802 - val_root_mean_squared_error: 0.1150 - val_RMSE_P: 1152.8011 - val_RMSE_T: 42.8097
# Epoch 145/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0129 - mean_absolute_error: 0.0799 - root_mean_squared_error: 0.1134 - RMSE_P: 1148.4635 - RMSE_T: 41.7945 - val_loss: 0.0131 - val_mean_absolute_error: 0.0801 - val_root_mean_squared_error: 0.1146 - val_RMSE_P: 1153.2905 - val_RMSE_T: 42.2763
# Epoch 146/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0129 - mean_absolute_error: 0.0805 - root_mean_squared_error: 0.1134 - RMSE_P: 1143.1324 - RMSE_T: 41.6010 - val_loss: 0.0131 - val_mean_absolute_error: 0.0797 - val_root_mean_squared_error: 0.1143 - val_RMSE_P: 1147.2776 - val_RMSE_T: 42.5247
# Epoch 147/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0129 - mean_absolute_error: 0.0807 - root_mean_squared_error: 0.1136 - RMSE_P: 1150.9996 - RMSE_T: 41.7972 - val_loss: 0.0132 - val_mean_absolute_error: 0.0802 - val_root_mean_squared_error: 0.1148 - val_RMSE_P: 1152.7474 - val_RMSE_T: 42.6556
# Epoch 148/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0128 - mean_absolute_error: 0.0797 - root_mean_squared_error: 0.1129 - RMSE_P: 1135.4424 - RMSE_T: 41.7347 - val_loss: 0.0131 - val_mean_absolute_error: 0.0799 - val_root_mean_squared_error: 0.1145 - val_RMSE_P: 1148.2914 - val_RMSE_T: 42.5201
# Epoch 149/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0129 - mean_absolute_error: 0.0809 - root_mean_squared_error: 0.1138 - RMSE_P: 1148.9099 - RMSE_T: 42.2673 - val_loss: 0.0132 - val_mean_absolute_error: 0.0809 - val_root_mean_squared_error: 0.1151 - val_RMSE_P: 1152.0804 - val_RMSE_T: 43.0732
# Epoch 150/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0124 - mean_absolute_error: 0.0795 - root_mean_squared_error: 0.1113 - RMSE_P: 1132.2933 - RMSE_T: 40.7152 - val_loss: 0.0131 - val_mean_absolute_error: 0.0797 - val_root_mean_squared_error: 0.1143 - val_RMSE_P: 1144.1025 - val_RMSE_T: 42.7036
# Epoch 151/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0129 - mean_absolute_error: 0.0805 - root_mean_squared_error: 0.1136 - RMSE_P: 1163.1995 - RMSE_T: 41.3800 - val_loss: 0.0132 - val_mean_absolute_error: 0.0804 - val_root_mean_squared_error: 0.1148 - val_RMSE_P: 1150.3245 - val_RMSE_T: 42.7933
# Epoch 152/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0125 - mean_absolute_error: 0.0803 - root_mean_squared_error: 0.1118 - RMSE_P: 1120.2147 - RMSE_T: 41.9495 - val_loss: 0.0131 - val_mean_absolute_error: 0.0798 - val_root_mean_squared_error: 0.1145 - val_RMSE_P: 1152.8427 - val_RMSE_T: 42.4972
# Epoch 153/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0129 - mean_absolute_error: 0.0803 - root_mean_squared_error: 0.1137 - RMSE_P: 1144.3842 - RMSE_T: 42.3807 - val_loss: 0.0133 - val_mean_absolute_error: 0.0804 - val_root_mean_squared_error: 0.1152 - val_RMSE_P: 1149.0765 - val_RMSE_T: 43.6188
# Epoch 154/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0128 - mean_absolute_error: 0.0800 - root_mean_squared_error: 0.1132 - RMSE_P: 1152.3607 - RMSE_T: 41.7627 - val_loss: 0.0130 - val_mean_absolute_error: 0.0793 - val_root_mean_squared_error: 0.1140 - val_RMSE_P: 1151.1471 - val_RMSE_T: 41.9654
# Epoch 155/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0126 - mean_absolute_error: 0.0802 - root_mean_squared_error: 0.1122 - RMSE_P: 1126.8685 - RMSE_T: 42.3207 - val_loss: 0.0130 - val_mean_absolute_error: 0.0793 - val_root_mean_squared_error: 0.1142 - val_RMSE_P: 1147.1531 - val_RMSE_T: 42.2972
# Epoch 156/5000
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0127 - mean_absolute_error: 0.0800 - root_mean_squared_error: 0.1129 - RMSE_P: 1134.5367 - RMSE_T: 41.7729 - val_loss: 0.0130 - val_mean_absolute_error: 0.0800 - val_root_mean_squared_error: 0.1141 - val_RMSE_P: 1151.1183 - val_RMSE_T: 42.1669
# Epoch 157/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0127 - mean_absolute_error: 0.0802 - root_mean_squared_error: 0.1129 - RMSE_P: 1142.9425 - RMSE_T: 41.6886 - val_loss: 0.0131 - val_mean_absolute_error: 0.0802 - val_root_mean_squared_error: 0.1146 - val_RMSE_P: 1151.5630 - val_RMSE_T: 42.8681
# Epoch 158/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0124 - mean_absolute_error: 0.0793 - root_mean_squared_error: 0.1112 - RMSE_P: 1124.3307 - RMSE_T: 41.4471 - val_loss: 0.0133 - val_mean_absolute_error: 0.0806 - val_root_mean_squared_error: 0.1152 - val_RMSE_P: 1152.3330 - val_RMSE_T: 43.3573
# Epoch 159/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0124 - mean_absolute_error: 0.0793 - root_mean_squared_error: 0.1112 - RMSE_P: 1121.6287 - RMSE_T: 41.6883 - val_loss: 0.0132 - val_mean_absolute_error: 0.0803 - val_root_mean_squared_error: 0.1151 - val_RMSE_P: 1153.1436 - val_RMSE_T: 43.1041
# Epoch 160/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0128 - mean_absolute_error: 0.0805 - root_mean_squared_error: 0.1131 - RMSE_P: 1133.7667 - RMSE_T: 42.0010 - val_loss: 0.0133 - val_mean_absolute_error: 0.0807 - val_root_mean_squared_error: 0.1154 - val_RMSE_P: 1156.6792 - val_RMSE_T: 43.2354
# Epoch 161/5000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0126 - mean_absolute_error: 0.0797 - root_mean_squared_error: 0.1123 - RMSE_P: 1137.4512 - RMSE_T: 41.3311 - val_loss: 0.0131 - val_mean_absolute_error: 0.0799 - val_root_mean_squared_error: 0.1146 - val_RMSE_P: 1151.5962 - val_RMSE_T: 42.6425
# Epoch 162/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0126 - mean_absolute_error: 0.0794 - root_mean_squared_error: 0.1123 - RMSE_P: 1143.9452 - RMSE_T: 41.0510 - val_loss: 0.0132 - val_mean_absolute_error: 0.0801 - val_root_mean_squared_error: 0.1149 - val_RMSE_P: 1142.4686 - val_RMSE_T: 43.5102
# Epoch 163/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0127 - mean_absolute_error: 0.0803 - root_mean_squared_error: 0.1127 - RMSE_P: 1135.4686 - RMSE_T: 41.2856 - val_loss: 0.0131 - val_mean_absolute_error: 0.0798 - val_root_mean_squared_error: 0.1144 - val_RMSE_P: 1139.7173 - val_RMSE_T: 43.3271
# Epoch 164/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0127 - mean_absolute_error: 0.0794 - root_mean_squared_error: 0.1125 - RMSE_P: 1140.4595 - RMSE_T: 41.2061 - val_loss: 0.0131 - val_mean_absolute_error: 0.0803 - val_root_mean_squared_error: 0.1144 - val_RMSE_P: 1150.2291 - val_RMSE_T: 42.6044
# Epoch 165/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0127 - mean_absolute_error: 0.0803 - root_mean_squared_error: 0.1126 - RMSE_P: 1141.4515 - RMSE_T: 40.8773 - val_loss: 0.0132 - val_mean_absolute_error: 0.0804 - val_root_mean_squared_error: 0.1150 - val_RMSE_P: 1157.7889 - val_RMSE_T: 42.6002
# Epoch 166/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0123 - mean_absolute_error: 0.0792 - root_mean_squared_error: 0.1111 - RMSE_P: 1130.4250 - RMSE_T: 40.9010 - val_loss: 0.0133 - val_mean_absolute_error: 0.0811 - val_root_mean_squared_error: 0.1155 - val_RMSE_P: 1170.7975 - val_RMSE_T: 42.2999
# Epoch 167/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0125 - mean_absolute_error: 0.0801 - root_mean_squared_error: 0.1117 - RMSE_P: 1128.3092 - RMSE_T: 41.0316 - val_loss: 0.0132 - val_mean_absolute_error: 0.0803 - val_root_mean_squared_error: 0.1151 - val_RMSE_P: 1147.1244 - val_RMSE_T: 43.5285
# Epoch 168/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0124 - mean_absolute_error: 0.0790 - root_mean_squared_error: 0.1114 - RMSE_P: 1135.2562 - RMSE_T: 40.8820 - val_loss: 0.0134 - val_mean_absolute_error: 0.0807 - val_root_mean_squared_error: 0.1157 - val_RMSE_P: 1157.7555 - val_RMSE_T: 43.5585
# Epoch 169/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0126 - mean_absolute_error: 0.0795 - root_mean_squared_error: 0.1122 - RMSE_P: 1129.9570 - RMSE_T: 41.3116 - val_loss: 0.0133 - val_mean_absolute_error: 0.0806 - val_root_mean_squared_error: 0.1153 - val_RMSE_P: 1154.5396 - val_RMSE_T: 43.2372
# Epoch 170/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0123 - mean_absolute_error: 0.0789 - root_mean_squared_error: 0.1109 - RMSE_P: 1114.4905 - RMSE_T: 41.7438 - val_loss: 0.0135 - val_mean_absolute_error: 0.0810 - val_root_mean_squared_error: 0.1161 - val_RMSE_P: 1160.7952 - val_RMSE_T: 43.6418
# Epoch 171/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0126 - mean_absolute_error: 0.0794 - root_mean_squared_error: 0.1120 - RMSE_P: 1124.6517 - RMSE_T: 42.0219 - val_loss: 0.0133 - val_mean_absolute_error: 0.0801 - val_root_mean_squared_error: 0.1154 - val_RMSE_P: 1161.1410 - val_RMSE_T: 42.6985
# Epoch 172/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0125 - mean_absolute_error: 0.0794 - root_mean_squared_error: 0.1118 - RMSE_P: 1129.7570 - RMSE_T: 41.0781 - val_loss: 0.0133 - val_mean_absolute_error: 0.0803 - val_root_mean_squared_error: 0.1155 - val_RMSE_P: 1159.4431 - val_RMSE_T: 42.9778
# INFO:tensorflow:Assets written to: saved_models\k_ds55BtT_4\assets
# INFO:tensorflow:Assets written to: saved_models\k_ds55BtT_4\assets

# %% [markdown]
# # Plot training curves

# %%
plot_multiple_training_curves(["k_ds55BtT_0.log", "k_ds55BtT_1.log", "k_ds55BtT_2.log", "k_ds55BtT_3.log", "k_ds55BtT_4.log"],
                              colors=sns.color_palette("Reds", 5), label="model", log_scale=True, ylims=[None, (10, 100), (100, 2500)])
# Out:
# (<Figure size 1200x400 with 3 Axes>,
#  array([<Axes: xlabel='Epoch', ylabel='Loss'>,
#         <Axes: xlabel='Epoch', ylabel='Temperature RMSE [K]'>,
#         <Axes: xlabel='Epoch', ylabel='Pressure RMSE [bar]'>], dtype=object))
