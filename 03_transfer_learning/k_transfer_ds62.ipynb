# %% [markdown]
# :warning:**IMPORTANT NOTICE**:warning:\
# *Since the initial parameterisation and gradient descent optimisation are stochastic processes, the training of a neural network is not fully reproducible.*
#
# *Therefore, it is not recommended to re-run this script as it will overwrite the original calibration of the neural network used in the work presented here.
# The purpose of this script is solely to document the training procedure and can be copied as a template to fit other new neural networks.*
#
# *To experiment with the models calibrated here, they can be loaded from the `saved_models` directory.*

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf

from pathlib import Path
from keras.models import Model, Sequential, load_model, clone_model
from keras.layers import Dense, Normalization, Input, Dropout
from keras.losses import MeanSquaredError
from keras.optimizers import Adam, schedules
from keras.metrics import MeanAbsoluteError, RootMeanSquaredError
from keras.callbacks import CSVLogger, EarlyStopping

from ml_tb.normalisation import MinMaxScaler
from ml_tb.metrics import RMSE_denormalised_P, RMSE_denormalised_T
from ml_tb.plot import plot_multiple_training_curves
# Out:
# C:\Users\ThinkPad\AppData\Local\Temp\ipykernel_24096\1129355832.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# WARNING:tensorflow:From c:\Users\ThinkPad\miniconda3\envs\masterproject\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# ## Load validation datasets

# %%
# Load the data
val_data_dir = Path("..", "01_fit_natural_biotite", "kfold_datasets")

DATA_train_0 = np.loadtxt(Path(val_data_dir, "train_data_0.csv"), delimiter=",")
DATA_val_0 = np.loadtxt(Path(val_data_dir, "test_data_0.csv"), delimiter=",")

DATA_train_1 = np.loadtxt(Path(val_data_dir, "train_data_1.csv"), delimiter=",")
DATA_val_1 = np.loadtxt(Path(val_data_dir, "test_data_1.csv"), delimiter=",")

DATA_train_2 = np.loadtxt(Path(val_data_dir, "train_data_2.csv"), delimiter=",")
DATA_val_2 = np.loadtxt(Path(val_data_dir, "test_data_2.csv"), delimiter=",")

DATA_train_3 = np.loadtxt(Path(val_data_dir, "train_data_3.csv"), delimiter=",")
DATA_val_3 = np.loadtxt(Path(val_data_dir, "test_data_3.csv"), delimiter=",")

DATA_train_4 = np.loadtxt(Path(val_data_dir, "train_data_4.csv"), delimiter=",")
DATA_val_4 = np.loadtxt(Path(val_data_dir, "test_data_4.csv"), delimiter=",")

train_data_list = [DATA_train_0, DATA_train_1, DATA_train_2, DATA_train_3, DATA_train_4]
val_data_list = [DATA_val_0, DATA_val_1, DATA_val_2, DATA_val_3, DATA_val_4]

# %% [markdown]
# ## Set-up global training parameters
#
# Define a function to calculate RMSE for pressure and temperature for unscaled values to have an interpretable metric.

# %%
scaling_pt = MinMaxScaler(min=[1500, 400], max=[10000, 900], axis=0)
inv_scaling_pt = MinMaxScaler(min=[1500, 400], max=[10000, 900], axis=0, invert=True)

def RMSE_P(y_true, y_pred):
    return RMSE_denormalised_P(y_true, y_pred, inv_scaling_pt)


def RMSE_T(y_true, y_pred):
    return RMSE_denormalised_T(y_true, y_pred, inv_scaling_pt)
# Out:
# WARNING:tensorflow:From c:\Users\ThinkPad\miniconda3\envs\masterproject\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
CALLBACKS_0 = [CSVLogger("k_ds62_0.log"), EarlyStopping(monitor="val_loss", patience=50, restore_best_weights=True)]
CALLBACKS_1 = [CSVLogger("k_ds62_1.log"), EarlyStopping(monitor="val_loss", patience=50, restore_best_weights=True)]
CALLBACKS_2 = [CSVLogger("k_ds62_2.log"), EarlyStopping(monitor="val_loss", patience=50, restore_best_weights=True)]
CALLBACKS_3 = [CSVLogger("k_ds62_3.log"), EarlyStopping(monitor="val_loss", patience=50, restore_best_weights=True)]
CALLBACKS_4 = [CSVLogger("k_ds62_4.log"), EarlyStopping(monitor="val_loss", patience=50, restore_best_weights=True)]

callsbacks_list = [CALLBACKS_0, CALLBACKS_1, CALLBACKS_2, CALLBACKS_3, CALLBACKS_4]

# %% [markdown]
# ## Load pre-trained model

# %%
# load a saved model from "02_pretraining\saved_models\model_ds62White2014"
model_prior = load_model(Path("..","02_pretraining", "saved_models/model_ds62White2014"), compile=False)
# Out:
# WARNING:tensorflow:From c:\Users\ThinkPad\miniconda3\envs\masterproject\Lib\site-packages\keras\src\saving\legacy\saved_model\load.py:107: The name tf.gfile.Exists is deprecated. Please use tf.io.gfile.exists instead.
#
# WARNING:tensorflow:From c:\Users\ThinkPad\miniconda3\envs\masterproject\Lib\site-packages\keras\src\saving\legacy\saved_model\load.py:471: The name tf.logging.warning is deprecated. Please use tf.compat.v1.logging.warning instead.
#
# WARNING:tensorflow:Unable to restore custom metric. Please ensure that the layer implements `get_config` and `from_config` when saving. In addition, please use the `custom_objects` arg when calling `load_model()`.
# WARNING:tensorflow:Unable to restore custom metric. Please ensure that the layer implements `get_config` and `from_config` when saving. In addition, please use the `custom_objects` arg when calling `load_model()`.

# %%
# train loop

def train_model(DATA_train, DATA_val, CALLBACKS, model_name):
    # split up data
    data_train = DATA_train[:, 0:6]
    data_val = DATA_val[:, 0:6]

    pt_train = DATA_train[:, -2:]
    pt_val = DATA_val[:, -2:]

    # NORMALISATION
    normalisation_biotite_composition = Normalization(axis=-1)
    normalisation_biotite_composition.adapt(data_train)

    # SCALING of PT
    pt_train_norm = scaling_pt(pt_train)
    pt_val_norm = scaling_pt(pt_val)

    # SET TRAINING PARAMETERS
    BATCH_SIZE = 50
    STEPS_PER_EPOCH = len(DATA_train_0) // BATCH_SIZE
    MAX_EPOCHS = 5000

    lr_schedule = schedules.InverseTimeDecay(0.0005, decay_steps=STEPS_PER_EPOCH*1000, decay_rate=1, staircase=False)

    LOSS = MeanSquaredError()
    METRICS = [MeanAbsoluteError(), RootMeanSquaredError(), RMSE_P, RMSE_T]
    OPT = Adam(lr_schedule)

    # build model
    model_prior_c = clone_model(model_prior, input_tensors=Input(shape=(6,)))

    model = Sequential()
    model.add(normalisation_biotite_composition)
    model.add(model_prior_c.layers[1])
    model.add(Dropout(0.2))
    model.add(model_prior_c.layers[2])
    model.add(Dropout(0.2))
    model.add(model_prior_c.layers[3])
    model.add(Dropout(0.2))
    model.add(model_prior_c.layers[4])
    model.add(model_prior_c.layers[5])
    model.compile(optimizer=OPT, loss=LOSS, metrics=METRICS)
    model.summary()

    # train model
    history = model.fit(data_train, pt_train_norm,
                        validation_data=(data_val, pt_val_norm),
                        batch_size=BATCH_SIZE,
                        epochs=MAX_EPOCHS,
                        callbacks=CALLBACKS)

    model.save(Path("saved_models", model_name))

# %%
model_name_list = ["k_ds62_0", "k_ds62_1", "k_ds62_2", "k_ds62_3", "k_ds62_4"]

for train_data, val_data, CALLBACKS, model_name in zip(train_data_list, val_data_list, callsbacks_list, model_name_list):
    train_model(train_data, val_data, CALLBACKS, model_name)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  normalization (Normalizati  (None, 6)                 13
#  on)
#
#  dense (Dense)               (None, 64)                448
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 64)                4160
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 64)                4160
#
#  dense_4 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 13071 (51.06 KB)
# Trainable params: 13058 (51.01 KB)
# Non-trainable params: 13 (56.00 Byte)
# _________________________________________________________________
# Epoch 1/5000
# WARNING:tensorflow:From c:\Users\ThinkPad\miniconda3\envs\masterproject\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\ThinkPad\miniconda3\envs\masterproject\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 35/35 [==============================] - 2s 10ms/step - loss: 0.0704 - mean_absolute_error: 0.2116 - root_mean_squared_error: 0.2654 - RMSE_P: 2280.6050 - RMSE_T: 126.6267 - val_loss: 0.0395 - val_mean_absolute_error: 0.1615 - val_root_mean_squared_error: 0.1989 - val_RMSE_P: 1772.4702 - val_RMSE_T: 92.9411
# Epoch 2/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0414 - mean_absolute_error: 0.1559 - root_mean_squared_error: 0.2034 - RMSE_P: 1827.6953 - RMSE_T: 92.3807 - val_loss: 0.0270 - val_mean_absolute_error: 0.1289 - val_root_mean_squared_error: 0.1644 - val_RMSE_P: 1478.6957 - val_RMSE_T: 75.9546
# Epoch 3/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0295 - mean_absolute_error: 0.1323 - root_mean_squared_error: 0.1718 - RMSE_P: 1562.2572 - RMSE_T: 77.5175 - val_loss: 0.0211 - val_mean_absolute_error: 0.1108 - val_root_mean_squared_error: 0.1453 - val_RMSE_P: 1360.1222 - val_RMSE_T: 63.5590
# Epoch 4/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0246 - mean_absolute_error: 0.1202 - root_mean_squared_error: 0.1568 - RMSE_P: 1462.8661 - RMSE_T: 68.7638 - val_loss: 0.0201 - val_mean_absolute_error: 0.1076 - val_root_mean_squared_error: 0.1416 - val_RMSE_P: 1320.7368 - val_RMSE_T: 62.6239
# Epoch 5/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0227 - mean_absolute_error: 0.1126 - root_mean_squared_error: 0.1505 - RMSE_P: 1447.7064 - RMSE_T: 63.3514 - val_loss: 0.0180 - val_mean_absolute_error: 0.1002 - val_root_mean_squared_error: 0.1342 - val_RMSE_P: 1265.6237 - val_RMSE_T: 58.3800
# Epoch 6/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0212 - mean_absolute_error: 0.1090 - root_mean_squared_error: 0.1456 - RMSE_P: 1383.2655 - RMSE_T: 61.3186 - val_loss: 0.0175 - val_mean_absolute_error: 0.0980 - val_root_mean_squared_error: 0.1323 - val_RMSE_P: 1261.8950 - val_RMSE_T: 56.6145
# Epoch 7/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0200 - mean_absolute_error: 0.1047 - root_mean_squared_error: 0.1412 - RMSE_P: 1345.4769 - RMSE_T: 59.0982 - val_loss: 0.0168 - val_mean_absolute_error: 0.0955 - val_root_mean_squared_error: 0.1295 - val_RMSE_P: 1250.5773 - val_RMSE_T: 54.0843
# Epoch 8/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0189 - mean_absolute_error: 0.1012 - root_mean_squared_error: 0.1374 - RMSE_P: 1349.4735 - RMSE_T: 54.8401 - val_loss: 0.0161 - val_mean_absolute_error: 0.0930 - val_root_mean_squared_error: 0.1268 - val_RMSE_P: 1240.6560 - val_RMSE_T: 51.6717
# Epoch 9/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0187 - mean_absolute_error: 0.1012 - root_mean_squared_error: 0.1368 - RMSE_P: 1345.0903 - RMSE_T: 54.0798 - val_loss: 0.0155 - val_mean_absolute_error: 0.0909 - val_root_mean_squared_error: 0.1246 - val_RMSE_P: 1238.5780 - val_RMSE_T: 49.2814
# Epoch 10/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0186 - mean_absolute_error: 0.1005 - root_mean_squared_error: 0.1364 - RMSE_P: 1330.2889 - RMSE_T: 54.9334 - val_loss: 0.0154 - val_mean_absolute_error: 0.0904 - val_root_mean_squared_error: 0.1241 - val_RMSE_P: 1238.4703 - val_RMSE_T: 48.5704
# Epoch 11/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0180 - mean_absolute_error: 0.0989 - root_mean_squared_error: 0.1343 - RMSE_P: 1319.8252 - RMSE_T: 52.8943 - val_loss: 0.0156 - val_mean_absolute_error: 0.0909 - val_root_mean_squared_error: 0.1249 - val_RMSE_P: 1227.6194 - val_RMSE_T: 50.6220
# Epoch 12/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0174 - mean_absolute_error: 0.0968 - root_mean_squared_error: 0.1317 - RMSE_P: 1285.8114 - RMSE_T: 53.2465 - val_loss: 0.0154 - val_mean_absolute_error: 0.0899 - val_root_mean_squared_error: 0.1241 - val_RMSE_P: 1231.9656 - val_RMSE_T: 49.1721
# Epoch 13/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0174 - mean_absolute_error: 0.0970 - root_mean_squared_error: 0.1319 - RMSE_P: 1304.1635 - RMSE_T: 50.5756 - val_loss: 0.0157 - val_mean_absolute_error: 0.0911 - val_root_mean_squared_error: 0.1255 - val_RMSE_P: 1233.3409 - val_RMSE_T: 50.8512
# Epoch 14/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0171 - mean_absolute_error: 0.0955 - root_mean_squared_error: 0.1309 - RMSE_P: 1291.9183 - RMSE_T: 51.9480 - val_loss: 0.0152 - val_mean_absolute_error: 0.0895 - val_root_mean_squared_error: 0.1234 - val_RMSE_P: 1231.0138 - val_RMSE_T: 48.5880
# Epoch 15/5000
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0172 - mean_absolute_error: 0.0961 - root_mean_squared_error: 0.1311 - RMSE_P: 1301.8418 - RMSE_T: 50.9377 - val_loss: 0.0150 - val_mean_absolute_error: 0.0886 - val_root_mean_squared_error: 0.1223 - val_RMSE_P: 1229.8156 - val_RMSE_T: 47.2259
# Epoch 16/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0168 - mean_absolute_error: 0.0952 - root_mean_squared_error: 0.1297 - RMSE_P: 1290.0013 - RMSE_T: 50.7386 - val_loss: 0.0151 - val_mean_absolute_error: 0.0889 - val_root_mean_squared_error: 0.1229 - val_RMSE_P: 1223.1979 - val_RMSE_T: 48.5925
# Epoch 17/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0170 - mean_absolute_error: 0.0942 - root_mean_squared_error: 0.1305 - RMSE_P: 1299.6808 - RMSE_T: 50.5832 - val_loss: 0.0149 - val_mean_absolute_error: 0.0884 - val_root_mean_squared_error: 0.1221 - val_RMSE_P: 1230.5298 - val_RMSE_T: 46.8599
# Epoch 18/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0166 - mean_absolute_error: 0.0945 - root_mean_squared_error: 0.1288 - RMSE_P: 1278.8951 - RMSE_T: 49.8308 - val_loss: 0.0149 - val_mean_absolute_error: 0.0882 - val_root_mean_squared_error: 0.1220 - val_RMSE_P: 1232.4155 - val_RMSE_T: 46.5613
# Epoch 19/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0167 - mean_absolute_error: 0.0942 - root_mean_squared_error: 0.1292 - RMSE_P: 1292.6766 - RMSE_T: 49.0254 - val_loss: 0.0148 - val_mean_absolute_error: 0.0878 - val_root_mean_squared_error: 0.1216 - val_RMSE_P: 1223.8492 - val_RMSE_T: 46.7304
# Epoch 20/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0168 - mean_absolute_error: 0.0937 - root_mean_squared_error: 0.1297 - RMSE_P: 1300.3242 - RMSE_T: 49.7839 - val_loss: 0.0151 - val_mean_absolute_error: 0.0890 - val_root_mean_squared_error: 0.1229 - val_RMSE_P: 1224.0310 - val_RMSE_T: 48.4537
# Epoch 21/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0160 - mean_absolute_error: 0.0919 - root_mean_squared_error: 0.1265 - RMSE_P: 1262.8163 - RMSE_T: 48.1993 - val_loss: 0.0149 - val_mean_absolute_error: 0.0881 - val_root_mean_squared_error: 0.1222 - val_RMSE_P: 1215.6704 - val_RMSE_T: 48.2976
# Epoch 22/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0161 - mean_absolute_error: 0.0918 - root_mean_squared_error: 0.1270 - RMSE_P: 1271.8176 - RMSE_T: 48.5165 - val_loss: 0.0148 - val_mean_absolute_error: 0.0877 - val_root_mean_squared_error: 0.1215 - val_RMSE_P: 1216.6431 - val_RMSE_T: 47.2459
# Epoch 23/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0160 - mean_absolute_error: 0.0917 - root_mean_squared_error: 0.1266 - RMSE_P: 1268.3416 - RMSE_T: 48.7008 - val_loss: 0.0150 - val_mean_absolute_error: 0.0886 - val_root_mean_squared_error: 0.1226 - val_RMSE_P: 1216.2750 - val_RMSE_T: 48.5594
# Epoch 24/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0158 - mean_absolute_error: 0.0910 - root_mean_squared_error: 0.1255 - RMSE_P: 1264.1661 - RMSE_T: 47.2540 - val_loss: 0.0146 - val_mean_absolute_error: 0.0873 - val_root_mean_squared_error: 0.1209 - val_RMSE_P: 1217.5405 - val_RMSE_T: 46.3450
# Epoch 25/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0159 - mean_absolute_error: 0.0919 - root_mean_squared_error: 0.1261 - RMSE_P: 1271.6843 - RMSE_T: 47.6362 - val_loss: 0.0148 - val_mean_absolute_error: 0.0880 - val_root_mean_squared_error: 0.1216 - val_RMSE_P: 1216.2133 - val_RMSE_T: 47.4517
# Epoch 26/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0163 - mean_absolute_error: 0.0921 - root_mean_squared_error: 0.1278 - RMSE_P: 1282.6659 - RMSE_T: 48.0897 - val_loss: 0.0145 - val_mean_absolute_error: 0.0871 - val_root_mean_squared_error: 0.1205 - val_RMSE_P: 1208.0587 - val_RMSE_T: 46.7652
# Epoch 27/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0158 - mean_absolute_error: 0.0910 - root_mean_squared_error: 0.1257 - RMSE_P: 1266.4902 - RMSE_T: 47.3082 - val_loss: 0.0146 - val_mean_absolute_error: 0.0873 - val_root_mean_squared_error: 0.1206 - val_RMSE_P: 1216.2512 - val_RMSE_T: 46.1921
# Epoch 28/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0159 - mean_absolute_error: 0.0921 - root_mean_squared_error: 0.1261 - RMSE_P: 1258.7338 - RMSE_T: 48.4039 - val_loss: 0.0145 - val_mean_absolute_error: 0.0866 - val_root_mean_squared_error: 0.1202 - val_RMSE_P: 1205.4966 - val_RMSE_T: 46.5875
# Epoch 29/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0161 - mean_absolute_error: 0.0917 - root_mean_squared_error: 0.1268 - RMSE_P: 1268.4561 - RMSE_T: 47.8716 - val_loss: 0.0149 - val_mean_absolute_error: 0.0884 - val_root_mean_squared_error: 0.1219 - val_RMSE_P: 1211.5736 - val_RMSE_T: 48.2475
# Epoch 30/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0157 - mean_absolute_error: 0.0907 - root_mean_squared_error: 0.1255 - RMSE_P: 1266.4940 - RMSE_T: 47.3976 - val_loss: 0.0145 - val_mean_absolute_error: 0.0869 - val_root_mean_squared_error: 0.1205 - val_RMSE_P: 1209.5341 - val_RMSE_T: 46.6647
# Epoch 31/5000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0158 - mean_absolute_error: 0.0910 - root_mean_squared_error: 0.1257 - RMSE_P: 1268.9567 - RMSE_T: 47.1524 - val_loss: 0.0144 - val_mean_absolute_error: 0.0863 - val_root_mean_squared_error: 0.1201 - val_RMSE_P: 1206.8566 - val_RMSE_T: 46.3006
# Epoch 32/5000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0159 - mean_absolute_error: 0.0910 - root_mean_squared_error: 0.1261 - RMSE_P: 1263.0804 - RMSE_T: 47.8149 - val_loss: 0.0145 - val_mean_absolute_error: 0.0868 - val_root_mean_squared_error: 0.1205 - val_RMSE_P: 1208.2914 - val_RMSE_T: 46.7087
# Epoch 33/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0154 - mean_absolute_error: 0.0896 - root_mean_squared_error: 0.1240 - RMSE_P: 1253.6686 - RMSE_T: 46.8156 - val_loss: 0.0145 - val_mean_absolute_error: 0.0865 - val_root_mean_squared_error: 0.1203 - val_RMSE_P: 1207.1724 - val_RMSE_T: 46.4524
# Epoch 34/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0158 - mean_absolute_error: 0.0907 - root_mean_squared_error: 0.1255 - RMSE_P: 1265.1025 - RMSE_T: 47.2038 - val_loss: 0.0145 - val_mean_absolute_error: 0.0868 - val_root_mean_squared_error: 0.1205 - val_RMSE_P: 1208.1979 - val_RMSE_T: 46.6467
# Epoch 35/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0154 - mean_absolute_error: 0.0890 - root_mean_squared_error: 0.1241 - RMSE_P: 1258.3236 - RMSE_T: 45.2829 - val_loss: 0.0145 - val_mean_absolute_error: 0.0866 - val_root_mean_squared_error: 0.1205 - val_RMSE_P: 1205.1753 - val_RMSE_T: 46.9864
# Epoch 36/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0154 - mean_absolute_error: 0.0893 - root_mean_squared_error: 0.1243 - RMSE_P: 1257.2875 - RMSE_T: 46.5703 - val_loss: 0.0144 - val_mean_absolute_error: 0.0863 - val_root_mean_squared_error: 0.1202 - val_RMSE_P: 1208.4729 - val_RMSE_T: 46.1927
# Epoch 37/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0154 - mean_absolute_error: 0.0893 - root_mean_squared_error: 0.1239 - RMSE_P: 1255.4360 - RMSE_T: 45.6912 - val_loss: 0.0144 - val_mean_absolute_error: 0.0859 - val_root_mean_squared_error: 0.1201 - val_RMSE_P: 1201.4868 - val_RMSE_T: 46.7906
# Epoch 38/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0152 - mean_absolute_error: 0.0885 - root_mean_squared_error: 0.1233 - RMSE_P: 1248.9630 - RMSE_T: 45.4779 - val_loss: 0.0144 - val_mean_absolute_error: 0.0861 - val_root_mean_squared_error: 0.1201 - val_RMSE_P: 1204.4629 - val_RMSE_T: 46.6120
# Epoch 39/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0149 - mean_absolute_error: 0.0878 - root_mean_squared_error: 0.1221 - RMSE_P: 1223.1559 - RMSE_T: 45.6866 - val_loss: 0.0143 - val_mean_absolute_error: 0.0859 - val_root_mean_squared_error: 0.1194 - val_RMSE_P: 1207.2345 - val_RMSE_T: 45.4743
# Epoch 40/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0151 - mean_absolute_error: 0.0886 - root_mean_squared_error: 0.1228 - RMSE_P: 1239.7557 - RMSE_T: 45.6841 - val_loss: 0.0144 - val_mean_absolute_error: 0.0866 - val_root_mean_squared_error: 0.1201 - val_RMSE_P: 1210.1891 - val_RMSE_T: 46.1275
# Epoch 41/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0151 - mean_absolute_error: 0.0883 - root_mean_squared_error: 0.1230 - RMSE_P: 1246.4199 - RMSE_T: 45.2547 - val_loss: 0.0141 - val_mean_absolute_error: 0.0851 - val_root_mean_squared_error: 0.1187 - val_RMSE_P: 1196.5144 - val_RMSE_T: 45.4977
# Epoch 42/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0152 - mean_absolute_error: 0.0885 - root_mean_squared_error: 0.1234 - RMSE_P: 1251.8250 - RMSE_T: 45.8782 - val_loss: 0.0142 - val_mean_absolute_error: 0.0857 - val_root_mean_squared_error: 0.1191 - val_RMSE_P: 1201.3198 - val_RMSE_T: 45.6175
# Epoch 43/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0152 - mean_absolute_error: 0.0886 - root_mean_squared_error: 0.1233 - RMSE_P: 1242.8224 - RMSE_T: 45.7930 - val_loss: 0.0143 - val_mean_absolute_error: 0.0860 - val_root_mean_squared_error: 0.1195 - val_RMSE_P: 1199.8354 - val_RMSE_T: 46.2039
# Epoch 44/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0151 - mean_absolute_error: 0.0878 - root_mean_squared_error: 0.1228 - RMSE_P: 1242.3551 - RMSE_T: 45.3826 - val_loss: 0.0140 - val_mean_absolute_error: 0.0848 - val_root_mean_squared_error: 0.1182 - val_RMSE_P: 1194.3232 - val_RMSE_T: 45.0603
# Epoch 45/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0151 - mean_absolute_error: 0.0883 - root_mean_squared_error: 0.1228 - RMSE_P: 1238.4574 - RMSE_T: 46.1856 - val_loss: 0.0144 - val_mean_absolute_error: 0.0862 - val_root_mean_squared_error: 0.1198 - val_RMSE_P: 1192.0901 - val_RMSE_T: 47.1954
# Epoch 46/5000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0153 - mean_absolute_error: 0.0888 - root_mean_squared_error: 0.1236 - RMSE_P: 1245.2062 - RMSE_T: 45.8886 - val_loss: 0.0144 - val_mean_absolute_error: 0.0859 - val_root_mean_squared_error: 0.1198 - val_RMSE_P: 1189.9390 - val_RMSE_T: 47.3458
# Epoch 47/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0156 - mean_absolute_error: 0.0898 - root_mean_squared_error: 0.1251 - RMSE_P: 1259.2834 - RMSE_T: 46.1417 - val_loss: 0.0144 - val_mean_absolute_error: 0.0862 - val_root_mean_squared_error: 0.1201 - val_RMSE_P: 1196.2927 - val_RMSE_T: 47.1400
# Epoch 48/5000
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0151 - mean_absolute_error: 0.0881 - root_mean_squared_error: 0.1228 - RMSE_P: 1254.8370 - RMSE_T: 44.9275 - val_loss: 0.0142 - val_mean_absolute_error: 0.0856 - val_root_mean_squared_error: 0.1193 - val_RMSE_P: 1190.5302 - val_RMSE_T: 46.6816
# Epoch 49/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0147 - mean_absolute_error: 0.0873 - root_mean_squared_error: 0.1214 - RMSE_P: 1219.9982 - RMSE_T: 45.5040 - val_loss: 0.0140 - val_mean_absolute_error: 0.0848 - val_root_mean_squared_error: 0.1182 - val_RMSE_P: 1188.1841 - val_RMSE_T: 45.4678
# Epoch 50/5000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0149 - mean_absolute_error: 0.0869 - root_mean_squared_error: 0.1219 - RMSE_P: 1238.3975 - RMSE_T: 45.0276 - val_loss: 0.0140 - val_mean_absolute_error: 0.0849 - val_root_mean_squared_error: 0.1183 - val_RMSE_P: 1191.6957 - val_RMSE_T: 45.2001
# Epoch 51/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0146 - mean_absolute_error: 0.0867 - root_mean_squared_error: 0.1210 - RMSE_P: 1228.0698 - RMSE_T: 44.9304 - val_loss: 0.0140 - val_mean_absolute_error: 0.0844 - val_root_mean_squared_error: 0.1182 - val_RMSE_P: 1185.6821 - val_RMSE_T: 45.6095
# Epoch 52/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0151 - mean_absolute_error: 0.0877 - root_mean_squared_error: 0.1230 - RMSE_P: 1251.1954 - RMSE_T: 45.0366 - val_loss: 0.0141 - val_mean_absolute_error: 0.0852 - val_root_mean_squared_error: 0.1186 - val_RMSE_P: 1189.8514 - val_RMSE_T: 45.7830
# Epoch 53/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0148 - mean_absolute_error: 0.0872 - root_mean_squared_error: 0.1217 - RMSE_P: 1238.1018 - RMSE_T: 44.7596 - val_loss: 0.0143 - val_mean_absolute_error: 0.0859 - val_root_mean_squared_error: 0.1194 - val_RMSE_P: 1189.3354 - val_RMSE_T: 46.8193
# Epoch 54/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0151 - mean_absolute_error: 0.0881 - root_mean_squared_error: 0.1228 - RMSE_P: 1240.4086 - RMSE_T: 45.7952 - val_loss: 0.0140 - val_mean_absolute_error: 0.0843 - val_root_mean_squared_error: 0.1182 - val_RMSE_P: 1188.6224 - val_RMSE_T: 45.2854
# Epoch 55/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0145 - mean_absolute_error: 0.0867 - root_mean_squared_error: 0.1204 - RMSE_P: 1211.5309 - RMSE_T: 44.8398 - val_loss: 0.0141 - val_mean_absolute_error: 0.0849 - val_root_mean_squared_error: 0.1187 - val_RMSE_P: 1190.7620 - val_RMSE_T: 45.8308
# Epoch 56/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0143 - mean_absolute_error: 0.0856 - root_mean_squared_error: 0.1194 - RMSE_P: 1201.8275 - RMSE_T: 44.9072 - val_loss: 0.0140 - val_mean_absolute_error: 0.0846 - val_root_mean_squared_error: 0.1184 - val_RMSE_P: 1185.5306 - val_RMSE_T: 45.9092
# Epoch 57/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0143 - mean_absolute_error: 0.0861 - root_mean_squared_error: 0.1196 - RMSE_P: 1214.3945 - RMSE_T: 44.6921 - val_loss: 0.0140 - val_mean_absolute_error: 0.0845 - val_root_mean_squared_error: 0.1182 - val_RMSE_P: 1187.3027 - val_RMSE_T: 45.4187
# Epoch 58/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0145 - mean_absolute_error: 0.0861 - root_mean_squared_error: 0.1202 - RMSE_P: 1220.0312 - RMSE_T: 44.0956 - val_loss: 0.0139 - val_mean_absolute_error: 0.0841 - val_root_mean_squared_error: 0.1177 - val_RMSE_P: 1180.3596 - val_RMSE_T: 45.4589
# Epoch 59/5000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0148 - mean_absolute_error: 0.0868 - root_mean_squared_error: 0.1217 - RMSE_P: 1216.2524 - RMSE_T: 45.3685 - val_loss: 0.0139 - val_mean_absolute_error: 0.0851 - val_root_mean_squared_error: 0.1181 - val_RMSE_P: 1181.2720 - val_RMSE_T: 45.9146
# Epoch 60/5000
# 35/35 [==============================] - 0s 7ms/step - loss: 0.0143 - mean_absolute_error: 0.0861 - root_mean_squared_error: 0.1196 - RMSE_P: 1212.9158 - RMSE_T: 43.1634 - val_loss: 0.0140 - val_mean_absolute_error: 0.0849 - val_root_mean_squared_error: 0.1182 - val_RMSE_P: 1187.4348 - val_RMSE_T: 45.4806
# Epoch 61/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0143 - mean_absolute_error: 0.0863 - root_mean_squared_error: 0.1198 - RMSE_P: 1220.2361 - RMSE_T: 44.3504 - val_loss: 0.0138 - val_mean_absolute_error: 0.0839 - val_root_mean_squared_error: 0.1173 - val_RMSE_P: 1180.8342 - val_RMSE_T: 44.9392
# Epoch 62/5000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0144 - mean_absolute_error: 0.0855 - root_mean_squared_error: 0.1200 - RMSE_P: 1227.9358 - RMSE_T: 43.4430 - val_loss: 0.0138 - val_mean_absolute_error: 0.0842 - val_root_mean_squared_error: 0.1175 - val_RMSE_P: 1180.3329 - val_RMSE_T: 45.2241
# Epoch 63/5000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0142 - mean_absolute_error: 0.0859 - root_mean_squared_error: 0.1191 - RMSE_P: 1208.3690 - RMSE_T: 43.6908 - val_loss: 0.0137 - val_mean_absolute_error: 0.0840 - val_root_mean_squared_error: 0.1172 - val_RMSE_P: 1181.6116 - val_RMSE_T: 44.7495
# Epoch 64/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0145 - mean_absolute_error: 0.0859 - root_mean_squared_error: 0.1204 - RMSE_P: 1220.4352 - RMSE_T: 44.4009 - val_loss: 0.0138 - val_mean_absolute_error: 0.0841 - val_root_mean_squared_error: 0.1177 - val_RMSE_P: 1181.0723 - val_RMSE_T: 45.3473
# Epoch 65/5000
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0144 - mean_absolute_error: 0.0863 - root_mean_squared_error: 0.1200 - RMSE_P: 1213.2838 - RMSE_T: 44.8747 - val_loss: 0.0139 - val_mean_absolute_error: 0.0843 - val_root_mean_squared_error: 0.1179 - val_RMSE_P: 1176.8051 - val_RMSE_T: 46.0040
# Epoch 66/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0145 - mean_absolute_error: 0.0859 - root_mean_squared_error: 0.1204 - RMSE_P: 1219.4523 - RMSE_T: 43.4097 - val_loss: 0.0139 - val_mean_absolute_error: 0.0842 - val_root_mean_squared_error: 0.1180 - val_RMSE_P: 1186.3357 - val_RMSE_T: 45.2374
# Epoch 67/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0146 - mean_absolute_error: 0.0859 - root_mean_squared_error: 0.1208 - RMSE_P: 1236.4537 - RMSE_T: 43.8313 - val_loss: 0.0138 - val_mean_absolute_error: 0.0835 - val_root_mean_squared_error: 0.1175 - val_RMSE_P: 1172.7241 - val_RMSE_T: 45.8027
# Epoch 68/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0144 - mean_absolute_error: 0.0860 - root_mean_squared_error: 0.1198 - RMSE_P: 1216.5664 - RMSE_T: 44.2842 - val_loss: 0.0139 - val_mean_absolute_error: 0.0842 - val_root_mean_squared_error: 0.1178 - val_RMSE_P: 1176.0079 - val_RMSE_T: 45.8149
# Epoch 69/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0143 - mean_absolute_error: 0.0860 - root_mean_squared_error: 0.1196 - RMSE_P: 1207.8077 - RMSE_T: 44.4138 - val_loss: 0.0139 - val_mean_absolute_error: 0.0839 - val_root_mean_squared_error: 0.1177 - val_RMSE_P: 1174.1451 - val_RMSE_T: 45.9254
# Epoch 70/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0143 - mean_absolute_error: 0.0851 - root_mean_squared_error: 0.1196 - RMSE_P: 1217.3523 - RMSE_T: 43.2677 - val_loss: 0.0140 - val_mean_absolute_error: 0.0848 - val_root_mean_squared_error: 0.1184 - val_RMSE_P: 1178.0815 - val_RMSE_T: 46.3825
# Epoch 71/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0144 - mean_absolute_error: 0.0856 - root_mean_squared_error: 0.1199 - RMSE_P: 1219.8204 - RMSE_T: 44.8752 - val_loss: 0.0141 - val_mean_absolute_error: 0.0852 - val_root_mean_squared_error: 0.1190 - val_RMSE_P: 1174.3748 - val_RMSE_T: 47.3946
# Epoch 72/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0145 - mean_absolute_error: 0.0859 - root_mean_squared_error: 0.1206 - RMSE_P: 1224.4844 - RMSE_T: 43.9166 - val_loss: 0.0137 - val_mean_absolute_error: 0.0835 - val_root_mean_squared_error: 0.1170 - val_RMSE_P: 1175.3619 - val_RMSE_T: 44.9486
# Epoch 73/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0142 - mean_absolute_error: 0.0853 - root_mean_squared_error: 0.1192 - RMSE_P: 1207.5964 - RMSE_T: 43.5938 - val_loss: 0.0136 - val_mean_absolute_error: 0.0830 - val_root_mean_squared_error: 0.1166 - val_RMSE_P: 1171.4736 - val_RMSE_T: 44.8501
# Epoch 74/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0145 - mean_absolute_error: 0.0859 - root_mean_squared_error: 0.1205 - RMSE_P: 1227.4470 - RMSE_T: 43.6802 - val_loss: 0.0137 - val_mean_absolute_error: 0.0834 - val_root_mean_squared_error: 0.1169 - val_RMSE_P: 1172.1141 - val_RMSE_T: 45.1570
# Epoch 75/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0141 - mean_absolute_error: 0.0848 - root_mean_squared_error: 0.1189 - RMSE_P: 1212.6752 - RMSE_T: 43.4316 - val_loss: 0.0137 - val_mean_absolute_error: 0.0837 - val_root_mean_squared_error: 0.1172 - val_RMSE_P: 1178.7283 - val_RMSE_T: 44.9013
# Epoch 76/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0139 - mean_absolute_error: 0.0835 - root_mean_squared_error: 0.1181 - RMSE_P: 1189.7567 - RMSE_T: 43.0340 - val_loss: 0.0138 - val_mean_absolute_error: 0.0838 - val_root_mean_squared_error: 0.1173 - val_RMSE_P: 1170.8149 - val_RMSE_T: 45.6907
# Epoch 77/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0138 - mean_absolute_error: 0.0840 - root_mean_squared_error: 0.1173 - RMSE_P: 1196.1053 - RMSE_T: 42.8402 - val_loss: 0.0136 - val_mean_absolute_error: 0.0833 - val_root_mean_squared_error: 0.1168 - val_RMSE_P: 1168.5979 - val_RMSE_T: 45.2676
# Epoch 78/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0140 - mean_absolute_error: 0.0841 - root_mean_squared_error: 0.1182 - RMSE_P: 1203.5372 - RMSE_T: 44.0234 - val_loss: 0.0135 - val_mean_absolute_error: 0.0826 - val_root_mean_squared_error: 0.1163 - val_RMSE_P: 1170.8582 - val_RMSE_T: 44.3530
# Epoch 79/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0143 - mean_absolute_error: 0.0856 - root_mean_squared_error: 0.1197 - RMSE_P: 1201.9811 - RMSE_T: 43.9720 - val_loss: 0.0137 - val_mean_absolute_error: 0.0833 - val_root_mean_squared_error: 0.1169 - val_RMSE_P: 1177.0745 - val_RMSE_T: 44.5509
# Epoch 80/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0139 - mean_absolute_error: 0.0841 - root_mean_squared_error: 0.1180 - RMSE_P: 1187.9264 - RMSE_T: 43.4726 - val_loss: 0.0138 - val_mean_absolute_error: 0.0836 - val_root_mean_squared_error: 0.1173 - val_RMSE_P: 1172.8248 - val_RMSE_T: 45.5377
# Epoch 81/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0139 - mean_absolute_error: 0.0846 - root_mean_squared_error: 0.1179 - RMSE_P: 1190.4825 - RMSE_T: 43.6381 - val_loss: 0.0137 - val_mean_absolute_error: 0.0830 - val_root_mean_squared_error: 0.1168 - val_RMSE_P: 1166.4840 - val_RMSE_T: 45.4417
# Epoch 82/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0140 - mean_absolute_error: 0.0841 - root_mean_squared_error: 0.1182 - RMSE_P: 1193.7319 - RMSE_T: 43.2454 - val_loss: 0.0136 - val_mean_absolute_error: 0.0834 - val_root_mean_squared_error: 0.1168 - val_RMSE_P: 1169.9177 - val_RMSE_T: 45.1298
# Epoch 83/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0136 - mean_absolute_error: 0.0833 - root_mean_squared_error: 0.1167 - RMSE_P: 1199.8889 - RMSE_T: 42.6477 - val_loss: 0.0137 - val_mean_absolute_error: 0.0842 - val_root_mean_squared_error: 0.1172 - val_RMSE_P: 1169.0603 - val_RMSE_T: 45.6561
# Epoch 84/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0139 - mean_absolute_error: 0.0846 - root_mean_squared_error: 0.1180 - RMSE_P: 1193.0206 - RMSE_T: 42.9117 - val_loss: 0.0136 - val_mean_absolute_error: 0.0835 - val_root_mean_squared_error: 0.1164 - val_RMSE_P: 1169.2212 - val_RMSE_T: 44.5155
# Epoch 85/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0140 - mean_absolute_error: 0.0847 - root_mean_squared_error: 0.1184 - RMSE_P: 1197.5719 - RMSE_T: 43.3885 - val_loss: 0.0134 - val_mean_absolute_error: 0.0826 - val_root_mean_squared_error: 0.1156 - val_RMSE_P: 1158.6147 - val_RMSE_T: 44.4397
# Epoch 86/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0143 - mean_absolute_error: 0.0854 - root_mean_squared_error: 0.1196 - RMSE_P: 1212.1998 - RMSE_T: 44.1927 - val_loss: 0.0135 - val_mean_absolute_error: 0.0829 - val_root_mean_squared_error: 0.1160 - val_RMSE_P: 1158.9860 - val_RMSE_T: 44.9798
# Epoch 87/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0141 - mean_absolute_error: 0.0846 - root_mean_squared_error: 0.1189 - RMSE_P: 1209.6348 - RMSE_T: 43.6359 - val_loss: 0.0137 - val_mean_absolute_error: 0.0839 - val_root_mean_squared_error: 0.1169 - val_RMSE_P: 1163.4552 - val_RMSE_T: 45.6580
# Epoch 88/5000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0135 - mean_absolute_error: 0.0835 - root_mean_squared_error: 0.1164 - RMSE_P: 1191.0844 - RMSE_T: 42.8934 - val_loss: 0.0133 - val_mean_absolute_error: 0.0821 - val_root_mean_squared_error: 0.1151 - val_RMSE_P: 1160.5627 - val_RMSE_T: 43.6984
# Epoch 89/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0138 - mean_absolute_error: 0.0841 - root_mean_squared_error: 0.1177 - RMSE_P: 1194.0298 - RMSE_T: 43.4878 - val_loss: 0.0134 - val_mean_absolute_error: 0.0825 - val_root_mean_squared_error: 0.1157 - val_RMSE_P: 1155.7891 - val_RMSE_T: 44.7253
# Epoch 90/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0136 - mean_absolute_error: 0.0829 - root_mean_squared_error: 0.1166 - RMSE_P: 1182.4235 - RMSE_T: 43.1705 - val_loss: 0.0134 - val_mean_absolute_error: 0.0827 - val_root_mean_squared_error: 0.1158 - val_RMSE_P: 1158.7567 - val_RMSE_T: 44.6685
# Epoch 91/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0138 - mean_absolute_error: 0.0839 - root_mean_squared_error: 0.1176 - RMSE_P: 1197.1780 - RMSE_T: 42.7660 - val_loss: 0.0133 - val_mean_absolute_error: 0.0824 - val_root_mean_squared_error: 0.1155 - val_RMSE_P: 1156.6392 - val_RMSE_T: 44.4083
# Epoch 92/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0135 - mean_absolute_error: 0.0826 - root_mean_squared_error: 0.1163 - RMSE_P: 1196.5646 - RMSE_T: 42.7192 - val_loss: 0.0133 - val_mean_absolute_error: 0.0822 - val_root_mean_squared_error: 0.1153 - val_RMSE_P: 1154.1267 - val_RMSE_T: 44.4175
# Epoch 93/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0135 - mean_absolute_error: 0.0834 - root_mean_squared_error: 0.1162 - RMSE_P: 1172.6750 - RMSE_T: 43.1702 - val_loss: 0.0134 - val_mean_absolute_error: 0.0826 - val_root_mean_squared_error: 0.1157 - val_RMSE_P: 1158.2365 - val_RMSE_T: 44.5413
# Epoch 94/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0137 - mean_absolute_error: 0.0836 - root_mean_squared_error: 0.1171 - RMSE_P: 1190.7258 - RMSE_T: 42.8220 - val_loss: 0.0132 - val_mean_absolute_error: 0.0822 - val_root_mean_squared_error: 0.1151 - val_RMSE_P: 1154.7974 - val_RMSE_T: 44.1174
# Epoch 95/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0136 - mean_absolute_error: 0.0829 - root_mean_squared_error: 0.1166 - RMSE_P: 1191.6765 - RMSE_T: 42.4636 - val_loss: 0.0133 - val_mean_absolute_error: 0.0823 - val_root_mean_squared_error: 0.1155 - val_RMSE_P: 1158.0396 - val_RMSE_T: 44.3974
# Epoch 96/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0137 - mean_absolute_error: 0.0834 - root_mean_squared_error: 0.1170 - RMSE_P: 1195.0358 - RMSE_T: 42.7461 - val_loss: 0.0133 - val_mean_absolute_error: 0.0821 - val_root_mean_squared_error: 0.1155 - val_RMSE_P: 1156.2715 - val_RMSE_T: 44.5080
# Epoch 97/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0136 - mean_absolute_error: 0.0827 - root_mean_squared_error: 0.1165 - RMSE_P: 1179.8477 - RMSE_T: 42.2347 - val_loss: 0.0134 - val_mean_absolute_error: 0.0824 - val_root_mean_squared_error: 0.1157 - val_RMSE_P: 1154.6664 - val_RMSE_T: 44.9325
# Epoch 98/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0138 - mean_absolute_error: 0.0839 - root_mean_squared_error: 0.1173 - RMSE_P: 1183.2386 - RMSE_T: 43.4246 - val_loss: 0.0135 - val_mean_absolute_error: 0.0832 - val_root_mean_squared_error: 0.1162 - val_RMSE_P: 1162.0649 - val_RMSE_T: 44.9766
# Epoch 99/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0137 - mean_absolute_error: 0.0834 - root_mean_squared_error: 0.1171 - RMSE_P: 1192.5743 - RMSE_T: 42.6204 - val_loss: 0.0133 - val_mean_absolute_error: 0.0822 - val_root_mean_squared_error: 0.1155 - val_RMSE_P: 1153.8549 - val_RMSE_T: 44.7460
# Epoch 100/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0136 - mean_absolute_error: 0.0826 - root_mean_squared_error: 0.1168 - RMSE_P: 1201.0399 - RMSE_T: 42.5996 - val_loss: 0.0134 - val_mean_absolute_error: 0.0824 - val_root_mean_squared_error: 0.1157 - val_RMSE_P: 1158.1952 - val_RMSE_T: 44.6601
# Epoch 101/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0135 - mean_absolute_error: 0.0834 - root_mean_squared_error: 0.1164 - RMSE_P: 1185.5535 - RMSE_T: 43.3215 - val_loss: 0.0133 - val_mean_absolute_error: 0.0819 - val_root_mean_squared_error: 0.1152 - val_RMSE_P: 1153.4990 - val_RMSE_T: 44.3800
# Epoch 102/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0135 - mean_absolute_error: 0.0826 - root_mean_squared_error: 0.1162 - RMSE_P: 1178.2676 - RMSE_T: 42.7197 - val_loss: 0.0132 - val_mean_absolute_error: 0.0817 - val_root_mean_squared_error: 0.1150 - val_RMSE_P: 1150.0460 - val_RMSE_T: 44.3601
# Epoch 103/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0136 - mean_absolute_error: 0.0829 - root_mean_squared_error: 0.1166 - RMSE_P: 1189.2297 - RMSE_T: 42.6183 - val_loss: 0.0133 - val_mean_absolute_error: 0.0823 - val_root_mean_squared_error: 0.1155 - val_RMSE_P: 1156.3843 - val_RMSE_T: 44.5146
# Epoch 104/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0137 - mean_absolute_error: 0.0825 - root_mean_squared_error: 0.1171 - RMSE_P: 1190.5468 - RMSE_T: 42.8713 - val_loss: 0.0133 - val_mean_absolute_error: 0.0820 - val_root_mean_squared_error: 0.1153 - val_RMSE_P: 1156.5598 - val_RMSE_T: 44.1576
# Epoch 105/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0136 - mean_absolute_error: 0.0834 - root_mean_squared_error: 0.1168 - RMSE_P: 1195.0066 - RMSE_T: 43.5082 - val_loss: 0.0133 - val_mean_absolute_error: 0.0814 - val_root_mean_squared_error: 0.1152 - val_RMSE_P: 1153.3431 - val_RMSE_T: 44.2296
# Epoch 106/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0134 - mean_absolute_error: 0.0819 - root_mean_squared_error: 0.1157 - RMSE_P: 1163.5619 - RMSE_T: 42.7528 - val_loss: 0.0134 - val_mean_absolute_error: 0.0819 - val_root_mean_squared_error: 0.1156 - val_RMSE_P: 1155.6760 - val_RMSE_T: 44.6070
# Epoch 107/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0134 - mean_absolute_error: 0.0820 - root_mean_squared_error: 0.1157 - RMSE_P: 1183.3574 - RMSE_T: 42.0024 - val_loss: 0.0135 - val_mean_absolute_error: 0.0826 - val_root_mean_squared_error: 0.1163 - val_RMSE_P: 1161.7036 - val_RMSE_T: 45.0271
# Epoch 108/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0134 - mean_absolute_error: 0.0827 - root_mean_squared_error: 0.1156 - RMSE_P: 1179.6665 - RMSE_T: 42.1008 - val_loss: 0.0134 - val_mean_absolute_error: 0.0818 - val_root_mean_squared_error: 0.1157 - val_RMSE_P: 1159.6791 - val_RMSE_T: 44.3208
# Epoch 109/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0139 - mean_absolute_error: 0.0828 - root_mean_squared_error: 0.1177 - RMSE_P: 1209.8936 - RMSE_T: 42.1363 - val_loss: 0.0133 - val_mean_absolute_error: 0.0818 - val_root_mean_squared_error: 0.1154 - val_RMSE_P: 1162.0580 - val_RMSE_T: 43.8522
# Epoch 110/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0136 - mean_absolute_error: 0.0825 - root_mean_squared_error: 0.1164 - RMSE_P: 1196.0743 - RMSE_T: 42.0851 - val_loss: 0.0135 - val_mean_absolute_error: 0.0826 - val_root_mean_squared_error: 0.1160 - val_RMSE_P: 1160.8435 - val_RMSE_T: 44.6936
# Epoch 111/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0134 - mean_absolute_error: 0.0827 - root_mean_squared_error: 0.1159 - RMSE_P: 1163.9667 - RMSE_T: 42.6471 - val_loss: 0.0134 - val_mean_absolute_error: 0.0822 - val_root_mean_squared_error: 0.1157 - val_RMSE_P: 1159.2329 - val_RMSE_T: 44.5645
# Epoch 112/5000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0133 - mean_absolute_error: 0.0817 - root_mean_squared_error: 0.1152 - RMSE_P: 1177.0847 - RMSE_T: 42.6347 - val_loss: 0.0133 - val_mean_absolute_error: 0.0820 - val_root_mean_squared_error: 0.1155 - val_RMSE_P: 1156.6908 - val_RMSE_T: 44.4717
# Epoch 113/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0137 - mean_absolute_error: 0.0828 - root_mean_squared_error: 0.1169 - RMSE_P: 1181.5996 - RMSE_T: 42.7233 - val_loss: 0.0134 - val_mean_absolute_error: 0.0822 - val_root_mean_squared_error: 0.1158 - val_RMSE_P: 1157.8921 - val_RMSE_T: 44.7305
# Epoch 114/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0133 - mean_absolute_error: 0.0825 - root_mean_squared_error: 0.1154 - RMSE_P: 1173.6509 - RMSE_T: 41.3893 - val_loss: 0.0137 - val_mean_absolute_error: 0.0834 - val_root_mean_squared_error: 0.1172 - val_RMSE_P: 1172.5903 - val_RMSE_T: 45.2231
# Epoch 115/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0131 - mean_absolute_error: 0.0815 - root_mean_squared_error: 0.1146 - RMSE_P: 1165.9889 - RMSE_T: 41.1515 - val_loss: 0.0135 - val_mean_absolute_error: 0.0829 - val_root_mean_squared_error: 0.1161 - val_RMSE_P: 1162.1780 - val_RMSE_T: 44.8243
# Epoch 116/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0133 - mean_absolute_error: 0.0823 - root_mean_squared_error: 0.1151 - RMSE_P: 1161.3270 - RMSE_T: 41.6411 - val_loss: 0.0133 - val_mean_absolute_error: 0.0820 - val_root_mean_squared_error: 0.1155 - val_RMSE_P: 1157.3719 - val_RMSE_T: 44.3355
# Epoch 117/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0134 - mean_absolute_error: 0.0819 - root_mean_squared_error: 0.1158 - RMSE_P: 1175.0322 - RMSE_T: 41.9923 - val_loss: 0.0134 - val_mean_absolute_error: 0.0822 - val_root_mean_squared_error: 0.1157 - val_RMSE_P: 1157.9393 - val_RMSE_T: 44.4781
# Epoch 118/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0135 - mean_absolute_error: 0.0823 - root_mean_squared_error: 0.1161 - RMSE_P: 1190.8398 - RMSE_T: 41.6545 - val_loss: 0.0134 - val_mean_absolute_error: 0.0825 - val_root_mean_squared_error: 0.1158 - val_RMSE_P: 1157.2778 - val_RMSE_T: 44.6692
# Epoch 119/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0133 - mean_absolute_error: 0.0821 - root_mean_squared_error: 0.1153 - RMSE_P: 1176.8678 - RMSE_T: 42.4468 - val_loss: 0.0133 - val_mean_absolute_error: 0.0822 - val_root_mean_squared_error: 0.1155 - val_RMSE_P: 1153.6522 - val_RMSE_T: 44.6765
# Epoch 120/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0133 - mean_absolute_error: 0.0814 - root_mean_squared_error: 0.1154 - RMSE_P: 1178.9420 - RMSE_T: 41.8881 - val_loss: 0.0133 - val_mean_absolute_error: 0.0821 - val_root_mean_squared_error: 0.1154 - val_RMSE_P: 1155.2622 - val_RMSE_T: 44.4425
# Epoch 121/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0132 - mean_absolute_error: 0.0818 - root_mean_squared_error: 0.1149 - RMSE_P: 1169.3943 - RMSE_T: 41.7262 - val_loss: 0.0133 - val_mean_absolute_error: 0.0818 - val_root_mean_squared_error: 0.1152 - val_RMSE_P: 1148.6768 - val_RMSE_T: 44.6393
# Epoch 122/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0134 - mean_absolute_error: 0.0820 - root_mean_squared_error: 0.1156 - RMSE_P: 1170.0427 - RMSE_T: 42.9280 - val_loss: 0.0135 - val_mean_absolute_error: 0.0829 - val_root_mean_squared_error: 0.1161 - val_RMSE_P: 1156.7114 - val_RMSE_T: 45.1687
# Epoch 123/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0132 - mean_absolute_error: 0.0815 - root_mean_squared_error: 0.1150 - RMSE_P: 1163.8663 - RMSE_T: 41.9642 - val_loss: 0.0134 - val_mean_absolute_error: 0.0826 - val_root_mean_squared_error: 0.1156 - val_RMSE_P: 1154.2963 - val_RMSE_T: 44.8504
# Epoch 124/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0131 - mean_absolute_error: 0.0814 - root_mean_squared_error: 0.1145 - RMSE_P: 1171.2349 - RMSE_T: 41.7898 - val_loss: 0.0134 - val_mean_absolute_error: 0.0827 - val_root_mean_squared_error: 0.1157 - val_RMSE_P: 1152.6888 - val_RMSE_T: 44.9769
# Epoch 125/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0133 - mean_absolute_error: 0.0819 - root_mean_squared_error: 0.1153 - RMSE_P: 1166.1622 - RMSE_T: 42.0770 - val_loss: 0.0131 - val_mean_absolute_error: 0.0811 - val_root_mean_squared_error: 0.1145 - val_RMSE_P: 1145.0415 - val_RMSE_T: 44.1715
# Epoch 126/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0133 - mean_absolute_error: 0.0819 - root_mean_squared_error: 0.1154 - RMSE_P: 1176.0063 - RMSE_T: 42.3112 - val_loss: 0.0132 - val_mean_absolute_error: 0.0816 - val_root_mean_squared_error: 0.1150 - val_RMSE_P: 1148.2931 - val_RMSE_T: 44.4488
# Epoch 127/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0128 - mean_absolute_error: 0.0805 - root_mean_squared_error: 0.1133 - RMSE_P: 1151.8667 - RMSE_T: 41.6527 - val_loss: 0.0133 - val_mean_absolute_error: 0.0821 - val_root_mean_squared_error: 0.1155 - val_RMSE_P: 1150.1427 - val_RMSE_T: 44.9512
# Epoch 128/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0131 - mean_absolute_error: 0.0815 - root_mean_squared_error: 0.1145 - RMSE_P: 1153.3010 - RMSE_T: 42.6463 - val_loss: 0.0134 - val_mean_absolute_error: 0.0818 - val_root_mean_squared_error: 0.1159 - val_RMSE_P: 1160.6686 - val_RMSE_T: 44.5295
# Epoch 129/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0131 - mean_absolute_error: 0.0811 - root_mean_squared_error: 0.1143 - RMSE_P: 1155.0957 - RMSE_T: 41.0967 - val_loss: 0.0133 - val_mean_absolute_error: 0.0820 - val_root_mean_squared_error: 0.1155 - val_RMSE_P: 1161.2211 - val_RMSE_T: 43.9874
# Epoch 130/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0131 - mean_absolute_error: 0.0821 - root_mean_squared_error: 0.1146 - RMSE_P: 1173.6338 - RMSE_T: 41.2888 - val_loss: 0.0134 - val_mean_absolute_error: 0.0820 - val_root_mean_squared_error: 0.1156 - val_RMSE_P: 1152.6035 - val_RMSE_T: 44.7624
# Epoch 131/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0131 - mean_absolute_error: 0.0812 - root_mean_squared_error: 0.1143 - RMSE_P: 1161.0547 - RMSE_T: 41.3188 - val_loss: 0.0132 - val_mean_absolute_error: 0.0816 - val_root_mean_squared_error: 0.1149 - val_RMSE_P: 1148.6647 - val_RMSE_T: 44.2154
# Epoch 132/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0127 - mean_absolute_error: 0.0800 - root_mean_squared_error: 0.1125 - RMSE_P: 1151.1326 - RMSE_T: 41.1451 - val_loss: 0.0132 - val_mean_absolute_error: 0.0812 - val_root_mean_squared_error: 0.1149 - val_RMSE_P: 1146.6421 - val_RMSE_T: 44.4007
# Epoch 133/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0130 - mean_absolute_error: 0.0807 - root_mean_squared_error: 0.1139 - RMSE_P: 1160.4791 - RMSE_T: 42.0733 - val_loss: 0.0131 - val_mean_absolute_error: 0.0810 - val_root_mean_squared_error: 0.1144 - val_RMSE_P: 1141.9921 - val_RMSE_T: 44.2768
# Epoch 134/5000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0129 - mean_absolute_error: 0.0807 - root_mean_squared_error: 0.1134 - RMSE_P: 1160.5665 - RMSE_T: 41.0228 - val_loss: 0.0132 - val_mean_absolute_error: 0.0815 - val_root_mean_squared_error: 0.1150 - val_RMSE_P: 1149.1230 - val_RMSE_T: 44.3835
# Epoch 135/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0131 - mean_absolute_error: 0.0812 - root_mean_squared_error: 0.1145 - RMSE_P: 1152.4628 - RMSE_T: 42.0923 - val_loss: 0.0131 - val_mean_absolute_error: 0.0810 - val_root_mean_squared_error: 0.1144 - val_RMSE_P: 1149.8076 - val_RMSE_T: 43.5383
# Epoch 136/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0128 - mean_absolute_error: 0.0800 - root_mean_squared_error: 0.1132 - RMSE_P: 1145.1283 - RMSE_T: 41.3416 - val_loss: 0.0131 - val_mean_absolute_error: 0.0810 - val_root_mean_squared_error: 0.1144 - val_RMSE_P: 1147.7124 - val_RMSE_T: 43.7340
# Epoch 137/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0127 - mean_absolute_error: 0.0797 - root_mean_squared_error: 0.1128 - RMSE_P: 1147.9636 - RMSE_T: 40.7632 - val_loss: 0.0132 - val_mean_absolute_error: 0.0816 - val_root_mean_squared_error: 0.1147 - val_RMSE_P: 1147.5356 - val_RMSE_T: 44.1698
# Epoch 138/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0130 - mean_absolute_error: 0.0813 - root_mean_squared_error: 0.1141 - RMSE_P: 1173.5630 - RMSE_T: 40.8575 - val_loss: 0.0131 - val_mean_absolute_error: 0.0816 - val_root_mean_squared_error: 0.1147 - val_RMSE_P: 1152.2858 - val_RMSE_T: 43.8103
# Epoch 139/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0128 - mean_absolute_error: 0.0805 - root_mean_squared_error: 0.1131 - RMSE_P: 1144.5734 - RMSE_T: 41.4733 - val_loss: 0.0132 - val_mean_absolute_error: 0.0814 - val_root_mean_squared_error: 0.1147 - val_RMSE_P: 1149.0950 - val_RMSE_T: 44.1612
# Epoch 140/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0131 - mean_absolute_error: 0.0813 - root_mean_squared_error: 0.1145 - RMSE_P: 1160.1173 - RMSE_T: 41.5391 - val_loss: 0.0131 - val_mean_absolute_error: 0.0814 - val_root_mean_squared_error: 0.1147 - val_RMSE_P: 1147.1926 - val_RMSE_T: 44.2807
# Epoch 141/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0126 - mean_absolute_error: 0.0794 - root_mean_squared_error: 0.1122 - RMSE_P: 1128.5527 - RMSE_T: 41.1985 - val_loss: 0.0131 - val_mean_absolute_error: 0.0810 - val_root_mean_squared_error: 0.1144 - val_RMSE_P: 1143.9485 - val_RMSE_T: 44.2959
# Epoch 142/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0125 - mean_absolute_error: 0.0796 - root_mean_squared_error: 0.1120 - RMSE_P: 1141.0020 - RMSE_T: 40.8152 - val_loss: 0.0132 - val_mean_absolute_error: 0.0812 - val_root_mean_squared_error: 0.1148 - val_RMSE_P: 1145.4911 - val_RMSE_T: 44.5408
# Epoch 143/5000
# ...
# Epoch 250/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0114 - mean_absolute_error: 0.0760 - root_mean_squared_error: 0.1068 - RMSE_P: 1075.5768 - RMSE_T: 40.1587 - val_loss: 0.0126 - val_mean_absolute_error: 0.0778 - val_root_mean_squared_error: 0.1122 - val_RMSE_P: 1122.7020 - val_RMSE_T: 41.6398
# Epoch 251/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0116 - mean_absolute_error: 0.0765 - root_mean_squared_error: 0.1077 - RMSE_P: 1082.1232 - RMSE_T: 40.2047 - val_loss: 0.0126 - val_mean_absolute_error: 0.0782 - val_root_mean_squared_error: 0.1124 - val_RMSE_P: 1135.8950 - val_RMSE_T: 41.2047
# Epoch 252/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0118 - mean_absolute_error: 0.0768 - root_mean_squared_error: 0.1086 - RMSE_P: 1097.3367 - RMSE_T: 40.0821 - val_loss: 0.0125 - val_mean_absolute_error: 0.0768 - val_root_mean_squared_error: 0.1117 - val_RMSE_P: 1127.9277 - val_RMSE_T: 40.7670
# Epoch 253/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0118 - mean_absolute_error: 0.0773 - root_mean_squared_error: 0.1087 - RMSE_P: 1102.4753 - RMSE_T: 40.0114 - val_loss: 0.0126 - val_mean_absolute_error: 0.0776 - val_root_mean_squared_error: 0.1123 - val_RMSE_P: 1131.7877 - val_RMSE_T: 41.0815
# Epoch 254/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0117 - mean_absolute_error: 0.0762 - root_mean_squared_error: 0.1084 - RMSE_P: 1107.8060 - RMSE_T: 39.8505 - val_loss: 0.0127 - val_mean_absolute_error: 0.0782 - val_root_mean_squared_error: 0.1126 - val_RMSE_P: 1133.7671 - val_RMSE_T: 41.1710
# Epoch 255/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0118 - mean_absolute_error: 0.0773 - root_mean_squared_error: 0.1087 - RMSE_P: 1104.1157 - RMSE_T: 40.4152 - val_loss: 0.0126 - val_mean_absolute_error: 0.0780 - val_root_mean_squared_error: 0.1121 - val_RMSE_P: 1129.0894 - val_RMSE_T: 41.2085
# Epoch 256/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0118 - mean_absolute_error: 0.0771 - root_mean_squared_error: 0.1084 - RMSE_P: 1088.1565 - RMSE_T: 39.7941 - val_loss: 0.0126 - val_mean_absolute_error: 0.0779 - val_root_mean_squared_error: 0.1121 - val_RMSE_P: 1124.4946 - val_RMSE_T: 41.4154
# Epoch 257/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0116 - mean_absolute_error: 0.0760 - root_mean_squared_error: 0.1075 - RMSE_P: 1086.3876 - RMSE_T: 39.9670 - val_loss: 0.0126 - val_mean_absolute_error: 0.0782 - val_root_mean_squared_error: 0.1124 - val_RMSE_P: 1135.2687 - val_RMSE_T: 41.0011
# Epoch 258/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0118 - mean_absolute_error: 0.0771 - root_mean_squared_error: 0.1086 - RMSE_P: 1098.5973 - RMSE_T: 40.1069 - val_loss: 0.0127 - val_mean_absolute_error: 0.0777 - val_root_mean_squared_error: 0.1125 - val_RMSE_P: 1134.1755 - val_RMSE_T: 41.0470
# Epoch 259/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0115 - mean_absolute_error: 0.0762 - root_mean_squared_error: 0.1073 - RMSE_P: 1089.4991 - RMSE_T: 39.1832 - val_loss: 0.0129 - val_mean_absolute_error: 0.0785 - val_root_mean_squared_error: 0.1135 - val_RMSE_P: 1138.3101 - val_RMSE_T: 41.9296
# Epoch 260/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0116 - mean_absolute_error: 0.0764 - root_mean_squared_error: 0.1078 - RMSE_P: 1089.0619 - RMSE_T: 39.8019 - val_loss: 0.0129 - val_mean_absolute_error: 0.0783 - val_root_mean_squared_error: 0.1136 - val_RMSE_P: 1143.6321 - val_RMSE_T: 41.5206
# Epoch 261/5000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0114 - mean_absolute_error: 0.0762 - root_mean_squared_error: 0.1070 - RMSE_P: 1069.5259 - RMSE_T: 39.8701 - val_loss: 0.0126 - val_mean_absolute_error: 0.0777 - val_root_mean_squared_error: 0.1123 - val_RMSE_P: 1128.6002 - val_RMSE_T: 41.2692
# Epoch 262/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0118 - mean_absolute_error: 0.0765 - root_mean_squared_error: 0.1084 - RMSE_P: 1097.4559 - RMSE_T: 40.6003 - val_loss: 0.0127 - val_mean_absolute_error: 0.0777 - val_root_mean_squared_error: 0.1128 - val_RMSE_P: 1134.3444 - val_RMSE_T: 41.3064
# Epoch 263/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0117 - mean_absolute_error: 0.0765 - root_mean_squared_error: 0.1083 - RMSE_P: 1086.8119 - RMSE_T: 40.8224 - val_loss: 0.0127 - val_mean_absolute_error: 0.0777 - val_root_mean_squared_error: 0.1126 - val_RMSE_P: 1134.6362 - val_RMSE_T: 41.0804
# Epoch 264/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0115 - mean_absolute_error: 0.0760 - root_mean_squared_error: 0.1071 - RMSE_P: 1079.9955 - RMSE_T: 39.8831 - val_loss: 0.0127 - val_mean_absolute_error: 0.0779 - val_root_mean_squared_error: 0.1127 - val_RMSE_P: 1137.1089 - val_RMSE_T: 41.2124
# Epoch 265/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0118 - mean_absolute_error: 0.0768 - root_mean_squared_error: 0.1087 - RMSE_P: 1097.8483 - RMSE_T: 39.8228 - val_loss: 0.0127 - val_mean_absolute_error: 0.0779 - val_root_mean_squared_error: 0.1127 - val_RMSE_P: 1138.5181 - val_RMSE_T: 41.0401
# Epoch 266/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0114 - mean_absolute_error: 0.0762 - root_mean_squared_error: 0.1069 - RMSE_P: 1096.0016 - RMSE_T: 38.8856 - val_loss: 0.0127 - val_mean_absolute_error: 0.0780 - val_root_mean_squared_error: 0.1126 - val_RMSE_P: 1135.3174 - val_RMSE_T: 41.1892
# Epoch 267/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0119 - mean_absolute_error: 0.0774 - root_mean_squared_error: 0.1089 - RMSE_P: 1100.4474 - RMSE_T: 40.2806 - val_loss: 0.0126 - val_mean_absolute_error: 0.0778 - val_root_mean_squared_error: 0.1121 - val_RMSE_P: 1136.5237 - val_RMSE_T: 40.6769
# Epoch 268/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0116 - mean_absolute_error: 0.0765 - root_mean_squared_error: 0.1079 - RMSE_P: 1091.0764 - RMSE_T: 39.6458 - val_loss: 0.0126 - val_mean_absolute_error: 0.0779 - val_root_mean_squared_error: 0.1124 - val_RMSE_P: 1134.1495 - val_RMSE_T: 41.0634
# Epoch 269/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0116 - mean_absolute_error: 0.0765 - root_mean_squared_error: 0.1079 - RMSE_P: 1089.5043 - RMSE_T: 39.4558 - val_loss: 0.0128 - val_mean_absolute_error: 0.0779 - val_root_mean_squared_error: 0.1133 - val_RMSE_P: 1139.0874 - val_RMSE_T: 41.3424
# Epoch 270/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0118 - mean_absolute_error: 0.0770 - root_mean_squared_error: 0.1086 - RMSE_P: 1097.4924 - RMSE_T: 40.5047 - val_loss: 0.0128 - val_mean_absolute_error: 0.0782 - val_root_mean_squared_error: 0.1133 - val_RMSE_P: 1138.2795 - val_RMSE_T: 41.5892
# Epoch 271/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0114 - mean_absolute_error: 0.0753 - root_mean_squared_error: 0.1068 - RMSE_P: 1070.6562 - RMSE_T: 40.3231 - val_loss: 0.0126 - val_mean_absolute_error: 0.0774 - val_root_mean_squared_error: 0.1124 - val_RMSE_P: 1135.2539 - val_RMSE_T: 40.7420
# Epoch 272/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0116 - mean_absolute_error: 0.0762 - root_mean_squared_error: 0.1077 - RMSE_P: 1091.7728 - RMSE_T: 39.1675 - val_loss: 0.0126 - val_mean_absolute_error: 0.0776 - val_root_mean_squared_error: 0.1122 - val_RMSE_P: 1130.3959 - val_RMSE_T: 40.8072
# Epoch 273/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0115 - mean_absolute_error: 0.0763 - root_mean_squared_error: 0.1073 - RMSE_P: 1079.4166 - RMSE_T: 39.8320 - val_loss: 0.0125 - val_mean_absolute_error: 0.0775 - val_root_mean_squared_error: 0.1119 - val_RMSE_P: 1131.3776 - val_RMSE_T: 40.5911
# Epoch 274/5000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0114 - mean_absolute_error: 0.0753 - root_mean_squared_error: 0.1067 - RMSE_P: 1066.9689 - RMSE_T: 39.7987 - val_loss: 0.0128 - val_mean_absolute_error: 0.0780 - val_root_mean_squared_error: 0.1130 - val_RMSE_P: 1136.4899 - val_RMSE_T: 41.3048
# Epoch 275/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0117 - mean_absolute_error: 0.0761 - root_mean_squared_error: 0.1081 - RMSE_P: 1090.1418 - RMSE_T: 40.7193 - val_loss: 0.0124 - val_mean_absolute_error: 0.0772 - val_root_mean_squared_error: 0.1116 - val_RMSE_P: 1125.3914 - val_RMSE_T: 40.7048
# Epoch 276/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0114 - mean_absolute_error: 0.0757 - root_mean_squared_error: 0.1067 - RMSE_P: 1082.6538 - RMSE_T: 39.3490 - val_loss: 0.0125 - val_mean_absolute_error: 0.0777 - val_root_mean_squared_error: 0.1116 - val_RMSE_P: 1127.3029 - val_RMSE_T: 40.9963
# Epoch 277/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0113 - mean_absolute_error: 0.0756 - root_mean_squared_error: 0.1065 - RMSE_P: 1059.2576 - RMSE_T: 39.9512 - val_loss: 0.0126 - val_mean_absolute_error: 0.0776 - val_root_mean_squared_error: 0.1121 - val_RMSE_P: 1130.0594 - val_RMSE_T: 41.0551
# Epoch 278/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0115 - mean_absolute_error: 0.0757 - root_mean_squared_error: 0.1074 - RMSE_P: 1076.9760 - RMSE_T: 39.4554 - val_loss: 0.0125 - val_mean_absolute_error: 0.0774 - val_root_mean_squared_error: 0.1119 - val_RMSE_P: 1126.0046 - val_RMSE_T: 41.1567
# Epoch 279/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0113 - mean_absolute_error: 0.0757 - root_mean_squared_error: 0.1064 - RMSE_P: 1071.0309 - RMSE_T: 39.9356 - val_loss: 0.0129 - val_mean_absolute_error: 0.0787 - val_root_mean_squared_error: 0.1134 - val_RMSE_P: 1135.5278 - val_RMSE_T: 42.1217
# Epoch 280/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0116 - mean_absolute_error: 0.0764 - root_mean_squared_error: 0.1078 - RMSE_P: 1086.0087 - RMSE_T: 39.7577 - val_loss: 0.0127 - val_mean_absolute_error: 0.0778 - val_root_mean_squared_error: 0.1129 - val_RMSE_P: 1139.0222 - val_RMSE_T: 41.0959
# Epoch 281/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0113 - mean_absolute_error: 0.0750 - root_mean_squared_error: 0.1061 - RMSE_P: 1067.3542 - RMSE_T: 39.8047 - val_loss: 0.0126 - val_mean_absolute_error: 0.0779 - val_root_mean_squared_error: 0.1122 - val_RMSE_P: 1136.5858 - val_RMSE_T: 40.9260
# Epoch 282/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0113 - mean_absolute_error: 0.0753 - root_mean_squared_error: 0.1064 - RMSE_P: 1065.2627 - RMSE_T: 40.2324 - val_loss: 0.0125 - val_mean_absolute_error: 0.0773 - val_root_mean_squared_error: 0.1119 - val_RMSE_P: 1132.1150 - val_RMSE_T: 40.7080
# Epoch 283/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0116 - mean_absolute_error: 0.0762 - root_mean_squared_error: 0.1078 - RMSE_P: 1094.5641 - RMSE_T: 39.8569 - val_loss: 0.0126 - val_mean_absolute_error: 0.0775 - val_root_mean_squared_error: 0.1123 - val_RMSE_P: 1134.9814 - val_RMSE_T: 40.8009
# Epoch 284/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0115 - mean_absolute_error: 0.0758 - root_mean_squared_error: 0.1072 - RMSE_P: 1081.4426 - RMSE_T: 39.8142 - val_loss: 0.0128 - val_mean_absolute_error: 0.0784 - val_root_mean_squared_error: 0.1133 - val_RMSE_P: 1145.0269 - val_RMSE_T: 41.1347
# Epoch 285/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0113 - mean_absolute_error: 0.0747 - root_mean_squared_error: 0.1062 - RMSE_P: 1062.2748 - RMSE_T: 39.0789 - val_loss: 0.0128 - val_mean_absolute_error: 0.0780 - val_root_mean_squared_error: 0.1130 - val_RMSE_P: 1147.3485 - val_RMSE_T: 40.7717
# Epoch 286/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0115 - mean_absolute_error: 0.0761 - root_mean_squared_error: 0.1071 - RMSE_P: 1085.7412 - RMSE_T: 39.2941 - val_loss: 0.0130 - val_mean_absolute_error: 0.0787 - val_root_mean_squared_error: 0.1140 - val_RMSE_P: 1146.1964 - val_RMSE_T: 41.6007
# Epoch 287/5000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0117 - mean_absolute_error: 0.0761 - root_mean_squared_error: 0.1081 - RMSE_P: 1094.7399 - RMSE_T: 39.1490 - val_loss: 0.0129 - val_mean_absolute_error: 0.0784 - val_root_mean_squared_error: 0.1137 - val_RMSE_P: 1140.4241 - val_RMSE_T: 41.5123
# Epoch 288/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0116 - mean_absolute_error: 0.0763 - root_mean_squared_error: 0.1078 - RMSE_P: 1088.2352 - RMSE_T: 40.2120 - val_loss: 0.0128 - val_mean_absolute_error: 0.0778 - val_root_mean_squared_error: 0.1131 - val_RMSE_P: 1140.1099 - val_RMSE_T: 41.0539
# Epoch 289/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0117 - mean_absolute_error: 0.0762 - root_mean_squared_error: 0.1080 - RMSE_P: 1088.9359 - RMSE_T: 40.0398 - val_loss: 0.0128 - val_mean_absolute_error: 0.0777 - val_root_mean_squared_error: 0.1132 - val_RMSE_P: 1140.5107 - val_RMSE_T: 41.1163
# Epoch 290/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0114 - mean_absolute_error: 0.0753 - root_mean_squared_error: 0.1067 - RMSE_P: 1079.3678 - RMSE_T: 39.3896 - val_loss: 0.0128 - val_mean_absolute_error: 0.0783 - val_root_mean_squared_error: 0.1132 - val_RMSE_P: 1139.6333 - val_RMSE_T: 41.4326
# Epoch 291/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0114 - mean_absolute_error: 0.0753 - root_mean_squared_error: 0.1065 - RMSE_P: 1072.8105 - RMSE_T: 39.5481 - val_loss: 0.0129 - val_mean_absolute_error: 0.0784 - val_root_mean_squared_error: 0.1134 - val_RMSE_P: 1142.4678 - val_RMSE_T: 41.3688
# Epoch 292/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0114 - mean_absolute_error: 0.0758 - root_mean_squared_error: 0.1068 - RMSE_P: 1075.4553 - RMSE_T: 39.8428 - val_loss: 0.0129 - val_mean_absolute_error: 0.0788 - val_root_mean_squared_error: 0.1137 - val_RMSE_P: 1144.1744 - val_RMSE_T: 41.6885
# Epoch 293/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0115 - mean_absolute_error: 0.0766 - root_mean_squared_error: 0.1070 - RMSE_P: 1072.9875 - RMSE_T: 40.9777 - val_loss: 0.0127 - val_mean_absolute_error: 0.0782 - val_root_mean_squared_error: 0.1129 - val_RMSE_P: 1142.4510 - val_RMSE_T: 40.9634
# Epoch 294/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0113 - mean_absolute_error: 0.0748 - root_mean_squared_error: 0.1061 - RMSE_P: 1061.2845 - RMSE_T: 39.3576 - val_loss: 0.0126 - val_mean_absolute_error: 0.0774 - val_root_mean_squared_error: 0.1122 - val_RMSE_P: 1132.1465 - val_RMSE_T: 40.9758
# Epoch 295/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0116 - mean_absolute_error: 0.0758 - root_mean_squared_error: 0.1075 - RMSE_P: 1089.5554 - RMSE_T: 39.3797 - val_loss: 0.0128 - val_mean_absolute_error: 0.0781 - val_root_mean_squared_error: 0.1133 - val_RMSE_P: 1141.3345 - val_RMSE_T: 41.4186
# Epoch 296/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0110 - mean_absolute_error: 0.0749 - root_mean_squared_error: 0.1049 - RMSE_P: 1046.0494 - RMSE_T: 40.1468 - val_loss: 0.0128 - val_mean_absolute_error: 0.0780 - val_root_mean_squared_error: 0.1130 - val_RMSE_P: 1142.6011 - val_RMSE_T: 41.2125
# Epoch 297/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0113 - mean_absolute_error: 0.0751 - root_mean_squared_error: 0.1063 - RMSE_P: 1068.2843 - RMSE_T: 39.8013 - val_loss: 0.0127 - val_mean_absolute_error: 0.0776 - val_root_mean_squared_error: 0.1129 - val_RMSE_P: 1140.8882 - val_RMSE_T: 40.9499
# Epoch 298/5000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0113 - mean_absolute_error: 0.0751 - root_mean_squared_error: 0.1065 - RMSE_P: 1069.9662 - RMSE_T: 40.4510 - val_loss: 0.0127 - val_mean_absolute_error: 0.0778 - val_root_mean_squared_error: 0.1128 - val_RMSE_P: 1140.1323 - val_RMSE_T: 41.0411
# INFO:tensorflow:Assets written to: saved_models\k_ds62_4\assets
# INFO:tensorflow:Assets written to: saved_models\k_ds62_4\assets

# %% [markdown]
# # Plot training curves

# %%
plot_multiple_training_curves(["k_ds62_0.log", "k_ds62_1.log", "k_ds62_2.log", "k_ds62_3.log", "k_ds62_4.log"],
                              colors=sns.color_palette("Reds", 5), label="model", log_scale=True, ylims=[None, (10, 100), (100, 2500)])
# Out:
# (<Figure size 1200x400 with 3 Axes>,
#  array([<Axes: xlabel='Epoch', ylabel='Loss'>,
#         <Axes: xlabel='Epoch', ylabel='Temperature RMSE [K]'>,
#         <Axes: xlabel='Epoch', ylabel='Pressure RMSE [bar]'>], dtype=object))
