# %%
import seaborn as sns
from pathlib import Path

from ml_tb.plot import plot_hyperparameter_test

# %%
fig, axs = plot_hyperparameter_test(log_files=[Path("..", "01_fit_natural_biotite", "logs/AA_k_MnFMAST_2.log"),
                                    "logs/Transfer_technique_feature_extraction.log",
                                    "logs/Transfer_technique_finetune_noreg.log",
                                    "logs/Transfer_technique_finetune_all.log",
                                    "logs/Transfer_technique_finetune_last2.log",
                                    "logs/Transfer_technique_finetune_last.log",
                                    "logs/Transfer_technique_finetune_l2.log"],
                                    colors=["black"] + sns.color_palette("deep", 6),
                                    labels=["No transfer baseline", "feature extraction", "finetune_no_reg", "finetune_all", "finetune_last2", "finetunelast", "finetune_l2"],
                                    # xlims=[None, (10, 500), (10, 500)],
                                    ylims=[None, (10, 80), (50, 2000)],
                                    log_scale=True)

# fig.savefig(Path("transfer_technique.pdf"), dpi=400)
