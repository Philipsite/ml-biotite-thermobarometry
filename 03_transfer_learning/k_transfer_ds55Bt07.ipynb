# %% [markdown]
# :warning:**IMPORTANT NOTICE**:warning:\
# *Since the initial parameterisation and gradient descent optimisation are stochastic processes, the training of a neural network is not fully reproducible.*
#
# *Therefore, it is not recommended to re-run this script as it will overwrite the original calibration of the neural network used in the work presented here.
# The purpose of this script is solely to document the training procedure and can be copied as a template to fit other new neural networks.*
#
# *To experiment with the models calibrated here, they can be loaded from the `saved_models` directory.*

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf

from pathlib import Path
from keras.models import Model, Sequential, load_model, clone_model
from keras.layers import Dense, Normalization, Input, Dropout
from keras.losses import MeanSquaredError
from keras.optimizers import Adam, schedules
from keras.metrics import MeanAbsoluteError, RootMeanSquaredError
from keras.callbacks import CSVLogger, EarlyStopping

from ml_tb.normalisation import MinMaxScaler
from ml_tb.metrics import RMSE_denormalised_P, RMSE_denormalised_T
from ml_tb.plot import plot_multiple_training_curves
# Out:
# C:\Users\ThinkPad\AppData\Local\Temp\ipykernel_12948\1129355832.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# WARNING:tensorflow:From c:\Users\ThinkPad\miniconda3\envs\masterproject\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# ## Load validation datasets

# %%
# Load the data
val_data_dir = Path("..", "01_fit_natural_biotite", "kfold_datasets")

DATA_train_0 = np.loadtxt(Path(val_data_dir, "train_data_0.csv"), delimiter=",")
DATA_val_0 = np.loadtxt(Path(val_data_dir, "test_data_0.csv"), delimiter=",")

DATA_train_1 = np.loadtxt(Path(val_data_dir, "train_data_1.csv"), delimiter=",")
DATA_val_1 = np.loadtxt(Path(val_data_dir, "test_data_1.csv"), delimiter=",")

DATA_train_2 = np.loadtxt(Path(val_data_dir, "train_data_2.csv"), delimiter=",")
DATA_val_2 = np.loadtxt(Path(val_data_dir, "test_data_2.csv"), delimiter=",")

DATA_train_3 = np.loadtxt(Path(val_data_dir, "train_data_3.csv"), delimiter=",")
DATA_val_3 = np.loadtxt(Path(val_data_dir, "test_data_3.csv"), delimiter=",")

DATA_train_4 = np.loadtxt(Path(val_data_dir, "train_data_4.csv"), delimiter=",")
DATA_val_4 = np.loadtxt(Path(val_data_dir, "test_data_4.csv"), delimiter=",")

train_data_list = [DATA_train_0, DATA_train_1, DATA_train_2, DATA_train_3, DATA_train_4]
val_data_list = [DATA_val_0, DATA_val_1, DATA_val_2, DATA_val_3, DATA_val_4]

# %% [markdown]
# ## Set-up global training parameters
#
# Define a function to calculate RMSE for pressure and temperature for unscaled values to have an interpretable metric.

# %%
scaling_pt = MinMaxScaler(min=[1500, 400], max=[10000, 900], axis=0)
inv_scaling_pt = MinMaxScaler(min=[1500, 400], max=[10000, 900], axis=0, invert=True)

def RMSE_P(y_true, y_pred):
    return RMSE_denormalised_P(y_true, y_pred, inv_scaling_pt)


def RMSE_T(y_true, y_pred):
    return RMSE_denormalised_T(y_true, y_pred, inv_scaling_pt)
# Out:
# WARNING:tensorflow:From c:\Users\ThinkPad\miniconda3\envs\masterproject\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
CALLBACKS_0 = [CSVLogger("k_ds55Bt07_0.log"), EarlyStopping(monitor="val_loss", patience=50, restore_best_weights=True)]
CALLBACKS_1 = [CSVLogger("k_ds55Bt07_1.log"), EarlyStopping(monitor="val_loss", patience=50, restore_best_weights=True)]
CALLBACKS_2 = [CSVLogger("k_ds55Bt07_2.log"), EarlyStopping(monitor="val_loss", patience=50, restore_best_weights=True)]
CALLBACKS_3 = [CSVLogger("k_ds55Bt07_3.log"), EarlyStopping(monitor="val_loss", patience=50, restore_best_weights=True)]
CALLBACKS_4 = [CSVLogger("k_ds55Bt07_4.log"), EarlyStopping(monitor="val_loss", patience=50, restore_best_weights=True)]

callsbacks_list = [CALLBACKS_0, CALLBACKS_1, CALLBACKS_2, CALLBACKS_3, CALLBACKS_4]

# %% [markdown]
# ## Load pre-trained model

# %%
# load a saved model from "02_pretraining\saved_models\model_ds62White2014"
model_prior = load_model(Path("..","02_pretraining", "saved_models/model_ds55White2007"), compile=False)
# Out:
# WARNING:tensorflow:From c:\Users\ThinkPad\miniconda3\envs\masterproject\Lib\site-packages\keras\src\saving\legacy\saved_model\load.py:107: The name tf.gfile.Exists is deprecated. Please use tf.io.gfile.exists instead.
#
# WARNING:tensorflow:From c:\Users\ThinkPad\miniconda3\envs\masterproject\Lib\site-packages\keras\src\saving\legacy\saved_model\load.py:471: The name tf.logging.warning is deprecated. Please use tf.compat.v1.logging.warning instead.
#
# WARNING:tensorflow:Unable to restore custom metric. Please ensure that the layer implements `get_config` and `from_config` when saving. In addition, please use the `custom_objects` arg when calling `load_model()`.
# WARNING:tensorflow:Unable to restore custom metric. Please ensure that the layer implements `get_config` and `from_config` when saving. In addition, please use the `custom_objects` arg when calling `load_model()`.

# %%
# train loop

def train_model(DATA_train, DATA_val, CALLBACKS, model_name):
    # split up data
    data_train = DATA_train[:, 0:6]
    data_val = DATA_val[:, 0:6]

    pt_train = DATA_train[:, -2:]
    pt_val = DATA_val[:, -2:]

    # NORMALISATION
    normalisation_biotite_composition = Normalization(axis=-1)
    normalisation_biotite_composition.adapt(data_train)

    # SCALING of PT
    pt_train_norm = scaling_pt(pt_train)
    pt_val_norm = scaling_pt(pt_val)

    # SET TRAINING PARAMETERS
    BATCH_SIZE = 50
    STEPS_PER_EPOCH = len(DATA_train_0) // BATCH_SIZE
    MAX_EPOCHS = 5000

    lr_schedule = schedules.InverseTimeDecay(0.0005, decay_steps=STEPS_PER_EPOCH*1000, decay_rate=1, staircase=False)

    LOSS = MeanSquaredError()
    METRICS = [MeanAbsoluteError(), RootMeanSquaredError(), RMSE_P, RMSE_T]
    OPT = Adam(lr_schedule)

    # build model
    model_prior_c = clone_model(model_prior, input_tensors=Input(shape=(6,)))

    model = Sequential()
    model.add(normalisation_biotite_composition)
    model.add(model_prior_c.layers[1])
    model.add(Dropout(0.2))
    model.add(model_prior_c.layers[2])
    model.add(Dropout(0.2))
    model.add(model_prior_c.layers[3])
    model.add(Dropout(0.2))
    model.add(model_prior_c.layers[4])
    model.add(model_prior_c.layers[5])
    model.compile(optimizer=OPT, loss=LOSS, metrics=METRICS)
    model.summary()

    # train model
    history = model.fit(data_train, pt_train_norm,
                        validation_data=(data_val, pt_val_norm),
                        batch_size=BATCH_SIZE,
                        epochs=MAX_EPOCHS,
                        callbacks=CALLBACKS)

    model.save(Path("saved_models", model_name))

# %%
model_name_list = ["k_ds55Bt07_0", "k_ds55Bt07_1", "k_ds55Bt07_2", "k_ds55Bt07_3", "k_ds55Bt07_4"]

for train_data, val_data, CALLBACKS, model_name in zip(train_data_list, val_data_list, callsbacks_list, model_name_list):
    train_model(train_data, val_data, CALLBACKS, model_name)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  normalization (Normalizati  (None, 6)                 13
#  on)
#
#  dense (Dense)               (None, 64)                448
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 64)                4160
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 64)                4160
#
#  dense_4 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 13071 (51.06 KB)
# Trainable params: 13058 (51.01 KB)
# Non-trainable params: 13 (56.00 Byte)
# _________________________________________________________________
# Epoch 1/5000
# WARNING:tensorflow:From c:\Users\ThinkPad\miniconda3\envs\masterproject\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\ThinkPad\miniconda3\envs\masterproject\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 35/35 [==============================] - 2s 10ms/step - loss: 0.0713 - mean_absolute_error: 0.2103 - root_mean_squared_error: 0.2671 - RMSE_P: 2208.1958 - RMSE_T: 132.0650 - val_loss: 0.0434 - val_mean_absolute_error: 0.1706 - val_root_mean_squared_error: 0.2084 - val_RMSE_P: 1841.2148 - val_RMSE_T: 98.0878
# Epoch 2/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0404 - mean_absolute_error: 0.1577 - root_mean_squared_error: 0.2009 - RMSE_P: 1767.1603 - RMSE_T: 94.5048 - val_loss: 0.0261 - val_mean_absolute_error: 0.1245 - val_root_mean_squared_error: 0.1614 - val_RMSE_P: 1494.1741 - val_RMSE_T: 71.0265
# Epoch 3/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0318 - mean_absolute_error: 0.1362 - root_mean_squared_error: 0.1782 - RMSE_P: 1610.2069 - RMSE_T: 81.0004 - val_loss: 0.0234 - val_mean_absolute_error: 0.1171 - val_root_mean_squared_error: 0.1528 - val_RMSE_P: 1379.7020 - val_RMSE_T: 70.1202
# Epoch 4/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0263 - mean_absolute_error: 0.1239 - root_mean_squared_error: 0.1622 - RMSE_P: 1497.8463 - RMSE_T: 72.0601 - val_loss: 0.0211 - val_mean_absolute_error: 0.1090 - val_root_mean_squared_error: 0.1451 - val_RMSE_P: 1342.4712 - val_RMSE_T: 64.5665
# Epoch 5/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0242 - mean_absolute_error: 0.1177 - root_mean_squared_error: 0.1557 - RMSE_P: 1455.4800 - RMSE_T: 67.3266 - val_loss: 0.0197 - val_mean_absolute_error: 0.1044 - val_root_mean_squared_error: 0.1404 - val_RMSE_P: 1319.2798 - val_RMSE_T: 61.0271
# Epoch 6/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0225 - mean_absolute_error: 0.1123 - root_mean_squared_error: 0.1499 - RMSE_P: 1417.9408 - RMSE_T: 64.5363 - val_loss: 0.0177 - val_mean_absolute_error: 0.0987 - val_root_mean_squared_error: 0.1330 - val_RMSE_P: 1264.4429 - val_RMSE_T: 56.8059
# Epoch 7/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0203 - mean_absolute_error: 0.1058 - root_mean_squared_error: 0.1423 - RMSE_P: 1369.5413 - RMSE_T: 59.1315 - val_loss: 0.0167 - val_mean_absolute_error: 0.0954 - val_root_mean_squared_error: 0.1294 - val_RMSE_P: 1244.2579 - val_RMSE_T: 54.1775
# Epoch 8/5000
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0195 - mean_absolute_error: 0.1041 - root_mean_squared_error: 0.1398 - RMSE_P: 1351.8446 - RMSE_T: 57.3127 - val_loss: 0.0161 - val_mean_absolute_error: 0.0927 - val_root_mean_squared_error: 0.1268 - val_RMSE_P: 1238.0526 - val_RMSE_T: 51.6156
# Epoch 9/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0191 - mean_absolute_error: 0.1020 - root_mean_squared_error: 0.1381 - RMSE_P: 1349.0735 - RMSE_T: 56.0186 - val_loss: 0.0165 - val_mean_absolute_error: 0.0943 - val_root_mean_squared_error: 0.1284 - val_RMSE_P: 1240.9847 - val_RMSE_T: 53.4820
# Epoch 10/5000
# 35/35 [==============================] - 0s 8ms/step - loss: 0.0192 - mean_absolute_error: 0.1025 - root_mean_squared_error: 0.1384 - RMSE_P: 1344.1169 - RMSE_T: 56.7443 - val_loss: 0.0163 - val_mean_absolute_error: 0.0931 - val_root_mean_squared_error: 0.1277 - val_RMSE_P: 1242.5426 - val_RMSE_T: 52.4814
# Epoch 11/5000
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0184 - mean_absolute_error: 0.0998 - root_mean_squared_error: 0.1355 - RMSE_P: 1339.6572 - RMSE_T: 53.9090 - val_loss: 0.0160 - val_mean_absolute_error: 0.0924 - val_root_mean_squared_error: 0.1265 - val_RMSE_P: 1237.4833 - val_RMSE_T: 51.5046
# Epoch 12/5000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0178 - mean_absolute_error: 0.0978 - root_mean_squared_error: 0.1334 - RMSE_P: 1307.6573 - RMSE_T: 52.1223 - val_loss: 0.0162 - val_mean_absolute_error: 0.0928 - val_root_mean_squared_error: 0.1272 - val_RMSE_P: 1240.0835 - val_RMSE_T: 52.1125
# Epoch 13/5000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0177 - mean_absolute_error: 0.0970 - root_mean_squared_error: 0.1329 - RMSE_P: 1308.5936 - RMSE_T: 52.5257 - val_loss: 0.0156 - val_mean_absolute_error: 0.0906 - val_root_mean_squared_error: 0.1248 - val_RMSE_P: 1231.3989 - val_RMSE_T: 49.8428
# Epoch 14/5000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0174 - mean_absolute_error: 0.0967 - root_mean_squared_error: 0.1318 - RMSE_P: 1307.8510 - RMSE_T: 51.7487 - val_loss: 0.0153 - val_mean_absolute_error: 0.0893 - val_root_mean_squared_error: 0.1237 - val_RMSE_P: 1231.5341 - val_RMSE_T: 48.6173
# Epoch 15/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0168 - mean_absolute_error: 0.0952 - root_mean_squared_error: 0.1297 - RMSE_P: 1280.4774 - RMSE_T: 51.6707 - val_loss: 0.0156 - val_mean_absolute_error: 0.0903 - val_root_mean_squared_error: 0.1251 - val_RMSE_P: 1230.4138 - val_RMSE_T: 50.4048
# Epoch 16/5000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0168 - mean_absolute_error: 0.0948 - root_mean_squared_error: 0.1298 - RMSE_P: 1304.4738 - RMSE_T: 49.0029 - val_loss: 0.0152 - val_mean_absolute_error: 0.0888 - val_root_mean_squared_error: 0.1231 - val_RMSE_P: 1223.5648 - val_RMSE_T: 48.6323
# Epoch 17/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0171 - mean_absolute_error: 0.0948 - root_mean_squared_error: 0.1308 - RMSE_P: 1287.4250 - RMSE_T: 50.6330 - val_loss: 0.0149 - val_mean_absolute_error: 0.0879 - val_root_mean_squared_error: 0.1219 - val_RMSE_P: 1208.0498 - val_RMSE_T: 48.3990
# Epoch 18/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0169 - mean_absolute_error: 0.0944 - root_mean_squared_error: 0.1301 - RMSE_P: 1295.5483 - RMSE_T: 50.1929 - val_loss: 0.0150 - val_mean_absolute_error: 0.0880 - val_root_mean_squared_error: 0.1225 - val_RMSE_P: 1210.2482 - val_RMSE_T: 48.8804
# Epoch 19/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0170 - mean_absolute_error: 0.0950 - root_mean_squared_error: 0.1303 - RMSE_P: 1269.1958 - RMSE_T: 52.0940 - val_loss: 0.0152 - val_mean_absolute_error: 0.0889 - val_root_mean_squared_error: 0.1234 - val_RMSE_P: 1207.8433 - val_RMSE_T: 50.0822
# Epoch 20/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0170 - mean_absolute_error: 0.0950 - root_mean_squared_error: 0.1305 - RMSE_P: 1286.8589 - RMSE_T: 50.9892 - val_loss: 0.0154 - val_mean_absolute_error: 0.0893 - val_root_mean_squared_error: 0.1240 - val_RMSE_P: 1209.4259 - val_RMSE_T: 50.7118
# Epoch 21/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0164 - mean_absolute_error: 0.0928 - root_mean_squared_error: 0.1280 - RMSE_P: 1275.0370 - RMSE_T: 50.0139 - val_loss: 0.0149 - val_mean_absolute_error: 0.0874 - val_root_mean_squared_error: 0.1221 - val_RMSE_P: 1210.1667 - val_RMSE_T: 48.3691
# Epoch 22/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0164 - mean_absolute_error: 0.0933 - root_mean_squared_error: 0.1282 - RMSE_P: 1287.8994 - RMSE_T: 48.5677 - val_loss: 0.0148 - val_mean_absolute_error: 0.0875 - val_root_mean_squared_error: 0.1217 - val_RMSE_P: 1207.0897 - val_RMSE_T: 48.0644
# Epoch 23/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0159 - mean_absolute_error: 0.0906 - root_mean_squared_error: 0.1262 - RMSE_P: 1274.7115 - RMSE_T: 47.6022 - val_loss: 0.0147 - val_mean_absolute_error: 0.0870 - val_root_mean_squared_error: 0.1212 - val_RMSE_P: 1205.6891 - val_RMSE_T: 47.5510
# Epoch 24/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0157 - mean_absolute_error: 0.0904 - root_mean_squared_error: 0.1252 - RMSE_P: 1250.8350 - RMSE_T: 47.8151 - val_loss: 0.0150 - val_mean_absolute_error: 0.0880 - val_root_mean_squared_error: 0.1224 - val_RMSE_P: 1216.4299 - val_RMSE_T: 48.1888
# Epoch 25/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0162 - mean_absolute_error: 0.0908 - root_mean_squared_error: 0.1272 - RMSE_P: 1282.6465 - RMSE_T: 48.3070 - val_loss: 0.0149 - val_mean_absolute_error: 0.0874 - val_root_mean_squared_error: 0.1222 - val_RMSE_P: 1206.1649 - val_RMSE_T: 48.6200
# Epoch 26/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0157 - mean_absolute_error: 0.0909 - root_mean_squared_error: 0.1255 - RMSE_P: 1261.8540 - RMSE_T: 47.6865 - val_loss: 0.0145 - val_mean_absolute_error: 0.0856 - val_root_mean_squared_error: 0.1203 - val_RMSE_P: 1202.8071 - val_RMSE_T: 46.6448
# Epoch 27/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0158 - mean_absolute_error: 0.0904 - root_mean_squared_error: 0.1258 - RMSE_P: 1252.1334 - RMSE_T: 47.3549 - val_loss: 0.0149 - val_mean_absolute_error: 0.0873 - val_root_mean_squared_error: 0.1220 - val_RMSE_P: 1203.5691 - val_RMSE_T: 48.7296
# Epoch 28/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0157 - mean_absolute_error: 0.0907 - root_mean_squared_error: 0.1255 - RMSE_P: 1263.1993 - RMSE_T: 46.8598 - val_loss: 0.0144 - val_mean_absolute_error: 0.0850 - val_root_mean_squared_error: 0.1198 - val_RMSE_P: 1202.3215 - val_RMSE_T: 46.1540
# Epoch 29/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0157 - mean_absolute_error: 0.0903 - root_mean_squared_error: 0.1255 - RMSE_P: 1260.1787 - RMSE_T: 47.2514 - val_loss: 0.0144 - val_mean_absolute_error: 0.0854 - val_root_mean_squared_error: 0.1198 - val_RMSE_P: 1199.5974 - val_RMSE_T: 46.4487
# Epoch 30/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0159 - mean_absolute_error: 0.0906 - root_mean_squared_error: 0.1261 - RMSE_P: 1276.0809 - RMSE_T: 47.1520 - val_loss: 0.0148 - val_mean_absolute_error: 0.0875 - val_root_mean_squared_error: 0.1215 - val_RMSE_P: 1196.1558 - val_RMSE_T: 48.8701
# Epoch 31/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0156 - mean_absolute_error: 0.0900 - root_mean_squared_error: 0.1248 - RMSE_P: 1256.3135 - RMSE_T: 46.5587 - val_loss: 0.0146 - val_mean_absolute_error: 0.0864 - val_root_mean_squared_error: 0.1207 - val_RMSE_P: 1198.7866 - val_RMSE_T: 47.6110
# Epoch 32/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0158 - mean_absolute_error: 0.0906 - root_mean_squared_error: 0.1258 - RMSE_P: 1271.0566 - RMSE_T: 47.0489 - val_loss: 0.0144 - val_mean_absolute_error: 0.0855 - val_root_mean_squared_error: 0.1201 - val_RMSE_P: 1204.2896 - val_RMSE_T: 46.3496
# Epoch 33/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0154 - mean_absolute_error: 0.0894 - root_mean_squared_error: 0.1242 - RMSE_P: 1255.1056 - RMSE_T: 46.4972 - val_loss: 0.0142 - val_mean_absolute_error: 0.0846 - val_root_mean_squared_error: 0.1193 - val_RMSE_P: 1196.1710 - val_RMSE_T: 46.0115
# Epoch 34/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0154 - mean_absolute_error: 0.0893 - root_mean_squared_error: 0.1240 - RMSE_P: 1253.3674 - RMSE_T: 46.3368 - val_loss: 0.0142 - val_mean_absolute_error: 0.0842 - val_root_mean_squared_error: 0.1191 - val_RMSE_P: 1190.8756 - val_RMSE_T: 46.2344
# Epoch 35/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0151 - mean_absolute_error: 0.0886 - root_mean_squared_error: 0.1227 - RMSE_P: 1234.9531 - RMSE_T: 45.3861 - val_loss: 0.0142 - val_mean_absolute_error: 0.0846 - val_root_mean_squared_error: 0.1192 - val_RMSE_P: 1188.4897 - val_RMSE_T: 46.6298
# Epoch 36/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0154 - mean_absolute_error: 0.0890 - root_mean_squared_error: 0.1240 - RMSE_P: 1256.1163 - RMSE_T: 45.8266 - val_loss: 0.0144 - val_mean_absolute_error: 0.0857 - val_root_mean_squared_error: 0.1201 - val_RMSE_P: 1187.1222 - val_RMSE_T: 47.8503
# Epoch 37/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0154 - mean_absolute_error: 0.0893 - root_mean_squared_error: 0.1241 - RMSE_P: 1256.3187 - RMSE_T: 46.1758 - val_loss: 0.0146 - val_mean_absolute_error: 0.0861 - val_root_mean_squared_error: 0.1210 - val_RMSE_P: 1194.7999 - val_RMSE_T: 48.2371
# Epoch 38/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0157 - mean_absolute_error: 0.0897 - root_mean_squared_error: 0.1252 - RMSE_P: 1258.1525 - RMSE_T: 46.7182 - val_loss: 0.0143 - val_mean_absolute_error: 0.0852 - val_root_mean_squared_error: 0.1196 - val_RMSE_P: 1185.2430 - val_RMSE_T: 47.3969
# Epoch 39/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0151 - mean_absolute_error: 0.0884 - root_mean_squared_error: 0.1229 - RMSE_P: 1247.4825 - RMSE_T: 45.7667 - val_loss: 0.0138 - val_mean_absolute_error: 0.0832 - val_root_mean_squared_error: 0.1177 - val_RMSE_P: 1179.6426 - val_RMSE_T: 45.4928
# Epoch 40/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0148 - mean_absolute_error: 0.0874 - root_mean_squared_error: 0.1215 - RMSE_P: 1226.1798 - RMSE_T: 45.7843 - val_loss: 0.0140 - val_mean_absolute_error: 0.0845 - val_root_mean_squared_error: 0.1185 - val_RMSE_P: 1181.1935 - val_RMSE_T: 46.4218
# Epoch 41/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0150 - mean_absolute_error: 0.0883 - root_mean_squared_error: 0.1224 - RMSE_P: 1231.8363 - RMSE_T: 45.5003 - val_loss: 0.0142 - val_mean_absolute_error: 0.0846 - val_root_mean_squared_error: 0.1190 - val_RMSE_P: 1189.7137 - val_RMSE_T: 46.2764
# Epoch 42/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0148 - mean_absolute_error: 0.0875 - root_mean_squared_error: 0.1215 - RMSE_P: 1228.3491 - RMSE_T: 45.8121 - val_loss: 0.0144 - val_mean_absolute_error: 0.0847 - val_root_mean_squared_error: 0.1200 - val_RMSE_P: 1193.5676 - val_RMSE_T: 47.1238
# Epoch 43/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0152 - mean_absolute_error: 0.0880 - root_mean_squared_error: 0.1233 - RMSE_P: 1255.2842 - RMSE_T: 45.4635 - val_loss: 0.0137 - val_mean_absolute_error: 0.0828 - val_root_mean_squared_error: 0.1171 - val_RMSE_P: 1175.5002 - val_RMSE_T: 45.1190
# Epoch 44/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0146 - mean_absolute_error: 0.0871 - root_mean_squared_error: 0.1210 - RMSE_P: 1231.4498 - RMSE_T: 43.8871 - val_loss: 0.0138 - val_mean_absolute_error: 0.0832 - val_root_mean_squared_error: 0.1177 - val_RMSE_P: 1178.4702 - val_RMSE_T: 45.4826
# Epoch 45/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0150 - mean_absolute_error: 0.0878 - root_mean_squared_error: 0.1225 - RMSE_P: 1235.6652 - RMSE_T: 45.3666 - val_loss: 0.0137 - val_mean_absolute_error: 0.0830 - val_root_mean_squared_error: 0.1171 - val_RMSE_P: 1172.0732 - val_RMSE_T: 45.3308
# Epoch 46/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0146 - mean_absolute_error: 0.0870 - root_mean_squared_error: 0.1210 - RMSE_P: 1234.3494 - RMSE_T: 44.6823 - val_loss: 0.0140 - val_mean_absolute_error: 0.0835 - val_root_mean_squared_error: 0.1184 - val_RMSE_P: 1186.8207 - val_RMSE_T: 45.7237
# Epoch 47/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0151 - mean_absolute_error: 0.0877 - root_mean_squared_error: 0.1229 - RMSE_P: 1243.1049 - RMSE_T: 45.4556 - val_loss: 0.0140 - val_mean_absolute_error: 0.0837 - val_root_mean_squared_error: 0.1182 - val_RMSE_P: 1180.2159 - val_RMSE_T: 46.0507
# Epoch 48/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0153 - mean_absolute_error: 0.0884 - root_mean_squared_error: 0.1235 - RMSE_P: 1258.5731 - RMSE_T: 45.4554 - val_loss: 0.0140 - val_mean_absolute_error: 0.0838 - val_root_mean_squared_error: 0.1184 - val_RMSE_P: 1182.1699 - val_RMSE_T: 46.0514
# Epoch 49/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0147 - mean_absolute_error: 0.0870 - root_mean_squared_error: 0.1212 - RMSE_P: 1218.8444 - RMSE_T: 45.8252 - val_loss: 0.0137 - val_mean_absolute_error: 0.0829 - val_root_mean_squared_error: 0.1171 - val_RMSE_P: 1173.8937 - val_RMSE_T: 45.2136
# Epoch 50/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0146 - mean_absolute_error: 0.0868 - root_mean_squared_error: 0.1209 - RMSE_P: 1224.1813 - RMSE_T: 44.5193 - val_loss: 0.0136 - val_mean_absolute_error: 0.0825 - val_root_mean_squared_error: 0.1165 - val_RMSE_P: 1168.7075 - val_RMSE_T: 44.8497
# Epoch 51/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0150 - mean_absolute_error: 0.0874 - root_mean_squared_error: 0.1226 - RMSE_P: 1242.6832 - RMSE_T: 44.8296 - val_loss: 0.0138 - val_mean_absolute_error: 0.0833 - val_root_mean_squared_error: 0.1173 - val_RMSE_P: 1169.8812 - val_RMSE_T: 45.7957
# Epoch 52/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0149 - mean_absolute_error: 0.0870 - root_mean_squared_error: 0.1220 - RMSE_P: 1233.6189 - RMSE_T: 45.2828 - val_loss: 0.0140 - val_mean_absolute_error: 0.0840 - val_root_mean_squared_error: 0.1184 - val_RMSE_P: 1176.2260 - val_RMSE_T: 46.6082
# Epoch 53/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0150 - mean_absolute_error: 0.0874 - root_mean_squared_error: 0.1226 - RMSE_P: 1250.3317 - RMSE_T: 45.0212 - val_loss: 0.0137 - val_mean_absolute_error: 0.0826 - val_root_mean_squared_error: 0.1170 - val_RMSE_P: 1171.4712 - val_RMSE_T: 45.1737
# Epoch 54/5000
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0151 - mean_absolute_error: 0.0878 - root_mean_squared_error: 0.1229 - RMSE_P: 1233.9277 - RMSE_T: 46.2085 - val_loss: 0.0136 - val_mean_absolute_error: 0.0827 - val_root_mean_squared_error: 0.1166 - val_RMSE_P: 1166.5015 - val_RMSE_T: 45.1957
# Epoch 55/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0145 - mean_absolute_error: 0.0862 - root_mean_squared_error: 0.1206 - RMSE_P: 1221.2220 - RMSE_T: 45.1235 - val_loss: 0.0140 - val_mean_absolute_error: 0.0840 - val_root_mean_squared_error: 0.1182 - val_RMSE_P: 1179.1523 - val_RMSE_T: 46.0864
# Epoch 56/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0145 - mean_absolute_error: 0.0863 - root_mean_squared_error: 0.1205 - RMSE_P: 1220.5006 - RMSE_T: 44.4403 - val_loss: 0.0137 - val_mean_absolute_error: 0.0832 - val_root_mean_squared_error: 0.1169 - val_RMSE_P: 1168.2501 - val_RMSE_T: 45.4764
# Epoch 57/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0147 - mean_absolute_error: 0.0870 - root_mean_squared_error: 0.1213 - RMSE_P: 1225.2603 - RMSE_T: 44.0837 - val_loss: 0.0135 - val_mean_absolute_error: 0.0824 - val_root_mean_squared_error: 0.1164 - val_RMSE_P: 1173.8970 - val_RMSE_T: 44.2095
# Epoch 58/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0144 - mean_absolute_error: 0.0852 - root_mean_squared_error: 0.1198 - RMSE_P: 1211.0801 - RMSE_T: 44.3062 - val_loss: 0.0139 - val_mean_absolute_error: 0.0838 - val_root_mean_squared_error: 0.1177 - val_RMSE_P: 1167.1821 - val_RMSE_T: 46.5021
# Epoch 59/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0143 - mean_absolute_error: 0.0859 - root_mean_squared_error: 0.1198 - RMSE_P: 1193.0963 - RMSE_T: 44.8764 - val_loss: 0.0135 - val_mean_absolute_error: 0.0826 - val_root_mean_squared_error: 0.1161 - val_RMSE_P: 1163.7798 - val_RMSE_T: 44.7150
# Epoch 60/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0142 - mean_absolute_error: 0.0844 - root_mean_squared_error: 0.1192 - RMSE_P: 1204.9384 - RMSE_T: 44.3030 - val_loss: 0.0135 - val_mean_absolute_error: 0.0822 - val_root_mean_squared_error: 0.1161 - val_RMSE_P: 1161.8763 - val_RMSE_T: 44.7824
# Epoch 61/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0143 - mean_absolute_error: 0.0853 - root_mean_squared_error: 0.1195 - RMSE_P: 1215.3512 - RMSE_T: 43.1698 - val_loss: 0.0134 - val_mean_absolute_error: 0.0823 - val_root_mean_squared_error: 0.1159 - val_RMSE_P: 1162.1733 - val_RMSE_T: 44.5247
# Epoch 62/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0145 - mean_absolute_error: 0.0857 - root_mean_squared_error: 0.1206 - RMSE_P: 1211.8264 - RMSE_T: 44.7383 - val_loss: 0.0136 - val_mean_absolute_error: 0.0826 - val_root_mean_squared_error: 0.1165 - val_RMSE_P: 1168.8745 - val_RMSE_T: 44.7500
# Epoch 63/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0142 - mean_absolute_error: 0.0850 - root_mean_squared_error: 0.1191 - RMSE_P: 1205.3142 - RMSE_T: 44.2992 - val_loss: 0.0136 - val_mean_absolute_error: 0.0826 - val_root_mean_squared_error: 0.1166 - val_RMSE_P: 1167.6351 - val_RMSE_T: 45.0846
# Epoch 64/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0143 - mean_absolute_error: 0.0854 - root_mean_squared_error: 0.1194 - RMSE_P: 1212.8905 - RMSE_T: 44.4808 - val_loss: 0.0137 - val_mean_absolute_error: 0.0822 - val_root_mean_squared_error: 0.1169 - val_RMSE_P: 1175.9966 - val_RMSE_T: 44.6454
# Epoch 65/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0140 - mean_absolute_error: 0.0839 - root_mean_squared_error: 0.1181 - RMSE_P: 1205.9108 - RMSE_T: 43.2261 - val_loss: 0.0138 - val_mean_absolute_error: 0.0831 - val_root_mean_squared_error: 0.1173 - val_RMSE_P: 1171.9655 - val_RMSE_T: 45.4821
# Epoch 66/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0145 - mean_absolute_error: 0.0860 - root_mean_squared_error: 0.1206 - RMSE_P: 1209.9318 - RMSE_T: 45.0409 - val_loss: 0.0136 - val_mean_absolute_error: 0.0824 - val_root_mean_squared_error: 0.1167 - val_RMSE_P: 1172.3149 - val_RMSE_T: 44.7689
# Epoch 67/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0142 - mean_absolute_error: 0.0854 - root_mean_squared_error: 0.1192 - RMSE_P: 1192.8894 - RMSE_T: 44.4209 - val_loss: 0.0133 - val_mean_absolute_error: 0.0817 - val_root_mean_squared_error: 0.1155 - val_RMSE_P: 1162.4137 - val_RMSE_T: 43.9831
# Epoch 68/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0139 - mean_absolute_error: 0.0844 - root_mean_squared_error: 0.1181 - RMSE_P: 1198.6569 - RMSE_T: 43.5553 - val_loss: 0.0133 - val_mean_absolute_error: 0.0818 - val_root_mean_squared_error: 0.1155 - val_RMSE_P: 1163.9208 - val_RMSE_T: 43.8314
# Epoch 69/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0142 - mean_absolute_error: 0.0844 - root_mean_squared_error: 0.1191 - RMSE_P: 1203.4288 - RMSE_T: 43.5893 - val_loss: 0.0133 - val_mean_absolute_error: 0.0815 - val_root_mean_squared_error: 0.1153 - val_RMSE_P: 1161.2837 - val_RMSE_T: 43.8711
# Epoch 70/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0139 - mean_absolute_error: 0.0843 - root_mean_squared_error: 0.1179 - RMSE_P: 1185.3768 - RMSE_T: 43.7574 - val_loss: 0.0134 - val_mean_absolute_error: 0.0817 - val_root_mean_squared_error: 0.1156 - val_RMSE_P: 1162.2563 - val_RMSE_T: 44.1051
# Epoch 71/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0144 - mean_absolute_error: 0.0858 - root_mean_squared_error: 0.1199 - RMSE_P: 1209.4637 - RMSE_T: 43.7161 - val_loss: 0.0134 - val_mean_absolute_error: 0.0821 - val_root_mean_squared_error: 0.1159 - val_RMSE_P: 1160.8807 - val_RMSE_T: 44.6367
# Epoch 72/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0141 - mean_absolute_error: 0.0843 - root_mean_squared_error: 0.1189 - RMSE_P: 1197.0752 - RMSE_T: 44.3835 - val_loss: 0.0134 - val_mean_absolute_error: 0.0820 - val_root_mean_squared_error: 0.1157 - val_RMSE_P: 1163.0181 - val_RMSE_T: 44.1997
# Epoch 73/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0140 - mean_absolute_error: 0.0840 - root_mean_squared_error: 0.1184 - RMSE_P: 1208.8558 - RMSE_T: 43.0146 - val_loss: 0.0136 - val_mean_absolute_error: 0.0825 - val_root_mean_squared_error: 0.1166 - val_RMSE_P: 1165.5559 - val_RMSE_T: 45.2350
# Epoch 74/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0138 - mean_absolute_error: 0.0836 - root_mean_squared_error: 0.1175 - RMSE_P: 1182.7987 - RMSE_T: 44.0920 - val_loss: 0.0133 - val_mean_absolute_error: 0.0820 - val_root_mean_squared_error: 0.1155 - val_RMSE_P: 1162.5886 - val_RMSE_T: 43.9661
# Epoch 75/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0139 - mean_absolute_error: 0.0846 - root_mean_squared_error: 0.1181 - RMSE_P: 1193.0382 - RMSE_T: 43.1984 - val_loss: 0.0135 - val_mean_absolute_error: 0.0825 - val_root_mean_squared_error: 0.1162 - val_RMSE_P: 1161.2823 - val_RMSE_T: 44.9675
# Epoch 76/5000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0139 - mean_absolute_error: 0.0840 - root_mean_squared_error: 0.1177 - RMSE_P: 1199.9471 - RMSE_T: 44.0477 - val_loss: 0.0137 - val_mean_absolute_error: 0.0825 - val_root_mean_squared_error: 0.1169 - val_RMSE_P: 1166.4757 - val_RMSE_T: 45.3478
# Epoch 77/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0137 - mean_absolute_error: 0.0835 - root_mean_squared_error: 0.1171 - RMSE_P: 1189.8990 - RMSE_T: 43.1461 - val_loss: 0.0135 - val_mean_absolute_error: 0.0819 - val_root_mean_squared_error: 0.1162 - val_RMSE_P: 1168.4253 - val_RMSE_T: 44.3383
# Epoch 78/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0137 - mean_absolute_error: 0.0829 - root_mean_squared_error: 0.1172 - RMSE_P: 1193.3715 - RMSE_T: 42.9705 - val_loss: 0.0136 - val_mean_absolute_error: 0.0826 - val_root_mean_squared_error: 0.1164 - val_RMSE_P: 1169.0317 - val_RMSE_T: 44.4966
# Epoch 79/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0140 - mean_absolute_error: 0.0836 - root_mean_squared_error: 0.1182 - RMSE_P: 1206.1962 - RMSE_T: 42.5199 - val_loss: 0.0139 - val_mean_absolute_error: 0.0836 - val_root_mean_squared_error: 0.1178 - val_RMSE_P: 1176.1509 - val_RMSE_T: 45.6421
# Epoch 80/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0140 - mean_absolute_error: 0.0843 - root_mean_squared_error: 0.1182 - RMSE_P: 1195.0093 - RMSE_T: 44.0001 - val_loss: 0.0138 - val_mean_absolute_error: 0.0831 - val_root_mean_squared_error: 0.1174 - val_RMSE_P: 1179.2914 - val_RMSE_T: 44.9638
# Epoch 81/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0141 - mean_absolute_error: 0.0839 - root_mean_squared_error: 0.1187 - RMSE_P: 1193.5101 - RMSE_T: 43.8472 - val_loss: 0.0136 - val_mean_absolute_error: 0.0828 - val_root_mean_squared_error: 0.1165 - val_RMSE_P: 1168.3468 - val_RMSE_T: 44.7447
# Epoch 82/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0143 - mean_absolute_error: 0.0851 - root_mean_squared_error: 0.1194 - RMSE_P: 1211.2728 - RMSE_T: 43.9303 - val_loss: 0.0136 - val_mean_absolute_error: 0.0828 - val_root_mean_squared_error: 0.1166 - val_RMSE_P: 1166.7959 - val_RMSE_T: 45.0307
# Epoch 83/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0140 - mean_absolute_error: 0.0841 - root_mean_squared_error: 0.1184 - RMSE_P: 1199.3165 - RMSE_T: 43.5511 - val_loss: 0.0135 - val_mean_absolute_error: 0.0826 - val_root_mean_squared_error: 0.1164 - val_RMSE_P: 1169.6012 - val_RMSE_T: 44.4285
# Epoch 84/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0137 - mean_absolute_error: 0.0840 - root_mean_squared_error: 0.1169 - RMSE_P: 1187.7490 - RMSE_T: 43.3802 - val_loss: 0.0138 - val_mean_absolute_error: 0.0832 - val_root_mean_squared_error: 0.1175 - val_RMSE_P: 1174.2423 - val_RMSE_T: 45.4902
# Epoch 85/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0137 - mean_absolute_error: 0.0835 - root_mean_squared_error: 0.1173 - RMSE_P: 1185.7046 - RMSE_T: 43.4590 - val_loss: 0.0135 - val_mean_absolute_error: 0.0818 - val_root_mean_squared_error: 0.1161 - val_RMSE_P: 1167.1794 - val_RMSE_T: 44.2421
# Epoch 86/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0137 - mean_absolute_error: 0.0832 - root_mean_squared_error: 0.1171 - RMSE_P: 1190.4528 - RMSE_T: 43.9380 - val_loss: 0.0135 - val_mean_absolute_error: 0.0823 - val_root_mean_squared_error: 0.1163 - val_RMSE_P: 1165.3282 - val_RMSE_T: 44.7192
# Epoch 87/5000
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0135 - mean_absolute_error: 0.0830 - root_mean_squared_error: 0.1163 - RMSE_P: 1175.4655 - RMSE_T: 41.9934 - val_loss: 0.0136 - val_mean_absolute_error: 0.0826 - val_root_mean_squared_error: 0.1165 - val_RMSE_P: 1166.6161 - val_RMSE_T: 44.8696
# Epoch 88/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0138 - mean_absolute_error: 0.0833 - root_mean_squared_error: 0.1177 - RMSE_P: 1194.3629 - RMSE_T: 42.6683 - val_loss: 0.0135 - val_mean_absolute_error: 0.0826 - val_root_mean_squared_error: 0.1163 - val_RMSE_P: 1167.0701 - val_RMSE_T: 44.5451
# Epoch 89/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0138 - mean_absolute_error: 0.0836 - root_mean_squared_error: 0.1174 - RMSE_P: 1194.8370 - RMSE_T: 43.1306 - val_loss: 0.0135 - val_mean_absolute_error: 0.0821 - val_root_mean_squared_error: 0.1163 - val_RMSE_P: 1170.6079 - val_RMSE_T: 44.2358
# Epoch 90/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0138 - mean_absolute_error: 0.0837 - root_mean_squared_error: 0.1176 - RMSE_P: 1181.5499 - RMSE_T: 43.8850 - val_loss: 0.0134 - val_mean_absolute_error: 0.0818 - val_root_mean_squared_error: 0.1155 - val_RMSE_P: 1163.6615 - val_RMSE_T: 43.8897
# Epoch 91/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0137 - mean_absolute_error: 0.0830 - root_mean_squared_error: 0.1170 - RMSE_P: 1202.1780 - RMSE_T: 42.6911 - val_loss: 0.0136 - val_mean_absolute_error: 0.0824 - val_root_mean_squared_error: 0.1166 - val_RMSE_P: 1176.4600 - val_RMSE_T: 44.2342
# Epoch 92/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0139 - mean_absolute_error: 0.0838 - root_mean_squared_error: 0.1179 - RMSE_P: 1200.1301 - RMSE_T: 42.9466 - val_loss: 0.0136 - val_mean_absolute_error: 0.0830 - val_root_mean_squared_error: 0.1168 - val_RMSE_P: 1173.2230 - val_RMSE_T: 44.7030
# Epoch 93/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0137 - mean_absolute_error: 0.0831 - root_mean_squared_error: 0.1172 - RMSE_P: 1183.2183 - RMSE_T: 42.4779 - val_loss: 0.0135 - val_mean_absolute_error: 0.0823 - val_root_mean_squared_error: 0.1162 - val_RMSE_P: 1174.6293 - val_RMSE_T: 43.7699
# Epoch 94/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0138 - mean_absolute_error: 0.0839 - root_mean_squared_error: 0.1173 - RMSE_P: 1192.9434 - RMSE_T: 43.1896 - val_loss: 0.0134 - val_mean_absolute_error: 0.0814 - val_root_mean_squared_error: 0.1160 - val_RMSE_P: 1168.4889 - val_RMSE_T: 43.9693
# Epoch 95/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0133 - mean_absolute_error: 0.0819 - root_mean_squared_error: 0.1151 - RMSE_P: 1168.9703 - RMSE_T: 42.4618 - val_loss: 0.0133 - val_mean_absolute_error: 0.0814 - val_root_mean_squared_error: 0.1153 - val_RMSE_P: 1165.7546 - val_RMSE_T: 43.2824
# Epoch 96/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0138 - mean_absolute_error: 0.0833 - root_mean_squared_error: 0.1174 - RMSE_P: 1186.6207 - RMSE_T: 43.6168 - val_loss: 0.0134 - val_mean_absolute_error: 0.0817 - val_root_mean_squared_error: 0.1158 - val_RMSE_P: 1166.5776 - val_RMSE_T: 43.9634
# Epoch 97/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0134 - mean_absolute_error: 0.0823 - root_mean_squared_error: 0.1158 - RMSE_P: 1168.2905 - RMSE_T: 42.1321 - val_loss: 0.0134 - val_mean_absolute_error: 0.0818 - val_root_mean_squared_error: 0.1157 - val_RMSE_P: 1165.2219 - val_RMSE_T: 43.9270
# Epoch 98/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0137 - mean_absolute_error: 0.0828 - root_mean_squared_error: 0.1170 - RMSE_P: 1196.2324 - RMSE_T: 42.1951 - val_loss: 0.0134 - val_mean_absolute_error: 0.0822 - val_root_mean_squared_error: 0.1156 - val_RMSE_P: 1166.0923 - val_RMSE_T: 43.7815
# Epoch 99/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0135 - mean_absolute_error: 0.0823 - root_mean_squared_error: 0.1160 - RMSE_P: 1176.4553 - RMSE_T: 42.2844 - val_loss: 0.0132 - val_mean_absolute_error: 0.0813 - val_root_mean_squared_error: 0.1151 - val_RMSE_P: 1162.2222 - val_RMSE_T: 43.3338
# Epoch 100/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0135 - mean_absolute_error: 0.0833 - root_mean_squared_error: 0.1162 - RMSE_P: 1167.1294 - RMSE_T: 43.3957 - val_loss: 0.0133 - val_mean_absolute_error: 0.0815 - val_root_mean_squared_error: 0.1153 - val_RMSE_P: 1161.8695 - val_RMSE_T: 43.7584
# Epoch 101/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0132 - mean_absolute_error: 0.0818 - root_mean_squared_error: 0.1149 - RMSE_P: 1169.2454 - RMSE_T: 42.8426 - val_loss: 0.0132 - val_mean_absolute_error: 0.0811 - val_root_mean_squared_error: 0.1150 - val_RMSE_P: 1160.0356 - val_RMSE_T: 43.4175
# Epoch 102/5000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0135 - mean_absolute_error: 0.0824 - root_mean_squared_error: 0.1164 - RMSE_P: 1185.1664 - RMSE_T: 42.5694 - val_loss: 0.0136 - val_mean_absolute_error: 0.0828 - val_root_mean_squared_error: 0.1167 - val_RMSE_P: 1166.6011 - val_RMSE_T: 45.1053
# Epoch 103/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0137 - mean_absolute_error: 0.0833 - root_mean_squared_error: 0.1169 - RMSE_P: 1172.6697 - RMSE_T: 44.0637 - val_loss: 0.0136 - val_mean_absolute_error: 0.0829 - val_root_mean_squared_error: 0.1166 - val_RMSE_P: 1162.1899 - val_RMSE_T: 45.3702
# Epoch 104/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0137 - mean_absolute_error: 0.0831 - root_mean_squared_error: 0.1172 - RMSE_P: 1176.2841 - RMSE_T: 43.4011 - val_loss: 0.0136 - val_mean_absolute_error: 0.0827 - val_root_mean_squared_error: 0.1165 - val_RMSE_P: 1161.0897 - val_RMSE_T: 45.3633
# Epoch 105/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0133 - mean_absolute_error: 0.0821 - root_mean_squared_error: 0.1152 - RMSE_P: 1162.3304 - RMSE_T: 42.9579 - val_loss: 0.0135 - val_mean_absolute_error: 0.0827 - val_root_mean_squared_error: 0.1160 - val_RMSE_P: 1168.8628 - val_RMSE_T: 44.0391
# Epoch 106/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0134 - mean_absolute_error: 0.0820 - root_mean_squared_error: 0.1157 - RMSE_P: 1180.7111 - RMSE_T: 42.9028 - val_loss: 0.0132 - val_mean_absolute_error: 0.0814 - val_root_mean_squared_error: 0.1149 - val_RMSE_P: 1162.6384 - val_RMSE_T: 43.2665
# Epoch 107/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0136 - mean_absolute_error: 0.0837 - root_mean_squared_error: 0.1168 - RMSE_P: 1181.2086 - RMSE_T: 42.8583 - val_loss: 0.0134 - val_mean_absolute_error: 0.0818 - val_root_mean_squared_error: 0.1157 - val_RMSE_P: 1166.8260 - val_RMSE_T: 43.8122
# Epoch 108/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0136 - mean_absolute_error: 0.0828 - root_mean_squared_error: 0.1166 - RMSE_P: 1190.7679 - RMSE_T: 42.4257 - val_loss: 0.0134 - val_mean_absolute_error: 0.0815 - val_root_mean_squared_error: 0.1158 - val_RMSE_P: 1167.5737 - val_RMSE_T: 44.0103
# Epoch 109/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0130 - mean_absolute_error: 0.0806 - root_mean_squared_error: 0.1139 - RMSE_P: 1165.7920 - RMSE_T: 41.7539 - val_loss: 0.0135 - val_mean_absolute_error: 0.0824 - val_root_mean_squared_error: 0.1161 - val_RMSE_P: 1163.4147 - val_RMSE_T: 44.7556
# Epoch 110/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0134 - mean_absolute_error: 0.0814 - root_mean_squared_error: 0.1158 - RMSE_P: 1175.5277 - RMSE_T: 42.5570 - val_loss: 0.0134 - val_mean_absolute_error: 0.0817 - val_root_mean_squared_error: 0.1157 - val_RMSE_P: 1164.6349 - val_RMSE_T: 44.1091
# Epoch 111/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0132 - mean_absolute_error: 0.0823 - root_mean_squared_error: 0.1151 - RMSE_P: 1172.3700 - RMSE_T: 42.7937 - val_loss: 0.0134 - val_mean_absolute_error: 0.0818 - val_root_mean_squared_error: 0.1158 - val_RMSE_P: 1166.3245 - val_RMSE_T: 44.0557
# Epoch 112/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0131 - mean_absolute_error: 0.0810 - root_mean_squared_error: 0.1144 - RMSE_P: 1153.6029 - RMSE_T: 41.8971 - val_loss: 0.0135 - val_mean_absolute_error: 0.0822 - val_root_mean_squared_error: 0.1162 - val_RMSE_P: 1171.5155 - val_RMSE_T: 44.1960
# Epoch 113/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0134 - mean_absolute_error: 0.0821 - root_mean_squared_error: 0.1159 - RMSE_P: 1170.6416 - RMSE_T: 42.5604 - val_loss: 0.0133 - val_mean_absolute_error: 0.0813 - val_root_mean_squared_error: 0.1155 - val_RMSE_P: 1167.4637 - val_RMSE_T: 43.5854
# Epoch 114/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0135 - mean_absolute_error: 0.0824 - root_mean_squared_error: 0.1162 - RMSE_P: 1174.3040 - RMSE_T: 42.6239 - val_loss: 0.0134 - val_mean_absolute_error: 0.0821 - val_root_mean_squared_error: 0.1159 - val_RMSE_P: 1168.6061 - val_RMSE_T: 43.9829
# Epoch 115/5000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0133 - mean_absolute_error: 0.0817 - root_mean_squared_error: 0.1152 - RMSE_P: 1169.4441 - RMSE_T: 42.5416 - val_loss: 0.0133 - val_mean_absolute_error: 0.0815 - val_root_mean_squared_error: 0.1154 - val_RMSE_P: 1165.1627 - val_RMSE_T: 43.6060
# Epoch 116/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0132 - mean_absolute_error: 0.0813 - root_mean_squared_error: 0.1149 - RMSE_P: 1163.5859 - RMSE_T: 42.8130 - val_loss: 0.0133 - val_mean_absolute_error: 0.0817 - val_root_mean_squared_error: 0.1155 - val_RMSE_P: 1163.4034 - val_RMSE_T: 43.7659
# Epoch 117/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0132 - mean_absolute_error: 0.0822 - root_mean_squared_error: 0.1149 - RMSE_P: 1170.5339 - RMSE_T: 41.5640 - val_loss: 0.0134 - val_mean_absolute_error: 0.0819 - val_root_mean_squared_error: 0.1156 - val_RMSE_P: 1163.0201 - val_RMSE_T: 43.9572
# Epoch 118/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0130 - mean_absolute_error: 0.0812 - root_mean_squared_error: 0.1138 - RMSE_P: 1159.8011 - RMSE_T: 41.3067 - val_loss: 0.0133 - val_mean_absolute_error: 0.0813 - val_root_mean_squared_error: 0.1152 - val_RMSE_P: 1168.0513 - val_RMSE_T: 43.0623
# Epoch 119/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0133 - mean_absolute_error: 0.0822 - root_mean_squared_error: 0.1154 - RMSE_P: 1172.7568 - RMSE_T: 41.4546 - val_loss: 0.0134 - val_mean_absolute_error: 0.0819 - val_root_mean_squared_error: 0.1157 - val_RMSE_P: 1165.3081 - val_RMSE_T: 43.9098
# Epoch 120/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0133 - mean_absolute_error: 0.0820 - root_mean_squared_error: 0.1154 - RMSE_P: 1174.5894 - RMSE_T: 41.9081 - val_loss: 0.0135 - val_mean_absolute_error: 0.0822 - val_root_mean_squared_error: 0.1163 - val_RMSE_P: 1167.5895 - val_RMSE_T: 44.5359
# Epoch 121/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0129 - mean_absolute_error: 0.0808 - root_mean_squared_error: 0.1137 - RMSE_P: 1153.5742 - RMSE_T: 42.2317 - val_loss: 0.0133 - val_mean_absolute_error: 0.0816 - val_root_mean_squared_error: 0.1154 - val_RMSE_P: 1165.7330 - val_RMSE_T: 43.5715
# Epoch 122/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0129 - mean_absolute_error: 0.0802 - root_mean_squared_error: 0.1134 - RMSE_P: 1149.9594 - RMSE_T: 41.5000 - val_loss: 0.0133 - val_mean_absolute_error: 0.0817 - val_root_mean_squared_error: 0.1155 - val_RMSE_P: 1165.2286 - val_RMSE_T: 43.7118
# Epoch 123/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0129 - mean_absolute_error: 0.0809 - root_mean_squared_error: 0.1138 - RMSE_P: 1159.2476 - RMSE_T: 41.7037 - val_loss: 0.0134 - val_mean_absolute_error: 0.0816 - val_root_mean_squared_error: 0.1157 - val_RMSE_P: 1164.3960 - val_RMSE_T: 44.0476
# Epoch 124/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0129 - mean_absolute_error: 0.0806 - root_mean_squared_error: 0.1136 - RMSE_P: 1146.3068 - RMSE_T: 42.0874 - val_loss: 0.0133 - val_mean_absolute_error: 0.0818 - val_root_mean_squared_error: 0.1153 - val_RMSE_P: 1158.2222 - val_RMSE_T: 44.0264
# Epoch 125/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0133 - mean_absolute_error: 0.0818 - root_mean_squared_error: 0.1153 - RMSE_P: 1191.4655 - RMSE_T: 41.3182 - val_loss: 0.0134 - val_mean_absolute_error: 0.0822 - val_root_mean_squared_error: 0.1160 - val_RMSE_P: 1165.9315 - val_RMSE_T: 44.2338
# Epoch 126/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0133 - mean_absolute_error: 0.0819 - root_mean_squared_error: 0.1154 - RMSE_P: 1169.4916 - RMSE_T: 42.1357 - val_loss: 0.0134 - val_mean_absolute_error: 0.0817 - val_root_mean_squared_error: 0.1157 - val_RMSE_P: 1165.7415 - val_RMSE_T: 43.9018
# Epoch 127/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0130 - mean_absolute_error: 0.0815 - root_mean_squared_error: 0.1140 - RMSE_P: 1159.4797 - RMSE_T: 41.9548 - val_loss: 0.0133 - val_mean_absolute_error: 0.0811 - val_root_mean_squared_error: 0.1153 - val_RMSE_P: 1164.3600 - val_RMSE_T: 43.4578
# Epoch 128/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0131 - mean_absolute_error: 0.0810 - root_mean_squared_error: 0.1142 - RMSE_P: 1158.2783 - RMSE_T: 41.9645 - val_loss: 0.0134 - val_mean_absolute_error: 0.0822 - val_root_mean_squared_error: 0.1157 - val_RMSE_P: 1163.1356 - val_RMSE_T: 44.1667
# Epoch 129/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0130 - mean_absolute_error: 0.0809 - root_mean_squared_error: 0.1140 - RMSE_P: 1160.0511 - RMSE_T: 42.0253 - val_loss: 0.0132 - val_mean_absolute_error: 0.0814 - val_root_mean_squared_error: 0.1149 - val_RMSE_P: 1158.3688 - val_RMSE_T: 43.6386
# Epoch 130/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0130 - mean_absolute_error: 0.0809 - root_mean_squared_error: 0.1140 - RMSE_P: 1149.4690 - RMSE_T: 41.3990 - val_loss: 0.0133 - val_mean_absolute_error: 0.0814 - val_root_mean_squared_error: 0.1151 - val_RMSE_P: 1159.1227 - val_RMSE_T: 43.7959
# Epoch 131/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0130 - mean_absolute_error: 0.0804 - root_mean_squared_error: 0.1141 - RMSE_P: 1150.0521 - RMSE_T: 42.0100 - val_loss: 0.0132 - val_mean_absolute_error: 0.0809 - val_root_mean_squared_error: 0.1148 - val_RMSE_P: 1156.1700 - val_RMSE_T: 43.6144
# Epoch 132/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0130 - mean_absolute_error: 0.0809 - root_mean_squared_error: 0.1141 - RMSE_P: 1153.5934 - RMSE_T: 42.3018 - val_loss: 0.0133 - val_mean_absolute_error: 0.0817 - val_root_mean_squared_error: 0.1154 - val_RMSE_P: 1153.3926 - val_RMSE_T: 44.6167
# Epoch 133/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0130 - mean_absolute_error: 0.0815 - root_mean_squared_error: 0.1140 - RMSE_P: 1153.5920 - RMSE_T: 41.8745 - val_loss: 0.0132 - val_mean_absolute_error: 0.0811 - val_root_mean_squared_error: 0.1151 - val_RMSE_P: 1155.1060 - val_RMSE_T: 43.9813
# Epoch 134/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0130 - mean_absolute_error: 0.0805 - root_mean_squared_error: 0.1140 - RMSE_P: 1158.5682 - RMSE_T: 41.7633 - val_loss: 0.0130 - val_mean_absolute_error: 0.0808 - val_root_mean_squared_error: 0.1142 - val_RMSE_P: 1148.2804 - val_RMSE_T: 43.5236
# Epoch 135/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0129 - mean_absolute_error: 0.0807 - root_mean_squared_error: 0.1134 - RMSE_P: 1139.2662 - RMSE_T: 42.0121 - val_loss: 0.0132 - val_mean_absolute_error: 0.0810 - val_root_mean_squared_error: 0.1148 - val_RMSE_P: 1154.5592 - val_RMSE_T: 43.7456
# Epoch 136/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0129 - mean_absolute_error: 0.0806 - root_mean_squared_error: 0.1136 - RMSE_P: 1150.8613 - RMSE_T: 41.9709 - val_loss: 0.0133 - val_mean_absolute_error: 0.0814 - val_root_mean_squared_error: 0.1151 - val_RMSE_P: 1157.7316 - val_RMSE_T: 43.8853
# Epoch 137/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0124 - mean_absolute_error: 0.0796 - root_mean_squared_error: 0.1115 - RMSE_P: 1139.3668 - RMSE_T: 41.1142 - val_loss: 0.0132 - val_mean_absolute_error: 0.0814 - val_root_mean_squared_error: 0.1148 - val_RMSE_P: 1153.9841 - val_RMSE_T: 43.7346
# Epoch 138/5000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0128 - mean_absolute_error: 0.0806 - root_mean_squared_error: 0.1133 - RMSE_P: 1149.6608 - RMSE_T: 40.9918 - val_loss: 0.0132 - val_mean_absolute_error: 0.0811 - val_root_mean_squared_error: 0.1147 - val_RMSE_P: 1155.7339 - val_RMSE_T: 43.5795
# Epoch 139/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0128 - mean_absolute_error: 0.0804 - root_mean_squared_error: 0.1130 - RMSE_P: 1149.1713 - RMSE_T: 41.6472 - val_loss: 0.0133 - val_mean_absolute_error: 0.0818 - val_root_mean_squared_error: 0.1151 - val_RMSE_P: 1159.0198 - val_RMSE_T: 43.7716
# Epoch 140/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0127 - mean_absolute_error: 0.0804 - root_mean_squared_error: 0.1125 - RMSE_P: 1142.9330 - RMSE_T: 40.6963 - val_loss: 0.0133 - val_mean_absolute_error: 0.0815 - val_root_mean_squared_error: 0.1152 - val_RMSE_P: 1158.9131 - val_RMSE_T: 43.8591
# Epoch 141/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0129 - mean_absolute_error: 0.0808 - root_mean_squared_error: 0.1134 - RMSE_P: 1144.1302 - RMSE_T: 42.8076 - val_loss: 0.0131 - val_mean_absolute_error: 0.0809 - val_root_mean_squared_error: 0.1146 - val_RMSE_P: 1152.5544 - val_RMSE_T: 43.6694
# Epoch 142/5000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0128 - mean_absolute_error: 0.0801 - root_mean_squared_error: 0.1131 - RMSE_P: 1144.3800 - RMSE_T: 41.4884 - val_loss: 0.0132 - val_mean_absolute_error: 0.0815 - val_root_mean_squared_error: 0.1149 - val_RMSE_P: 1152.9767 - val_RMSE_T: 44.0656
# Epoch 143/5000
# ...
# Epoch 168/5000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0124 - mean_absolute_error: 0.0790 - root_mean_squared_error: 0.1114 - RMSE_P: 1135.7999 - RMSE_T: 41.0037 - val_loss: 0.0126 - val_mean_absolute_error: 0.0778 - val_root_mean_squared_error: 0.1121 - val_RMSE_P: 1124.0415 - val_RMSE_T: 41.8586
# Epoch 169/5000
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0124 - mean_absolute_error: 0.0796 - root_mean_squared_error: 0.1115 - RMSE_P: 1116.7257 - RMSE_T: 42.2831 - val_loss: 0.0127 - val_mean_absolute_error: 0.0785 - val_root_mean_squared_error: 0.1128 - val_RMSE_P: 1139.0044 - val_RMSE_T: 41.5345
# Epoch 170/5000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0126 - mean_absolute_error: 0.0795 - root_mean_squared_error: 0.1124 - RMSE_P: 1141.1860 - RMSE_T: 41.7576 - val_loss: 0.0127 - val_mean_absolute_error: 0.0783 - val_root_mean_squared_error: 0.1126 - val_RMSE_P: 1129.0739 - val_RMSE_T: 41.9532
# Epoch 171/5000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0128 - mean_absolute_error: 0.0805 - root_mean_squared_error: 0.1132 - RMSE_P: 1151.6840 - RMSE_T: 42.1971 - val_loss: 0.0125 - val_mean_absolute_error: 0.0776 - val_root_mean_squared_error: 0.1120 - val_RMSE_P: 1125.2411 - val_RMSE_T: 41.4735
# Epoch 172/5000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0125 - mean_absolute_error: 0.0798 - root_mean_squared_error: 0.1119 - RMSE_P: 1129.2467 - RMSE_T: 41.8004 - val_loss: 0.0124 - val_mean_absolute_error: 0.0773 - val_root_mean_squared_error: 0.1114 - val_RMSE_P: 1121.0981 - val_RMSE_T: 41.1815
# Epoch 173/5000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0125 - mean_absolute_error: 0.0793 - root_mean_squared_error: 0.1118 - RMSE_P: 1137.0928 - RMSE_T: 40.8462 - val_loss: 0.0126 - val_mean_absolute_error: 0.0783 - val_root_mean_squared_error: 0.1124 - val_RMSE_P: 1127.1838 - val_RMSE_T: 41.7778
# Epoch 174/5000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0127 - mean_absolute_error: 0.0801 - root_mean_squared_error: 0.1129 - RMSE_P: 1143.9972 - RMSE_T: 41.9448 - val_loss: 0.0127 - val_mean_absolute_error: 0.0783 - val_root_mean_squared_error: 0.1126 - val_RMSE_P: 1128.6307 - val_RMSE_T: 41.8334
# Epoch 175/5000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0126 - mean_absolute_error: 0.0800 - root_mean_squared_error: 0.1125 - RMSE_P: 1124.0546 - RMSE_T: 42.7336 - val_loss: 0.0128 - val_mean_absolute_error: 0.0788 - val_root_mean_squared_error: 0.1133 - val_RMSE_P: 1136.6493 - val_RMSE_T: 42.2028
# Epoch 176/5000
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0124 - mean_absolute_error: 0.0788 - root_mean_squared_error: 0.1114 - RMSE_P: 1123.6426 - RMSE_T: 41.0787 - val_loss: 0.0129 - val_mean_absolute_error: 0.0789 - val_root_mean_squared_error: 0.1135 - val_RMSE_P: 1147.9327 - val_RMSE_T: 41.6918
# Epoch 177/5000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0123 - mean_absolute_error: 0.0792 - root_mean_squared_error: 0.1109 - RMSE_P: 1124.3677 - RMSE_T: 41.5394 - val_loss: 0.0127 - val_mean_absolute_error: 0.0783 - val_root_mean_squared_error: 0.1125 - val_RMSE_P: 1135.0277 - val_RMSE_T: 41.2557
# Epoch 178/5000
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0125 - mean_absolute_error: 0.0789 - root_mean_squared_error: 0.1119 - RMSE_P: 1131.2640 - RMSE_T: 41.3971 - val_loss: 0.0125 - val_mean_absolute_error: 0.0775 - val_root_mean_squared_error: 0.1118 - val_RMSE_P: 1123.3827 - val_RMSE_T: 41.2453
# Epoch 179/5000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0127 - mean_absolute_error: 0.0805 - root_mean_squared_error: 0.1126 - RMSE_P: 1132.3331 - RMSE_T: 41.4670 - val_loss: 0.0127 - val_mean_absolute_error: 0.0781 - val_root_mean_squared_error: 0.1127 - val_RMSE_P: 1123.6602 - val_RMSE_T: 42.2088
# Epoch 180/5000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0124 - mean_absolute_error: 0.0791 - root_mean_squared_error: 0.1113 - RMSE_P: 1126.5674 - RMSE_T: 41.6204 - val_loss: 0.0127 - val_mean_absolute_error: 0.0785 - val_root_mean_squared_error: 0.1126 - val_RMSE_P: 1130.8837 - val_RMSE_T: 41.6673
# Epoch 181/5000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0126 - mean_absolute_error: 0.0794 - root_mean_squared_error: 0.1121 - RMSE_P: 1135.9215 - RMSE_T: 41.2435 - val_loss: 0.0126 - val_mean_absolute_error: 0.0784 - val_root_mean_squared_error: 0.1124 - val_RMSE_P: 1128.9342 - val_RMSE_T: 41.7036
# Epoch 182/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0126 - mean_absolute_error: 0.0795 - root_mean_squared_error: 0.1124 - RMSE_P: 1131.4792 - RMSE_T: 41.9372 - val_loss: 0.0125 - val_mean_absolute_error: 0.0781 - val_root_mean_squared_error: 0.1119 - val_RMSE_P: 1129.4056 - val_RMSE_T: 41.0505
# Epoch 183/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0125 - mean_absolute_error: 0.0791 - root_mean_squared_error: 0.1118 - RMSE_P: 1123.8076 - RMSE_T: 41.6953 - val_loss: 0.0125 - val_mean_absolute_error: 0.0778 - val_root_mean_squared_error: 0.1119 - val_RMSE_P: 1125.9854 - val_RMSE_T: 41.3482
# Epoch 184/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0124 - mean_absolute_error: 0.0788 - root_mean_squared_error: 0.1111 - RMSE_P: 1116.6592 - RMSE_T: 42.1551 - val_loss: 0.0126 - val_mean_absolute_error: 0.0777 - val_root_mean_squared_error: 0.1121 - val_RMSE_P: 1128.7369 - val_RMSE_T: 41.3730
# Epoch 185/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0124 - mean_absolute_error: 0.0783 - root_mean_squared_error: 0.1115 - RMSE_P: 1126.7363 - RMSE_T: 41.0882 - val_loss: 0.0127 - val_mean_absolute_error: 0.0786 - val_root_mean_squared_error: 0.1128 - val_RMSE_P: 1139.1289 - val_RMSE_T: 41.4852
# Epoch 186/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0125 - mean_absolute_error: 0.0790 - root_mean_squared_error: 0.1116 - RMSE_P: 1134.3950 - RMSE_T: 41.2396 - val_loss: 0.0126 - val_mean_absolute_error: 0.0780 - val_root_mean_squared_error: 0.1124 - val_RMSE_P: 1129.4685 - val_RMSE_T: 41.6542
# Epoch 187/5000
# 35/35 [==============================] - 0s 9ms/step - loss: 0.0124 - mean_absolute_error: 0.0793 - root_mean_squared_error: 0.1113 - RMSE_P: 1120.6483 - RMSE_T: 41.2351 - val_loss: 0.0126 - val_mean_absolute_error: 0.0780 - val_root_mean_squared_error: 0.1123 - val_RMSE_P: 1130.0356 - val_RMSE_T: 41.5266
# Epoch 188/5000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0126 - mean_absolute_error: 0.0793 - root_mean_squared_error: 0.1121 - RMSE_P: 1138.2029 - RMSE_T: 41.2412 - val_loss: 0.0128 - val_mean_absolute_error: 0.0788 - val_root_mean_squared_error: 0.1129 - val_RMSE_P: 1136.2942 - val_RMSE_T: 41.8888
# Epoch 189/5000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0120 - mean_absolute_error: 0.0780 - root_mean_squared_error: 0.1098 - RMSE_P: 1098.3381 - RMSE_T: 41.6676 - val_loss: 0.0127 - val_mean_absolute_error: 0.0781 - val_root_mean_squared_error: 0.1125 - val_RMSE_P: 1132.4333 - val_RMSE_T: 41.5323
# Epoch 190/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0123 - mean_absolute_error: 0.0788 - root_mean_squared_error: 0.1108 - RMSE_P: 1122.3412 - RMSE_T: 41.3807 - val_loss: 0.0128 - val_mean_absolute_error: 0.0781 - val_root_mean_squared_error: 0.1131 - val_RMSE_P: 1131.7554 - val_RMSE_T: 41.9801
# Epoch 191/5000
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0123 - mean_absolute_error: 0.0782 - root_mean_squared_error: 0.1111 - RMSE_P: 1115.6749 - RMSE_T: 40.9597 - val_loss: 0.0126 - val_mean_absolute_error: 0.0781 - val_root_mean_squared_error: 0.1123 - val_RMSE_P: 1133.6633 - val_RMSE_T: 41.1763
# Epoch 192/5000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0127 - mean_absolute_error: 0.0795 - root_mean_squared_error: 0.1125 - RMSE_P: 1131.0985 - RMSE_T: 42.2482 - val_loss: 0.0128 - val_mean_absolute_error: 0.0782 - val_root_mean_squared_error: 0.1129 - val_RMSE_P: 1129.2208 - val_RMSE_T: 42.0519
# Epoch 193/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0124 - mean_absolute_error: 0.0789 - root_mean_squared_error: 0.1116 - RMSE_P: 1127.6239 - RMSE_T: 41.4677 - val_loss: 0.0125 - val_mean_absolute_error: 0.0776 - val_root_mean_squared_error: 0.1120 - val_RMSE_P: 1128.7145 - val_RMSE_T: 41.1776
# Epoch 194/5000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0123 - mean_absolute_error: 0.0792 - root_mean_squared_error: 0.1111 - RMSE_P: 1119.5601 - RMSE_T: 41.3611 - val_loss: 0.0124 - val_mean_absolute_error: 0.0774 - val_root_mean_squared_error: 0.1116 - val_RMSE_P: 1125.3900 - val_RMSE_T: 40.9378
# Epoch 195/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0122 - mean_absolute_error: 0.0783 - root_mean_squared_error: 0.1103 - RMSE_P: 1112.1691 - RMSE_T: 40.2619 - val_loss: 0.0125 - val_mean_absolute_error: 0.0781 - val_root_mean_squared_error: 0.1118 - val_RMSE_P: 1131.8599 - val_RMSE_T: 40.8063
# Epoch 196/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0124 - mean_absolute_error: 0.0790 - root_mean_squared_error: 0.1113 - RMSE_P: 1124.4252 - RMSE_T: 41.8352 - val_loss: 0.0125 - val_mean_absolute_error: 0.0783 - val_root_mean_squared_error: 0.1119 - val_RMSE_P: 1126.4839 - val_RMSE_T: 41.4098
# Epoch 197/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0125 - mean_absolute_error: 0.0796 - root_mean_squared_error: 0.1119 - RMSE_P: 1140.9160 - RMSE_T: 41.3774 - val_loss: 0.0127 - val_mean_absolute_error: 0.0783 - val_root_mean_squared_error: 0.1127 - val_RMSE_P: 1126.5801 - val_RMSE_T: 42.1813
# Epoch 198/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0122 - mean_absolute_error: 0.0782 - root_mean_squared_error: 0.1103 - RMSE_P: 1112.6190 - RMSE_T: 41.2713 - val_loss: 0.0125 - val_mean_absolute_error: 0.0773 - val_root_mean_squared_error: 0.1119 - val_RMSE_P: 1128.9940 - val_RMSE_T: 40.9840
# Epoch 199/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0122 - mean_absolute_error: 0.0784 - root_mean_squared_error: 0.1104 - RMSE_P: 1098.2294 - RMSE_T: 41.3117 - val_loss: 0.0129 - val_mean_absolute_error: 0.0789 - val_root_mean_squared_error: 0.1135 - val_RMSE_P: 1140.1886 - val_RMSE_T: 42.1085
# Epoch 200/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0124 - mean_absolute_error: 0.0786 - root_mean_squared_error: 0.1113 - RMSE_P: 1135.7026 - RMSE_T: 41.5183 - val_loss: 0.0126 - val_mean_absolute_error: 0.0779 - val_root_mean_squared_error: 0.1124 - val_RMSE_P: 1130.7809 - val_RMSE_T: 41.4245
# Epoch 201/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0118 - mean_absolute_error: 0.0776 - root_mean_squared_error: 0.1088 - RMSE_P: 1102.7871 - RMSE_T: 40.8845 - val_loss: 0.0128 - val_mean_absolute_error: 0.0781 - val_root_mean_squared_error: 0.1130 - val_RMSE_P: 1141.3469 - val_RMSE_T: 41.3457
# Epoch 202/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0120 - mean_absolute_error: 0.0787 - root_mean_squared_error: 0.1096 - RMSE_P: 1102.6743 - RMSE_T: 41.2538 - val_loss: 0.0127 - val_mean_absolute_error: 0.0785 - val_root_mean_squared_error: 0.1127 - val_RMSE_P: 1135.7732 - val_RMSE_T: 41.4438
# Epoch 203/5000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0121 - mean_absolute_error: 0.0777 - root_mean_squared_error: 0.1100 - RMSE_P: 1117.6023 - RMSE_T: 40.7191 - val_loss: 0.0127 - val_mean_absolute_error: 0.0783 - val_root_mean_squared_error: 0.1128 - val_RMSE_P: 1128.1499 - val_RMSE_T: 42.1170
# Epoch 204/5000
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0124 - mean_absolute_error: 0.0790 - root_mean_squared_error: 0.1113 - RMSE_P: 1129.4380 - RMSE_T: 41.3006 - val_loss: 0.0129 - val_mean_absolute_error: 0.0786 - val_root_mean_squared_error: 0.1134 - val_RMSE_P: 1126.8776 - val_RMSE_T: 42.6580
# Epoch 205/5000
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0121 - mean_absolute_error: 0.0776 - root_mean_squared_error: 0.1101 - RMSE_P: 1113.8483 - RMSE_T: 40.5547 - val_loss: 0.0125 - val_mean_absolute_error: 0.0776 - val_root_mean_squared_error: 0.1119 - val_RMSE_P: 1127.5736 - val_RMSE_T: 41.0919
# Epoch 206/5000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0124 - mean_absolute_error: 0.0790 - root_mean_squared_error: 0.1111 - RMSE_P: 1116.4045 - RMSE_T: 41.6438 - val_loss: 0.0126 - val_mean_absolute_error: 0.0777 - val_root_mean_squared_error: 0.1121 - val_RMSE_P: 1126.4331 - val_RMSE_T: 41.2223
# Epoch 207/5000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0121 - mean_absolute_error: 0.0776 - root_mean_squared_error: 0.1099 - RMSE_P: 1102.7115 - RMSE_T: 40.6262 - val_loss: 0.0125 - val_mean_absolute_error: 0.0773 - val_root_mean_squared_error: 0.1118 - val_RMSE_P: 1127.1117 - val_RMSE_T: 40.9423
# Epoch 208/5000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0123 - mean_absolute_error: 0.0786 - root_mean_squared_error: 0.1109 - RMSE_P: 1125.1361 - RMSE_T: 41.5766 - val_loss: 0.0126 - val_mean_absolute_error: 0.0776 - val_root_mean_squared_error: 0.1122 - val_RMSE_P: 1127.1652 - val_RMSE_T: 41.3809
# Epoch 209/5000
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0119 - mean_absolute_error: 0.0777 - root_mean_squared_error: 0.1093 - RMSE_P: 1102.6541 - RMSE_T: 41.0934 - val_loss: 0.0127 - val_mean_absolute_error: 0.0780 - val_root_mean_squared_error: 0.1125 - val_RMSE_P: 1132.8385 - val_RMSE_T: 41.2689
# Epoch 210/5000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0120 - mean_absolute_error: 0.0775 - root_mean_squared_error: 0.1097 - RMSE_P: 1106.9135 - RMSE_T: 41.2120 - val_loss: 0.0127 - val_mean_absolute_error: 0.0778 - val_root_mean_squared_error: 0.1127 - val_RMSE_P: 1135.0853 - val_RMSE_T: 41.3698
# Epoch 211/5000
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0122 - mean_absolute_error: 0.0788 - root_mean_squared_error: 0.1106 - RMSE_P: 1109.3429 - RMSE_T: 41.4413 - val_loss: 0.0127 - val_mean_absolute_error: 0.0779 - val_root_mean_squared_error: 0.1125 - val_RMSE_P: 1132.0894 - val_RMSE_T: 41.3846
# Epoch 212/5000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0122 - mean_absolute_error: 0.0786 - root_mean_squared_error: 0.1105 - RMSE_P: 1114.5820 - RMSE_T: 41.2091 - val_loss: 0.0127 - val_mean_absolute_error: 0.0779 - val_root_mean_squared_error: 0.1125 - val_RMSE_P: 1134.5801 - val_RMSE_T: 41.2973
# Epoch 213/5000
# 35/35 [==============================] - 0s 7ms/step - loss: 0.0119 - mean_absolute_error: 0.0778 - root_mean_squared_error: 0.1092 - RMSE_P: 1103.4211 - RMSE_T: 40.9271 - val_loss: 0.0126 - val_mean_absolute_error: 0.0778 - val_root_mean_squared_error: 0.1122 - val_RMSE_P: 1127.7260 - val_RMSE_T: 41.4142
# Epoch 214/5000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0119 - mean_absolute_error: 0.0773 - root_mean_squared_error: 0.1091 - RMSE_P: 1102.0273 - RMSE_T: 39.9271 - val_loss: 0.0125 - val_mean_absolute_error: 0.0773 - val_root_mean_squared_error: 0.1119 - val_RMSE_P: 1127.3800 - val_RMSE_T: 41.1322
# Epoch 215/5000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0117 - mean_absolute_error: 0.0766 - root_mean_squared_error: 0.1082 - RMSE_P: 1099.5409 - RMSE_T: 39.5612 - val_loss: 0.0126 - val_mean_absolute_error: 0.0778 - val_root_mean_squared_error: 0.1124 - val_RMSE_P: 1128.9989 - val_RMSE_T: 41.6237
# Epoch 216/5000
# 35/35 [==============================] - 0s 7ms/step - loss: 0.0118 - mean_absolute_error: 0.0769 - root_mean_squared_error: 0.1085 - RMSE_P: 1099.4081 - RMSE_T: 40.2078 - val_loss: 0.0124 - val_mean_absolute_error: 0.0770 - val_root_mean_squared_error: 0.1114 - val_RMSE_P: 1123.0558 - val_RMSE_T: 40.9097
# INFO:tensorflow:Assets written to: saved_models\k_ds55Bt07_4\assets
# INFO:tensorflow:Assets written to: saved_models\k_ds55Bt07_4\assets

# %% [markdown]
# # Plot training curves

# %%
plot_multiple_training_curves(["k_ds55Bt07_0.log", "k_ds55Bt07_1.log", "k_ds55Bt07_2.log", "k_ds55Bt07_3.log", "k_ds55Bt07_4.log"],
                              colors=sns.color_palette("Reds", 5), label="model", log_scale=True, ylims=[None, (10, 100), (100, 2500)])
# Out:
# (<Figure size 1200x400 with 3 Axes>,
#  array([<Axes: xlabel='Epoch', ylabel='Loss'>,
#         <Axes: xlabel='Epoch', ylabel='Temperature RMSE [K]'>,
#         <Axes: xlabel='Epoch', ylabel='Pressure RMSE [bar]'>], dtype=object))
