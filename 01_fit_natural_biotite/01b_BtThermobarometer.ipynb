# %% [markdown]
# :warning:**IMPORTANT NOTICE**:warning:\
# *Since the initial parameterisation and gradient descent optimisation are stochastic processes, the training of a neural network is not fully reproducible.*
#
# *Therefore, it is not recommended to re-run this script as it will overwrite the original calibration of the neural network used in the work presented here.
# The purpose of this script is solely to document the training procedure and can be copied as a template to fit other new neural networks.*
#
# *To experiment with the models calibrated here, they can be loaded from the `saved_models` directory.*

# %% [markdown]
# # **Biotite Thermobarometer**: Direct fit on natural biotite composition data + Index minerals

# %% [markdown]
# This notebook is used for the final model fitting of a biotite thermobarometer based on bioite compositional data from the databse of Pattison & Forshaw (in prep.).\
# Additionally, index minerals in the biotite-bearing rocks are used as an input feature of the model. The following index minerals are considered: chlorite, garnet, cordierite, staurolite, andalusite, kyanite, sillimanite and k-feldspar.\
#
# Based on hyperparameter optimisation and feature engineering the following dataset and hyperparameters were selected:
#
# **Data**:\
# Elements [apfu] of the biotite solution models: Si, Ti, Al, Fe, Mg, Mn\
# Feature engineering showed no significant performance improvement when including Na & K
#
# Index minerals:\
# chlorite, garnet, cordierite, staurolite, andalusite, kyanite, sillimanite and k-feldspar\
# Feature engineering has shown no significant increase in performance including Fe-Ti minerals.
#
# *Normalisation*:
# - Normalisation of compositional input data [-1, 1], input normalisation parameters (mean + std) are learned from the training data.
# - One-hot encoding of index minerals, no normalisation required.
# - MinMaxScaler for target data (*P*-*T*) [0, 1], traget scaling parameters (min + max) are hard-coded to the range of the training data: *P* [1500, 10000] [bar] and *T* [400, 900] [°C].
#
# **Hyperparameters**:
# - Architecture: "huge" (3 hidden layer with 64 neurons), best validation performance for *T* and *P*
# - Learning rate: 0.001, all lr resulted in similar performance only training duration varied, 0.001 was chosen for faster training while keeping lr small\
# - Regularisation: Dropout layers (0.2)
#
# ⚠️ *Note*:\
# 2 models were tested for the final model fitting, based on the hyperparam tests:
# - A simple model with a (16) architecture and no additional regularization
# ---> This model performed statistically good, but predicted "outliers" (espiecially for *P*: negative predictions). Most likely it relied too much on certain mineral presence or absence.
# - A complex model with a (64, 64, 64) architecture and dropout layers
# --> we interpret that the additon of dropout layers helped to get rid of the "outliers" in the predictions.
#
#
# *Parameters not systematically tested*:
# - Activation function: "relu", not systematically tested, but no effect in exploratory tests
# - Optimizer: "adam"
# - Loss function: "mean_squared_error", given by regression task
# - Lr scheduler: Inverse time decay
# - Batch size: 50

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf

from pathlib import Path
from keras.models import Sequential
from keras.layers import Dense, Normalization, BatchNormalization, LayerNormalization, Dropout
from keras.losses import MeanSquaredError
from keras.optimizers import Adam, schedules
from keras.metrics import MeanAbsoluteError, RootMeanSquaredError
from keras.callbacks import CSVLogger, EarlyStopping
from sklearn.model_selection import train_test_split

from ml_tb.normalisation import MinMaxScaler
from ml_tb.metrics import rootmeansquarerror_temperature_denormalised, rootmeansquarerror_pressure_denormalised
from ml_tb.plot import plot_training_curve, prediction_vs_truth
# Out:
# C:\Users\ThinkPad\AppData\Local\Temp\ipykernel_16836\4009084104.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# WARNING:tensorflow:From c:\Users\ThinkPad\miniconda3\envs\masterproject\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# ## Import data, pre-procesing and train/test split
#
# Validation set is **10%** of the training set. Approx. 100 samples. Validation fraction is reduced to keep the training set as large as possible. Witht the set of hyperparameters obtained by hyperparameter optimisation, overfittings should be kept to a minimum.

# %%
VALIDATION_FRACTION = 0.1

# %% [markdown]
# Global scaling parameters for MinMaxScaling of the target data are hard-coded to the range of the training data.

# %%
scaling_pt = MinMaxScaler(min=[1500, 400], max=[10000, 900], axis=0)
inv_scaling_pt = MinMaxScaler(min=[1500, 400], max=[10000, 900], axis=0, invert=True)
# Out:
# WARNING:tensorflow:From c:\Users\ThinkPad\miniconda3\envs\masterproject\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
# load excel file
data = pd.read_excel(Path("Metapelite-Database_Bt_CLEAN_2024-02-03.xlsx"))

biotite_composition = np.zeros(shape=(len(data), 6))
biotite_composition[:, 0] = data["Bt-Si"]
biotite_composition[:, 1] = data["Bt-Ti"]
biotite_composition[:, 2] = data["Bt-Al"]
biotite_composition[:, 3] = data["Bt-FeTot"]
biotite_composition[:, 4] = data["Bt-Mn"]
biotite_composition[:, 5] = data["Bt-Mg"]

# extract one-hot encoded minerals in the following order: Chl, Grt, Crd, And, St, Ky, Sil, Kfs
index_minerals = np.zeros(shape=(len(data), 8))
index_minerals[:, 0] = data["Chl"]
index_minerals[:, 1] = data["Grt"]
index_minerals[:, 2] = data["Crd"]
index_minerals[:, 3] = data["And"]
index_minerals[:, 4] = data["St"]
index_minerals[:, 5] = data["Ky"]
index_minerals[:, 6] = data["Sil"]
index_minerals[:, 7] = data["Kfs"]

# Some minerals (Chl, Grt, St) have NaN values. Replace them with 0. Most likely samples with regional or metastable phases?!
index_minerals = np.nan_to_num(index_minerals, nan=0)

# combine biotite composition and one-hot encoded minerals
biotite_composition_idxmin = np.concatenate((biotite_composition, index_minerals), axis=1)

pt = np.zeros(shape=(len(data), 2))
pt[:, 0] = data["Pressure estimate random uniform"] * 1000 # convert to bar
pt[:, 1] = data["Temperature random ordered after Ti-in-Bt"]

# check for NaN values (should be already filtered out)
print("NaN values in biotite composition: ", np.isnan(biotite_composition_idxmin).any())
print("NaN values in PT: ", np.isnan(pt).any())
# Out:
# NaN values in biotite composition:  False
# NaN values in PT:  False

# %%
# test train split
data_train, data_val, pt_train, pt_val = train_test_split(biotite_composition_idxmin, pt, test_size=VALIDATION_FRACTION, shuffle=True)

# NORMALISATION
normalisation_biotite_composition = Normalization(axis=-1)
normalisation_biotite_composition.adapt(data_train)

# the one-hot encoded minerals should not be normalised. This is not necessary, as they are already in the range [0, 1]
# Set the mean and variance to 0 and 1, respectively
norm_mean = normalisation_biotite_composition.mean.numpy()
norm_mean[0,-8:] = 0
norm_var = normalisation_biotite_composition.variance.numpy()
norm_var[0,-8:] = 1
normalisation_biotite_composition.mean = tf.convert_to_tensor(norm_mean)
normalisation_biotite_composition.variance = tf.convert_to_tensor(norm_var)

print(normalisation_biotite_composition.mean.numpy())
print(np.sqrt(normalisation_biotite_composition.variance.numpy()))

# SCALING of PT
pt_train_norm = scaling_pt(pt_train)
pt_val_norm = scaling_pt(pt_val)

print("After scaling, the minimal values of P and T are: ", np.min(pt_train_norm, axis=0))
print("After scaling, the maximal values of P and T are: ", np.max(pt_train_norm, axis=0))
# Out:
# [[2.70771    0.12064927 1.7103409  1.2296611  0.00848337 1.0905079
#   0.         0.         0.         0.         0.         0.
#   0.         0.        ]]
# [[0.04726482 0.047674   0.09382845 0.22844881 0.00727573 0.2611914
#   1.         1.         1.         1.         1.         1.
#   1.         1.        ]]
# After scaling, the minimal values of P and T are:  [0.00010304 0.00066034]
# After scaling, the maximal values of P and T are:  [0.940462  0.8988128]

# %% [markdown]
# ## Set-up global training parameters
#
# Define a function to calculate RMSE for pressure and temperature for unscaled values to have an interpretable metric.

# %%
def RMSE_P(y_true, y_pred):
    return rootmeansquarerror_pressure_denormalised(y_true, y_pred, inv_scaling_pt)


def RMSE_T(y_true, y_pred):
    return rootmeansquarerror_temperature_denormalised(y_true, y_pred, inv_scaling_pt)

# %%
BATCH_SIZE = 50
STEPS_PER_EPOCH = len(data_train) // BATCH_SIZE
MAX_EPOCHS = 5000

lr_schedule = schedules.InverseTimeDecay(0.001, decay_steps=STEPS_PER_EPOCH*1000, decay_rate=1, staircase=False)

LOSS = MeanSquaredError()
METRICS = [MeanAbsoluteError(), RootMeanSquaredError(), RMSE_P, RMSE_T]
OPT = Adam(lr_schedule)

CALLBACKS = [CSVLogger("01b_BtThermobaromater_composition.log"), EarlyStopping(monitor="loss", patience=50, restore_best_weights=True)]

# %% [markdown]
# ### Build model

# %%
model = Sequential()
model.add(normalisation_biotite_composition)
model.add(Dense(64, activation="relu"))
model.add(Dropout(0.2))
model.add(Dense(64, activation="relu"))
model.add(Dropout(0.2))
model.add(Dense(64, activation="relu"))
model.add(Dropout(0.2))
model.add(Dense(2))

model.compile(optimizer=OPT, loss=LOSS, metrics=METRICS)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  normalization (Normalizati  (None, 14)                29
#  on)
#
#  dense (Dense)               (None, 64)                960
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 64)                4160
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 9439 (36.88 KB)
# Trainable params: 9410 (36.76 KB)
# Non-trainable params: 29 (120.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Train model

# %%
history = model.fit(data_train, pt_train_norm,
                    validation_data=(data_val, pt_val_norm),
                    batch_size=BATCH_SIZE,
                    epochs=MAX_EPOCHS,
                    callbacks=CALLBACKS)

model.save(Path("saved_models", "01b_BtThermobaromater_composition"))
# Out:
# Epoch 1/5000
# WARNING:tensorflow:From c:\Users\ThinkPad\miniconda3\envs\masterproject\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\ThinkPad\miniconda3\envs\masterproject\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 39/39 [==============================] - 2s 10ms/step - loss: 0.0667 - mean_absolute_error: 0.1979 - root_mean_squared_error: 0.2582 - RMSE_P: 1746.4897 - RMSE_T: 95.1649 - val_loss: 0.0204 - val_mean_absolute_error: 0.1052 - val_root_mean_squared_error: 0.1429 - val_RMSE_P: 953.5443 - val_RMSE_T: 49.1165
# Epoch 2/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0333 - mean_absolute_error: 0.1385 - root_mean_squared_error: 0.1824 - RMSE_P: 1188.9672 - RMSE_T: 68.5158 - val_loss: 0.0159 - val_mean_absolute_error: 0.0908 - val_root_mean_squared_error: 0.1259 - val_RMSE_P: 840.0996 - val_RMSE_T: 41.4311
# Epoch 3/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0235 - mean_absolute_error: 0.1169 - root_mean_squared_error: 0.1533 - RMSE_P: 1021.1570 - RMSE_T: 56.7926 - val_loss: 0.0155 - val_mean_absolute_error: 0.0895 - val_root_mean_squared_error: 0.1247 - val_RMSE_P: 774.3307 - val_RMSE_T: 43.9692
# Epoch 4/5000
# 39/39 [==============================] - 0s 4ms/step - loss: 0.0199 - mean_absolute_error: 0.1072 - root_mean_squared_error: 0.1411 - RMSE_P: 945.6024 - RMSE_T: 51.5391 - val_loss: 0.0131 - val_mean_absolute_error: 0.0812 - val_root_mean_squared_error: 0.1145 - val_RMSE_P: 754.1584 - val_RMSE_T: 36.8492
# Epoch 5/5000
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0184 - mean_absolute_error: 0.1020 - root_mean_squared_error: 0.1356 - RMSE_P: 909.3519 - RMSE_T: 48.5509 - val_loss: 0.0146 - val_mean_absolute_error: 0.0857 - val_root_mean_squared_error: 0.1208 - val_RMSE_P: 765.2321 - val_RMSE_T: 40.6664
# Epoch 6/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0165 - mean_absolute_error: 0.0965 - root_mean_squared_error: 0.1283 - RMSE_P: 869.6406 - RMSE_T: 45.3604 - val_loss: 0.0129 - val_mean_absolute_error: 0.0796 - val_root_mean_squared_error: 0.1134 - val_RMSE_P: 738.5757 - val_RMSE_T: 36.1189
# Epoch 7/5000
# 39/39 [==============================] - 0s 4ms/step - loss: 0.0154 - mean_absolute_error: 0.0925 - root_mean_squared_error: 0.1240 - RMSE_P: 845.5825 - RMSE_T: 42.7773 - val_loss: 0.0122 - val_mean_absolute_error: 0.0770 - val_root_mean_squared_error: 0.1105 - val_RMSE_P: 731.4882 - val_RMSE_T: 33.9302
# Epoch 8/5000
# 39/39 [==============================] - 0s 4ms/step - loss: 0.0149 - mean_absolute_error: 0.0905 - root_mean_squared_error: 0.1219 - RMSE_P: 845.4605 - RMSE_T: 40.7375 - val_loss: 0.0118 - val_mean_absolute_error: 0.0754 - val_root_mean_squared_error: 0.1085 - val_RMSE_P: 710.6187 - val_RMSE_T: 33.5881
# Epoch 9/5000
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0138 - mean_absolute_error: 0.0874 - root_mean_squared_error: 0.1174 - RMSE_P: 814.7659 - RMSE_T: 39.4247 - val_loss: 0.0115 - val_mean_absolute_error: 0.0740 - val_root_mean_squared_error: 0.1070 - val_RMSE_P: 701.7604 - val_RMSE_T: 32.7107
# Epoch 10/5000
# 39/39 [==============================] - 0s 4ms/step - loss: 0.0137 - mean_absolute_error: 0.0871 - root_mean_squared_error: 0.1168 - RMSE_P: 813.1283 - RMSE_T: 39.2481 - val_loss: 0.0114 - val_mean_absolute_error: 0.0737 - val_root_mean_squared_error: 0.1069 - val_RMSE_P: 701.2393 - val_RMSE_T: 32.4983
# Epoch 11/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0130 - mean_absolute_error: 0.0856 - root_mean_squared_error: 0.1140 - RMSE_P: 794.7316 - RMSE_T: 38.8866 - val_loss: 0.0108 - val_mean_absolute_error: 0.0725 - val_root_mean_squared_error: 0.1042 - val_RMSE_P: 693.2530 - val_RMSE_T: 31.7683
# Epoch 12/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0125 - mean_absolute_error: 0.0829 - root_mean_squared_error: 0.1116 - RMSE_P: 776.3819 - RMSE_T: 37.1835 - val_loss: 0.0111 - val_mean_absolute_error: 0.0739 - val_root_mean_squared_error: 0.1052 - val_RMSE_P: 691.3591 - val_RMSE_T: 33.2500
# Epoch 13/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0126 - mean_absolute_error: 0.0825 - root_mean_squared_error: 0.1121 - RMSE_P: 768.4243 - RMSE_T: 37.3386 - val_loss: 0.0107 - val_mean_absolute_error: 0.0717 - val_root_mean_squared_error: 0.1036 - val_RMSE_P: 688.4921 - val_RMSE_T: 31.1802
# Epoch 14/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0119 - mean_absolute_error: 0.0802 - root_mean_squared_error: 0.1090 - RMSE_P: 757.1603 - RMSE_T: 35.6620 - val_loss: 0.0112 - val_mean_absolute_error: 0.0731 - val_root_mean_squared_error: 0.1058 - val_RMSE_P: 687.8854 - val_RMSE_T: 32.5895
# Epoch 15/5000
# 39/39 [==============================] - 0s 4ms/step - loss: 0.0115 - mean_absolute_error: 0.0784 - root_mean_squared_error: 0.1073 - RMSE_P: 740.8226 - RMSE_T: 34.8467 - val_loss: 0.0112 - val_mean_absolute_error: 0.0724 - val_root_mean_squared_error: 0.1058 - val_RMSE_P: 685.7212 - val_RMSE_T: 32.0559
# Epoch 16/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0115 - mean_absolute_error: 0.0793 - root_mean_squared_error: 0.1074 - RMSE_P: 753.4912 - RMSE_T: 34.9499 - val_loss: 0.0104 - val_mean_absolute_error: 0.0697 - val_root_mean_squared_error: 0.1022 - val_RMSE_P: 676.3976 - val_RMSE_T: 29.8654
# Epoch 17/5000
# 39/39 [==============================] - 0s 4ms/step - loss: 0.0111 - mean_absolute_error: 0.0769 - root_mean_squared_error: 0.1053 - RMSE_P: 723.7806 - RMSE_T: 34.3444 - val_loss: 0.0099 - val_mean_absolute_error: 0.0683 - val_root_mean_squared_error: 0.0994 - val_RMSE_P: 662.4371 - val_RMSE_T: 29.3072
# Epoch 18/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0113 - mean_absolute_error: 0.0787 - root_mean_squared_error: 0.1061 - RMSE_P: 737.7198 - RMSE_T: 35.3136 - val_loss: 0.0103 - val_mean_absolute_error: 0.0699 - val_root_mean_squared_error: 0.1015 - val_RMSE_P: 669.2057 - val_RMSE_T: 30.5737
# Epoch 19/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0107 - mean_absolute_error: 0.0760 - root_mean_squared_error: 0.1034 - RMSE_P: 718.1454 - RMSE_T: 33.7964 - val_loss: 0.0100 - val_mean_absolute_error: 0.0682 - val_root_mean_squared_error: 0.0999 - val_RMSE_P: 662.5535 - val_RMSE_T: 29.2402
# Epoch 20/5000
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0105 - mean_absolute_error: 0.0754 - root_mean_squared_error: 0.1026 - RMSE_P: 718.8182 - RMSE_T: 33.0867 - val_loss: 0.0098 - val_mean_absolute_error: 0.0674 - val_root_mean_squared_error: 0.0990 - val_RMSE_P: 656.5408 - val_RMSE_T: 28.7345
# Epoch 21/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0105 - mean_absolute_error: 0.0748 - root_mean_squared_error: 0.1026 - RMSE_P: 709.1251 - RMSE_T: 33.0383 - val_loss: 0.0105 - val_mean_absolute_error: 0.0692 - val_root_mean_squared_error: 0.1027 - val_RMSE_P: 663.4961 - val_RMSE_T: 30.2080
# Epoch 22/5000
# 39/39 [==============================] - 0s 2ms/step - loss: 0.0105 - mean_absolute_error: 0.0750 - root_mean_squared_error: 0.1027 - RMSE_P: 719.4828 - RMSE_T: 32.6968 - val_loss: 0.0101 - val_mean_absolute_error: 0.0683 - val_root_mean_squared_error: 0.1006 - val_RMSE_P: 658.7421 - val_RMSE_T: 29.5369
# Epoch 23/5000
# 39/39 [==============================] - 0s 2ms/step - loss: 0.0105 - mean_absolute_error: 0.0751 - root_mean_squared_error: 0.1023 - RMSE_P: 713.9688 - RMSE_T: 33.0905 - val_loss: 0.0103 - val_mean_absolute_error: 0.0687 - val_root_mean_squared_error: 0.1012 - val_RMSE_P: 658.7386 - val_RMSE_T: 29.9365
# Epoch 24/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0098 - mean_absolute_error: 0.0726 - root_mean_squared_error: 0.0992 - RMSE_P: 684.6887 - RMSE_T: 32.3416 - val_loss: 0.0104 - val_mean_absolute_error: 0.0692 - val_root_mean_squared_error: 0.1022 - val_RMSE_P: 668.2541 - val_RMSE_T: 29.8956
# Epoch 25/5000
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0101 - mean_absolute_error: 0.0735 - root_mean_squared_error: 0.1006 - RMSE_P: 690.9437 - RMSE_T: 32.8754 - val_loss: 0.0098 - val_mean_absolute_error: 0.0674 - val_root_mean_squared_error: 0.0989 - val_RMSE_P: 655.8264 - val_RMSE_T: 28.8115
# Epoch 26/5000
# 39/39 [==============================] - 0s 4ms/step - loss: 0.0096 - mean_absolute_error: 0.0715 - root_mean_squared_error: 0.0978 - RMSE_P: 683.7401 - RMSE_T: 31.2476 - val_loss: 0.0098 - val_mean_absolute_error: 0.0673 - val_root_mean_squared_error: 0.0989 - val_RMSE_P: 651.9554 - val_RMSE_T: 28.9721
# Epoch 27/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0101 - mean_absolute_error: 0.0734 - root_mean_squared_error: 0.1004 - RMSE_P: 696.9447 - RMSE_T: 32.4420 - val_loss: 0.0098 - val_mean_absolute_error: 0.0668 - val_root_mean_squared_error: 0.0992 - val_RMSE_P: 646.4153 - val_RMSE_T: 28.7568
# Epoch 28/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0097 - mean_absolute_error: 0.0721 - root_mean_squared_error: 0.0985 - RMSE_P: 683.4782 - RMSE_T: 31.9052 - val_loss: 0.0096 - val_mean_absolute_error: 0.0661 - val_root_mean_squared_error: 0.0981 - val_RMSE_P: 644.0587 - val_RMSE_T: 28.1948
# Epoch 29/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0097 - mean_absolute_error: 0.0722 - root_mean_squared_error: 0.0985 - RMSE_P: 686.2144 - RMSE_T: 31.8225 - val_loss: 0.0096 - val_mean_absolute_error: 0.0659 - val_root_mean_squared_error: 0.0981 - val_RMSE_P: 642.3286 - val_RMSE_T: 28.0957
# Epoch 30/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0096 - mean_absolute_error: 0.0710 - root_mean_squared_error: 0.0979 - RMSE_P: 666.0502 - RMSE_T: 31.7957 - val_loss: 0.0095 - val_mean_absolute_error: 0.0657 - val_root_mean_squared_error: 0.0975 - val_RMSE_P: 635.8307 - val_RMSE_T: 28.3190
# Epoch 31/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0091 - mean_absolute_error: 0.0692 - root_mean_squared_error: 0.0956 - RMSE_P: 656.2705 - RMSE_T: 30.6302 - val_loss: 0.0095 - val_mean_absolute_error: 0.0660 - val_root_mean_squared_error: 0.0975 - val_RMSE_P: 640.7295 - val_RMSE_T: 28.3387
# Epoch 32/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0095 - mean_absolute_error: 0.0713 - root_mean_squared_error: 0.0976 - RMSE_P: 682.4749 - RMSE_T: 31.1202 - val_loss: 0.0097 - val_mean_absolute_error: 0.0669 - val_root_mean_squared_error: 0.0986 - val_RMSE_P: 647.0443 - val_RMSE_T: 28.8551
# Epoch 33/5000
# 39/39 [==============================] - 0s 4ms/step - loss: 0.0091 - mean_absolute_error: 0.0701 - root_mean_squared_error: 0.0956 - RMSE_P: 667.3821 - RMSE_T: 30.8155 - val_loss: 0.0095 - val_mean_absolute_error: 0.0657 - val_root_mean_squared_error: 0.0976 - val_RMSE_P: 641.7360 - val_RMSE_T: 27.9911
# Epoch 34/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0091 - mean_absolute_error: 0.0697 - root_mean_squared_error: 0.0955 - RMSE_P: 667.2727 - RMSE_T: 30.4029 - val_loss: 0.0094 - val_mean_absolute_error: 0.0652 - val_root_mean_squared_error: 0.0969 - val_RMSE_P: 636.5739 - val_RMSE_T: 27.7239
# Epoch 35/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0092 - mean_absolute_error: 0.0696 - root_mean_squared_error: 0.0958 - RMSE_P: 664.7067 - RMSE_T: 30.5439 - val_loss: 0.0096 - val_mean_absolute_error: 0.0653 - val_root_mean_squared_error: 0.0980 - val_RMSE_P: 629.4819 - val_RMSE_T: 28.2832
# Epoch 36/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0088 - mean_absolute_error: 0.0676 - root_mean_squared_error: 0.0936 - RMSE_P: 648.8563 - RMSE_T: 29.4535 - val_loss: 0.0092 - val_mean_absolute_error: 0.0652 - val_root_mean_squared_error: 0.0962 - val_RMSE_P: 636.3136 - val_RMSE_T: 27.7266
# Epoch 37/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0090 - mean_absolute_error: 0.0686 - root_mean_squared_error: 0.0948 - RMSE_P: 647.3159 - RMSE_T: 30.4821 - val_loss: 0.0093 - val_mean_absolute_error: 0.0654 - val_root_mean_squared_error: 0.0963 - val_RMSE_P: 642.7393 - val_RMSE_T: 27.6280
# Epoch 38/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0090 - mean_absolute_error: 0.0691 - root_mean_squared_error: 0.0950 - RMSE_P: 664.4351 - RMSE_T: 29.9886 - val_loss: 0.0093 - val_mean_absolute_error: 0.0651 - val_root_mean_squared_error: 0.0965 - val_RMSE_P: 638.3453 - val_RMSE_T: 27.5010
# Epoch 39/5000
# 39/39 [==============================] - 0s 4ms/step - loss: 0.0088 - mean_absolute_error: 0.0679 - root_mean_squared_error: 0.0939 - RMSE_P: 648.0850 - RMSE_T: 29.8010 - val_loss: 0.0092 - val_mean_absolute_error: 0.0648 - val_root_mean_squared_error: 0.0961 - val_RMSE_P: 635.4023 - val_RMSE_T: 27.4114
# Epoch 40/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0085 - mean_absolute_error: 0.0672 - root_mean_squared_error: 0.0920 - RMSE_P: 641.0400 - RMSE_T: 29.5345 - val_loss: 0.0096 - val_mean_absolute_error: 0.0656 - val_root_mean_squared_error: 0.0982 - val_RMSE_P: 634.1753 - val_RMSE_T: 28.3251
# Epoch 41/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0089 - mean_absolute_error: 0.0678 - root_mean_squared_error: 0.0942 - RMSE_P: 645.7104 - RMSE_T: 29.7761 - val_loss: 0.0094 - val_mean_absolute_error: 0.0651 - val_root_mean_squared_error: 0.0970 - val_RMSE_P: 636.1857 - val_RMSE_T: 27.7192
# Epoch 42/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0085 - mean_absolute_error: 0.0669 - root_mean_squared_error: 0.0920 - RMSE_P: 644.7789 - RMSE_T: 28.9721 - val_loss: 0.0094 - val_mean_absolute_error: 0.0645 - val_root_mean_squared_error: 0.0969 - val_RMSE_P: 631.1291 - val_RMSE_T: 27.4112
# Epoch 43/5000
# 39/39 [==============================] - 0s 4ms/step - loss: 0.0086 - mean_absolute_error: 0.0669 - root_mean_squared_error: 0.0926 - RMSE_P: 635.9088 - RMSE_T: 29.4881 - val_loss: 0.0098 - val_mean_absolute_error: 0.0657 - val_root_mean_squared_error: 0.0990 - val_RMSE_P: 632.4628 - val_RMSE_T: 28.4534
# Epoch 44/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0088 - mean_absolute_error: 0.0675 - root_mean_squared_error: 0.0937 - RMSE_P: 643.7941 - RMSE_T: 29.5830 - val_loss: 0.0095 - val_mean_absolute_error: 0.0642 - val_root_mean_squared_error: 0.0973 - val_RMSE_P: 632.0073 - val_RMSE_T: 27.0475
# Epoch 45/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0089 - mean_absolute_error: 0.0675 - root_mean_squared_error: 0.0944 - RMSE_P: 645.5536 - RMSE_T: 29.5495 - val_loss: 0.0091 - val_mean_absolute_error: 0.0636 - val_root_mean_squared_error: 0.0955 - val_RMSE_P: 628.3854 - val_RMSE_T: 26.6345
# Epoch 46/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0084 - mean_absolute_error: 0.0660 - root_mean_squared_error: 0.0918 - RMSE_P: 624.6325 - RMSE_T: 29.2808 - val_loss: 0.0093 - val_mean_absolute_error: 0.0641 - val_root_mean_squared_error: 0.0964 - val_RMSE_P: 633.3596 - val_RMSE_T: 26.8242
# Epoch 47/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0084 - mean_absolute_error: 0.0658 - root_mean_squared_error: 0.0915 - RMSE_P: 631.1291 - RMSE_T: 28.6716 - val_loss: 0.0096 - val_mean_absolute_error: 0.0645 - val_root_mean_squared_error: 0.0981 - val_RMSE_P: 635.7164 - val_RMSE_T: 27.0632
# Epoch 48/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0083 - mean_absolute_error: 0.0663 - root_mean_squared_error: 0.0911 - RMSE_P: 641.2814 - RMSE_T: 28.5541 - val_loss: 0.0098 - val_mean_absolute_error: 0.0652 - val_root_mean_squared_error: 0.0988 - val_RMSE_P: 638.7985 - val_RMSE_T: 27.6092
# Epoch 49/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0084 - mean_absolute_error: 0.0655 - root_mean_squared_error: 0.0915 - RMSE_P: 629.0287 - RMSE_T: 28.4485 - val_loss: 0.0094 - val_mean_absolute_error: 0.0648 - val_root_mean_squared_error: 0.0971 - val_RMSE_P: 640.3666 - val_RMSE_T: 27.1158
# Epoch 50/5000
# 39/39 [==============================] - 0s 4ms/step - loss: 0.0084 - mean_absolute_error: 0.0659 - root_mean_squared_error: 0.0916 - RMSE_P: 631.6483 - RMSE_T: 28.7452 - val_loss: 0.0094 - val_mean_absolute_error: 0.0646 - val_root_mean_squared_error: 0.0968 - val_RMSE_P: 634.9471 - val_RMSE_T: 27.2536
# Epoch 51/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0082 - mean_absolute_error: 0.0655 - root_mean_squared_error: 0.0906 - RMSE_P: 632.4999 - RMSE_T: 28.2707 - val_loss: 0.0091 - val_mean_absolute_error: 0.0634 - val_root_mean_squared_error: 0.0956 - val_RMSE_P: 629.2791 - val_RMSE_T: 26.3672
# Epoch 52/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0083 - mean_absolute_error: 0.0658 - root_mean_squared_error: 0.0913 - RMSE_P: 631.9593 - RMSE_T: 28.5920 - val_loss: 0.0093 - val_mean_absolute_error: 0.0642 - val_root_mean_squared_error: 0.0965 - val_RMSE_P: 637.2562 - val_RMSE_T: 26.7298
# Epoch 53/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0085 - mean_absolute_error: 0.0661 - root_mean_squared_error: 0.0923 - RMSE_P: 636.2130 - RMSE_T: 28.6756 - val_loss: 0.0091 - val_mean_absolute_error: 0.0637 - val_root_mean_squared_error: 0.0954 - val_RMSE_P: 639.8852 - val_RMSE_T: 26.0822
# Epoch 54/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0080 - mean_absolute_error: 0.0646 - root_mean_squared_error: 0.0894 - RMSE_P: 613.6133 - RMSE_T: 28.4597 - val_loss: 0.0091 - val_mean_absolute_error: 0.0636 - val_root_mean_squared_error: 0.0953 - val_RMSE_P: 630.9525 - val_RMSE_T: 26.4575
# Epoch 55/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0078 - mean_absolute_error: 0.0636 - root_mean_squared_error: 0.0882 - RMSE_P: 615.8577 - RMSE_T: 27.4099 - val_loss: 0.0091 - val_mean_absolute_error: 0.0636 - val_root_mean_squared_error: 0.0953 - val_RMSE_P: 634.3278 - val_RMSE_T: 26.2480
# Epoch 56/5000
# 39/39 [==============================] - 0s 4ms/step - loss: 0.0078 - mean_absolute_error: 0.0644 - root_mean_squared_error: 0.0884 - RMSE_P: 622.5258 - RMSE_T: 27.8067 - val_loss: 0.0092 - val_mean_absolute_error: 0.0644 - val_root_mean_squared_error: 0.0960 - val_RMSE_P: 639.4262 - val_RMSE_T: 26.8026
# Epoch 57/5000
# 39/39 [==============================] - 0s 4ms/step - loss: 0.0077 - mean_absolute_error: 0.0635 - root_mean_squared_error: 0.0877 - RMSE_P: 610.2639 - RMSE_T: 27.6321 - val_loss: 0.0096 - val_mean_absolute_error: 0.0646 - val_root_mean_squared_error: 0.0978 - val_RMSE_P: 639.9542 - val_RMSE_T: 26.9622
# Epoch 58/5000
# 39/39 [==============================] - 0s 2ms/step - loss: 0.0080 - mean_absolute_error: 0.0644 - root_mean_squared_error: 0.0894 - RMSE_P: 626.9950 - RMSE_T: 27.4748 - val_loss: 0.0092 - val_mean_absolute_error: 0.0637 - val_root_mean_squared_error: 0.0957 - val_RMSE_P: 632.0065 - val_RMSE_T: 26.5426
# Epoch 59/5000
# 39/39 [==============================] - 0s 4ms/step - loss: 0.0080 - mean_absolute_error: 0.0643 - root_mean_squared_error: 0.0896 - RMSE_P: 623.6303 - RMSE_T: 27.5779 - val_loss: 0.0091 - val_mean_absolute_error: 0.0632 - val_root_mean_squared_error: 0.0955 - val_RMSE_P: 628.3423 - val_RMSE_T: 26.2699
# Epoch 60/5000
# 39/39 [==============================] - 0s 4ms/step - loss: 0.0080 - mean_absolute_error: 0.0636 - root_mean_squared_error: 0.0893 - RMSE_P: 610.4133 - RMSE_T: 27.6496 - val_loss: 0.0091 - val_mean_absolute_error: 0.0636 - val_root_mean_squared_error: 0.0954 - val_RMSE_P: 630.0599 - val_RMSE_T: 26.5398
# Epoch 61/5000
# 39/39 [==============================] - 0s 4ms/step - loss: 0.0077 - mean_absolute_error: 0.0632 - root_mean_squared_error: 0.0880 - RMSE_P: 611.7529 - RMSE_T: 27.2445 - val_loss: 0.0090 - val_mean_absolute_error: 0.0631 - val_root_mean_squared_error: 0.0951 - val_RMSE_P: 634.0339 - val_RMSE_T: 25.7694
# Epoch 62/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0079 - mean_absolute_error: 0.0635 - root_mean_squared_error: 0.0887 - RMSE_P: 614.8738 - RMSE_T: 27.3372 - val_loss: 0.0092 - val_mean_absolute_error: 0.0637 - val_root_mean_squared_error: 0.0957 - val_RMSE_P: 634.4584 - val_RMSE_T: 26.3421
# Epoch 63/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0080 - mean_absolute_error: 0.0644 - root_mean_squared_error: 0.0897 - RMSE_P: 626.4729 - RMSE_T: 27.5769 - val_loss: 0.0090 - val_mean_absolute_error: 0.0631 - val_root_mean_squared_error: 0.0951 - val_RMSE_P: 631.9079 - val_RMSE_T: 25.9499
# Epoch 64/5000
# 39/39 [==============================] - 0s 4ms/step - loss: 0.0076 - mean_absolute_error: 0.0629 - root_mean_squared_error: 0.0873 - RMSE_P: 606.3453 - RMSE_T: 27.2030 - val_loss: 0.0091 - val_mean_absolute_error: 0.0635 - val_root_mean_squared_error: 0.0953 - val_RMSE_P: 635.1995 - val_RMSE_T: 26.1402
# Epoch 65/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0076 - mean_absolute_error: 0.0631 - root_mean_squared_error: 0.0869 - RMSE_P: 606.2081 - RMSE_T: 27.4469 - val_loss: 0.0093 - val_mean_absolute_error: 0.0642 - val_root_mean_squared_error: 0.0965 - val_RMSE_P: 638.6722 - val_RMSE_T: 26.6182
# Epoch 66/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0076 - mean_absolute_error: 0.0627 - root_mean_squared_error: 0.0871 - RMSE_P: 609.6271 - RMSE_T: 26.8668 - val_loss: 0.0091 - val_mean_absolute_error: 0.0632 - val_root_mean_squared_error: 0.0953 - val_RMSE_P: 628.2186 - val_RMSE_T: 26.2957
# Epoch 67/5000
# 39/39 [==============================] - 0s 6ms/step - loss: 0.0076 - mean_absolute_error: 0.0621 - root_mean_squared_error: 0.0869 - RMSE_P: 599.4612 - RMSE_T: 26.8756 - val_loss: 0.0091 - val_mean_absolute_error: 0.0632 - val_root_mean_squared_error: 0.0953 - val_RMSE_P: 627.4334 - val_RMSE_T: 26.2574
# Epoch 68/5000
# 39/39 [==============================] - 0s 6ms/step - loss: 0.0074 - mean_absolute_error: 0.0618 - root_mean_squared_error: 0.0862 - RMSE_P: 598.7722 - RMSE_T: 26.5748 - val_loss: 0.0091 - val_mean_absolute_error: 0.0634 - val_root_mean_squared_error: 0.0956 - val_RMSE_P: 635.7233 - val_RMSE_T: 26.0514
# Epoch 69/5000
# 39/39 [==============================] - 0s 6ms/step - loss: 0.0074 - mean_absolute_error: 0.0625 - root_mean_squared_error: 0.0861 - RMSE_P: 609.5689 - RMSE_T: 26.6574 - val_loss: 0.0091 - val_mean_absolute_error: 0.0640 - val_root_mean_squared_error: 0.0955 - val_RMSE_P: 640.6912 - val_RMSE_T: 26.2873
# Epoch 70/5000
# 39/39 [==============================] - 0s 4ms/step - loss: 0.0075 - mean_absolute_error: 0.0625 - root_mean_squared_error: 0.0867 - RMSE_P: 607.7880 - RMSE_T: 26.7455 - val_loss: 0.0091 - val_mean_absolute_error: 0.0632 - val_root_mean_squared_error: 0.0956 - val_RMSE_P: 634.3275 - val_RMSE_T: 25.9030
# Epoch 71/5000
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0075 - mean_absolute_error: 0.0620 - root_mean_squared_error: 0.0867 - RMSE_P: 598.9769 - RMSE_T: 26.7747 - val_loss: 0.0092 - val_mean_absolute_error: 0.0636 - val_root_mean_squared_error: 0.0960 - val_RMSE_P: 630.4145 - val_RMSE_T: 26.4700
# Epoch 72/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0075 - mean_absolute_error: 0.0627 - root_mean_squared_error: 0.0867 - RMSE_P: 606.5602 - RMSE_T: 27.0179 - val_loss: 0.0092 - val_mean_absolute_error: 0.0631 - val_root_mean_squared_error: 0.0961 - val_RMSE_P: 624.4366 - val_RMSE_T: 26.3259
# Epoch 73/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0077 - mean_absolute_error: 0.0627 - root_mean_squared_error: 0.0876 - RMSE_P: 601.4413 - RMSE_T: 27.3590 - val_loss: 0.0091 - val_mean_absolute_error: 0.0630 - val_root_mean_squared_error: 0.0952 - val_RMSE_P: 625.0430 - val_RMSE_T: 26.1920
# Epoch 74/5000
# 39/39 [==============================] - 0s 4ms/step - loss: 0.0076 - mean_absolute_error: 0.0632 - root_mean_squared_error: 0.0871 - RMSE_P: 612.8617 - RMSE_T: 27.1439 - val_loss: 0.0089 - val_mean_absolute_error: 0.0622 - val_root_mean_squared_error: 0.0943 - val_RMSE_P: 620.5555 - val_RMSE_T: 25.6598
# Epoch 75/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0073 - mean_absolute_error: 0.0615 - root_mean_squared_error: 0.0854 - RMSE_P: 598.8345 - RMSE_T: 26.2889 - val_loss: 0.0090 - val_mean_absolute_error: 0.0627 - val_root_mean_squared_error: 0.0948 - val_RMSE_P: 625.4462 - val_RMSE_T: 25.9574
# Epoch 76/5000
# 39/39 [==============================] - 0s 4ms/step - loss: 0.0075 - mean_absolute_error: 0.0623 - root_mean_squared_error: 0.0865 - RMSE_P: 597.1083 - RMSE_T: 27.1534 - val_loss: 0.0089 - val_mean_absolute_error: 0.0620 - val_root_mean_squared_error: 0.0943 - val_RMSE_P: 619.8556 - val_RMSE_T: 25.5340
# Epoch 77/5000
# 39/39 [==============================] - 0s 4ms/step - loss: 0.0073 - mean_absolute_error: 0.0612 - root_mean_squared_error: 0.0852 - RMSE_P: 586.3889 - RMSE_T: 26.7523 - val_loss: 0.0091 - val_mean_absolute_error: 0.0625 - val_root_mean_squared_error: 0.0953 - val_RMSE_P: 622.7410 - val_RMSE_T: 25.8508
# Epoch 78/5000
# 39/39 [==============================] - 0s 4ms/step - loss: 0.0074 - mean_absolute_error: 0.0619 - root_mean_squared_error: 0.0860 - RMSE_P: 602.8816 - RMSE_T: 26.4229 - val_loss: 0.0090 - val_mean_absolute_error: 0.0627 - val_root_mean_squared_error: 0.0947 - val_RMSE_P: 625.4030 - val_RMSE_T: 25.8822
# Epoch 79/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0071 - mean_absolute_error: 0.0605 - root_mean_squared_error: 0.0845 - RMSE_P: 586.2764 - RMSE_T: 25.9698 - val_loss: 0.0089 - val_mean_absolute_error: 0.0625 - val_root_mean_squared_error: 0.0943 - val_RMSE_P: 621.1677 - val_RMSE_T: 25.9210
# Epoch 80/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0074 - mean_absolute_error: 0.0620 - root_mean_squared_error: 0.0862 - RMSE_P: 597.4042 - RMSE_T: 26.8371 - val_loss: 0.0092 - val_mean_absolute_error: 0.0638 - val_root_mean_squared_error: 0.0961 - val_RMSE_P: 633.9002 - val_RMSE_T: 26.4947
# Epoch 81/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0070 - mean_absolute_error: 0.0601 - root_mean_squared_error: 0.0836 - RMSE_P: 580.9631 - RMSE_T: 25.8774 - val_loss: 0.0092 - val_mean_absolute_error: 0.0631 - val_root_mean_squared_error: 0.0957 - val_RMSE_P: 626.6664 - val_RMSE_T: 26.2282
# Epoch 82/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0072 - mean_absolute_error: 0.0613 - root_mean_squared_error: 0.0850 - RMSE_P: 584.8685 - RMSE_T: 26.8463 - val_loss: 0.0092 - val_mean_absolute_error: 0.0631 - val_root_mean_squared_error: 0.0957 - val_RMSE_P: 623.2180 - val_RMSE_T: 26.4027
# Epoch 83/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0070 - mean_absolute_error: 0.0603 - root_mean_squared_error: 0.0836 - RMSE_P: 583.7747 - RMSE_T: 25.9348 - val_loss: 0.0087 - val_mean_absolute_error: 0.0620 - val_root_mean_squared_error: 0.0933 - val_RMSE_P: 618.1688 - val_RMSE_T: 25.5918
# Epoch 84/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0071 - mean_absolute_error: 0.0605 - root_mean_squared_error: 0.0841 - RMSE_P: 585.0233 - RMSE_T: 26.0936 - val_loss: 0.0088 - val_mean_absolute_error: 0.0619 - val_root_mean_squared_error: 0.0939 - val_RMSE_P: 612.7581 - val_RMSE_T: 25.8503
# Epoch 85/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0073 - mean_absolute_error: 0.0616 - root_mean_squared_error: 0.0852 - RMSE_P: 590.2516 - RMSE_T: 26.8769 - val_loss: 0.0090 - val_mean_absolute_error: 0.0630 - val_root_mean_squared_error: 0.0948 - val_RMSE_P: 625.1901 - val_RMSE_T: 26.1830
# Epoch 86/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0071 - mean_absolute_error: 0.0608 - root_mean_squared_error: 0.0842 - RMSE_P: 597.2784 - RMSE_T: 25.6847 - val_loss: 0.0090 - val_mean_absolute_error: 0.0624 - val_root_mean_squared_error: 0.0948 - val_RMSE_P: 619.8997 - val_RMSE_T: 25.8924
# Epoch 87/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0070 - mean_absolute_error: 0.0603 - root_mean_squared_error: 0.0836 - RMSE_P: 585.2178 - RMSE_T: 25.8597 - val_loss: 0.0090 - val_mean_absolute_error: 0.0630 - val_root_mean_squared_error: 0.0946 - val_RMSE_P: 624.1365 - val_RMSE_T: 26.2871
# Epoch 88/5000
# 39/39 [==============================] - 0s 2ms/step - loss: 0.0072 - mean_absolute_error: 0.0607 - root_mean_squared_error: 0.0851 - RMSE_P: 593.0574 - RMSE_T: 25.8507 - val_loss: 0.0091 - val_mean_absolute_error: 0.0628 - val_root_mean_squared_error: 0.0952 - val_RMSE_P: 621.3094 - val_RMSE_T: 26.2990
# Epoch 89/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0068 - mean_absolute_error: 0.0593 - root_mean_squared_error: 0.0825 - RMSE_P: 578.3558 - RMSE_T: 25.2761 - val_loss: 0.0088 - val_mean_absolute_error: 0.0615 - val_root_mean_squared_error: 0.0938 - val_RMSE_P: 611.9431 - val_RMSE_T: 25.5294
# Epoch 90/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0070 - mean_absolute_error: 0.0598 - root_mean_squared_error: 0.0838 - RMSE_P: 583.3610 - RMSE_T: 25.5236 - val_loss: 0.0090 - val_mean_absolute_error: 0.0627 - val_root_mean_squared_error: 0.0947 - val_RMSE_P: 621.7600 - val_RMSE_T: 26.1017
# Epoch 91/5000
# 39/39 [==============================] - 0s 2ms/step - loss: 0.0070 - mean_absolute_error: 0.0604 - root_mean_squared_error: 0.0836 - RMSE_P: 591.3081 - RMSE_T: 25.6319 - val_loss: 0.0089 - val_mean_absolute_error: 0.0617 - val_root_mean_squared_error: 0.0943 - val_RMSE_P: 614.8951 - val_RMSE_T: 25.4904
# Epoch 92/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0070 - mean_absolute_error: 0.0603 - root_mean_squared_error: 0.0834 - RMSE_P: 584.2759 - RMSE_T: 25.9196 - val_loss: 0.0087 - val_mean_absolute_error: 0.0612 - val_root_mean_squared_error: 0.0934 - val_RMSE_P: 615.8570 - val_RMSE_T: 24.9826
# Epoch 93/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0067 - mean_absolute_error: 0.0589 - root_mean_squared_error: 0.0817 - RMSE_P: 568.2280 - RMSE_T: 25.4468 - val_loss: 0.0086 - val_mean_absolute_error: 0.0609 - val_root_mean_squared_error: 0.0929 - val_RMSE_P: 614.3956 - val_RMSE_T: 24.7393
# Epoch 94/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0070 - mean_absolute_error: 0.0603 - root_mean_squared_error: 0.0835 - RMSE_P: 581.4922 - RMSE_T: 26.0481 - val_loss: 0.0089 - val_mean_absolute_error: 0.0626 - val_root_mean_squared_error: 0.0942 - val_RMSE_P: 621.4888 - val_RMSE_T: 26.0472
# Epoch 95/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0070 - mean_absolute_error: 0.0593 - root_mean_squared_error: 0.0834 - RMSE_P: 569.5598 - RMSE_T: 25.7954 - val_loss: 0.0091 - val_mean_absolute_error: 0.0628 - val_root_mean_squared_error: 0.0952 - val_RMSE_P: 621.7871 - val_RMSE_T: 26.2167
# Epoch 96/5000
# 39/39 [==============================] - 0s 4ms/step - loss: 0.0069 - mean_absolute_error: 0.0596 - root_mean_squared_error: 0.0830 - RMSE_P: 561.9866 - RMSE_T: 26.4946 - val_loss: 0.0087 - val_mean_absolute_error: 0.0620 - val_root_mean_squared_error: 0.0931 - val_RMSE_P: 614.8597 - val_RMSE_T: 25.8187
# Epoch 97/5000
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0071 - mean_absolute_error: 0.0607 - root_mean_squared_error: 0.0843 - RMSE_P: 590.3757 - RMSE_T: 25.9363 - val_loss: 0.0092 - val_mean_absolute_error: 0.0629 - val_root_mean_squared_error: 0.0957 - val_RMSE_P: 624.7964 - val_RMSE_T: 26.1313
# Epoch 98/5000
# 39/39 [==============================] - 0s 4ms/step - loss: 0.0069 - mean_absolute_error: 0.0597 - root_mean_squared_error: 0.0832 - RMSE_P: 586.1603 - RMSE_T: 25.2295 - val_loss: 0.0088 - val_mean_absolute_error: 0.0614 - val_root_mean_squared_error: 0.0936 - val_RMSE_P: 609.9095 - val_RMSE_T: 25.5002
# Epoch 99/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0067 - mean_absolute_error: 0.0587 - root_mean_squared_error: 0.0821 - RMSE_P: 568.7879 - RMSE_T: 25.2485 - val_loss: 0.0089 - val_mean_absolute_error: 0.0619 - val_root_mean_squared_error: 0.0944 - val_RMSE_P: 615.7749 - val_RMSE_T: 25.6752
# Epoch 100/5000
# 39/39 [==============================] - 0s 4ms/step - loss: 0.0069 - mean_absolute_error: 0.0597 - root_mean_squared_error: 0.0832 - RMSE_P: 583.8518 - RMSE_T: 25.3448 - val_loss: 0.0089 - val_mean_absolute_error: 0.0615 - val_root_mean_squared_error: 0.0943 - val_RMSE_P: 608.3209 - val_RMSE_T: 25.7155
# Epoch 101/5000
# 39/39 [==============================] - 0s 4ms/step - loss: 0.0067 - mean_absolute_error: 0.0590 - root_mean_squared_error: 0.0821 - RMSE_P: 566.8099 - RMSE_T: 25.6274 - val_loss: 0.0088 - val_mean_absolute_error: 0.0618 - val_root_mean_squared_error: 0.0940 - val_RMSE_P: 609.9055 - val_RMSE_T: 25.8804
# Epoch 102/5000
# 39/39 [==============================] - 0s 4ms/step - loss: 0.0068 - mean_absolute_error: 0.0592 - root_mean_squared_error: 0.0824 - RMSE_P: 573.1175 - RMSE_T: 25.4929 - val_loss: 0.0087 - val_mean_absolute_error: 0.0611 - val_root_mean_squared_error: 0.0933 - val_RMSE_P: 613.0613 - val_RMSE_T: 25.0226
# Epoch 103/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0067 - mean_absolute_error: 0.0591 - root_mean_squared_error: 0.0821 - RMSE_P: 574.3807 - RMSE_T: 25.2831 - val_loss: 0.0087 - val_mean_absolute_error: 0.0611 - val_root_mean_squared_error: 0.0931 - val_RMSE_P: 609.3403 - val_RMSE_T: 25.2184
# Epoch 104/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0067 - mean_absolute_error: 0.0594 - root_mean_squared_error: 0.0821 - RMSE_P: 574.3572 - RMSE_T: 25.5752 - val_loss: 0.0087 - val_mean_absolute_error: 0.0605 - val_root_mean_squared_error: 0.0930 - val_RMSE_P: 607.6704 - val_RMSE_T: 24.7582
# Epoch 105/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0068 - mean_absolute_error: 0.0590 - root_mean_squared_error: 0.0824 - RMSE_P: 572.3361 - RMSE_T: 25.3006 - val_loss: 0.0086 - val_mean_absolute_error: 0.0605 - val_root_mean_squared_error: 0.0927 - val_RMSE_P: 604.4142 - val_RMSE_T: 24.9791
# Epoch 106/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0067 - mean_absolute_error: 0.0588 - root_mean_squared_error: 0.0816 - RMSE_P: 563.2818 - RMSE_T: 25.6509 - val_loss: 0.0087 - val_mean_absolute_error: 0.0611 - val_root_mean_squared_error: 0.0935 - val_RMSE_P: 609.9967 - val_RMSE_T: 25.1709
# Epoch 107/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0066 - mean_absolute_error: 0.0584 - root_mean_squared_error: 0.0812 - RMSE_P: 560.0009 - RMSE_T: 25.4599 - val_loss: 0.0088 - val_mean_absolute_error: 0.0609 - val_root_mean_squared_error: 0.0937 - val_RMSE_P: 604.3704 - val_RMSE_T: 25.3204
# Epoch 108/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0065 - mean_absolute_error: 0.0582 - root_mean_squared_error: 0.0807 - RMSE_P: 568.8568 - RMSE_T: 24.7733 - val_loss: 0.0085 - val_mean_absolute_error: 0.0598 - val_root_mean_squared_error: 0.0919 - val_RMSE_P: 609.9356 - val_RMSE_T: 23.9166
# Epoch 109/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0065 - mean_absolute_error: 0.0580 - root_mean_squared_error: 0.0807 - RMSE_P: 565.5361 - RMSE_T: 24.7610 - val_loss: 0.0089 - val_mean_absolute_error: 0.0614 - val_root_mean_squared_error: 0.0945 - val_RMSE_P: 615.8288 - val_RMSE_T: 25.2032
# Epoch 110/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0066 - mean_absolute_error: 0.0581 - root_mean_squared_error: 0.0812 - RMSE_P: 567.2717 - RMSE_T: 24.7675 - val_loss: 0.0085 - val_mean_absolute_error: 0.0602 - val_root_mean_squared_error: 0.0925 - val_RMSE_P: 611.3707 - val_RMSE_T: 24.2812
# Epoch 111/5000
# 39/39 [==============================] - 0s 2ms/step - loss: 0.0068 - mean_absolute_error: 0.0595 - root_mean_squared_error: 0.0827 - RMSE_P: 574.9731 - RMSE_T: 25.6918 - val_loss: 0.0089 - val_mean_absolute_error: 0.0623 - val_root_mean_squared_error: 0.0944 - val_RMSE_P: 616.4542 - val_RMSE_T: 26.0828
# Epoch 112/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0067 - mean_absolute_error: 0.0590 - root_mean_squared_error: 0.0821 - RMSE_P: 577.3357 - RMSE_T: 25.0531 - val_loss: 0.0089 - val_mean_absolute_error: 0.0613 - val_root_mean_squared_error: 0.0944 - val_RMSE_P: 617.0554 - val_RMSE_T: 24.9883
# Epoch 113/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0069 - mean_absolute_error: 0.0594 - root_mean_squared_error: 0.0830 - RMSE_P: 576.0646 - RMSE_T: 25.4823 - val_loss: 0.0087 - val_mean_absolute_error: 0.0613 - val_root_mean_squared_error: 0.0932 - val_RMSE_P: 623.5569 - val_RMSE_T: 24.6203
# Epoch 114/5000
# 39/39 [==============================] - 0s 4ms/step - loss: 0.0068 - mean_absolute_error: 0.0588 - root_mean_squared_error: 0.0823 - RMSE_P: 566.9216 - RMSE_T: 25.4195 - val_loss: 0.0089 - val_mean_absolute_error: 0.0605 - val_root_mean_squared_error: 0.0942 - val_RMSE_P: 611.6113 - val_RMSE_T: 24.5089
# Epoch 115/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0065 - mean_absolute_error: 0.0578 - root_mean_squared_error: 0.0807 - RMSE_P: 563.4293 - RMSE_T: 24.6474 - val_loss: 0.0088 - val_mean_absolute_error: 0.0604 - val_root_mean_squared_error: 0.0936 - val_RMSE_P: 608.0957 - val_RMSE_T: 24.6644
# Epoch 116/5000
# 39/39 [==============================] - 0s 2ms/step - loss: 0.0064 - mean_absolute_error: 0.0574 - root_mean_squared_error: 0.0797 - RMSE_P: 555.4569 - RMSE_T: 24.7266 - val_loss: 0.0089 - val_mean_absolute_error: 0.0611 - val_root_mean_squared_error: 0.0944 - val_RMSE_P: 623.9172 - val_RMSE_T: 24.3981
# Epoch 117/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0063 - mean_absolute_error: 0.0570 - root_mean_squared_error: 0.0795 - RMSE_P: 551.6006 - RMSE_T: 24.5185 - val_loss: 0.0087 - val_mean_absolute_error: 0.0608 - val_root_mean_squared_error: 0.0934 - val_RMSE_P: 612.3462 - val_RMSE_T: 24.7690
# Epoch 118/5000
# 39/39 [==============================] - 0s 2ms/step - loss: 0.0065 - mean_absolute_error: 0.0581 - root_mean_squared_error: 0.0804 - RMSE_P: 556.9044 - RMSE_T: 25.3631 - val_loss: 0.0087 - val_mean_absolute_error: 0.0607 - val_root_mean_squared_error: 0.0933 - val_RMSE_P: 610.0913 - val_RMSE_T: 24.8458
# Epoch 119/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0067 - mean_absolute_error: 0.0590 - root_mean_squared_error: 0.0818 - RMSE_P: 567.3839 - RMSE_T: 25.6380 - val_loss: 0.0089 - val_mean_absolute_error: 0.0612 - val_root_mean_squared_error: 0.0942 - val_RMSE_P: 613.8483 - val_RMSE_T: 25.0933
# Epoch 120/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0067 - mean_absolute_error: 0.0590 - root_mean_squared_error: 0.0816 - RMSE_P: 567.8033 - RMSE_T: 25.6135 - val_loss: 0.0085 - val_mean_absolute_error: 0.0602 - val_root_mean_squared_error: 0.0925 - val_RMSE_P: 610.2172 - val_RMSE_T: 24.3532
# Epoch 121/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0066 - mean_absolute_error: 0.0584 - root_mean_squared_error: 0.0815 - RMSE_P: 568.1353 - RMSE_T: 24.9897 - val_loss: 0.0088 - val_mean_absolute_error: 0.0617 - val_root_mean_squared_error: 0.0939 - val_RMSE_P: 626.9705 - val_RMSE_T: 24.8612
# Epoch 122/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0065 - mean_absolute_error: 0.0579 - root_mean_squared_error: 0.0807 - RMSE_P: 555.5656 - RMSE_T: 25.2612 - val_loss: 0.0088 - val_mean_absolute_error: 0.0610 - val_root_mean_squared_error: 0.0937 - val_RMSE_P: 611.9600 - val_RMSE_T: 25.0453
# Epoch 123/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0065 - mean_absolute_error: 0.0583 - root_mean_squared_error: 0.0808 - RMSE_P: 561.9305 - RMSE_T: 25.2383 - val_loss: 0.0088 - val_mean_absolute_error: 0.0621 - val_root_mean_squared_error: 0.0938 - val_RMSE_P: 621.5258 - val_RMSE_T: 25.5269
# Epoch 124/5000
# 39/39 [==============================] - 0s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0575 - root_mean_squared_error: 0.0802 - RMSE_P: 555.7211 - RMSE_T: 24.8500 - val_loss: 0.0090 - val_mean_absolute_error: 0.0613 - val_root_mean_squared_error: 0.0948 - val_RMSE_P: 615.0206 - val_RMSE_T: 25.1105
# Epoch 125/5000
# 39/39 [==============================] - 0s 4ms/step - loss: 0.0065 - mean_absolute_error: 0.0583 - root_mean_squared_error: 0.0809 - RMSE_P: 563.0847 - RMSE_T: 25.1768 - val_loss: 0.0090 - val_mean_absolute_error: 0.0626 - val_root_mean_squared_error: 0.0947 - val_RMSE_P: 616.3268 - val_RMSE_T: 26.3625
# Epoch 126/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0064 - mean_absolute_error: 0.0577 - root_mean_squared_error: 0.0799 - RMSE_P: 562.7633 - RMSE_T: 24.6025 - val_loss: 0.0089 - val_mean_absolute_error: 0.0611 - val_root_mean_squared_error: 0.0941 - val_RMSE_P: 611.3168 - val_RMSE_T: 25.1023
# Epoch 127/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0065 - mean_absolute_error: 0.0582 - root_mean_squared_error: 0.0807 - RMSE_P: 566.5000 - RMSE_T: 24.9173 - val_loss: 0.0087 - val_mean_absolute_error: 0.0618 - val_root_mean_squared_error: 0.0933 - val_RMSE_P: 626.4368 - val_RMSE_T: 24.9389
# Epoch 128/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0064 - mean_absolute_error: 0.0577 - root_mean_squared_error: 0.0798 - RMSE_P: 557.8983 - RMSE_T: 24.8962 - val_loss: 0.0087 - val_mean_absolute_error: 0.0608 - val_root_mean_squared_error: 0.0935 - val_RMSE_P: 614.6783 - val_RMSE_T: 24.6550
# Epoch 129/5000
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0064 - mean_absolute_error: 0.0573 - root_mean_squared_error: 0.0798 - RMSE_P: 554.9624 - RMSE_T: 24.6748 - val_loss: 0.0088 - val_mean_absolute_error: 0.0614 - val_root_mean_squared_error: 0.0939 - val_RMSE_P: 613.2709 - val_RMSE_T: 25.2778
# Epoch 130/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0063 - mean_absolute_error: 0.0572 - root_mean_squared_error: 0.0793 - RMSE_P: 550.2789 - RMSE_T: 24.8457 - val_loss: 0.0088 - val_mean_absolute_error: 0.0610 - val_root_mean_squared_error: 0.0939 - val_RMSE_P: 609.2617 - val_RMSE_T: 25.1935
# Epoch 131/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0062 - mean_absolute_error: 0.0565 - root_mean_squared_error: 0.0787 - RMSE_P: 539.8928 - RMSE_T: 24.7568 - val_loss: 0.0088 - val_mean_absolute_error: 0.0615 - val_root_mean_squared_error: 0.0940 - val_RMSE_P: 619.5026 - val_RMSE_T: 25.0602
# Epoch 132/5000
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0061 - mean_absolute_error: 0.0564 - root_mean_squared_error: 0.0782 - RMSE_P: 548.4252 - RMSE_T: 24.1194 - val_loss: 0.0089 - val_mean_absolute_error: 0.0617 - val_root_mean_squared_error: 0.0942 - val_RMSE_P: 612.8517 - val_RMSE_T: 25.6399
# Epoch 133/5000
# 39/39 [==============================] - 0s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0571 - root_mean_squared_error: 0.0798 - RMSE_P: 552.4083 - RMSE_T: 24.6077 - val_loss: 0.0089 - val_mean_absolute_error: 0.0618 - val_root_mean_squared_error: 0.0943 - val_RMSE_P: 617.3460 - val_RMSE_T: 25.5233
# Epoch 134/5000
# 39/39 [==============================] - 0s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0571 - root_mean_squared_error: 0.0794 - RMSE_P: 554.0950 - RMSE_T: 24.5099 - val_loss: 0.0088 - val_mean_absolute_error: 0.0614 - val_root_mean_squared_error: 0.0936 - val_RMSE_P: 621.7394 - val_RMSE_T: 24.7970
# Epoch 135/5000
# 39/39 [==============================] - 0s 6ms/step - loss: 0.0062 - mean_absolute_error: 0.0570 - root_mean_squared_error: 0.0789 - RMSE_P: 545.8367 - RMSE_T: 24.9296 - val_loss: 0.0092 - val_mean_absolute_error: 0.0627 - val_root_mean_squared_error: 0.0958 - val_RMSE_P: 630.2812 - val_RMSE_T: 25.6132
# Epoch 136/5000
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0062 - mean_absolute_error: 0.0563 - root_mean_squared_error: 0.0785 - RMSE_P: 546.0520 - RMSE_T: 24.1744 - val_loss: 0.0089 - val_mean_absolute_error: 0.0615 - val_root_mean_squared_error: 0.0942 - val_RMSE_P: 622.6705 - val_RMSE_T: 24.8760
# Epoch 137/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0060 - mean_absolute_error: 0.0561 - root_mean_squared_error: 0.0776 - RMSE_P: 542.6768 - RMSE_T: 24.1701 - val_loss: 0.0090 - val_mean_absolute_error: 0.0615 - val_root_mean_squared_error: 0.0948 - val_RMSE_P: 621.3863 - val_RMSE_T: 24.9281
# Epoch 138/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0059 - mean_absolute_error: 0.0554 - root_mean_squared_error: 0.0771 - RMSE_P: 533.5613 - RMSE_T: 24.0017 - val_loss: 0.0089 - val_mean_absolute_error: 0.0612 - val_root_mean_squared_error: 0.0941 - val_RMSE_P: 609.0992 - val_RMSE_T: 25.4086
# Epoch 139/5000
# 39/39 [==============================] - 0s 4ms/step - loss: 0.0061 - mean_absolute_error: 0.0564 - root_mean_squared_error: 0.0784 - RMSE_P: 540.6438 - RMSE_T: 24.5475 - val_loss: 0.0088 - val_mean_absolute_error: 0.0612 - val_root_mean_squared_error: 0.0936 - val_RMSE_P: 619.9274 - val_RMSE_T: 24.7726
# Epoch 140/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0064 - mean_absolute_error: 0.0570 - root_mean_squared_error: 0.0798 - RMSE_P: 553.0192 - RMSE_T: 24.5133 - val_loss: 0.0089 - val_mean_absolute_error: 0.0625 - val_root_mean_squared_error: 0.0945 - val_RMSE_P: 622.6584 - val_RMSE_T: 25.8306
# Epoch 141/5000
# 39/39 [==============================] - 0s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0574 - root_mean_squared_error: 0.0795 - RMSE_P: 557.5477 - RMSE_T: 24.5641 - val_loss: 0.0088 - val_mean_absolute_error: 0.0609 - val_root_mean_squared_error: 0.0937 - val_RMSE_P: 601.0803 - val_RMSE_T: 25.5597
# Epoch 142/5000
# 39/39 [==============================] - 0s 4ms/step - loss: 0.0060 - mean_absolute_error: 0.0558 - root_mean_squared_error: 0.0774 - RMSE_P: 535.5696 - RMSE_T: 24.2522 - val_loss: 0.0090 - val_mean_absolute_error: 0.0617 - val_root_mean_squared_error: 0.0946 - val_RMSE_P: 614.0847 - val_RMSE_T: 25.6163
# Epoch 143/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0064 - mean_absolute_error: 0.0574 - root_mean_squared_error: 0.0801 - RMSE_P: 550.3759 - RMSE_T: 25.0722 - val_loss: 0.0090 - val_mean_absolute_error: 0.0628 - val_root_mean_squared_error: 0.0946 - val_RMSE_P: 627.3829 - val_RMSE_T: 25.8575
# Epoch 144/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0063 - mean_absolute_error: 0.0572 - root_mean_squared_error: 0.0794 - RMSE_P: 551.4255 - RMSE_T: 24.8052 - val_loss: 0.0087 - val_mean_absolute_error: 0.0602 - val_root_mean_squared_error: 0.0932 - val_RMSE_P: 606.2790 - val_RMSE_T: 24.5719
# Epoch 145/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0064 - mean_absolute_error: 0.0580 - root_mean_squared_error: 0.0802 - RMSE_P: 560.2237 - RMSE_T: 25.0548 - val_loss: 0.0087 - val_mean_absolute_error: 0.0604 - val_root_mean_squared_error: 0.0932 - val_RMSE_P: 601.1617 - val_RMSE_T: 25.0340
# Epoch 146/5000
# 39/39 [==============================] - 0s 2ms/step - loss: 0.0061 - mean_absolute_error: 0.0563 - root_mean_squared_error: 0.0784 - RMSE_P: 545.4939 - RMSE_T: 24.2479 - val_loss: 0.0088 - val_mean_absolute_error: 0.0608 - val_root_mean_squared_error: 0.0939 - val_RMSE_P: 611.9124 - val_RMSE_T: 24.8222
# Epoch 147/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0061 - mean_absolute_error: 0.0566 - root_mean_squared_error: 0.0781 - RMSE_P: 545.6657 - RMSE_T: 24.5122 - val_loss: 0.0089 - val_mean_absolute_error: 0.0610 - val_root_mean_squared_error: 0.0941 - val_RMSE_P: 610.0896 - val_RMSE_T: 25.1573
# Epoch 148/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0060 - mean_absolute_error: 0.0555 - root_mean_squared_error: 0.0776 - RMSE_P: 543.2158 - RMSE_T: 23.5881 - val_loss: 0.0088 - val_mean_absolute_error: 0.0610 - val_root_mean_squared_error: 0.0939 - val_RMSE_P: 617.0493 - val_RMSE_T: 24.7432
# Epoch 149/5000
# ...
# Epoch 654/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0041 - mean_absolute_error: 0.0469 - root_mean_squared_error: 0.0637 - RMSE_P: 446.4087 - RMSE_T: 20.6338 - val_loss: 0.0092 - val_mean_absolute_error: 0.0616 - val_root_mean_squared_error: 0.0960 - val_RMSE_P: 638.4577 - val_RMSE_T: 24.0290
# Epoch 655/5000
# 39/39 [==============================] - 0s 4ms/step - loss: 0.0041 - mean_absolute_error: 0.0467 - root_mean_squared_error: 0.0639 - RMSE_P: 439.4487 - RMSE_T: 20.8225 - val_loss: 0.0090 - val_mean_absolute_error: 0.0611 - val_root_mean_squared_error: 0.0950 - val_RMSE_P: 631.8833 - val_RMSE_T: 23.9458
# Epoch 656/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0041 - mean_absolute_error: 0.0469 - root_mean_squared_error: 0.0642 - RMSE_P: 435.5108 - RMSE_T: 21.2381 - val_loss: 0.0090 - val_mean_absolute_error: 0.0611 - val_root_mean_squared_error: 0.0949 - val_RMSE_P: 628.8797 - val_RMSE_T: 24.0595
# Epoch 657/5000
# 39/39 [==============================] - 0s 4ms/step - loss: 0.0042 - mean_absolute_error: 0.0465 - root_mean_squared_error: 0.0645 - RMSE_P: 438.1786 - RMSE_T: 20.7296 - val_loss: 0.0092 - val_mean_absolute_error: 0.0609 - val_root_mean_squared_error: 0.0960 - val_RMSE_P: 635.6810 - val_RMSE_T: 23.5492
# Epoch 658/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0042 - mean_absolute_error: 0.0471 - root_mean_squared_error: 0.0649 - RMSE_P: 454.7131 - RMSE_T: 20.3581 - val_loss: 0.0092 - val_mean_absolute_error: 0.0613 - val_root_mean_squared_error: 0.0958 - val_RMSE_P: 634.9382 - val_RMSE_T: 23.9697
# Epoch 659/5000
# 39/39 [==============================] - 0s 4ms/step - loss: 0.0043 - mean_absolute_error: 0.0475 - root_mean_squared_error: 0.0657 - RMSE_P: 445.4473 - RMSE_T: 21.2951 - val_loss: 0.0092 - val_mean_absolute_error: 0.0613 - val_root_mean_squared_error: 0.0957 - val_RMSE_P: 637.1352 - val_RMSE_T: 23.7877
# Epoch 660/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0043 - mean_absolute_error: 0.0473 - root_mean_squared_error: 0.0653 - RMSE_P: 444.8691 - RMSE_T: 21.1799 - val_loss: 0.0093 - val_mean_absolute_error: 0.0616 - val_root_mean_squared_error: 0.0962 - val_RMSE_P: 635.0283 - val_RMSE_T: 24.2234
# Epoch 661/5000
# 39/39 [==============================] - 0s 4ms/step - loss: 0.0042 - mean_absolute_error: 0.0474 - root_mean_squared_error: 0.0647 - RMSE_P: 449.7158 - RMSE_T: 20.9020 - val_loss: 0.0093 - val_mean_absolute_error: 0.0615 - val_root_mean_squared_error: 0.0963 - val_RMSE_P: 635.4376 - val_RMSE_T: 24.1405
# Epoch 662/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0041 - mean_absolute_error: 0.0468 - root_mean_squared_error: 0.0643 - RMSE_P: 438.9991 - RMSE_T: 20.9614 - val_loss: 0.0092 - val_mean_absolute_error: 0.0614 - val_root_mean_squared_error: 0.0961 - val_RMSE_P: 634.9653 - val_RMSE_T: 24.0666
# Epoch 663/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0042 - mean_absolute_error: 0.0469 - root_mean_squared_error: 0.0644 - RMSE_P: 444.2380 - RMSE_T: 20.7262 - val_loss: 0.0090 - val_mean_absolute_error: 0.0606 - val_root_mean_squared_error: 0.0949 - val_RMSE_P: 630.7867 - val_RMSE_T: 23.4914
# Epoch 664/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0042 - mean_absolute_error: 0.0467 - root_mean_squared_error: 0.0647 - RMSE_P: 447.4521 - RMSE_T: 20.4233 - val_loss: 0.0089 - val_mean_absolute_error: 0.0597 - val_root_mean_squared_error: 0.0944 - val_RMSE_P: 626.0692 - val_RMSE_T: 22.9205
# Epoch 665/5000
# 39/39 [==============================] - 0s 4ms/step - loss: 0.0043 - mean_absolute_error: 0.0474 - root_mean_squared_error: 0.0653 - RMSE_P: 447.3395 - RMSE_T: 21.0803 - val_loss: 0.0090 - val_mean_absolute_error: 0.0601 - val_root_mean_squared_error: 0.0949 - val_RMSE_P: 626.3870 - val_RMSE_T: 23.2622
# Epoch 666/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0042 - mean_absolute_error: 0.0471 - root_mean_squared_error: 0.0645 - RMSE_P: 446.2278 - RMSE_T: 20.8603 - val_loss: 0.0090 - val_mean_absolute_error: 0.0606 - val_root_mean_squared_error: 0.0947 - val_RMSE_P: 626.6567 - val_RMSE_T: 23.6891
# Epoch 667/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0042 - mean_absolute_error: 0.0466 - root_mean_squared_error: 0.0647 - RMSE_P: 435.3374 - RMSE_T: 20.9821 - val_loss: 0.0090 - val_mean_absolute_error: 0.0611 - val_root_mean_squared_error: 0.0951 - val_RMSE_P: 628.6483 - val_RMSE_T: 24.0934
# Epoch 668/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0042 - mean_absolute_error: 0.0474 - root_mean_squared_error: 0.0650 - RMSE_P: 447.4250 - RMSE_T: 21.0586 - val_loss: 0.0089 - val_mean_absolute_error: 0.0604 - val_root_mean_squared_error: 0.0942 - val_RMSE_P: 625.0676 - val_RMSE_T: 23.5900
# Epoch 669/5000
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0042 - mean_absolute_error: 0.0472 - root_mean_squared_error: 0.0646 - RMSE_P: 450.1866 - RMSE_T: 20.6714 - val_loss: 0.0089 - val_mean_absolute_error: 0.0606 - val_root_mean_squared_error: 0.0945 - val_RMSE_P: 629.9310 - val_RMSE_T: 23.5450
# Epoch 670/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0040 - mean_absolute_error: 0.0459 - root_mean_squared_error: 0.0629 - RMSE_P: 436.7722 - RMSE_T: 20.1592 - val_loss: 0.0092 - val_mean_absolute_error: 0.0610 - val_root_mean_squared_error: 0.0957 - val_RMSE_P: 638.8644 - val_RMSE_T: 23.4563
# Epoch 671/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0042 - mean_absolute_error: 0.0481 - root_mean_squared_error: 0.0651 - RMSE_P: 457.6244 - RMSE_T: 21.2162 - val_loss: 0.0093 - val_mean_absolute_error: 0.0614 - val_root_mean_squared_error: 0.0967 - val_RMSE_P: 645.0995 - val_RMSE_T: 23.4871
# Epoch 672/5000
# 39/39 [==============================] - 0s 4ms/step - loss: 0.0042 - mean_absolute_error: 0.0471 - root_mean_squared_error: 0.0650 - RMSE_P: 445.8599 - RMSE_T: 20.9103 - val_loss: 0.0091 - val_mean_absolute_error: 0.0605 - val_root_mean_squared_error: 0.0952 - val_RMSE_P: 632.6883 - val_RMSE_T: 23.3023
# Epoch 673/5000
# 39/39 [==============================] - 0s 4ms/step - loss: 0.0041 - mean_absolute_error: 0.0475 - root_mean_squared_error: 0.0644 - RMSE_P: 451.5999 - RMSE_T: 20.8870 - val_loss: 0.0090 - val_mean_absolute_error: 0.0603 - val_root_mean_squared_error: 0.0950 - val_RMSE_P: 632.4059 - val_RMSE_T: 23.1378
# Epoch 674/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0042 - mean_absolute_error: 0.0470 - root_mean_squared_error: 0.0647 - RMSE_P: 445.5878 - RMSE_T: 20.7521 - val_loss: 0.0092 - val_mean_absolute_error: 0.0612 - val_root_mean_squared_error: 0.0960 - val_RMSE_P: 637.0361 - val_RMSE_T: 23.7695
# Epoch 675/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0041 - mean_absolute_error: 0.0458 - root_mean_squared_error: 0.0637 - RMSE_P: 430.1716 - RMSE_T: 20.5276 - val_loss: 0.0092 - val_mean_absolute_error: 0.0610 - val_root_mean_squared_error: 0.0958 - val_RMSE_P: 630.0599 - val_RMSE_T: 23.9668
# Epoch 676/5000
# 39/39 [==============================] - 0s 4ms/step - loss: 0.0040 - mean_absolute_error: 0.0461 - root_mean_squared_error: 0.0630 - RMSE_P: 435.6017 - RMSE_T: 20.5259 - val_loss: 0.0092 - val_mean_absolute_error: 0.0610 - val_root_mean_squared_error: 0.0961 - val_RMSE_P: 634.5195 - val_RMSE_T: 23.6801
# Epoch 677/5000
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0042 - mean_absolute_error: 0.0470 - root_mean_squared_error: 0.0647 - RMSE_P: 440.6733 - RMSE_T: 21.0977 - val_loss: 0.0093 - val_mean_absolute_error: 0.0611 - val_root_mean_squared_error: 0.0963 - val_RMSE_P: 635.3141 - val_RMSE_T: 23.6919
# Epoch 678/5000
# 39/39 [==============================] - 0s 6ms/step - loss: 0.0041 - mean_absolute_error: 0.0468 - root_mean_squared_error: 0.0641 - RMSE_P: 443.6249 - RMSE_T: 20.7203 - val_loss: 0.0090 - val_mean_absolute_error: 0.0601 - val_root_mean_squared_error: 0.0949 - val_RMSE_P: 628.0005 - val_RMSE_T: 23.1209
# Epoch 679/5000
# 39/39 [==============================] - 0s 4ms/step - loss: 0.0041 - mean_absolute_error: 0.0462 - root_mean_squared_error: 0.0639 - RMSE_P: 432.6478 - RMSE_T: 20.7785 - val_loss: 0.0090 - val_mean_absolute_error: 0.0607 - val_root_mean_squared_error: 0.0951 - val_RMSE_P: 628.3516 - val_RMSE_T: 23.6997
# Epoch 680/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0040 - mean_absolute_error: 0.0463 - root_mean_squared_error: 0.0635 - RMSE_P: 437.6767 - RMSE_T: 20.5423 - val_loss: 0.0089 - val_mean_absolute_error: 0.0604 - val_root_mean_squared_error: 0.0944 - val_RMSE_P: 627.6183 - val_RMSE_T: 23.4469
# Epoch 681/5000
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0040 - mean_absolute_error: 0.0468 - root_mean_squared_error: 0.0636 - RMSE_P: 436.1658 - RMSE_T: 21.1621 - val_loss: 0.0091 - val_mean_absolute_error: 0.0604 - val_root_mean_squared_error: 0.0954 - val_RMSE_P: 625.4028 - val_RMSE_T: 23.6384
# Epoch 682/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0044 - mean_absolute_error: 0.0484 - root_mean_squared_error: 0.0663 - RMSE_P: 456.7762 - RMSE_T: 21.5231 - val_loss: 0.0090 - val_mean_absolute_error: 0.0613 - val_root_mean_squared_error: 0.0950 - val_RMSE_P: 625.1337 - val_RMSE_T: 24.5303
# Epoch 683/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0041 - mean_absolute_error: 0.0469 - root_mean_squared_error: 0.0640 - RMSE_P: 446.3966 - RMSE_T: 20.6214 - val_loss: 0.0090 - val_mean_absolute_error: 0.0607 - val_root_mean_squared_error: 0.0949 - val_RMSE_P: 628.7703 - val_RMSE_T: 23.6752
# Epoch 684/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0044 - mean_absolute_error: 0.0476 - root_mean_squared_error: 0.0663 - RMSE_P: 455.9401 - RMSE_T: 20.7546 - val_loss: 0.0092 - val_mean_absolute_error: 0.0613 - val_root_mean_squared_error: 0.0962 - val_RMSE_P: 632.3654 - val_RMSE_T: 24.1480
# Epoch 685/5000
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0044 - mean_absolute_error: 0.0476 - root_mean_squared_error: 0.0661 - RMSE_P: 454.7234 - RMSE_T: 20.8394 - val_loss: 0.0090 - val_mean_absolute_error: 0.0603 - val_root_mean_squared_error: 0.0947 - val_RMSE_P: 622.8122 - val_RMSE_T: 23.6814
# Epoch 686/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0041 - mean_absolute_error: 0.0460 - root_mean_squared_error: 0.0637 - RMSE_P: 439.2126 - RMSE_T: 20.1521 - val_loss: 0.0090 - val_mean_absolute_error: 0.0607 - val_root_mean_squared_error: 0.0948 - val_RMSE_P: 629.9274 - val_RMSE_T: 23.6331
# Epoch 687/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0042 - mean_absolute_error: 0.0472 - root_mean_squared_error: 0.0644 - RMSE_P: 440.9980 - RMSE_T: 21.3025 - val_loss: 0.0093 - val_mean_absolute_error: 0.0616 - val_root_mean_squared_error: 0.0962 - val_RMSE_P: 636.7092 - val_RMSE_T: 24.1826
# Epoch 688/5000
# 39/39 [==============================] - 0s 4ms/step - loss: 0.0040 - mean_absolute_error: 0.0460 - root_mean_squared_error: 0.0636 - RMSE_P: 433.1613 - RMSE_T: 20.5678 - val_loss: 0.0091 - val_mean_absolute_error: 0.0615 - val_root_mean_squared_error: 0.0952 - val_RMSE_P: 634.5765 - val_RMSE_T: 24.1624
# Epoch 689/5000
# 39/39 [==============================] - 0s 8ms/step - loss: 0.0042 - mean_absolute_error: 0.0470 - root_mean_squared_error: 0.0650 - RMSE_P: 444.6533 - RMSE_T: 20.8513 - val_loss: 0.0091 - val_mean_absolute_error: 0.0612 - val_root_mean_squared_error: 0.0952 - val_RMSE_P: 632.0450 - val_RMSE_T: 24.0218
# Epoch 690/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0041 - mean_absolute_error: 0.0462 - root_mean_squared_error: 0.0640 - RMSE_P: 433.1394 - RMSE_T: 20.7184 - val_loss: 0.0090 - val_mean_absolute_error: 0.0614 - val_root_mean_squared_error: 0.0951 - val_RMSE_P: 632.7380 - val_RMSE_T: 24.1639
# Epoch 691/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0040 - mean_absolute_error: 0.0465 - root_mean_squared_error: 0.0633 - RMSE_P: 435.0349 - RMSE_T: 20.9536 - val_loss: 0.0091 - val_mean_absolute_error: 0.0613 - val_root_mean_squared_error: 0.0955 - val_RMSE_P: 634.0786 - val_RMSE_T: 24.0154
# Epoch 692/5000
# 39/39 [==============================] - 0s 4ms/step - loss: 0.0039 - mean_absolute_error: 0.0461 - root_mean_squared_error: 0.0628 - RMSE_P: 438.9194 - RMSE_T: 20.2613 - val_loss: 0.0090 - val_mean_absolute_error: 0.0607 - val_root_mean_squared_error: 0.0947 - val_RMSE_P: 628.9349 - val_RMSE_T: 23.7085
# Epoch 693/5000
# 39/39 [==============================] - 0s 4ms/step - loss: 0.0040 - mean_absolute_error: 0.0462 - root_mean_squared_error: 0.0630 - RMSE_P: 429.4739 - RMSE_T: 20.9052 - val_loss: 0.0090 - val_mean_absolute_error: 0.0606 - val_root_mean_squared_error: 0.0949 - val_RMSE_P: 622.5522 - val_RMSE_T: 24.0178
# Epoch 694/5000
# 39/39 [==============================] - 0s 4ms/step - loss: 0.0041 - mean_absolute_error: 0.0464 - root_mean_squared_error: 0.0644 - RMSE_P: 437.4751 - RMSE_T: 20.6527 - val_loss: 0.0091 - val_mean_absolute_error: 0.0599 - val_root_mean_squared_error: 0.0954 - val_RMSE_P: 618.4886 - val_RMSE_T: 23.4809
# Epoch 695/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0041 - mean_absolute_error: 0.0465 - root_mean_squared_error: 0.0643 - RMSE_P: 442.6930 - RMSE_T: 20.4642 - val_loss: 0.0091 - val_mean_absolute_error: 0.0604 - val_root_mean_squared_error: 0.0957 - val_RMSE_P: 622.6310 - val_RMSE_T: 23.7680
# Epoch 696/5000
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0044 - mean_absolute_error: 0.0473 - root_mean_squared_error: 0.0660 - RMSE_P: 443.2036 - RMSE_T: 21.2359 - val_loss: 0.0090 - val_mean_absolute_error: 0.0607 - val_root_mean_squared_error: 0.0951 - val_RMSE_P: 624.0616 - val_RMSE_T: 23.9504
# Epoch 697/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0041 - mean_absolute_error: 0.0469 - root_mean_squared_error: 0.0639 - RMSE_P: 440.4428 - RMSE_T: 21.0200 - val_loss: 0.0090 - val_mean_absolute_error: 0.0603 - val_root_mean_squared_error: 0.0951 - val_RMSE_P: 624.2463 - val_RMSE_T: 23.5964
# Epoch 698/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0041 - mean_absolute_error: 0.0469 - root_mean_squared_error: 0.0641 - RMSE_P: 439.1423 - RMSE_T: 21.0793 - val_loss: 0.0090 - val_mean_absolute_error: 0.0601 - val_root_mean_squared_error: 0.0948 - val_RMSE_P: 624.1866 - val_RMSE_T: 23.4022
# Epoch 699/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0041 - mean_absolute_error: 0.0468 - root_mean_squared_error: 0.0640 - RMSE_P: 444.5024 - RMSE_T: 20.6146 - val_loss: 0.0092 - val_mean_absolute_error: 0.0613 - val_root_mean_squared_error: 0.0961 - val_RMSE_P: 631.0841 - val_RMSE_T: 24.1885
# Epoch 700/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0041 - mean_absolute_error: 0.0461 - root_mean_squared_error: 0.0642 - RMSE_P: 436.5020 - RMSE_T: 20.3786 - val_loss: 0.0090 - val_mean_absolute_error: 0.0600 - val_root_mean_squared_error: 0.0946 - val_RMSE_P: 625.5076 - val_RMSE_T: 23.2367
# Epoch 701/5000
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0041 - mean_absolute_error: 0.0468 - root_mean_squared_error: 0.0639 - RMSE_P: 445.7391 - RMSE_T: 20.5846 - val_loss: 0.0091 - val_mean_absolute_error: 0.0604 - val_root_mean_squared_error: 0.0952 - val_RMSE_P: 631.2257 - val_RMSE_T: 23.2410
# Epoch 702/5000
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0040 - mean_absolute_error: 0.0464 - root_mean_squared_error: 0.0631 - RMSE_P: 440.9798 - RMSE_T: 20.4412 - val_loss: 0.0090 - val_mean_absolute_error: 0.0607 - val_root_mean_squared_error: 0.0950 - val_RMSE_P: 632.3148 - val_RMSE_T: 23.5326
# INFO:tensorflow:Assets written to: saved_models\01b_BtThermobaromater_composition\assets
# INFO:tensorflow:Assets written to: saved_models\01b_BtThermobaromater_composition\assets

# %% [markdown]
# # Plot training history

# %%
plot_training_curve("01b_BtThermobaromater_composition.log", color="red", label="model", log_scale=True, ylims=[None, (2.5, 100), (500, 1500)])
# Out:
# (<Figure size 1200x400 with 3 Axes>,
#  array([<Axes: xlabel='Epoch', ylabel='Loss'>,
#         <Axes: xlabel='Epoch', ylabel='Temperature RMSE [K]'>,
#         <Axes: xlabel='Epoch', ylabel='Pressure RMSE [bar]'>], dtype=object))

# %%
y_true = pt_val
y_pred = inv_scaling_pt(model.predict(data_val))

color = "red"

prediction_vs_truth(y_true, y_pred, color)
# Out:
# 7/7 [==============================] - 0s 1ms/step
# (<Figure size 800x400 with 2 Axes>,
#  array([<Axes: xlabel='True pressure [bar]', ylabel='Predicted pressure [bar]'>,
#         <Axes: xlabel='True temperature [°C]', ylabel='Predicted temperature [°C]'>],
#        dtype=object))
