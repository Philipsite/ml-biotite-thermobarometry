# %% [markdown]
# :warning:**IMPORTANT NOTICE**:warning:\
# *Since the initial parameterisation and gradient descent optimisation are stochastic processes, the training of a neural network is not fully reproducible.*
#
# *Therefore, it is not recommended to re-run this script as it will overwrite the original calibration of the neural network used in the work presented here.
# The purpose of this script is solely to document the training procedure and can be copied as a template to fit other new neural networks.*
#
# *To experiment with the models calibrated here, they can be loaded from the `saved_models` directory.*

# %% [markdown]
# # **Biotite Thermobarometer**: Direct fit on natural biotite composition data

# %% [markdown]
# **TEST with latest version of Pattison & Forsahw (during review in Februar 2025)**
#
# This notebook is used for the final model fitting of a biotite thermobarometer based on bioite compositional data from the databse of Pattison & Forshaw (in prep.).
#
# Based on hyperparameter optimisation and feature engineering the following dataset and hyperparameters were selected:
#
# **Data**:\
# Elements [apfu] of the biotite solution models: Si, Ti, Al, Fe, Mg, Mn\
# Feature engineering showed no significant performance improvement when including Na & K
#
# *Normalisation*:
# - Normalisation of compositional input data [-1, 1], input normalisation parameters (mean + std) are learned from the training data.
# - MinMaxScaler for target data (*P*-*T*) [0, 1], traget scaling parameters (min + max) are hard-coded to the range of the training data: *P* [1500, 10000] [bar] and *T* [400, 900] [°C].
#
# **Hyperparameters**:
# - Architecture: "small" (1 hidden layer with 16 neurons), best validation performance for *T* and *P*
# - Learning rate: 0.001, all lr resulted in similar performance only training duration varied, 0.001 was chosen for faster training while keeping lr small\
# - Regularisation: None. No singificant performance improvement by using larger networks with regularisation
#
# *Parameters not systematically tested*:
# - Activation function: "relu", not systematically tested, but no effect in exploratory tests
# - Optimizer: "adam"
# - Loss function: "mean_squared_error", given by regression task
# - Lr scheduler: Inverse time decay
# - Batch size: 50

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf

from pathlib import Path
from keras.models import Sequential
from keras.layers import Dense, Normalization, BatchNormalization, LayerNormalization, Dropout
from keras.losses import MeanSquaredError
from keras.optimizers import Adam, schedules
from keras.metrics import MeanAbsoluteError, RootMeanSquaredError
from keras.callbacks import CSVLogger, EarlyStopping
from sklearn.model_selection import train_test_split

from ml_tb.normalisation import MinMaxScaler
from ml_tb.metrics import RMSE_denormalised_T, RMSE_denormalised_P
from ml_tb.plot import plot_training_curve, prediction_vs_truth

# %% [markdown]
# ## Import data, pre-procesing and train/test split
#
# Validation set is **10%** of the training set. Approx. 100 samples. Validation fraction is reduced to keep the training set as large as possible. Witht the set of hyperparameters obtained by hyperparameter optimisation, overfittings should be kept to a minimum.

# %%
VALIDATION_FRACTION = 0.1

# %% [markdown]
# Global scaling parameters for MinMaxScaling of the target data are hard-coded to the range of the training data.

# %%
scaling_pt = MinMaxScaler(min=[1500, 400], max=[10000, 900], axis=0)
inv_scaling_pt = MinMaxScaler(min=[1500, 400], max=[10000, 900], axis=0, invert=True)

# %%
# load excel file
data = pd.read_excel(Path("Metapelite-Database_Bt_CLEAN_2025-02-25.xlsx"))

biotite_composition = np.zeros(shape=(len(data), 6))
biotite_composition[:, 0] = data["Bt-Si"]
biotite_composition[:, 1] = data["Bt-Ti"]
biotite_composition[:, 2] = data["Bt-Al"]
biotite_composition[:, 3] = data["Bt-FeTot"]
biotite_composition[:, 4] = data["Bt-Mn"]
biotite_composition[:, 5] = data["Bt-Mg"]

pt = np.zeros(shape=(len(data), 2))
pt[:, 0] = data["Pressure estimate random uniform"] * 1000 # convert to bar
pt[:, 1] = data["Temperature random ordered after Ti-in-Bt"]

# check for NaN values (should be already filtered out)
print("NaN values in biotite composition: ", np.isnan(biotite_composition).any())
print("NaN values in PT: ", np.isnan(pt).any())
# Out:
# NaN values in biotite composition:  False
# NaN values in PT:  False

# %%
# test train split
data_train, data_val, pt_train, pt_val = train_test_split(biotite_composition, pt, test_size=VALIDATION_FRACTION, shuffle=True)

# NORMALISATION
normalisation_biotite_composition = Normalization(axis=-1)
normalisation_biotite_composition.adapt(data_train)

print(normalisation_biotite_composition.mean.numpy())
print(np.sqrt(normalisation_biotite_composition.variance.numpy()))

# SCALING of PT
pt_train_norm = scaling_pt(pt_train)
pt_val_norm = scaling_pt(pt_val)

print("After scaling, the minimal values of P and T are: ", np.min(pt_train_norm, axis=0))
print("After scaling, the maximal values of P and T are: ", np.max(pt_train_norm, axis=0))
# Out:
# [[2.7082555  0.12043887 1.7143489  1.2353271  0.00842916 1.08035   ]]
# [[0.05328848 0.04798059 0.09761142 0.2300482  0.00723119 0.2626512 ]]
# After scaling, the minimal values of P and T are:  [ 0.00224826 -0.05432373]
# After scaling, the maximal values of P and T are:  [0.9170322  0.89971226]

# %% [markdown]
# ## Set-up global training parameters
#
# Define a function to calculate RMSE for pressure and temperature for unscaled values to have an interpretable metric.

# %%
def RMSE_P(y_true, y_pred):
    return RMSE_denormalised_P(y_true, y_pred, inv_scaling_pt)


def RMSE_T(y_true, y_pred):
    return RMSE_denormalised_T(y_true, y_pred, inv_scaling_pt)

# %%
BATCH_SIZE = 50
STEPS_PER_EPOCH = len(data_train) // BATCH_SIZE
MAX_EPOCHS = 5000

lr_schedule = schedules.InverseTimeDecay(0.001, decay_steps=STEPS_PER_EPOCH*1000, decay_rate=1, staircase=False)

LOSS = MeanSquaredError()
METRICS = [MeanAbsoluteError(), RootMeanSquaredError(), RMSE_P, RMSE_T]
OPT = Adam(lr_schedule)

CALLBACKS = [CSVLogger("01c_BtThermobaromater_Feb2025.log"), EarlyStopping(monitor="loss", patience=50, restore_best_weights=True)]
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.

# %% [markdown]
# ### Build model

# %%
model = Sequential()
model.add(normalisation_biotite_composition)
model.add(Dense(16, activation="relu"))
model.add(Dense(2))

model.compile(optimizer=OPT, loss=LOSS, metrics=METRICS)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  normalization (Normalizati  (None, 6)                 13
#  on)
#
#  dense (Dense)               (None, 16)                112
#
#  dense_1 (Dense)             (None, 2)                 34
#
# =================================================================
# Total params: 159 (640.00 Byte)
# Trainable params: 146 (584.00 Byte)
# Non-trainable params: 13 (56.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Train model

# %%
history = model.fit(data_train, pt_train_norm,
                    validation_data=(data_val, pt_val_norm),
                    batch_size=BATCH_SIZE,
                    epochs=MAX_EPOCHS,
                    callbacks=CALLBACKS)

model.save(Path("saved_models", "01c_BtThermobaromater_Feb25"))
# Out:
# Epoch 1/5000
# 45/45 [==============================] - 0s 3ms/step - loss: 0.4896 - mean_absolute_error: 0.5679 - root_mean_squared_error: 0.6997 - RMSE_P: 6113.0063 - RMSE_T: 320.3717 - val_loss: 0.2652 - val_mean_absolute_error: 0.4235 - val_root_mean_squared_error: 0.5149 - val_RMSE_P: 4682.8008 - val_RMSE_T: 235.3340
# Epoch 2/5000
# 45/45 [==============================] - 0s 643us/step - loss: 0.1761 - mean_absolute_error: 0.3429 - root_mean_squared_error: 0.4196 - RMSE_P: 3953.8062 - RMSE_T: 177.3111 - val_loss: 0.1203 - val_mean_absolute_error: 0.2790 - val_root_mean_squared_error: 0.3468 - val_RMSE_P: 3326.6738 - val_RMSE_T: 145.8009
# Epoch 3/5000
# 45/45 [==============================] - 0s 494us/step - loss: 0.0944 - mean_absolute_error: 0.2459 - root_mean_squared_error: 0.3072 - RMSE_P: 2974.1211 - RMSE_T: 125.8966 - val_loss: 0.0826 - val_mean_absolute_error: 0.2240 - val_root_mean_squared_error: 0.2873 - val_RMSE_P: 2729.0740 - val_RMSE_T: 121.1559
# Epoch 4/5000
# 45/45 [==============================] - 0s 494us/step - loss: 0.0655 - mean_absolute_error: 0.2018 - root_mean_squared_error: 0.2559 - RMSE_P: 2450.2856 - RMSE_T: 106.7852 - val_loss: 0.0639 - val_mean_absolute_error: 0.1920 - val_root_mean_squared_error: 0.2527 - val_RMSE_P: 2360.3154 - val_RMSE_T: 108.7845
# Epoch 5/5000
# 45/45 [==============================] - 0s 491us/step - loss: 0.0498 - mean_absolute_error: 0.1754 - root_mean_squared_error: 0.2231 - RMSE_P: 2126.6812 - RMSE_T: 93.8092 - val_loss: 0.0528 - val_mean_absolute_error: 0.1713 - val_root_mean_squared_error: 0.2297 - val_RMSE_P: 2109.6633 - val_RMSE_T: 101.0275
# Epoch 6/5000
# 45/45 [==============================] - 0s 483us/step - loss: 0.0404 - mean_absolute_error: 0.1568 - root_mean_squared_error: 0.2011 - RMSE_P: 1910.2898 - RMSE_T: 85.5376 - val_loss: 0.0454 - val_mean_absolute_error: 0.1563 - val_root_mean_squared_error: 0.2132 - val_RMSE_P: 1927.5603 - val_RMSE_T: 95.2940
# Epoch 7/5000
# 45/45 [==============================] - 0s 464us/step - loss: 0.0346 - mean_absolute_error: 0.1438 - root_mean_squared_error: 0.1859 - RMSE_P: 1774.7976 - RMSE_T: 78.2027 - val_loss: 0.0397 - val_mean_absolute_error: 0.1458 - val_root_mean_squared_error: 0.1994 - val_RMSE_P: 1802.0989 - val_RMSE_T: 89.2046
# Epoch 8/5000
# 45/45 [==============================] - 0s 484us/step - loss: 0.0306 - mean_absolute_error: 0.1342 - root_mean_squared_error: 0.1748 - RMSE_P: 1670.0983 - RMSE_T: 72.9213 - val_loss: 0.0357 - val_mean_absolute_error: 0.1382 - val_root_mean_squared_error: 0.1889 - val_RMSE_P: 1701.9860 - val_RMSE_T: 84.7730
# Epoch 9/5000
# 45/45 [==============================] - 0s 479us/step - loss: 0.0278 - mean_absolute_error: 0.1276 - root_mean_squared_error: 0.1668 - RMSE_P: 1592.2343 - RMSE_T: 69.6884 - val_loss: 0.0324 - val_mean_absolute_error: 0.1319 - val_root_mean_squared_error: 0.1801 - val_RMSE_P: 1621.3922 - val_RMSE_T: 80.9979
# Epoch 10/5000
# 45/45 [==============================] - 0s 463us/step - loss: 0.0258 - mean_absolute_error: 0.1220 - root_mean_squared_error: 0.1607 - RMSE_P: 1548.6809 - RMSE_T: 66.7956 - val_loss: 0.0303 - val_mean_absolute_error: 0.1278 - val_root_mean_squared_error: 0.1740 - val_RMSE_P: 1570.0049 - val_RMSE_T: 78.0872
# Epoch 11/5000
# 45/45 [==============================] - 0s 473us/step - loss: 0.0244 - mean_absolute_error: 0.1181 - root_mean_squared_error: 0.1562 - RMSE_P: 1505.4224 - RMSE_T: 64.2172 - val_loss: 0.0285 - val_mean_absolute_error: 0.1235 - val_root_mean_squared_error: 0.1687 - val_RMSE_P: 1524.4928 - val_RMSE_T: 75.6928
# Epoch 12/5000
# 45/45 [==============================] - 0s 465us/step - loss: 0.0233 - mean_absolute_error: 0.1147 - root_mean_squared_error: 0.1525 - RMSE_P: 1476.4963 - RMSE_T: 62.3084 - val_loss: 0.0267 - val_mean_absolute_error: 0.1209 - val_root_mean_squared_error: 0.1635 - val_RMSE_P: 1489.4668 - val_RMSE_T: 72.8457
# Epoch 13/5000
# 45/45 [==============================] - 0s 487us/step - loss: 0.0225 - mean_absolute_error: 0.1124 - root_mean_squared_error: 0.1499 - RMSE_P: 1458.5017 - RMSE_T: 61.6942 - val_loss: 0.0258 - val_mean_absolute_error: 0.1189 - val_root_mean_squared_error: 0.1607 - val_RMSE_P: 1469.1118 - val_RMSE_T: 71.2950
# Epoch 14/5000
# 45/45 [==============================] - 0s 464us/step - loss: 0.0217 - mean_absolute_error: 0.1100 - root_mean_squared_error: 0.1474 - RMSE_P: 1434.9142 - RMSE_T: 60.2888 - val_loss: 0.0249 - val_mean_absolute_error: 0.1161 - val_root_mean_squared_error: 0.1579 - val_RMSE_P: 1442.6582 - val_RMSE_T: 70.2021
# Epoch 15/5000
# 45/45 [==============================] - 0s 471us/step - loss: 0.0211 - mean_absolute_error: 0.1087 - root_mean_squared_error: 0.1454 - RMSE_P: 1417.0747 - RMSE_T: 58.8665 - val_loss: 0.0241 - val_mean_absolute_error: 0.1145 - val_root_mean_squared_error: 0.1553 - val_RMSE_P: 1423.2949 - val_RMSE_T: 68.9748
# Epoch 16/5000
# 45/45 [==============================] - 0s 474us/step - loss: 0.0206 - mean_absolute_error: 0.1069 - root_mean_squared_error: 0.1436 - RMSE_P: 1402.9806 - RMSE_T: 58.2444 - val_loss: 0.0236 - val_mean_absolute_error: 0.1132 - val_root_mean_squared_error: 0.1537 - val_RMSE_P: 1415.4788 - val_RMSE_T: 67.8192
# Epoch 17/5000
# 45/45 [==============================] - 0s 460us/step - loss: 0.0202 - mean_absolute_error: 0.1057 - root_mean_squared_error: 0.1421 - RMSE_P: 1383.9476 - RMSE_T: 57.3409 - val_loss: 0.0231 - val_mean_absolute_error: 0.1122 - val_root_mean_squared_error: 0.1519 - val_RMSE_P: 1402.7543 - val_RMSE_T: 66.8950
# Epoch 18/5000
# 45/45 [==============================] - 0s 468us/step - loss: 0.0197 - mean_absolute_error: 0.1043 - root_mean_squared_error: 0.1405 - RMSE_P: 1368.5966 - RMSE_T: 56.5868 - val_loss: 0.0225 - val_mean_absolute_error: 0.1105 - val_root_mean_squared_error: 0.1499 - val_RMSE_P: 1387.1523 - val_RMSE_T: 65.7657
# Epoch 19/5000
# 45/45 [==============================] - 0s 456us/step - loss: 0.0195 - mean_absolute_error: 0.1034 - root_mean_squared_error: 0.1397 - RMSE_P: 1370.9070 - RMSE_T: 56.2481 - val_loss: 0.0220 - val_mean_absolute_error: 0.1094 - val_root_mean_squared_error: 0.1483 - val_RMSE_P: 1378.7544 - val_RMSE_T: 64.6882
# Epoch 20/5000
# 45/45 [==============================] - 0s 457us/step - loss: 0.0192 - mean_absolute_error: 0.1027 - root_mean_squared_error: 0.1385 - RMSE_P: 1352.2920 - RMSE_T: 55.5570 - val_loss: 0.0218 - val_mean_absolute_error: 0.1083 - val_root_mean_squared_error: 0.1476 - val_RMSE_P: 1374.9740 - val_RMSE_T: 64.2563
# Epoch 21/5000
# 45/45 [==============================] - 0s 462us/step - loss: 0.0189 - mean_absolute_error: 0.1017 - root_mean_squared_error: 0.1376 - RMSE_P: 1347.0164 - RMSE_T: 55.2592 - val_loss: 0.0216 - val_mean_absolute_error: 0.1080 - val_root_mean_squared_error: 0.1469 - val_RMSE_P: 1373.6167 - val_RMSE_T: 63.6142
# Epoch 22/5000
# 45/45 [==============================] - 0s 476us/step - loss: 0.0187 - mean_absolute_error: 0.1010 - root_mean_squared_error: 0.1368 - RMSE_P: 1344.3728 - RMSE_T: 55.1136 - val_loss: 0.0212 - val_mean_absolute_error: 0.1066 - val_root_mean_squared_error: 0.1457 - val_RMSE_P: 1364.7034 - val_RMSE_T: 62.8525
# Epoch 23/5000
# 45/45 [==============================] - 0s 464us/step - loss: 0.0185 - mean_absolute_error: 0.1000 - root_mean_squared_error: 0.1359 - RMSE_P: 1330.7885 - RMSE_T: 54.4425 - val_loss: 0.0210 - val_mean_absolute_error: 0.1061 - val_root_mean_squared_error: 0.1448 - val_RMSE_P: 1360.9874 - val_RMSE_T: 62.1355
# Epoch 24/5000
# 45/45 [==============================] - 0s 521us/step - loss: 0.0183 - mean_absolute_error: 0.0998 - root_mean_squared_error: 0.1352 - RMSE_P: 1322.0302 - RMSE_T: 54.1896 - val_loss: 0.0210 - val_mean_absolute_error: 0.1055 - val_root_mean_squared_error: 0.1450 - val_RMSE_P: 1370.1696 - val_RMSE_T: 61.7600
# Epoch 25/5000
# 45/45 [==============================] - 0s 464us/step - loss: 0.0181 - mean_absolute_error: 0.0989 - root_mean_squared_error: 0.1345 - RMSE_P: 1310.4390 - RMSE_T: 53.8204 - val_loss: 0.0206 - val_mean_absolute_error: 0.1043 - val_root_mean_squared_error: 0.1435 - val_RMSE_P: 1354.7838 - val_RMSE_T: 61.2010
# Epoch 26/5000
# 45/45 [==============================] - 0s 489us/step - loss: 0.0180 - mean_absolute_error: 0.0985 - root_mean_squared_error: 0.1341 - RMSE_P: 1315.4545 - RMSE_T: 53.1906 - val_loss: 0.0206 - val_mean_absolute_error: 0.1040 - val_root_mean_squared_error: 0.1435 - val_RMSE_P: 1357.8763 - val_RMSE_T: 61.0550
# Epoch 27/5000
# 45/45 [==============================] - 0s 477us/step - loss: 0.0179 - mean_absolute_error: 0.0978 - root_mean_squared_error: 0.1336 - RMSE_P: 1310.6608 - RMSE_T: 53.3933 - val_loss: 0.0205 - val_mean_absolute_error: 0.1043 - val_root_mean_squared_error: 0.1433 - val_RMSE_P: 1359.7578 - val_RMSE_T: 60.6943
# Epoch 28/5000
# 45/45 [==============================] - 0s 460us/step - loss: 0.0177 - mean_absolute_error: 0.0977 - root_mean_squared_error: 0.1331 - RMSE_P: 1307.9146 - RMSE_T: 53.2037 - val_loss: 0.0204 - val_mean_absolute_error: 0.1035 - val_root_mean_squared_error: 0.1428 - val_RMSE_P: 1361.1366 - val_RMSE_T: 60.0164
# Epoch 29/5000
# 45/45 [==============================] - 0s 459us/step - loss: 0.0176 - mean_absolute_error: 0.0971 - root_mean_squared_error: 0.1326 - RMSE_P: 1297.6362 - RMSE_T: 52.7022 - val_loss: 0.0201 - val_mean_absolute_error: 0.1022 - val_root_mean_squared_error: 0.1418 - val_RMSE_P: 1344.4525 - val_RMSE_T: 60.0240
# Epoch 30/5000
# 45/45 [==============================] - 0s 460us/step - loss: 0.0174 - mean_absolute_error: 0.0965 - root_mean_squared_error: 0.1320 - RMSE_P: 1298.9137 - RMSE_T: 52.5691 - val_loss: 0.0199 - val_mean_absolute_error: 0.1023 - val_root_mean_squared_error: 0.1410 - val_RMSE_P: 1342.5093 - val_RMSE_T: 59.1826
# Epoch 31/5000
# 45/45 [==============================] - 0s 523us/step - loss: 0.0174 - mean_absolute_error: 0.0966 - root_mean_squared_error: 0.1320 - RMSE_P: 1299.3190 - RMSE_T: 52.2847 - val_loss: 0.0201 - val_mean_absolute_error: 0.1018 - val_root_mean_squared_error: 0.1418 - val_RMSE_P: 1357.0750 - val_RMSE_T: 59.1301
# Epoch 32/5000
# 45/45 [==============================] - 0s 493us/step - loss: 0.0172 - mean_absolute_error: 0.0957 - root_mean_squared_error: 0.1311 - RMSE_P: 1285.4764 - RMSE_T: 51.7836 - val_loss: 0.0198 - val_mean_absolute_error: 0.1010 - val_root_mean_squared_error: 0.1407 - val_RMSE_P: 1337.9795 - val_RMSE_T: 59.2041
# Epoch 33/5000
# 45/45 [==============================] - 0s 480us/step - loss: 0.0172 - mean_absolute_error: 0.0956 - root_mean_squared_error: 0.1310 - RMSE_P: 1290.1831 - RMSE_T: 51.9148 - val_loss: 0.0196 - val_mean_absolute_error: 0.1006 - val_root_mean_squared_error: 0.1402 - val_RMSE_P: 1342.7834 - val_RMSE_T: 58.2492
# Epoch 34/5000
# 45/45 [==============================] - 0s 491us/step - loss: 0.0171 - mean_absolute_error: 0.0954 - root_mean_squared_error: 0.1309 - RMSE_P: 1285.8823 - RMSE_T: 51.8496 - val_loss: 0.0196 - val_mean_absolute_error: 0.1005 - val_root_mean_squared_error: 0.1402 - val_RMSE_P: 1339.2606 - val_RMSE_T: 58.5902
# Epoch 35/5000
# 45/45 [==============================] - 0s 478us/step - loss: 0.0170 - mean_absolute_error: 0.0954 - root_mean_squared_error: 0.1305 - RMSE_P: 1290.3364 - RMSE_T: 51.4988 - val_loss: 0.0195 - val_mean_absolute_error: 0.0997 - val_root_mean_squared_error: 0.1398 - val_RMSE_P: 1334.7765 - val_RMSE_T: 58.4257
# Epoch 36/5000
# 45/45 [==============================] - 0s 490us/step - loss: 0.0170 - mean_absolute_error: 0.0948 - root_mean_squared_error: 0.1303 - RMSE_P: 1287.7870 - RMSE_T: 51.5708 - val_loss: 0.0196 - val_mean_absolute_error: 0.1005 - val_root_mean_squared_error: 0.1400 - val_RMSE_P: 1344.3108 - val_RMSE_T: 58.0614
# Epoch 37/5000
# 45/45 [==============================] - 0s 474us/step - loss: 0.0168 - mean_absolute_error: 0.0945 - root_mean_squared_error: 0.1297 - RMSE_P: 1282.6632 - RMSE_T: 51.5072 - val_loss: 0.0192 - val_mean_absolute_error: 0.0993 - val_root_mean_squared_error: 0.1386 - val_RMSE_P: 1330.9216 - val_RMSE_T: 57.3221
# Epoch 38/5000
# 45/45 [==============================] - 0s 464us/step - loss: 0.0168 - mean_absolute_error: 0.0944 - root_mean_squared_error: 0.1296 - RMSE_P: 1276.9343 - RMSE_T: 50.9321 - val_loss: 0.0192 - val_mean_absolute_error: 0.0994 - val_root_mean_squared_error: 0.1387 - val_RMSE_P: 1331.3496 - val_RMSE_T: 57.3792
# Epoch 39/5000
# 45/45 [==============================] - 0s 472us/step - loss: 0.0167 - mean_absolute_error: 0.0941 - root_mean_squared_error: 0.1292 - RMSE_P: 1274.8735 - RMSE_T: 50.6954 - val_loss: 0.0193 - val_mean_absolute_error: 0.0999 - val_root_mean_squared_error: 0.1389 - val_RMSE_P: 1336.9148 - val_RMSE_T: 57.1333
# Epoch 40/5000
# 45/45 [==============================] - 0s 484us/step - loss: 0.0167 - mean_absolute_error: 0.0938 - root_mean_squared_error: 0.1291 - RMSE_P: 1281.8093 - RMSE_T: 50.8849 - val_loss: 0.0190 - val_mean_absolute_error: 0.0985 - val_root_mean_squared_error: 0.1379 - val_RMSE_P: 1327.0032 - val_RMSE_T: 56.7706
# Epoch 41/5000
# 45/45 [==============================] - 0s 461us/step - loss: 0.0166 - mean_absolute_error: 0.0937 - root_mean_squared_error: 0.1287 - RMSE_P: 1271.6580 - RMSE_T: 50.2141 - val_loss: 0.0191 - val_mean_absolute_error: 0.0980 - val_root_mean_squared_error: 0.1382 - val_RMSE_P: 1331.1746 - val_RMSE_T: 56.7588
# Epoch 42/5000
# 45/45 [==============================] - 0s 462us/step - loss: 0.0165 - mean_absolute_error: 0.0933 - root_mean_squared_error: 0.1286 - RMSE_P: 1262.7472 - RMSE_T: 50.1927 - val_loss: 0.0190 - val_mean_absolute_error: 0.0977 - val_root_mean_squared_error: 0.1378 - val_RMSE_P: 1326.3453 - val_RMSE_T: 56.6968
# Epoch 43/5000
# 45/45 [==============================] - 0s 457us/step - loss: 0.0165 - mean_absolute_error: 0.0932 - root_mean_squared_error: 0.1284 - RMSE_P: 1270.8466 - RMSE_T: 50.1971 - val_loss: 0.0188 - val_mean_absolute_error: 0.0978 - val_root_mean_squared_error: 0.1373 - val_RMSE_P: 1324.4908 - val_RMSE_T: 56.2376
# Epoch 44/5000
# 45/45 [==============================] - 0s 451us/step - loss: 0.0164 - mean_absolute_error: 0.0929 - root_mean_squared_error: 0.1281 - RMSE_P: 1274.9241 - RMSE_T: 49.8582 - val_loss: 0.0190 - val_mean_absolute_error: 0.0979 - val_root_mean_squared_error: 0.1378 - val_RMSE_P: 1335.8387 - val_RMSE_T: 55.9328
# Epoch 45/5000
# 45/45 [==============================] - 0s 457us/step - loss: 0.0164 - mean_absolute_error: 0.0929 - root_mean_squared_error: 0.1282 - RMSE_P: 1273.6459 - RMSE_T: 49.8523 - val_loss: 0.0191 - val_mean_absolute_error: 0.0989 - val_root_mean_squared_error: 0.1382 - val_RMSE_P: 1349.5837 - val_RMSE_T: 55.2935
# Epoch 46/5000
# 45/45 [==============================] - 0s 462us/step - loss: 0.0164 - mean_absolute_error: 0.0927 - root_mean_squared_error: 0.1279 - RMSE_P: 1274.1914 - RMSE_T: 49.6600 - val_loss: 0.0187 - val_mean_absolute_error: 0.0968 - val_root_mean_squared_error: 0.1367 - val_RMSE_P: 1320.8485 - val_RMSE_T: 55.7997
# Epoch 47/5000
# 45/45 [==============================] - 0s 462us/step - loss: 0.0164 - mean_absolute_error: 0.0927 - root_mean_squared_error: 0.1280 - RMSE_P: 1272.1494 - RMSE_T: 49.9079 - val_loss: 0.0184 - val_mean_absolute_error: 0.0966 - val_root_mean_squared_error: 0.1358 - val_RMSE_P: 1316.4817 - val_RMSE_T: 55.0791
# Epoch 48/5000
# 45/45 [==============================] - 0s 462us/step - loss: 0.0163 - mean_absolute_error: 0.0923 - root_mean_squared_error: 0.1275 - RMSE_P: 1263.6593 - RMSE_T: 49.5258 - val_loss: 0.0187 - val_mean_absolute_error: 0.0973 - val_root_mean_squared_error: 0.1366 - val_RMSE_P: 1322.8291 - val_RMSE_T: 55.5176
# Epoch 49/5000
# 45/45 [==============================] - 0s 455us/step - loss: 0.0162 - mean_absolute_error: 0.0922 - root_mean_squared_error: 0.1274 - RMSE_P: 1257.5243 - RMSE_T: 49.3342 - val_loss: 0.0184 - val_mean_absolute_error: 0.0964 - val_root_mean_squared_error: 0.1356 - val_RMSE_P: 1317.4998 - val_RMSE_T: 54.7213
# Epoch 50/5000
# 45/45 [==============================] - 0s 453us/step - loss: 0.0162 - mean_absolute_error: 0.0919 - root_mean_squared_error: 0.1272 - RMSE_P: 1267.0756 - RMSE_T: 49.1815 - val_loss: 0.0187 - val_mean_absolute_error: 0.0966 - val_root_mean_squared_error: 0.1369 - val_RMSE_P: 1330.5754 - val_RMSE_T: 55.1462
# Epoch 51/5000
# 45/45 [==============================] - 0s 458us/step - loss: 0.0162 - mean_absolute_error: 0.0918 - root_mean_squared_error: 0.1271 - RMSE_P: 1264.7662 - RMSE_T: 49.1730 - val_loss: 0.0185 - val_mean_absolute_error: 0.0965 - val_root_mean_squared_error: 0.1358 - val_RMSE_P: 1320.0842 - val_RMSE_T: 54.7830
# Epoch 52/5000
# 45/45 [==============================] - 0s 457us/step - loss: 0.0161 - mean_absolute_error: 0.0917 - root_mean_squared_error: 0.1269 - RMSE_P: 1263.4504 - RMSE_T: 49.1489 - val_loss: 0.0182 - val_mean_absolute_error: 0.0960 - val_root_mean_squared_error: 0.1350 - val_RMSE_P: 1315.4238 - val_RMSE_T: 54.0235
# Epoch 53/5000
# 45/45 [==============================] - 0s 458us/step - loss: 0.0161 - mean_absolute_error: 0.0915 - root_mean_squared_error: 0.1268 - RMSE_P: 1262.1769 - RMSE_T: 49.1904 - val_loss: 0.0182 - val_mean_absolute_error: 0.0962 - val_root_mean_squared_error: 0.1351 - val_RMSE_P: 1317.2533 - val_RMSE_T: 54.0891
# Epoch 54/5000
# 45/45 [==============================] - 0s 460us/step - loss: 0.0160 - mean_absolute_error: 0.0912 - root_mean_squared_error: 0.1264 - RMSE_P: 1256.6804 - RMSE_T: 48.5966 - val_loss: 0.0181 - val_mean_absolute_error: 0.0954 - val_root_mean_squared_error: 0.1345 - val_RMSE_P: 1312.3137 - val_RMSE_T: 53.8493
# Epoch 55/5000
# 45/45 [==============================] - 0s 674us/step - loss: 0.0160 - mean_absolute_error: 0.0913 - root_mean_squared_error: 0.1265 - RMSE_P: 1259.4359 - RMSE_T: 48.8172 - val_loss: 0.0181 - val_mean_absolute_error: 0.0953 - val_root_mean_squared_error: 0.1345 - val_RMSE_P: 1313.3080 - val_RMSE_T: 53.5562
# Epoch 56/5000
# 45/45 [==============================] - 0s 565us/step - loss: 0.0160 - mean_absolute_error: 0.0915 - root_mean_squared_error: 0.1267 - RMSE_P: 1266.9237 - RMSE_T: 48.7486 - val_loss: 0.0184 - val_mean_absolute_error: 0.0954 - val_root_mean_squared_error: 0.1356 - val_RMSE_P: 1325.7314 - val_RMSE_T: 53.9157
# Epoch 57/5000
# 45/45 [==============================] - 0s 479us/step - loss: 0.0159 - mean_absolute_error: 0.0910 - root_mean_squared_error: 0.1262 - RMSE_P: 1252.6606 - RMSE_T: 48.3556 - val_loss: 0.0180 - val_mean_absolute_error: 0.0952 - val_root_mean_squared_error: 0.1343 - val_RMSE_P: 1312.9215 - val_RMSE_T: 53.3766
# Epoch 58/5000
# 45/45 [==============================] - 0s 479us/step - loss: 0.0159 - mean_absolute_error: 0.0909 - root_mean_squared_error: 0.1261 - RMSE_P: 1257.8932 - RMSE_T: 48.3790 - val_loss: 0.0178 - val_mean_absolute_error: 0.0946 - val_root_mean_squared_error: 0.1335 - val_RMSE_P: 1303.4404 - val_RMSE_T: 53.1999
# Epoch 59/5000
# 45/45 [==============================] - 0s 465us/step - loss: 0.0159 - mean_absolute_error: 0.0907 - root_mean_squared_error: 0.1259 - RMSE_P: 1255.9691 - RMSE_T: 48.2994 - val_loss: 0.0178 - val_mean_absolute_error: 0.0948 - val_root_mean_squared_error: 0.1334 - val_RMSE_P: 1309.2509 - val_RMSE_T: 52.6203
# Epoch 60/5000
# 45/45 [==============================] - 0s 462us/step - loss: 0.0159 - mean_absolute_error: 0.0908 - root_mean_squared_error: 0.1261 - RMSE_P: 1254.6785 - RMSE_T: 48.2814 - val_loss: 0.0178 - val_mean_absolute_error: 0.0944 - val_root_mean_squared_error: 0.1332 - val_RMSE_P: 1304.0784 - val_RMSE_T: 52.7903
# Epoch 61/5000
# 45/45 [==============================] - 0s 458us/step - loss: 0.0159 - mean_absolute_error: 0.0905 - root_mean_squared_error: 0.1260 - RMSE_P: 1257.4906 - RMSE_T: 48.4340 - val_loss: 0.0178 - val_mean_absolute_error: 0.0942 - val_root_mean_squared_error: 0.1334 - val_RMSE_P: 1306.2817 - val_RMSE_T: 52.9947
# Epoch 62/5000
# 45/45 [==============================] - 0s 466us/step - loss: 0.0158 - mean_absolute_error: 0.0906 - root_mean_squared_error: 0.1257 - RMSE_P: 1255.7620 - RMSE_T: 48.2117 - val_loss: 0.0180 - val_mean_absolute_error: 0.0946 - val_root_mean_squared_error: 0.1341 - val_RMSE_P: 1317.5989 - val_RMSE_T: 52.6995
# Epoch 63/5000
# 45/45 [==============================] - 0s 460us/step - loss: 0.0158 - mean_absolute_error: 0.0905 - root_mean_squared_error: 0.1257 - RMSE_P: 1253.4575 - RMSE_T: 47.7067 - val_loss: 0.0178 - val_mean_absolute_error: 0.0946 - val_root_mean_squared_error: 0.1333 - val_RMSE_P: 1307.4927 - val_RMSE_T: 52.5984
# Epoch 64/5000
# 45/45 [==============================] - 0s 464us/step - loss: 0.0158 - mean_absolute_error: 0.0904 - root_mean_squared_error: 0.1256 - RMSE_P: 1259.3337 - RMSE_T: 47.5283 - val_loss: 0.0175 - val_mean_absolute_error: 0.0937 - val_root_mean_squared_error: 0.1324 - val_RMSE_P: 1294.8210 - val_RMSE_T: 52.4739
# Epoch 65/5000
# 45/45 [==============================] - 0s 474us/step - loss: 0.0159 - mean_absolute_error: 0.0909 - root_mean_squared_error: 0.1262 - RMSE_P: 1258.2856 - RMSE_T: 47.8518 - val_loss: 0.0178 - val_mean_absolute_error: 0.0935 - val_root_mean_squared_error: 0.1336 - val_RMSE_P: 1303.9823 - val_RMSE_T: 53.0729
# Epoch 66/5000
# 45/45 [==============================] - 0s 473us/step - loss: 0.0158 - mean_absolute_error: 0.0903 - root_mean_squared_error: 0.1256 - RMSE_P: 1258.8387 - RMSE_T: 47.5667 - val_loss: 0.0177 - val_mean_absolute_error: 0.0941 - val_root_mean_squared_error: 0.1331 - val_RMSE_P: 1305.9143 - val_RMSE_T: 52.4769
# Epoch 67/5000
# 45/45 [==============================] - 0s 462us/step - loss: 0.0157 - mean_absolute_error: 0.0902 - root_mean_squared_error: 0.1253 - RMSE_P: 1253.9684 - RMSE_T: 47.7490 - val_loss: 0.0178 - val_mean_absolute_error: 0.0938 - val_root_mean_squared_error: 0.1334 - val_RMSE_P: 1315.9033 - val_RMSE_T: 51.8494
# Epoch 68/5000
# 45/45 [==============================] - 0s 464us/step - loss: 0.0157 - mean_absolute_error: 0.0898 - root_mean_squared_error: 0.1251 - RMSE_P: 1250.9070 - RMSE_T: 47.4687 - val_loss: 0.0179 - val_mean_absolute_error: 0.0940 - val_root_mean_squared_error: 0.1336 - val_RMSE_P: 1311.8027 - val_RMSE_T: 52.7792
# Epoch 69/5000
# 45/45 [==============================] - 0s 454us/step - loss: 0.0157 - mean_absolute_error: 0.0901 - root_mean_squared_error: 0.1255 - RMSE_P: 1255.9886 - RMSE_T: 47.6334 - val_loss: 0.0177 - val_mean_absolute_error: 0.0936 - val_root_mean_squared_error: 0.1329 - val_RMSE_P: 1303.6964 - val_RMSE_T: 52.5300
# Epoch 70/5000
# 45/45 [==============================] - 0s 459us/step - loss: 0.0156 - mean_absolute_error: 0.0899 - root_mean_squared_error: 0.1251 - RMSE_P: 1254.9044 - RMSE_T: 47.4246 - val_loss: 0.0180 - val_mean_absolute_error: 0.0943 - val_root_mean_squared_error: 0.1340 - val_RMSE_P: 1324.2395 - val_RMSE_T: 52.0003
# Epoch 71/5000
# 45/45 [==============================] - 0s 457us/step - loss: 0.0156 - mean_absolute_error: 0.0895 - root_mean_squared_error: 0.1249 - RMSE_P: 1247.8594 - RMSE_T: 47.4900 - val_loss: 0.0174 - val_mean_absolute_error: 0.0932 - val_root_mean_squared_error: 0.1317 - val_RMSE_P: 1294.6792 - val_RMSE_T: 51.5697
# Epoch 72/5000
# 45/45 [==============================] - 0s 464us/step - loss: 0.0156 - mean_absolute_error: 0.0895 - root_mean_squared_error: 0.1251 - RMSE_P: 1253.5223 - RMSE_T: 47.5102 - val_loss: 0.0173 - val_mean_absolute_error: 0.0937 - val_root_mean_squared_error: 0.1314 - val_RMSE_P: 1290.1340 - val_RMSE_T: 51.6855
# Epoch 73/5000
# 45/45 [==============================] - 0s 462us/step - loss: 0.0156 - mean_absolute_error: 0.0898 - root_mean_squared_error: 0.1248 - RMSE_P: 1246.3085 - RMSE_T: 47.4330 - val_loss: 0.0174 - val_mean_absolute_error: 0.0935 - val_root_mean_squared_error: 0.1320 - val_RMSE_P: 1300.7219 - val_RMSE_T: 51.4760
# Epoch 74/5000
# 45/45 [==============================] - 0s 462us/step - loss: 0.0155 - mean_absolute_error: 0.0896 - root_mean_squared_error: 0.1247 - RMSE_P: 1248.9392 - RMSE_T: 47.3783 - val_loss: 0.0173 - val_mean_absolute_error: 0.0926 - val_root_mean_squared_error: 0.1315 - val_RMSE_P: 1291.3541 - val_RMSE_T: 51.6019
# Epoch 75/5000
# 45/45 [==============================] - 0s 455us/step - loss: 0.0155 - mean_absolute_error: 0.0893 - root_mean_squared_error: 0.1246 - RMSE_P: 1246.1847 - RMSE_T: 47.1143 - val_loss: 0.0171 - val_mean_absolute_error: 0.0927 - val_root_mean_squared_error: 0.1309 - val_RMSE_P: 1289.8569 - val_RMSE_T: 50.9174
# Epoch 76/5000
# 45/45 [==============================] - 0s 590us/step - loss: 0.0155 - mean_absolute_error: 0.0895 - root_mean_squared_error: 0.1247 - RMSE_P: 1247.3959 - RMSE_T: 47.0477 - val_loss: 0.0174 - val_mean_absolute_error: 0.0922 - val_root_mean_squared_error: 0.1319 - val_RMSE_P: 1295.4694 - val_RMSE_T: 51.7041
# Epoch 77/5000
# 45/45 [==============================] - 0s 532us/step - loss: 0.0155 - mean_absolute_error: 0.0893 - root_mean_squared_error: 0.1246 - RMSE_P: 1242.1083 - RMSE_T: 47.2268 - val_loss: 0.0171 - val_mean_absolute_error: 0.0919 - val_root_mean_squared_error: 0.1309 - val_RMSE_P: 1285.4502 - val_RMSE_T: 51.2279
# Epoch 78/5000
# 45/45 [==============================] - 0s 519us/step - loss: 0.0154 - mean_absolute_error: 0.0889 - root_mean_squared_error: 0.1242 - RMSE_P: 1250.1561 - RMSE_T: 47.0249 - val_loss: 0.0174 - val_mean_absolute_error: 0.0930 - val_root_mean_squared_error: 0.1318 - val_RMSE_P: 1302.1731 - val_RMSE_T: 51.0898
# Epoch 79/5000
# 45/45 [==============================] - 0s 518us/step - loss: 0.0154 - mean_absolute_error: 0.0890 - root_mean_squared_error: 0.1241 - RMSE_P: 1247.3972 - RMSE_T: 46.9370 - val_loss: 0.0176 - val_mean_absolute_error: 0.0921 - val_root_mean_squared_error: 0.1325 - val_RMSE_P: 1300.8694 - val_RMSE_T: 51.9612
# Epoch 80/5000
# 45/45 [==============================] - 0s 552us/step - loss: 0.0154 - mean_absolute_error: 0.0892 - root_mean_squared_error: 0.1243 - RMSE_P: 1242.8091 - RMSE_T: 46.7980 - val_loss: 0.0171 - val_mean_absolute_error: 0.0916 - val_root_mean_squared_error: 0.1306 - val_RMSE_P: 1285.6890 - val_RMSE_T: 50.7387
# Epoch 81/5000
# 45/45 [==============================] - 0s 509us/step - loss: 0.0154 - mean_absolute_error: 0.0892 - root_mean_squared_error: 0.1242 - RMSE_P: 1247.3846 - RMSE_T: 46.9231 - val_loss: 0.0172 - val_mean_absolute_error: 0.0919 - val_root_mean_squared_error: 0.1312 - val_RMSE_P: 1295.4397 - val_RMSE_T: 50.6310
# Epoch 82/5000
# 45/45 [==============================] - 0s 490us/step - loss: 0.0155 - mean_absolute_error: 0.0892 - root_mean_squared_error: 0.1244 - RMSE_P: 1252.8239 - RMSE_T: 47.1071 - val_loss: 0.0172 - val_mean_absolute_error: 0.0921 - val_root_mean_squared_error: 0.1311 - val_RMSE_P: 1292.3665 - val_RMSE_T: 50.7402
# Epoch 83/5000
# 45/45 [==============================] - 0s 490us/step - loss: 0.0154 - mean_absolute_error: 0.0888 - root_mean_squared_error: 0.1241 - RMSE_P: 1246.6407 - RMSE_T: 46.6844 - val_loss: 0.0174 - val_mean_absolute_error: 0.0928 - val_root_mean_squared_error: 0.1319 - val_RMSE_P: 1306.4510 - val_RMSE_T: 50.7951
# Epoch 84/5000
# 45/45 [==============================] - 0s 467us/step - loss: 0.0154 - mean_absolute_error: 0.0886 - root_mean_squared_error: 0.1240 - RMSE_P: 1243.3280 - RMSE_T: 46.7081 - val_loss: 0.0175 - val_mean_absolute_error: 0.0934 - val_root_mean_squared_error: 0.1323 - val_RMSE_P: 1311.7424 - val_RMSE_T: 50.7686
# Epoch 85/5000
# 45/45 [==============================] - 0s 476us/step - loss: 0.0153 - mean_absolute_error: 0.0886 - root_mean_squared_error: 0.1239 - RMSE_P: 1243.8435 - RMSE_T: 46.7847 - val_loss: 0.0171 - val_mean_absolute_error: 0.0919 - val_root_mean_squared_error: 0.1308 - val_RMSE_P: 1288.5056 - val_RMSE_T: 50.9823
# Epoch 86/5000
# 45/45 [==============================] - 0s 477us/step - loss: 0.0153 - mean_absolute_error: 0.0887 - root_mean_squared_error: 0.1236 - RMSE_P: 1243.2231 - RMSE_T: 47.0237 - val_loss: 0.0172 - val_mean_absolute_error: 0.0915 - val_root_mean_squared_error: 0.1312 - val_RMSE_P: 1291.2692 - val_RMSE_T: 51.1019
# Epoch 87/5000
# 45/45 [==============================] - 0s 463us/step - loss: 0.0153 - mean_absolute_error: 0.0886 - root_mean_squared_error: 0.1236 - RMSE_P: 1243.4126 - RMSE_T: 46.6500 - val_loss: 0.0171 - val_mean_absolute_error: 0.0918 - val_root_mean_squared_error: 0.1308 - val_RMSE_P: 1290.7371 - val_RMSE_T: 50.5234
# Epoch 88/5000
# 45/45 [==============================] - 0s 469us/step - loss: 0.0153 - mean_absolute_error: 0.0887 - root_mean_squared_error: 0.1237 - RMSE_P: 1241.9427 - RMSE_T: 46.5978 - val_loss: 0.0171 - val_mean_absolute_error: 0.0917 - val_root_mean_squared_error: 0.1308 - val_RMSE_P: 1292.2939 - val_RMSE_T: 50.5062
# Epoch 89/5000
# 45/45 [==============================] - 0s 448us/step - loss: 0.0153 - mean_absolute_error: 0.0884 - root_mean_squared_error: 0.1238 - RMSE_P: 1244.9734 - RMSE_T: 46.7555 - val_loss: 0.0172 - val_mean_absolute_error: 0.0917 - val_root_mean_squared_error: 0.1311 - val_RMSE_P: 1297.7053 - val_RMSE_T: 50.3544
# Epoch 90/5000
# 45/45 [==============================] - 0s 466us/step - loss: 0.0152 - mean_absolute_error: 0.0883 - root_mean_squared_error: 0.1235 - RMSE_P: 1238.2113 - RMSE_T: 46.2877 - val_loss: 0.0172 - val_mean_absolute_error: 0.0915 - val_root_mean_squared_error: 0.1310 - val_RMSE_P: 1290.6631 - val_RMSE_T: 50.6703
# Epoch 91/5000
# 45/45 [==============================] - 0s 456us/step - loss: 0.0153 - mean_absolute_error: 0.0887 - root_mean_squared_error: 0.1236 - RMSE_P: 1238.5353 - RMSE_T: 46.5152 - val_loss: 0.0170 - val_mean_absolute_error: 0.0923 - val_root_mean_squared_error: 0.1306 - val_RMSE_P: 1292.4456 - val_RMSE_T: 50.0246
# Epoch 92/5000
# 45/45 [==============================] - 0s 465us/step - loss: 0.0152 - mean_absolute_error: 0.0883 - root_mean_squared_error: 0.1234 - RMSE_P: 1242.5601 - RMSE_T: 46.3920 - val_loss: 0.0171 - val_mean_absolute_error: 0.0918 - val_root_mean_squared_error: 0.1309 - val_RMSE_P: 1297.7227 - val_RMSE_T: 50.1248
# Epoch 93/5000
# 45/45 [==============================] - 0s 456us/step - loss: 0.0152 - mean_absolute_error: 0.0883 - root_mean_squared_error: 0.1234 - RMSE_P: 1241.4226 - RMSE_T: 46.5143 - val_loss: 0.0168 - val_mean_absolute_error: 0.0911 - val_root_mean_squared_error: 0.1298 - val_RMSE_P: 1283.3810 - val_RMSE_T: 50.0629
# Epoch 94/5000
# 45/45 [==============================] - 0s 457us/step - loss: 0.0152 - mean_absolute_error: 0.0880 - root_mean_squared_error: 0.1232 - RMSE_P: 1240.7152 - RMSE_T: 45.8439 - val_loss: 0.0169 - val_mean_absolute_error: 0.0910 - val_root_mean_squared_error: 0.1299 - val_RMSE_P: 1283.7168 - val_RMSE_T: 49.8798
# Epoch 95/5000
# 45/45 [==============================] - 0s 463us/step - loss: 0.0151 - mean_absolute_error: 0.0879 - root_mean_squared_error: 0.1230 - RMSE_P: 1241.1726 - RMSE_T: 45.8724 - val_loss: 0.0172 - val_mean_absolute_error: 0.0911 - val_root_mean_squared_error: 0.1311 - val_RMSE_P: 1296.9314 - val_RMSE_T: 50.2084
# Epoch 96/5000
# 45/45 [==============================] - 0s 460us/step - loss: 0.0151 - mean_absolute_error: 0.0878 - root_mean_squared_error: 0.1231 - RMSE_P: 1236.5287 - RMSE_T: 46.0290 - val_loss: 0.0170 - val_mean_absolute_error: 0.0908 - val_root_mean_squared_error: 0.1302 - val_RMSE_P: 1283.7924 - val_RMSE_T: 50.3581
# Epoch 97/5000
# 45/45 [==============================] - 0s 462us/step - loss: 0.0152 - mean_absolute_error: 0.0880 - root_mean_squared_error: 0.1231 - RMSE_P: 1247.6735 - RMSE_T: 46.3974 - val_loss: 0.0171 - val_mean_absolute_error: 0.0920 - val_root_mean_squared_error: 0.1309 - val_RMSE_P: 1300.6038 - val_RMSE_T: 49.8071
# Epoch 98/5000
# 45/45 [==============================] - 0s 468us/step - loss: 0.0151 - mean_absolute_error: 0.0877 - root_mean_squared_error: 0.1229 - RMSE_P: 1239.6769 - RMSE_T: 46.1495 - val_loss: 0.0172 - val_mean_absolute_error: 0.0917 - val_root_mean_squared_error: 0.1312 - val_RMSE_P: 1301.3031 - val_RMSE_T: 50.0890
# Epoch 99/5000
# 45/45 [==============================] - 0s 499us/step - loss: 0.0150 - mean_absolute_error: 0.0876 - root_mean_squared_error: 0.1227 - RMSE_P: 1238.7528 - RMSE_T: 46.0349 - val_loss: 0.0175 - val_mean_absolute_error: 0.0934 - val_root_mean_squared_error: 0.1323 - val_RMSE_P: 1323.9088 - val_RMSE_T: 49.5620
# Epoch 100/5000
# 45/45 [==============================] - 0s 490us/step - loss: 0.0152 - mean_absolute_error: 0.0879 - root_mean_squared_error: 0.1232 - RMSE_P: 1245.8859 - RMSE_T: 46.2267 - val_loss: 0.0167 - val_mean_absolute_error: 0.0913 - val_root_mean_squared_error: 0.1292 - val_RMSE_P: 1277.9368 - val_RMSE_T: 49.7435
# Epoch 101/5000
# 45/45 [==============================] - 0s 457us/step - loss: 0.0151 - mean_absolute_error: 0.0878 - root_mean_squared_error: 0.1228 - RMSE_P: 1242.9869 - RMSE_T: 45.9379 - val_loss: 0.0168 - val_mean_absolute_error: 0.0906 - val_root_mean_squared_error: 0.1295 - val_RMSE_P: 1276.9645 - val_RMSE_T: 49.9602
# Epoch 102/5000
# 45/45 [==============================] - 0s 476us/step - loss: 0.0151 - mean_absolute_error: 0.0877 - root_mean_squared_error: 0.1228 - RMSE_P: 1236.6742 - RMSE_T: 45.9824 - val_loss: 0.0168 - val_mean_absolute_error: 0.0900 - val_root_mean_squared_error: 0.1298 - val_RMSE_P: 1281.5916 - val_RMSE_T: 49.7102
# Epoch 103/5000
# 45/45 [==============================] - 0s 481us/step - loss: 0.0150 - mean_absolute_error: 0.0877 - root_mean_squared_error: 0.1226 - RMSE_P: 1240.3250 - RMSE_T: 45.9648 - val_loss: 0.0172 - val_mean_absolute_error: 0.0913 - val_root_mean_squared_error: 0.1311 - val_RMSE_P: 1293.0935 - val_RMSE_T: 50.6173
# Epoch 104/5000
# 45/45 [==============================] - 0s 461us/step - loss: 0.0151 - mean_absolute_error: 0.0877 - root_mean_squared_error: 0.1230 - RMSE_P: 1231.8438 - RMSE_T: 45.7138 - val_loss: 0.0168 - val_mean_absolute_error: 0.0916 - val_root_mean_squared_error: 0.1296 - val_RMSE_P: 1283.0980 - val_RMSE_T: 49.7512
# Epoch 105/5000
# 45/45 [==============================] - 0s 495us/step - loss: 0.0151 - mean_absolute_error: 0.0879 - root_mean_squared_error: 0.1229 - RMSE_P: 1235.6118 - RMSE_T: 46.0849 - val_loss: 0.0168 - val_mean_absolute_error: 0.0918 - val_root_mean_squared_error: 0.1298 - val_RMSE_P: 1287.2732 - val_RMSE_T: 49.3597
# Epoch 106/5000
# 45/45 [==============================] - 0s 470us/step - loss: 0.0150 - mean_absolute_error: 0.0877 - root_mean_squared_error: 0.1226 - RMSE_P: 1233.2616 - RMSE_T: 45.7480 - val_loss: 0.0168 - val_mean_absolute_error: 0.0906 - val_root_mean_squared_error: 0.1294 - val_RMSE_P: 1278.5518 - val_RMSE_T: 49.6752
# Epoch 107/5000
# 45/45 [==============================] - 0s 465us/step - loss: 0.0150 - mean_absolute_error: 0.0874 - root_mean_squared_error: 0.1226 - RMSE_P: 1239.9556 - RMSE_T: 45.5256 - val_loss: 0.0168 - val_mean_absolute_error: 0.0910 - val_root_mean_squared_error: 0.1296 - val_RMSE_P: 1281.0359 - val_RMSE_T: 49.9279
# Epoch 108/5000
# 45/45 [==============================] - 0s 461us/step - loss: 0.0150 - mean_absolute_error: 0.0875 - root_mean_squared_error: 0.1226 - RMSE_P: 1235.5704 - RMSE_T: 45.6552 - val_loss: 0.0168 - val_mean_absolute_error: 0.0907 - val_root_mean_squared_error: 0.1296 - val_RMSE_P: 1280.2952 - val_RMSE_T: 49.6963
# Epoch 109/5000
# 45/45 [==============================] - 0s 466us/step - loss: 0.0150 - mean_absolute_error: 0.0873 - root_mean_squared_error: 0.1223 - RMSE_P: 1235.3171 - RMSE_T: 45.4310 - val_loss: 0.0170 - val_mean_absolute_error: 0.0907 - val_root_mean_squared_error: 0.1303 - val_RMSE_P: 1288.0728 - val_RMSE_T: 50.1090
# Epoch 110/5000
# 45/45 [==============================] - 0s 462us/step - loss: 0.0149 - mean_absolute_error: 0.0871 - root_mean_squared_error: 0.1222 - RMSE_P: 1236.7264 - RMSE_T: 45.3464 - val_loss: 0.0167 - val_mean_absolute_error: 0.0909 - val_root_mean_squared_error: 0.1294 - val_RMSE_P: 1282.3142 - val_RMSE_T: 49.2239
# Epoch 111/5000
# 45/45 [==============================] - 0s 460us/step - loss: 0.0150 - mean_absolute_error: 0.0875 - root_mean_squared_error: 0.1223 - RMSE_P: 1242.8019 - RMSE_T: 45.4516 - val_loss: 0.0168 - val_mean_absolute_error: 0.0899 - val_root_mean_squared_error: 0.1297 - val_RMSE_P: 1275.1499 - val_RMSE_T: 50.1707
# Epoch 112/5000
# 45/45 [==============================] - 0s 469us/step - loss: 0.0149 - mean_absolute_error: 0.0871 - root_mean_squared_error: 0.1221 - RMSE_P: 1227.8701 - RMSE_T: 45.4327 - val_loss: 0.0167 - val_mean_absolute_error: 0.0902 - val_root_mean_squared_error: 0.1290 - val_RMSE_P: 1277.5671 - val_RMSE_T: 49.3268
# Epoch 113/5000
# 45/45 [==============================] - 0s 498us/step - loss: 0.0149 - mean_absolute_error: 0.0870 - root_mean_squared_error: 0.1219 - RMSE_P: 1230.4877 - RMSE_T: 45.2008 - val_loss: 0.0167 - val_mean_absolute_error: 0.0897 - val_root_mean_squared_error: 0.1291 - val_RMSE_P: 1274.2590 - val_RMSE_T: 49.6818
# Epoch 114/5000
# 45/45 [==============================] - 0s 467us/step - loss: 0.0149 - mean_absolute_error: 0.0869 - root_mean_squared_error: 0.1221 - RMSE_P: 1235.4152 - RMSE_T: 45.5043 - val_loss: 0.0166 - val_mean_absolute_error: 0.0901 - val_root_mean_squared_error: 0.1289 - val_RMSE_P: 1270.2057 - val_RMSE_T: 49.8316
# Epoch 115/5000
# 45/45 [==============================] - 0s 468us/step - loss: 0.0149 - mean_absolute_error: 0.0871 - root_mean_squared_error: 0.1221 - RMSE_P: 1234.3820 - RMSE_T: 45.2170 - val_loss: 0.0166 - val_mean_absolute_error: 0.0896 - val_root_mean_squared_error: 0.1288 - val_RMSE_P: 1275.2683 - val_RMSE_T: 48.9500
# Epoch 116/5000
# 45/45 [==============================] - 0s 465us/step - loss: 0.0149 - mean_absolute_error: 0.0871 - root_mean_squared_error: 0.1221 - RMSE_P: 1231.4388 - RMSE_T: 45.4870 - val_loss: 0.0169 - val_mean_absolute_error: 0.0901 - val_root_mean_squared_error: 0.1300 - val_RMSE_P: 1283.9209 - val_RMSE_T: 49.8301
# Epoch 117/5000
# 45/45 [==============================] - 0s 469us/step - loss: 0.0149 - mean_absolute_error: 0.0870 - root_mean_squared_error: 0.1221 - RMSE_P: 1235.4474 - RMSE_T: 45.1642 - val_loss: 0.0171 - val_mean_absolute_error: 0.0911 - val_root_mean_squared_error: 0.1306 - val_RMSE_P: 1299.7925 - val_RMSE_T: 49.4464
# Epoch 118/5000
# 45/45 [==============================] - 0s 457us/step - loss: 0.0149 - mean_absolute_error: 0.0871 - root_mean_squared_error: 0.1221 - RMSE_P: 1241.0170 - RMSE_T: 45.3891 - val_loss: 0.0168 - val_mean_absolute_error: 0.0908 - val_root_mean_squared_error: 0.1295 - val_RMSE_P: 1286.0234 - val_RMSE_T: 49.2020
# Epoch 119/5000
# 45/45 [==============================] - 0s 453us/step - loss: 0.0150 - mean_absolute_error: 0.0873 - root_mean_squared_error: 0.1225 - RMSE_P: 1242.2838 - RMSE_T: 45.5117 - val_loss: 0.0170 - val_mean_absolute_error: 0.0911 - val_root_mean_squared_error: 0.1305 - val_RMSE_P: 1299.4651 - val_RMSE_T: 49.1843
# Epoch 120/5000
# 45/45 [==============================] - 0s 475us/step - loss: 0.0149 - mean_absolute_error: 0.0871 - root_mean_squared_error: 0.1222 - RMSE_P: 1235.9449 - RMSE_T: 45.2162 - val_loss: 0.0169 - val_mean_absolute_error: 0.0915 - val_root_mean_squared_error: 0.1302 - val_RMSE_P: 1295.0868 - val_RMSE_T: 49.1999
# Epoch 121/5000
# 45/45 [==============================] - 0s 468us/step - loss: 0.0149 - mean_absolute_error: 0.0873 - root_mean_squared_error: 0.1221 - RMSE_P: 1234.5946 - RMSE_T: 45.0307 - val_loss: 0.0166 - val_mean_absolute_error: 0.0897 - val_root_mean_squared_error: 0.1288 - val_RMSE_P: 1276.2122 - val_RMSE_T: 48.9451
# Epoch 122/5000
# 45/45 [==============================] - 0s 620us/step - loss: 0.0148 - mean_absolute_error: 0.0867 - root_mean_squared_error: 0.1218 - RMSE_P: 1233.0803 - RMSE_T: 45.1570 - val_loss: 0.0166 - val_mean_absolute_error: 0.0896 - val_root_mean_squared_error: 0.1288 - val_RMSE_P: 1273.5228 - val_RMSE_T: 49.3801
# Epoch 123/5000
# 45/45 [==============================] - 0s 575us/step - loss: 0.0148 - mean_absolute_error: 0.0868 - root_mean_squared_error: 0.1216 - RMSE_P: 1230.1042 - RMSE_T: 45.0119 - val_loss: 0.0168 - val_mean_absolute_error: 0.0911 - val_root_mean_squared_error: 0.1298 - val_RMSE_P: 1295.3400 - val_RMSE_T: 48.5860
# Epoch 124/5000
# 45/45 [==============================] - 0s 479us/step - loss: 0.0148 - mean_absolute_error: 0.0867 - root_mean_squared_error: 0.1217 - RMSE_P: 1237.5037 - RMSE_T: 45.2466 - val_loss: 0.0167 - val_mean_absolute_error: 0.0912 - val_root_mean_squared_error: 0.1293 - val_RMSE_P: 1284.6517 - val_RMSE_T: 49.1419
# Epoch 125/5000
# 45/45 [==============================] - 0s 468us/step - loss: 0.0148 - mean_absolute_error: 0.0870 - root_mean_squared_error: 0.1218 - RMSE_P: 1231.8104 - RMSE_T: 45.3766 - val_loss: 0.0165 - val_mean_absolute_error: 0.0902 - val_root_mean_squared_error: 0.1285 - val_RMSE_P: 1271.0803 - val_RMSE_T: 49.0351
# Epoch 126/5000
# 45/45 [==============================] - 0s 468us/step - loss: 0.0148 - mean_absolute_error: 0.0866 - root_mean_squared_error: 0.1218 - RMSE_P: 1236.4713 - RMSE_T: 45.2992 - val_loss: 0.0167 - val_mean_absolute_error: 0.0906 - val_root_mean_squared_error: 0.1293 - val_RMSE_P: 1287.2693 - val_RMSE_T: 48.9060
# Epoch 127/5000
# 45/45 [==============================] - 0s 467us/step - loss: 0.0148 - mean_absolute_error: 0.0868 - root_mean_squared_error: 0.1217 - RMSE_P: 1228.9974 - RMSE_T: 45.0754 - val_loss: 0.0167 - val_mean_absolute_error: 0.0901 - val_root_mean_squared_error: 0.1293 - val_RMSE_P: 1287.5828 - val_RMSE_T: 48.8060
# Epoch 128/5000
# 45/45 [==============================] - 0s 471us/step - loss: 0.0148 - mean_absolute_error: 0.0867 - root_mean_squared_error: 0.1217 - RMSE_P: 1229.8990 - RMSE_T: 45.3031 - val_loss: 0.0167 - val_mean_absolute_error: 0.0911 - val_root_mean_squared_error: 0.1293 - val_RMSE_P: 1288.6925 - val_RMSE_T: 48.7011
# Epoch 129/5000
# 45/45 [==============================] - 0s 462us/step - loss: 0.0148 - mean_absolute_error: 0.0871 - root_mean_squared_error: 0.1218 - RMSE_P: 1233.3887 - RMSE_T: 45.0011 - val_loss: 0.0165 - val_mean_absolute_error: 0.0898 - val_root_mean_squared_error: 0.1285 - val_RMSE_P: 1271.7081 - val_RMSE_T: 48.8506
# Epoch 130/5000
# 45/45 [==============================] - 0s 472us/step - loss: 0.0148 - mean_absolute_error: 0.0865 - root_mean_squared_error: 0.1217 - RMSE_P: 1226.6394 - RMSE_T: 44.7115 - val_loss: 0.0169 - val_mean_absolute_error: 0.0908 - val_root_mean_squared_error: 0.1299 - val_RMSE_P: 1290.5636 - val_RMSE_T: 49.3595
# Epoch 131/5000
# 45/45 [==============================] - 0s 464us/step - loss: 0.0149 - mean_absolute_error: 0.0868 - root_mean_squared_error: 0.1219 - RMSE_P: 1234.5330 - RMSE_T: 44.9834 - val_loss: 0.0165 - val_mean_absolute_error: 0.0900 - val_root_mean_squared_error: 0.1283 - val_RMSE_P: 1273.6654 - val_RMSE_T: 48.8248
# Epoch 132/5000
# 45/45 [==============================] - 0s 473us/step - loss: 0.0148 - mean_absolute_error: 0.0864 - root_mean_squared_error: 0.1216 - RMSE_P: 1226.8088 - RMSE_T: 45.1828 - val_loss: 0.0169 - val_mean_absolute_error: 0.0919 - val_root_mean_squared_error: 0.1300 - val_RMSE_P: 1296.3799 - val_RMSE_T: 48.9168
# Epoch 133/5000
# 45/45 [==============================] - 0s 466us/step - loss: 0.0148 - mean_absolute_error: 0.0870 - root_mean_squared_error: 0.1218 - RMSE_P: 1233.1571 - RMSE_T: 44.9465 - val_loss: 0.0165 - val_mean_absolute_error: 0.0901 - val_root_mean_squared_error: 0.1286 - val_RMSE_P: 1278.8607 - val_RMSE_T: 48.4340
# Epoch 134/5000
# 45/45 [==============================] - 0s 467us/step - loss: 0.0148 - mean_absolute_error: 0.0867 - root_mean_squared_error: 0.1216 - RMSE_P: 1234.6385 - RMSE_T: 44.7709 - val_loss: 0.0165 - val_mean_absolute_error: 0.0893 - val_root_mean_squared_error: 0.1283 - val_RMSE_P: 1271.5577 - val_RMSE_T: 48.5788
# Epoch 135/5000
# 45/45 [==============================] - 0s 455us/step - loss: 0.0147 - mean_absolute_error: 0.0866 - root_mean_squared_error: 0.1214 - RMSE_P: 1227.7142 - RMSE_T: 44.7701 - val_loss: 0.0164 - val_mean_absolute_error: 0.0895 - val_root_mean_squared_error: 0.1280 - val_RMSE_P: 1272.5145 - val_RMSE_T: 48.3303
# Epoch 136/5000
# 45/45 [==============================] - 0s 461us/step - loss: 0.0147 - mean_absolute_error: 0.0864 - root_mean_squared_error: 0.1213 - RMSE_P: 1225.0725 - RMSE_T: 45.0299 - val_loss: 0.0167 - val_mean_absolute_error: 0.0901 - val_root_mean_squared_error: 0.1293 - val_RMSE_P: 1282.9089 - val_RMSE_T: 49.0956
# Epoch 137/5000
# 45/45 [==============================] - 0s 452us/step - loss: 0.0148 - mean_absolute_error: 0.0866 - root_mean_squared_error: 0.1217 - RMSE_P: 1230.1581 - RMSE_T: 45.1534 - val_loss: 0.0167 - val_mean_absolute_error: 0.0906 - val_root_mean_squared_error: 0.1293 - val_RMSE_P: 1289.2106 - val_RMSE_T: 48.7620
# Epoch 138/5000
# 45/45 [==============================] - 0s 460us/step - loss: 0.0147 - mean_absolute_error: 0.0867 - root_mean_squared_error: 0.1214 - RMSE_P: 1229.0858 - RMSE_T: 44.9156 - val_loss: 0.0163 - val_mean_absolute_error: 0.0888 - val_root_mean_squared_error: 0.1278 - val_RMSE_P: 1266.6666 - val_RMSE_T: 48.3446
# Epoch 139/5000
# 45/45 [==============================] - 0s 471us/step - loss: 0.0147 - mean_absolute_error: 0.0863 - root_mean_squared_error: 0.1214 - RMSE_P: 1235.6093 - RMSE_T: 45.0675 - val_loss: 0.0165 - val_mean_absolute_error: 0.0892 - val_root_mean_squared_error: 0.1283 - val_RMSE_P: 1273.7710 - val_RMSE_T: 48.6427
# Epoch 140/5000
# 45/45 [==============================] - 0s 465us/step - loss: 0.0148 - mean_absolute_error: 0.0866 - root_mean_squared_error: 0.1216 - RMSE_P: 1231.4106 - RMSE_T: 45.1886 - val_loss: 0.0167 - val_mean_absolute_error: 0.0903 - val_root_mean_squared_error: 0.1291 - val_RMSE_P: 1288.9054 - val_RMSE_T: 48.3692
# Epoch 141/5000
# 45/45 [==============================] - 0s 468us/step - loss: 0.0148 - mean_absolute_error: 0.0866 - root_mean_squared_error: 0.1215 - RMSE_P: 1222.1401 - RMSE_T: 45.1606 - val_loss: 0.0165 - val_mean_absolute_error: 0.0901 - val_root_mean_squared_error: 0.1284 - val_RMSE_P: 1276.0991 - val_RMSE_T: 48.5504
# Epoch 142/5000
# 45/45 [==============================] - 0s 473us/step - loss: 0.0147 - mean_absolute_error: 0.0864 - root_mean_squared_error: 0.1212 - RMSE_P: 1232.5519 - RMSE_T: 45.1255 - val_loss: 0.0165 - val_mean_absolute_error: 0.0895 - val_root_mean_squared_error: 0.1283 - val_RMSE_P: 1277.2692 - val_RMSE_T: 48.2087
# Epoch 143/5000
# 45/45 [==============================] - 0s 459us/step - loss: 0.0148 - mean_absolute_error: 0.0866 - root_mean_squared_error: 0.1217 - RMSE_P: 1234.8612 - RMSE_T: 44.9841 - val_loss: 0.0165 - val_mean_absolute_error: 0.0906 - val_root_mean_squared_error: 0.1285 - val_RMSE_P: 1278.9348 - val_RMSE_T: 48.3608
# Epoch 144/5000
# 45/45 [==============================] - 0s 467us/step - loss: 0.0148 - mean_absolute_error: 0.0866 - root_mean_squared_error: 0.1217 - RMSE_P: 1227.1045 - RMSE_T: 45.3714 - val_loss: 0.0163 - val_mean_absolute_error: 0.0888 - val_root_mean_squared_error: 0.1275 - val_RMSE_P: 1261.6671 - val_RMSE_T: 48.5157
# Epoch 145/5000
# 45/45 [==============================] - 0s 482us/step - loss: 0.0147 - mean_absolute_error: 0.0866 - root_mean_squared_error: 0.1213 - RMSE_P: 1228.5968 - RMSE_T: 44.8798 - val_loss: 0.0165 - val_mean_absolute_error: 0.0898 - val_root_mean_squared_error: 0.1285 - val_RMSE_P: 1274.9955 - val_RMSE_T: 48.6505
# Epoch 146/5000
# 45/45 [==============================] - 0s 488us/step - loss: 0.0147 - mean_absolute_error: 0.0867 - root_mean_squared_error: 0.1213 - RMSE_P: 1227.3733 - RMSE_T: 45.0696 - val_loss: 0.0165 - val_mean_absolute_error: 0.0905 - val_root_mean_squared_error: 0.1284 - val_RMSE_P: 1276.2217 - val_RMSE_T: 48.3454
# Epoch 147/5000
# 45/45 [==============================] - 0s 467us/step - loss: 0.0147 - mean_absolute_error: 0.0863 - root_mean_squared_error: 0.1214 - RMSE_P: 1232.1345 - RMSE_T: 44.8430 - val_loss: 0.0165 - val_mean_absolute_error: 0.0899 - val_root_mean_squared_error: 0.1284 - val_RMSE_P: 1276.5709 - val_RMSE_T: 48.6326
# Epoch 148/5000
# 45/45 [==============================] - 0s 473us/step - loss: 0.0147 - mean_absolute_error: 0.0864 - root_mean_squared_error: 0.1214 - RMSE_P: 1229.6587 - RMSE_T: 45.0706 - val_loss: 0.0162 - val_mean_absolute_error: 0.0894 - val_root_mean_squared_error: 0.1271 - val_RMSE_P: 1260.8040 - val_RMSE_T: 48.3361
# Epoch 149/5000
# ...
# Epoch 494/5000
# 45/45 [==============================] - 0s 476us/step - loss: 0.0140 - mean_absolute_error: 0.0840 - root_mean_squared_error: 0.1185 - RMSE_P: 1204.4642 - RMSE_T: 43.7474 - val_loss: 0.0157 - val_mean_absolute_error: 0.0881 - val_root_mean_squared_error: 0.1254 - val_RMSE_P: 1231.2017 - val_RMSE_T: 48.5970
# Epoch 495/5000
# 45/45 [==============================] - 0s 462us/step - loss: 0.0140 - mean_absolute_error: 0.0842 - root_mean_squared_error: 0.1183 - RMSE_P: 1200.5591 - RMSE_T: 43.9215 - val_loss: 0.0155 - val_mean_absolute_error: 0.0879 - val_root_mean_squared_error: 0.1244 - val_RMSE_P: 1226.1090 - val_RMSE_T: 47.7057
# Epoch 496/5000
# 45/45 [==============================] - 0s 464us/step - loss: 0.0140 - mean_absolute_error: 0.0842 - root_mean_squared_error: 0.1184 - RMSE_P: 1197.8861 - RMSE_T: 43.5275 - val_loss: 0.0157 - val_mean_absolute_error: 0.0876 - val_root_mean_squared_error: 0.1252 - val_RMSE_P: 1234.5441 - val_RMSE_T: 47.9289
# Epoch 497/5000
# 45/45 [==============================] - 0s 472us/step - loss: 0.0140 - mean_absolute_error: 0.0841 - root_mean_squared_error: 0.1185 - RMSE_P: 1196.4454 - RMSE_T: 44.0069 - val_loss: 0.0156 - val_mean_absolute_error: 0.0876 - val_root_mean_squared_error: 0.1247 - val_RMSE_P: 1225.7289 - val_RMSE_T: 48.1356
# Epoch 498/5000
# 45/45 [==============================] - 0s 477us/step - loss: 0.0140 - mean_absolute_error: 0.0840 - root_mean_squared_error: 0.1184 - RMSE_P: 1205.2195 - RMSE_T: 43.8378 - val_loss: 0.0155 - val_mean_absolute_error: 0.0876 - val_root_mean_squared_error: 0.1247 - val_RMSE_P: 1227.2549 - val_RMSE_T: 47.9955
# Epoch 499/5000
# 45/45 [==============================] - 0s 635us/step - loss: 0.0141 - mean_absolute_error: 0.0842 - root_mean_squared_error: 0.1186 - RMSE_P: 1200.1393 - RMSE_T: 43.8657 - val_loss: 0.0157 - val_mean_absolute_error: 0.0876 - val_root_mean_squared_error: 0.1253 - val_RMSE_P: 1233.6707 - val_RMSE_T: 48.1407
# Epoch 500/5000
# 45/45 [==============================] - 0s 563us/step - loss: 0.0140 - mean_absolute_error: 0.0842 - root_mean_squared_error: 0.1183 - RMSE_P: 1196.9401 - RMSE_T: 43.8314 - val_loss: 0.0161 - val_mean_absolute_error: 0.0890 - val_root_mean_squared_error: 0.1269 - val_RMSE_P: 1258.9662 - val_RMSE_T: 48.1256
# Epoch 501/5000
# 45/45 [==============================] - 0s 467us/step - loss: 0.0141 - mean_absolute_error: 0.0841 - root_mean_squared_error: 0.1186 - RMSE_P: 1205.5903 - RMSE_T: 43.6213 - val_loss: 0.0155 - val_mean_absolute_error: 0.0879 - val_root_mean_squared_error: 0.1243 - val_RMSE_P: 1223.1449 - val_RMSE_T: 47.8857
# Epoch 502/5000
# 45/45 [==============================] - 0s 471us/step - loss: 0.0141 - mean_absolute_error: 0.0843 - root_mean_squared_error: 0.1186 - RMSE_P: 1208.2388 - RMSE_T: 43.7869 - val_loss: 0.0154 - val_mean_absolute_error: 0.0870 - val_root_mean_squared_error: 0.1240 - val_RMSE_P: 1217.3748 - val_RMSE_T: 47.8548
# Epoch 503/5000
# 45/45 [==============================] - 0s 470us/step - loss: 0.0141 - mean_absolute_error: 0.0844 - root_mean_squared_error: 0.1186 - RMSE_P: 1201.9689 - RMSE_T: 43.9236 - val_loss: 0.0155 - val_mean_absolute_error: 0.0872 - val_root_mean_squared_error: 0.1243 - val_RMSE_P: 1223.3606 - val_RMSE_T: 47.7204
# Epoch 504/5000
# 45/45 [==============================] - 0s 463us/step - loss: 0.0140 - mean_absolute_error: 0.0840 - root_mean_squared_error: 0.1183 - RMSE_P: 1194.7092 - RMSE_T: 43.7155 - val_loss: 0.0156 - val_mean_absolute_error: 0.0876 - val_root_mean_squared_error: 0.1250 - val_RMSE_P: 1231.2827 - val_RMSE_T: 48.0299
# Epoch 505/5000
# 45/45 [==============================] - 0s 492us/step - loss: 0.0140 - mean_absolute_error: 0.0840 - root_mean_squared_error: 0.1185 - RMSE_P: 1200.8276 - RMSE_T: 43.6186 - val_loss: 0.0157 - val_mean_absolute_error: 0.0879 - val_root_mean_squared_error: 0.1251 - val_RMSE_P: 1229.6228 - val_RMSE_T: 48.3884
# Epoch 506/5000
# 45/45 [==============================] - 0s 470us/step - loss: 0.0141 - mean_absolute_error: 0.0843 - root_mean_squared_error: 0.1185 - RMSE_P: 1205.7303 - RMSE_T: 43.8103 - val_loss: 0.0155 - val_mean_absolute_error: 0.0873 - val_root_mean_squared_error: 0.1247 - val_RMSE_P: 1223.4363 - val_RMSE_T: 48.1488
# Epoch 507/5000
# 45/45 [==============================] - 0s 464us/step - loss: 0.0140 - mean_absolute_error: 0.0841 - root_mean_squared_error: 0.1183 - RMSE_P: 1198.3252 - RMSE_T: 43.5541 - val_loss: 0.0156 - val_mean_absolute_error: 0.0874 - val_root_mean_squared_error: 0.1247 - val_RMSE_P: 1224.7198 - val_RMSE_T: 48.3956
# Epoch 508/5000
# 45/45 [==============================] - 0s 469us/step - loss: 0.0140 - mean_absolute_error: 0.0841 - root_mean_squared_error: 0.1184 - RMSE_P: 1202.0762 - RMSE_T: 43.9195 - val_loss: 0.0155 - val_mean_absolute_error: 0.0875 - val_root_mean_squared_error: 0.1247 - val_RMSE_P: 1228.5867 - val_RMSE_T: 47.9239
# Epoch 509/5000
# 45/45 [==============================] - 0s 484us/step - loss: 0.0140 - mean_absolute_error: 0.0844 - root_mean_squared_error: 0.1185 - RMSE_P: 1200.8378 - RMSE_T: 43.7639 - val_loss: 0.0158 - val_mean_absolute_error: 0.0880 - val_root_mean_squared_error: 0.1257 - val_RMSE_P: 1239.5074 - val_RMSE_T: 48.2016
# Epoch 510/5000
# 45/45 [==============================] - 0s 469us/step - loss: 0.0141 - mean_absolute_error: 0.0841 - root_mean_squared_error: 0.1186 - RMSE_P: 1203.6952 - RMSE_T: 43.7763 - val_loss: 0.0156 - val_mean_absolute_error: 0.0871 - val_root_mean_squared_error: 0.1248 - val_RMSE_P: 1224.0361 - val_RMSE_T: 48.2125
# Epoch 511/5000
# 45/45 [==============================] - 0s 470us/step - loss: 0.0140 - mean_absolute_error: 0.0842 - root_mean_squared_error: 0.1183 - RMSE_P: 1199.7003 - RMSE_T: 43.8304 - val_loss: 0.0156 - val_mean_absolute_error: 0.0870 - val_root_mean_squared_error: 0.1248 - val_RMSE_P: 1223.4899 - val_RMSE_T: 48.2851
# Epoch 512/5000
# 45/45 [==============================] - 0s 475us/step - loss: 0.0141 - mean_absolute_error: 0.0843 - root_mean_squared_error: 0.1187 - RMSE_P: 1201.4800 - RMSE_T: 43.7107 - val_loss: 0.0159 - val_mean_absolute_error: 0.0882 - val_root_mean_squared_error: 0.1261 - val_RMSE_P: 1243.8208 - val_RMSE_T: 48.1298
# Epoch 513/5000
# 45/45 [==============================] - 0s 508us/step - loss: 0.0141 - mean_absolute_error: 0.0844 - root_mean_squared_error: 0.1187 - RMSE_P: 1207.9644 - RMSE_T: 43.7784 - val_loss: 0.0155 - val_mean_absolute_error: 0.0871 - val_root_mean_squared_error: 0.1245 - val_RMSE_P: 1224.2223 - val_RMSE_T: 47.8288
# Epoch 514/5000
# 45/45 [==============================] - 0s 689us/step - loss: 0.0140 - mean_absolute_error: 0.0840 - root_mean_squared_error: 0.1184 - RMSE_P: 1197.1837 - RMSE_T: 43.3095 - val_loss: 0.0155 - val_mean_absolute_error: 0.0869 - val_root_mean_squared_error: 0.1245 - val_RMSE_P: 1223.6644 - val_RMSE_T: 47.9180
# Epoch 515/5000
# 45/45 [==============================] - 0s 480us/step - loss: 0.0140 - mean_absolute_error: 0.0838 - root_mean_squared_error: 0.1183 - RMSE_P: 1197.0015 - RMSE_T: 43.8880 - val_loss: 0.0156 - val_mean_absolute_error: 0.0881 - val_root_mean_squared_error: 0.1248 - val_RMSE_P: 1230.8219 - val_RMSE_T: 47.9906
# Epoch 516/5000
# 45/45 [==============================] - 0s 473us/step - loss: 0.0140 - mean_absolute_error: 0.0843 - root_mean_squared_error: 0.1184 - RMSE_P: 1203.3331 - RMSE_T: 43.8182 - val_loss: 0.0157 - val_mean_absolute_error: 0.0877 - val_root_mean_squared_error: 0.1253 - val_RMSE_P: 1232.8678 - val_RMSE_T: 48.3428
# Epoch 517/5000
# 45/45 [==============================] - 0s 471us/step - loss: 0.0140 - mean_absolute_error: 0.0839 - root_mean_squared_error: 0.1183 - RMSE_P: 1197.4413 - RMSE_T: 43.8167 - val_loss: 0.0157 - val_mean_absolute_error: 0.0882 - val_root_mean_squared_error: 0.1254 - val_RMSE_P: 1237.8474 - val_RMSE_T: 48.1876
# Epoch 518/5000
# 45/45 [==============================] - 0s 468us/step - loss: 0.0140 - mean_absolute_error: 0.0841 - root_mean_squared_error: 0.1185 - RMSE_P: 1198.1567 - RMSE_T: 43.9911 - val_loss: 0.0158 - val_mean_absolute_error: 0.0878 - val_root_mean_squared_error: 0.1256 - val_RMSE_P: 1233.7551 - val_RMSE_T: 48.6537
# Epoch 519/5000
# 45/45 [==============================] - 0s 489us/step - loss: 0.0140 - mean_absolute_error: 0.0842 - root_mean_squared_error: 0.1183 - RMSE_P: 1200.5199 - RMSE_T: 43.7537 - val_loss: 0.0155 - val_mean_absolute_error: 0.0877 - val_root_mean_squared_error: 0.1246 - val_RMSE_P: 1227.8046 - val_RMSE_T: 47.9503
# Epoch 520/5000
# 45/45 [==============================] - 0s 479us/step - loss: 0.0140 - mean_absolute_error: 0.0842 - root_mean_squared_error: 0.1185 - RMSE_P: 1194.2838 - RMSE_T: 43.5108 - val_loss: 0.0154 - val_mean_absolute_error: 0.0874 - val_root_mean_squared_error: 0.1241 - val_RMSE_P: 1220.9397 - val_RMSE_T: 47.7104
# Epoch 521/5000
# 45/45 [==============================] - 0s 477us/step - loss: 0.0141 - mean_absolute_error: 0.0845 - root_mean_squared_error: 0.1186 - RMSE_P: 1193.3025 - RMSE_T: 43.7654 - val_loss: 0.0157 - val_mean_absolute_error: 0.0879 - val_root_mean_squared_error: 0.1252 - val_RMSE_P: 1233.0065 - val_RMSE_T: 48.0201
# Epoch 522/5000
# 45/45 [==============================] - 0s 486us/step - loss: 0.0141 - mean_absolute_error: 0.0842 - root_mean_squared_error: 0.1186 - RMSE_P: 1205.2748 - RMSE_T: 43.8088 - val_loss: 0.0156 - val_mean_absolute_error: 0.0883 - val_root_mean_squared_error: 0.1249 - val_RMSE_P: 1233.6038 - val_RMSE_T: 47.8159
# Epoch 523/5000
# 45/45 [==============================] - 0s 466us/step - loss: 0.0140 - mean_absolute_error: 0.0841 - root_mean_squared_error: 0.1184 - RMSE_P: 1198.1392 - RMSE_T: 43.6390 - val_loss: 0.0154 - val_mean_absolute_error: 0.0874 - val_root_mean_squared_error: 0.1240 - val_RMSE_P: 1218.5632 - val_RMSE_T: 47.7809
# Epoch 524/5000
# 45/45 [==============================] - 0s 478us/step - loss: 0.0140 - mean_absolute_error: 0.0840 - root_mean_squared_error: 0.1183 - RMSE_P: 1196.7832 - RMSE_T: 43.9957 - val_loss: 0.0157 - val_mean_absolute_error: 0.0875 - val_root_mean_squared_error: 0.1252 - val_RMSE_P: 1236.1971 - val_RMSE_T: 47.7076
# Epoch 525/5000
# 45/45 [==============================] - 0s 475us/step - loss: 0.0140 - mean_absolute_error: 0.0842 - root_mean_squared_error: 0.1185 - RMSE_P: 1201.2673 - RMSE_T: 44.0424 - val_loss: 0.0155 - val_mean_absolute_error: 0.0876 - val_root_mean_squared_error: 0.1246 - val_RMSE_P: 1227.3309 - val_RMSE_T: 47.8318
# Epoch 526/5000
# 45/45 [==============================] - 0s 467us/step - loss: 0.0140 - mean_absolute_error: 0.0843 - root_mean_squared_error: 0.1184 - RMSE_P: 1201.4113 - RMSE_T: 43.7726 - val_loss: 0.0158 - val_mean_absolute_error: 0.0880 - val_root_mean_squared_error: 0.1256 - val_RMSE_P: 1231.3339 - val_RMSE_T: 48.9872
# Epoch 527/5000
# 45/45 [==============================] - 0s 471us/step - loss: 0.0140 - mean_absolute_error: 0.0842 - root_mean_squared_error: 0.1185 - RMSE_P: 1193.8214 - RMSE_T: 43.5968 - val_loss: 0.0155 - val_mean_absolute_error: 0.0879 - val_root_mean_squared_error: 0.1245 - val_RMSE_P: 1225.1340 - val_RMSE_T: 47.9856
# Epoch 528/5000
# 45/45 [==============================] - 0s 748us/step - loss: 0.0140 - mean_absolute_error: 0.0842 - root_mean_squared_error: 0.1183 - RMSE_P: 1201.6567 - RMSE_T: 43.7201 - val_loss: 0.0157 - val_mean_absolute_error: 0.0877 - val_root_mean_squared_error: 0.1252 - val_RMSE_P: 1229.5564 - val_RMSE_T: 48.3760
# Epoch 529/5000
# 45/45 [==============================] - 0s 501us/step - loss: 0.0140 - mean_absolute_error: 0.0840 - root_mean_squared_error: 0.1183 - RMSE_P: 1200.9113 - RMSE_T: 43.5794 - val_loss: 0.0157 - val_mean_absolute_error: 0.0878 - val_root_mean_squared_error: 0.1254 - val_RMSE_P: 1233.9674 - val_RMSE_T: 48.3761
# Epoch 530/5000
# 45/45 [==============================] - 0s 470us/step - loss: 0.0141 - mean_absolute_error: 0.0844 - root_mean_squared_error: 0.1187 - RMSE_P: 1201.7823 - RMSE_T: 43.8699 - val_loss: 0.0160 - val_mean_absolute_error: 0.0883 - val_root_mean_squared_error: 0.1266 - val_RMSE_P: 1246.3656 - val_RMSE_T: 48.7781
# Epoch 531/5000
# 45/45 [==============================] - 0s 476us/step - loss: 0.0141 - mean_absolute_error: 0.0843 - root_mean_squared_error: 0.1186 - RMSE_P: 1198.5927 - RMSE_T: 44.0255 - val_loss: 0.0156 - val_mean_absolute_error: 0.0876 - val_root_mean_squared_error: 0.1248 - val_RMSE_P: 1226.9490 - val_RMSE_T: 48.0637
# Epoch 532/5000
# 45/45 [==============================] - 0s 475us/step - loss: 0.0140 - mean_absolute_error: 0.0840 - root_mean_squared_error: 0.1185 - RMSE_P: 1197.8077 - RMSE_T: 43.8770 - val_loss: 0.0158 - val_mean_absolute_error: 0.0881 - val_root_mean_squared_error: 0.1259 - val_RMSE_P: 1243.7640 - val_RMSE_T: 48.1440
# Epoch 533/5000
# 45/45 [==============================] - 0s 476us/step - loss: 0.0140 - mean_absolute_error: 0.0842 - root_mean_squared_error: 0.1183 - RMSE_P: 1195.9346 - RMSE_T: 43.8637 - val_loss: 0.0155 - val_mean_absolute_error: 0.0871 - val_root_mean_squared_error: 0.1244 - val_RMSE_P: 1217.5022 - val_RMSE_T: 48.4610
# Epoch 534/5000
# 45/45 [==============================] - 0s 470us/step - loss: 0.0140 - mean_absolute_error: 0.0842 - root_mean_squared_error: 0.1185 - RMSE_P: 1200.9711 - RMSE_T: 43.7814 - val_loss: 0.0155 - val_mean_absolute_error: 0.0868 - val_root_mean_squared_error: 0.1245 - val_RMSE_P: 1224.2654 - val_RMSE_T: 47.8313
# Epoch 535/5000
# 45/45 [==============================] - 0s 478us/step - loss: 0.0140 - mean_absolute_error: 0.0841 - root_mean_squared_error: 0.1185 - RMSE_P: 1199.1927 - RMSE_T: 43.8769 - val_loss: 0.0153 - val_mean_absolute_error: 0.0869 - val_root_mean_squared_error: 0.1235 - val_RMSE_P: 1212.4625 - val_RMSE_T: 47.7640
# Epoch 536/5000
# 45/45 [==============================] - 0s 476us/step - loss: 0.0141 - mean_absolute_error: 0.0843 - root_mean_squared_error: 0.1188 - RMSE_P: 1206.5197 - RMSE_T: 43.7206 - val_loss: 0.0159 - val_mean_absolute_error: 0.0889 - val_root_mean_squared_error: 0.1260 - val_RMSE_P: 1248.6721 - val_RMSE_T: 47.9062
# Epoch 537/5000
# 45/45 [==============================] - 0s 489us/step - loss: 0.0140 - mean_absolute_error: 0.0841 - root_mean_squared_error: 0.1182 - RMSE_P: 1200.3538 - RMSE_T: 43.6236 - val_loss: 0.0155 - val_mean_absolute_error: 0.0881 - val_root_mean_squared_error: 0.1245 - val_RMSE_P: 1228.3030 - val_RMSE_T: 47.7131
# Epoch 538/5000
# 45/45 [==============================] - 0s 469us/step - loss: 0.0140 - mean_absolute_error: 0.0841 - root_mean_squared_error: 0.1183 - RMSE_P: 1200.3181 - RMSE_T: 43.7196 - val_loss: 0.0156 - val_mean_absolute_error: 0.0879 - val_root_mean_squared_error: 0.1249 - val_RMSE_P: 1232.8575 - val_RMSE_T: 47.9239
# Epoch 539/5000
# 45/45 [==============================] - 0s 465us/step - loss: 0.0140 - mean_absolute_error: 0.0843 - root_mean_squared_error: 0.1185 - RMSE_P: 1201.0764 - RMSE_T: 43.8450 - val_loss: 0.0154 - val_mean_absolute_error: 0.0874 - val_root_mean_squared_error: 0.1241 - val_RMSE_P: 1219.6232 - val_RMSE_T: 47.9620
# Epoch 540/5000
# 45/45 [==============================] - 0s 481us/step - loss: 0.0140 - mean_absolute_error: 0.0844 - root_mean_squared_error: 0.1184 - RMSE_P: 1193.7651 - RMSE_T: 44.0433 - val_loss: 0.0155 - val_mean_absolute_error: 0.0871 - val_root_mean_squared_error: 0.1244 - val_RMSE_P: 1222.9097 - val_RMSE_T: 47.9953
# Epoch 541/5000
# 45/45 [==============================] - 0s 604us/step - loss: 0.0141 - mean_absolute_error: 0.0843 - root_mean_squared_error: 0.1187 - RMSE_P: 1194.4622 - RMSE_T: 43.6517 - val_loss: 0.0155 - val_mean_absolute_error: 0.0871 - val_root_mean_squared_error: 0.1246 - val_RMSE_P: 1222.6218 - val_RMSE_T: 48.0782
# INFO:tensorflow:Assets written to: saved_models/01c_BtThermobaromater_Feb25/assets
# INFO:tensorflow:Assets written to: saved_models/01c_BtThermobaromater_Feb25/assets

# %% [markdown]
# # Plot training history

# %%
plot_training_curve("01c_BtThermobaromater_Feb2025.log", color="red", label="model", log_scale=True, ylims=[None, (2.5, 100), (500, 1500)])
# Out:
# (<Figure size 1200x400 with 3 Axes>,
#  array([<Axes: xlabel='Epoch', ylabel='Loss'>,
#         <Axes: xlabel='Epoch', ylabel='Temperature RMSE [K]'>,
#         <Axes: xlabel='Epoch', ylabel='Pressure RMSE [bar]'>], dtype=object))

# %%
y_true = pt_val
y_pred = inv_scaling_pt(model.predict(data_val))

color = "red"

prediction_vs_truth(y_true, y_pred, color)
# Out:
# 8/8 [==============================] - 0s 411us/step
# (<Figure size 800x400 with 2 Axes>,
#  array([<Axes: xlabel='True pressure [bar]', ylabel='Predicted pressure [bar]'>,
#         <Axes: xlabel='True temperature [°C]', ylabel='Predicted temperature [°C]'>],
#        dtype=object))
