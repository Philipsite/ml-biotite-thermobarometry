# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from pathlib import Path
from ml_tb.plot import _smooth, plot_hyperparameter_test

# %%
fig, axs = plot_hyperparameter_test(log_files=["logs/Features00_TiXMg.log", "logs/Features01_full_EPMA_analysis.log", "logs/Features02_elements_solution_model.log", "logs/Features03_elements_solution_model_Fe2Fe3.log", "logs/Features04_elements_solution_model_exclMn.log", "logs/Features05_Bt_comp_index_min.log", "logs/Features06_Bt_comp_index_min.log"],
                                    colors=sns.color_palette("deep", 7),
                                    labels=["TiXMg", "MnNKFMAST", "MnFMAST", "MnFMAST (Fe2+/Fe3+)", "FMAST", "MnFMAST + index", "MnFMAST + index + FeTi-Min"],
                                    ylims=[None, (25, 50), (500, 2500)],
                                    log_scale=False)

# %%
fig, axs = plot_hyperparameter_test(log_files=["logs/Features00_TiXMg.log", "logs/Features01_full_EPMA_analysis.log", "logs/Features02_elements_solution_model.log", "logs/Features03_elements_solution_model_Fe2Fe3.log", "logs/Features04_elements_solution_model_exclMn.log"],
                                    colors=sns.color_palette("deep", 5),
                                    labels=["TiXMg", "MnNKFMAST", "MnFMAST", "MnFMAST (Fe2+/Fe3+)", "FMAST"],
                                    ylims=[None, (35, 50), (1000, 1500)],
                                    log_scale=False)

# %%
fig, axs = plot_hyperparameter_test(log_files=["logs/Features00_TiXMg.log", "logs/Features01_full_EPMA_analysis.log", "logs/Features02_elements_solution_model.log", "logs/Features03_elements_solution_model_Fe2Fe3.log", "logs/Features04_elements_solution_model_exclMn.log", "logs/Features05_Bt_comp_index_min.log", "logs/Features06_Bt_comp_index_min.log"],
                                    colors=sns.color_palette("deep", 7),
                                    labels=["TiXMg", "MnNKFMAST", "MnFMAST", "MnFMAST (Fe2+/Fe3+)", "FMAST", "MnFMAST + index", "MnFMAST + index + FeTi-Min"],
                                    ylims=[None, (25, 50), (500, 2500)])

# fig.savefig(Path("plot_feature_eng_export_figs", "feature_eng.pdf"), dpi=400)

# %%
fig, axs = plot_hyperparameter_test(log_files=["logs/Features_PTcentral.log", "logs/Features_PTuniform.log", "logs/Features_PTordered.log"],
                                    colors=sns.color_palette("deep", 3),
                                    labels=["Central P/T", "Random uniform P/T", "random orderd P/T"],
                                    ylims=[None, (25, 100), (500, 2500)])

# fig.savefig(Path("plot_feature_eng_export_figs", "PT_assignement.pdf"), dpi=400)
