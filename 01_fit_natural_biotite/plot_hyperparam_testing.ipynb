# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from pathlib import Path

from ml_tb.plot import _smooth, plot_hyperparameter_test, plot_hyperparameter_test_thermometer
# Out:
# C:\Users\ThinkPad\AppData\Local\Temp\ipykernel_12072\4245796407.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# WARNING:tensorflow:From c:\Users\ThinkPad\miniconda3\envs\masterproject\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# ## Ti-XMg model

# %%
fig, axs = plot_hyperparameter_test_thermometer(log_files=["HyperParamTest_verysmall_TiXMg.log", "HyperParamTest_small_TiXMg.log", "HyperParamTest_large_TiXMg.log", "HyperParamTest_small_2hl_TiXMg.log", "HyperParamTest_large_2hl_TiXMg.log", "HyperParamTest_huge_TiXMg.log"],
                                                colors=sns.color_palette("deep", 6),
                                                labels=["Very small", "Small", "Large", "Small 2HL", "Large 2HL", "Huge"],
                                                ylims=[None, (30, 80)])

fig.savefig(Path("plot_hyperparamtesting_export_figs", "TiXmg_model_architecture.pdf"), dpi=400)

# %%
fig, axs = plot_hyperparameter_test_thermometer(log_files=["HyperParamTest_LR1_TiXMg.log", "HyperParamTest_LR2_TiXMg.log", "HyperParamTest_LR3_TiXMg.log", "HyperParamTest_LR4_TiXMg.log"],
                                                colors=sns.color_palette("deep", 4),
                                                labels=["0.01", "0.001", "0.0005", "0.0001"],
                                                ylims=[None, (30, 80)])

fig.savefig(Path("plot_hyperparamtesting_export_figs", "TiXmg_model_lr.pdf"), dpi=400)

# %% [markdown]
# ## MnFMAST model

# %%
fig, axs = plot_hyperparameter_test(log_files=["HyperParamTest_verysmall_DATA01.log", "HyperParamTest_small_DATA01.log", "HyperParamTest_large_DATA01.log", "HyperParamTest_small_2hl_DATA01.log", "HyperParamTest_large_2hl_DATA01.log", "HyperParamTest_huge_DATA01.log"],
                                    colors=sns.color_palette("deep", 6),
                                    labels=["Very small", "Small", "Large", "Small 2HL", "Large 2HL", "Huge"],
                                    ylims=[None, (10, 80), (50, 2000)])

fig.savefig(Path("plot_hyperparamtesting_export_figs", "MnFMAST_model_architecture.pdf"), dpi=400)

# %%
fig, axs = plot_hyperparameter_test(log_files=["HyperParamTest_LR1_DATA01.log", "HyperParamTest_LR2_DATA01.log", "HyperParamTest_LR3_DATA01.log", "HyperParamTest_LR4_DATA01.log"],
                                    colors=sns.color_palette("deep", 4),
                                    labels=["0.01", "0.001", "0.0005", "0.0001"],
                                    ylims=[None, (10, 80), (50, 2000)])

fig.savefig(Path("plot_hyperparamtesting_export_figs", "MnFMAST_model_lr.pdf"), dpi=400)

# %% [markdown]
# ## MnFMAST + index minerals model

# %%
fig, axs = plot_hyperparameter_test(log_files=["HyperParamTest_verysmall_DATA02.log", "HyperParamTest_small_DATA02.log", "HyperParamTest_large_DATA02.log", "HyperParamTest_small_2hl_DATA02.log", "HyperParamTest_large_2hl_DATA02.log", "HyperParamTest_huge_DATA02.log"],
                                    colors=sns.color_palette("deep", 6),
                                    labels=["Very small", "Small", "Large", "Small 2HL", "Large 2HL", "Huge"],
                                    ylims=[None, (10, 80), (50, 2000)])

fig.savefig(Path("plot_hyperparamtesting_export_figs", "MnFMAST_indexMinerals_model_architecture.pdf"), dpi=400)

# %%
fig, axs = plot_hyperparameter_test(log_files=["HyperParamTest_LR1_DATA02.log", "HyperParamTest_LR2_DATA02.log", "HyperParamTest_LR3_DATA02.log", "HyperParamTest_LR4_DATA02.log"],
                                    colors=sns.color_palette("deep", 4),
                                    labels=["0.01", "0.001", "0.0005", "0.0001"],
                                    ylims=[None, (10, 80), (50, 2000)])

fig.savefig(Path("plot_hyperparamtesting_export_figs", "MnFMAST_indexMinerals_model_lr.pdf"), dpi=400)

# %%
fig, axs = plot_hyperparameter_test(log_files=["HyperParamTest_noReg.log", "HyperParamTest_L2.log","HyperParamTest_dropout.log", "HyperParamTest_BatchNorm.log", "HyperParamTest_LayerNorm.log", "HyperParamTest_L2_dropout.log"],
                                    colors=sns.color_palette("deep", 6),
                                    labels=["NoReg", "L2", "Dropout", "BatchNorm", "LayerNorm", "L2+Dropout"],
                                    ylims=[None, (10, 80), (50, 2000)])

fig.savefig(Path("plot_hyperparamtesting_export_figs", "MnFMAST_indexMinerals_model_reg.pdf"), dpi=400)
