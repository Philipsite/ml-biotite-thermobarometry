# %% [markdown]
# :warning:**IMPORTANT NOTICE**:warning:\
# *Since the initial parameterisation and gradient descent optimisation are stochastic processes, the training of a neural network is not fully reproducible.*
#
# *Therefore, it is not recommended to re-run this script as it will overwrite the original calibration of the neural network used in the work presented here.
# The purpose of this script is solely to document the training procedure and can be copied as a template to fit other new neural networks.*
#
# *To experiment with the models calibrated here, they can be loaded from the `saved_models` directory.*

# %% [markdown]
# # Train neural network on simulated data from **ds55** with **White et al. (2007)** biotite solution model
#
# Predict pressure and temperature from biotite composition.\
# The data are simulated biotite composition - pressure - temperature triples. These data were generated using phase equilibrium modelling (Theriak-Domino).
#
# Trained ANN is used as prior in transfer learning with natural data.
#
# ### Hyperparameter
# These hyperparameters were determined by tests conducted in "hyperparameter_testing.ipynb".\
# All tests were conducted on the simulated data of ds62-White2014. **It is assumed, that the same hyperparameters are optimal for ds55-White2007.**
#
# **Performance metrics:**
# - Mean Absolute Error (MAE)
# - Mean Absolute Percentage Error (MAPE)
# - Root Mean Square Error (RMSE)
#     - RMSE inverse transformed for pressure and temperature
#
# **Last layer activation function:**
# - Linear --> Regression problem
#
# **Loss function:**
# - Mean Squared Error (MSE)
#
# **Optimizer:**
# - Adam with inverse time decay learning rate scheduler
#
# **Batch size:**
# - 500
#
# **Architecture:**
# - 4 hidden layers with 64 neurons each
#
# **Activation function:**
# - ReLU
#
# **Regularization:**
# - Small network capacity proved to be sufficient for this problem. Therefore, no regularization was used.
#
# ### Goal
# Best possible performance on the validation set.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import h5py

from pathlib import Path
from keras.models import Sequential
from keras.layers import Dense, Normalization, BatchNormalization, LayerNormalization, Dropout
from keras.losses import MeanSquaredError
from keras.optimizers import Adam, schedules
from keras.metrics import MeanAbsoluteError, RootMeanSquaredError, MeanAbsolutePercentageError
from keras.callbacks import CSVLogger, EarlyStopping
from sklearn.model_selection import train_test_split

from ml_tb.normalisation import MinMaxScaler
from ml_tb.metrics import RMSE_denormalised_P, RMSE_denormalised_T
from ml_tb.plot import _smooth
# Out:
# C:\Users\ThinkPad\AppData\Local\Temp\ipykernel_18876\3732669427.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# WARNING:tensorflow:From c:\Users\ThinkPad\miniconda3\envs\masterproject\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# ## Import data, pre-procesing and train/test split
#
# For bioitte composition only extract elements which are modelled to be present in biotite by ds55. Idel end-member added for Mn.\
# Element-idx from hdf5 file:
# ```python
# (0, 'O') (1, 'AL') (2, 'CA') (3, 'F3') (4, 'FE') (5, 'H') (6, 'K') (7, 'MN') (8, 'MG') (9, 'NA') (10, 'SI') (11, 'TI')
# ```
# Only extract: Si, Ti, Al, Fe, Mg, Mn.\
# K would be in modelled biotite, but is fixed at 1.0.
#
# Validation set is **10%** of the training set. Approx. 6000 samples.

# %%
# load hdf file
file = Path("15022024_Biotite_ds55Bt07.hdf5")
with h5py.File(file, "r") as hdf_file:
    PT = np.array(hdf_file["PT"])
    full_biotite_composition = np.array(hdf_file["mineral_composition"])
    element_idx = hdf_file["mineral_composition"].attrs["element idx [apfu]"]

print(*enumerate(element_idx))

biotite_composition = full_biotite_composition[:,[10, 11, 1, 4, 7, 8]]
biotite_F3 = full_biotite_composition[:, 3]
# Consider Fe as Fe total in biotite composition, add Fe and Fe3
biotite_composition[:, 3] += biotite_F3

pt = PT

biotite_composition_train, biotite_composition_val, pt_train, pt_val = train_test_split(biotite_composition, pt, test_size=0.10, shuffle=True)

# normalise biotite composition & min-max scale PT
normalisation_biotite_composition = Normalization(axis=-1)
normalisation_biotite_composition.adapt(biotite_composition_train)

print(normalisation_biotite_composition.mean.numpy())
print(np.sqrt(normalisation_biotite_composition.variance.numpy()))

scaling_pt = MinMaxScaler(min=[1500, 400], max=[10000, 900], axis=0)
inv_scaling_pt = MinMaxScaler(min=[1500, 400], max=[10000, 900], axis=0, invert=True)
pt_train_norm = scaling_pt(pt_train)
pt_val_norm = scaling_pt(pt_val)
# Out:
# (0, 'O') (1, 'AL') (2, 'CA') (3, 'F3') (4, 'FE') (5, 'H') (6, 'K') (7, 'MN') (8, 'MG') (9, 'NA') (10, 'SI') (11, 'TI')
# WARNING:tensorflow:From c:\Users\ThinkPad\miniconda3\envs\masterproject\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# [[2.6389399  0.08302815 1.7019893  1.4628754  0.00660345 1.106564  ]]
# [[0.16861786 0.04025044 0.33482304 0.28671214 0.00600933 0.2798569 ]]

# %% [markdown]
# ## Set-up model & training parameters
#
# Use callbacks to save the best model and to stop training if the validation loss does not decrease for 10 epochs.

# %% [markdown]
# ### Custom metrics
#
# Define a custom metric to evaluate the RMSE of temperature and pressure in meaningful units.\
# The RMSE is calculated on the inverse transformed data and therefore has the units of the original data ([bar]/[&deg;C]).

# %%
def RMSE_P(y_true, y_pred):
    return RMSE_denormalised_P(y_true, y_pred, inv_scaling_pt)


def RMSE_T(y_true, y_pred):
    return RMSE_denormalised_T(y_true, y_pred, inv_scaling_pt)

# %%
BATCH_SIZE = 500
STEPS_PER_EPOCH = len(biotite_composition_train) // BATCH_SIZE
MAX_EPOCHS = 5000

lr_schedule = schedules.InverseTimeDecay(0.001, decay_steps=STEPS_PER_EPOCH*1000, decay_rate=1, staircase=False)
OPT = Adam(lr_schedule)

LOSS = MeanSquaredError()
METRICS = [MeanAbsoluteError(), MeanAbsolutePercentageError(), RootMeanSquaredError(), RMSE_P, RMSE_T]

CALLBACKS = [EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=True), CSVLogger("model_ds55White2007.log", append=False)]

# %%
model = Sequential()
model.add(normalisation_biotite_composition)
model.add(Dense(64, activation="relu"))
model.add(Dense(64, activation="relu"))
model.add(Dense(64, activation="relu"))
model.add(Dense(64, activation="relu"))
model.add(Dense(2))

model.compile(optimizer=OPT, loss=LOSS, metrics=METRICS)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  normalization (Normalizati  (None, 6)                 13
#  on)
#
#  dense (Dense)               (None, 64)                448
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  dense_2 (Dense)             (None, 64)                4160
#
#  dense_3 (Dense)             (None, 64)                4160
#
#  dense_4 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 13071 (51.06 KB)
# Trainable params: 13058 (51.01 KB)
# Non-trainable params: 13 (56.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(biotite_composition_train, pt_train_norm,
                    batch_size=BATCH_SIZE, epochs=MAX_EPOCHS,
                    validation_data=[biotite_composition_val, pt_val_norm],
                    callbacks=CALLBACKS, verbose=True)

model.save(Path("saved_models", "model_ds55White2007"))
# Out:
# Epoch 1/5000
# WARNING:tensorflow:From c:\Users\ThinkPad\miniconda3\envs\masterproject\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\ThinkPad\miniconda3\envs\masterproject\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 136/136 [==============================] - 3s 7ms/step - loss: 0.0425 - mean_absolute_error: 0.1452 - mean_absolute_percentage_error: 150301.4688 - root_mean_squared_error: 0.2062 - RMSE_P: 2094.6643 - RMSE_T: 56.6091 - val_loss: 0.0193 - val_mean_absolute_error: 0.0927 - val_mean_absolute_percentage_error: 71353.6641 - val_root_mean_squared_error: 0.1388 - val_RMSE_P: 1641.7712 - val_RMSE_T: 23.9625
# Epoch 2/5000
# 136/136 [==============================] - 1s 4ms/step - loss: 0.0168 - mean_absolute_error: 0.0830 - mean_absolute_percentage_error: 46741.6641 - root_mean_squared_error: 0.1295 - RMSE_P: 1512.0693 - RMSE_T: 21.2978 - val_loss: 0.0155 - val_mean_absolute_error: 0.0792 - val_mean_absolute_percentage_error: 30890.0508 - val_root_mean_squared_error: 0.1244 - val_RMSE_P: 1474.6139 - val_RMSE_T: 19.8030
# Epoch 3/5000
# 136/136 [==============================] - 1s 5ms/step - loss: 0.0147 - mean_absolute_error: 0.0749 - mean_absolute_percentage_error: 34344.0586 - root_mean_squared_error: 0.1212 - RMSE_P: 1417.4790 - RMSE_T: 19.4573 - val_loss: 0.0137 - val_mean_absolute_error: 0.0710 - val_mean_absolute_percentage_error: 20396.4414 - val_root_mean_squared_error: 0.1169 - val_RMSE_P: 1386.2365 - val_RMSE_T: 18.5283
# Epoch 4/5000
# 136/136 [==============================] - 1s 6ms/step - loss: 0.0136 - mean_absolute_error: 0.0711 - mean_absolute_percentage_error: 34712.8242 - root_mean_squared_error: 0.1168 - RMSE_P: 1364.2533 - RMSE_T: 18.8685 - val_loss: 0.0129 - val_mean_absolute_error: 0.0693 - val_mean_absolute_percentage_error: 18092.6758 - val_root_mean_squared_error: 0.1137 - val_RMSE_P: 1346.1366 - val_RMSE_T: 18.4446
# Epoch 5/5000
# 136/136 [==============================] - 1s 4ms/step - loss: 0.0128 - mean_absolute_error: 0.0680 - mean_absolute_percentage_error: 34539.4609 - root_mean_squared_error: 0.1133 - RMSE_P: 1323.8781 - RMSE_T: 18.2120 - val_loss: 0.0123 - val_mean_absolute_error: 0.0663 - val_mean_absolute_percentage_error: 24529.2598 - val_root_mean_squared_error: 0.1107 - val_RMSE_P: 1309.7206 - val_RMSE_T: 17.7175
# Epoch 6/5000
# 136/136 [==============================] - 0s 3ms/step - loss: 0.0123 - mean_absolute_error: 0.0661 - mean_absolute_percentage_error: 31493.4727 - root_mean_squared_error: 0.1109 - RMSE_P: 1295.5287 - RMSE_T: 17.9235 - val_loss: 0.0118 - val_mean_absolute_error: 0.0649 - val_mean_absolute_percentage_error: 30768.3027 - val_root_mean_squared_error: 0.1086 - val_RMSE_P: 1283.4518 - val_RMSE_T: 17.6526
# Epoch 7/5000
# 136/136 [==============================] - 0s 3ms/step - loss: 0.0119 - mean_absolute_error: 0.0647 - mean_absolute_percentage_error: 30706.6426 - root_mean_squared_error: 0.1090 - RMSE_P: 1273.8062 - RMSE_T: 17.6689 - val_loss: 0.0115 - val_mean_absolute_error: 0.0631 - val_mean_absolute_percentage_error: 32590.4414 - val_root_mean_squared_error: 0.1074 - val_RMSE_P: 1267.4564 - val_RMSE_T: 17.4898
# Epoch 8/5000
# 136/136 [==============================] - 0s 3ms/step - loss: 0.0116 - mean_absolute_error: 0.0637 - mean_absolute_percentage_error: 31219.9141 - root_mean_squared_error: 0.1078 - RMSE_P: 1259.1677 - RMSE_T: 17.5173 - val_loss: 0.0112 - val_mean_absolute_error: 0.0624 - val_mean_absolute_percentage_error: 26409.5098 - val_root_mean_squared_error: 0.1057 - val_RMSE_P: 1249.0283 - val_RMSE_T: 17.0178
# Epoch 9/5000
# 136/136 [==============================] - 0s 3ms/step - loss: 0.0114 - mean_absolute_error: 0.0626 - mean_absolute_percentage_error: 31824.4297 - root_mean_squared_error: 0.1066 - RMSE_P: 1244.6683 - RMSE_T: 17.2896 - val_loss: 0.0111 - val_mean_absolute_error: 0.0621 - val_mean_absolute_percentage_error: 17725.2695 - val_root_mean_squared_error: 0.1056 - val_RMSE_P: 1243.4244 - val_RMSE_T: 17.2764
# Epoch 10/5000
# 136/136 [==============================] - 0s 3ms/step - loss: 0.0113 - mean_absolute_error: 0.0627 - mean_absolute_percentage_error: 31378.3047 - root_mean_squared_error: 0.1064 - RMSE_P: 1242.3663 - RMSE_T: 17.2360 - val_loss: 0.0111 - val_mean_absolute_error: 0.0615 - val_mean_absolute_percentage_error: 33746.3672 - val_root_mean_squared_error: 0.1055 - val_RMSE_P: 1244.9360 - val_RMSE_T: 17.2214
# Epoch 11/5000
# 136/136 [==============================] - 0s 3ms/step - loss: 0.0110 - mean_absolute_error: 0.0615 - mean_absolute_percentage_error: 28618.3223 - root_mean_squared_error: 0.1051 - RMSE_P: 1227.5750 - RMSE_T: 17.0540 - val_loss: 0.0109 - val_mean_absolute_error: 0.0605 - val_mean_absolute_percentage_error: 29505.6035 - val_root_mean_squared_error: 0.1043 - val_RMSE_P: 1228.4897 - val_RMSE_T: 16.8350
# Epoch 12/5000
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0109 - mean_absolute_error: 0.0611 - mean_absolute_percentage_error: 27475.4609 - root_mean_squared_error: 0.1045 - RMSE_P: 1220.2532 - RMSE_T: 16.9300 - val_loss: 0.0109 - val_mean_absolute_error: 0.0609 - val_mean_absolute_percentage_error: 31093.7129 - val_root_mean_squared_error: 0.1043 - val_RMSE_P: 1227.7894 - val_RMSE_T: 17.3968
# Epoch 13/5000
# 136/136 [==============================] - 0s 3ms/step - loss: 0.0108 - mean_absolute_error: 0.0607 - mean_absolute_percentage_error: 26602.3633 - root_mean_squared_error: 0.1037 - RMSE_P: 1211.2372 - RMSE_T: 16.9093 - val_loss: 0.0107 - val_mean_absolute_error: 0.0586 - val_mean_absolute_percentage_error: 38727.6094 - val_root_mean_squared_error: 0.1032 - val_RMSE_P: 1219.7734 - val_RMSE_T: 16.5886
# Epoch 14/5000
# 136/136 [==============================] - 0s 3ms/step - loss: 0.0106 - mean_absolute_error: 0.0597 - mean_absolute_percentage_error: 27448.1289 - root_mean_squared_error: 0.1028 - RMSE_P: 1200.3629 - RMSE_T: 16.7474 - val_loss: 0.0107 - val_mean_absolute_error: 0.0607 - val_mean_absolute_percentage_error: 23872.4707 - val_root_mean_squared_error: 0.1036 - val_RMSE_P: 1225.1820 - val_RMSE_T: 16.6478
# Epoch 15/5000
# 136/136 [==============================] - 1s 5ms/step - loss: 0.0106 - mean_absolute_error: 0.0601 - mean_absolute_percentage_error: 27909.0859 - root_mean_squared_error: 0.1027 - RMSE_P: 1199.8629 - RMSE_T: 16.6529 - val_loss: 0.0106 - val_mean_absolute_error: 0.0617 - val_mean_absolute_percentage_error: 22094.1016 - val_root_mean_squared_error: 0.1030 - val_RMSE_P: 1213.3335 - val_RMSE_T: 16.8178
# Epoch 16/5000
# 136/136 [==============================] - 1s 4ms/step - loss: 0.0105 - mean_absolute_error: 0.0598 - mean_absolute_percentage_error: 27679.3262 - root_mean_squared_error: 0.1024 - RMSE_P: 1196.1143 - RMSE_T: 16.5985 - val_loss: 0.0101 - val_mean_absolute_error: 0.0585 - val_mean_absolute_percentage_error: 21310.8477 - val_root_mean_squared_error: 0.1006 - val_RMSE_P: 1189.0583 - val_RMSE_T: 16.2793
# Epoch 17/5000
# 136/136 [==============================] - 1s 5ms/step - loss: 0.0103 - mean_absolute_error: 0.0589 - mean_absolute_percentage_error: 27589.4785 - root_mean_squared_error: 0.1014 - RMSE_P: 1183.5428 - RMSE_T: 16.4403 - val_loss: 0.0102 - val_mean_absolute_error: 0.0589 - val_mean_absolute_percentage_error: 33232.8984 - val_root_mean_squared_error: 0.1011 - val_RMSE_P: 1189.0286 - val_RMSE_T: 16.5557
# Epoch 18/5000
# 136/136 [==============================] - 0s 3ms/step - loss: 0.0102 - mean_absolute_error: 0.0589 - mean_absolute_percentage_error: 28302.3770 - root_mean_squared_error: 0.1011 - RMSE_P: 1181.0315 - RMSE_T: 16.4010 - val_loss: 0.0102 - val_mean_absolute_error: 0.0580 - val_mean_absolute_percentage_error: 23196.3281 - val_root_mean_squared_error: 0.1010 - val_RMSE_P: 1192.3177 - val_RMSE_T: 16.9351
# Epoch 19/5000
# 136/136 [==============================] - 1s 4ms/step - loss: 0.0101 - mean_absolute_error: 0.0585 - mean_absolute_percentage_error: 29028.4023 - root_mean_squared_error: 0.1005 - RMSE_P: 1174.0696 - RMSE_T: 16.3192 - val_loss: 0.0102 - val_mean_absolute_error: 0.0592 - val_mean_absolute_percentage_error: 28676.2090 - val_root_mean_squared_error: 0.1011 - val_RMSE_P: 1193.8888 - val_RMSE_T: 16.0496
# Epoch 20/5000
# 136/136 [==============================] - 0s 3ms/step - loss: 0.0099 - mean_absolute_error: 0.0576 - mean_absolute_percentage_error: 25746.1816 - root_mean_squared_error: 0.0997 - RMSE_P: 1164.5129 - RMSE_T: 16.2261 - val_loss: 0.0106 - val_mean_absolute_error: 0.0604 - val_mean_absolute_percentage_error: 17826.7520 - val_root_mean_squared_error: 0.1028 - val_RMSE_P: 1217.1866 - val_RMSE_T: 16.7190
# Epoch 21/5000
# 136/136 [==============================] - 0s 3ms/step - loss: 0.0099 - mean_absolute_error: 0.0575 - mean_absolute_percentage_error: 27687.0684 - root_mean_squared_error: 0.0995 - RMSE_P: 1162.2744 - RMSE_T: 16.1762 - val_loss: 0.0100 - val_mean_absolute_error: 0.0572 - val_mean_absolute_percentage_error: 24208.8555 - val_root_mean_squared_error: 0.1000 - val_RMSE_P: 1180.7156 - val_RMSE_T: 16.2299
# Epoch 22/5000
# 136/136 [==============================] - 0s 4ms/step - loss: 0.0098 - mean_absolute_error: 0.0573 - mean_absolute_percentage_error: 28359.2715 - root_mean_squared_error: 0.0989 - RMSE_P: 1154.8682 - RMSE_T: 16.1466 - val_loss: 0.0097 - val_mean_absolute_error: 0.0564 - val_mean_absolute_percentage_error: 17328.6328 - val_root_mean_squared_error: 0.0985 - val_RMSE_P: 1160.5104 - val_RMSE_T: 15.6973
# Epoch 23/5000
# 136/136 [==============================] - 0s 3ms/step - loss: 0.0098 - mean_absolute_error: 0.0575 - mean_absolute_percentage_error: 28555.3477 - root_mean_squared_error: 0.0990 - RMSE_P: 1154.9725 - RMSE_T: 16.1811 - val_loss: 0.0099 - val_mean_absolute_error: 0.0587 - val_mean_absolute_percentage_error: 47734.9258 - val_root_mean_squared_error: 0.0994 - val_RMSE_P: 1169.0293 - val_RMSE_T: 17.2676
# Epoch 24/5000
# 136/136 [==============================] - 0s 3ms/step - loss: 0.0096 - mean_absolute_error: 0.0563 - mean_absolute_percentage_error: 28872.7637 - root_mean_squared_error: 0.0977 - RMSE_P: 1141.0498 - RMSE_T: 15.9619 - val_loss: 0.0095 - val_mean_absolute_error: 0.0562 - val_mean_absolute_percentage_error: 30837.1895 - val_root_mean_squared_error: 0.0975 - val_RMSE_P: 1149.7612 - val_RMSE_T: 15.9103
# Epoch 25/5000
# 136/136 [==============================] - 1s 4ms/step - loss: 0.0094 - mean_absolute_error: 0.0560 - mean_absolute_percentage_error: 26986.8398 - root_mean_squared_error: 0.0972 - RMSE_P: 1134.2621 - RMSE_T: 15.9196 - val_loss: 0.0095 - val_mean_absolute_error: 0.0564 - val_mean_absolute_percentage_error: 22325.2871 - val_root_mean_squared_error: 0.0977 - val_RMSE_P: 1151.7684 - val_RMSE_T: 16.0346
# Epoch 26/5000
# 136/136 [==============================] - 1s 4ms/step - loss: 0.0094 - mean_absolute_error: 0.0556 - mean_absolute_percentage_error: 26790.6777 - root_mean_squared_error: 0.0968 - RMSE_P: 1129.0393 - RMSE_T: 15.8988 - val_loss: 0.0095 - val_mean_absolute_error: 0.0550 - val_mean_absolute_percentage_error: 21867.8652 - val_root_mean_squared_error: 0.0974 - val_RMSE_P: 1148.6566 - val_RMSE_T: 15.8955
# Epoch 27/5000
# 136/136 [==============================] - 1s 4ms/step - loss: 0.0092 - mean_absolute_error: 0.0555 - mean_absolute_percentage_error: 28171.6152 - root_mean_squared_error: 0.0961 - RMSE_P: 1121.3038 - RMSE_T: 15.8615 - val_loss: 0.0095 - val_mean_absolute_error: 0.0566 - val_mean_absolute_percentage_error: 30830.4453 - val_root_mean_squared_error: 0.0972 - val_RMSE_P: 1146.3865 - val_RMSE_T: 15.6621
# Epoch 28/5000
# 136/136 [==============================] - 0s 3ms/step - loss: 0.0091 - mean_absolute_error: 0.0549 - mean_absolute_percentage_error: 28486.5605 - root_mean_squared_error: 0.0955 - RMSE_P: 1113.1093 - RMSE_T: 15.9172 - val_loss: 0.0093 - val_mean_absolute_error: 0.0541 - val_mean_absolute_percentage_error: 23014.3105 - val_root_mean_squared_error: 0.0965 - val_RMSE_P: 1135.4968 - val_RMSE_T: 15.4729
# Epoch 29/5000
# 136/136 [==============================] - 0s 3ms/step - loss: 0.0091 - mean_absolute_error: 0.0549 - mean_absolute_percentage_error: 26774.0879 - root_mean_squared_error: 0.0956 - RMSE_P: 1114.3143 - RMSE_T: 15.8517 - val_loss: 0.0094 - val_mean_absolute_error: 0.0559 - val_mean_absolute_percentage_error: 30233.2676 - val_root_mean_squared_error: 0.0967 - val_RMSE_P: 1134.4977 - val_RMSE_T: 16.0833
# Epoch 30/5000
# 136/136 [==============================] - 0s 4ms/step - loss: 0.0089 - mean_absolute_error: 0.0541 - mean_absolute_percentage_error: 26806.4375 - root_mean_squared_error: 0.0944 - RMSE_P: 1100.2102 - RMSE_T: 15.7483 - val_loss: 0.0091 - val_mean_absolute_error: 0.0541 - val_mean_absolute_percentage_error: 20757.3086 - val_root_mean_squared_error: 0.0952 - val_RMSE_P: 1119.7133 - val_RMSE_T: 15.7932
# Epoch 31/5000
# 136/136 [==============================] - 1s 4ms/step - loss: 0.0089 - mean_absolute_error: 0.0543 - mean_absolute_percentage_error: 26887.4902 - root_mean_squared_error: 0.0944 - RMSE_P: 1101.2770 - RMSE_T: 15.6592 - val_loss: 0.0090 - val_mean_absolute_error: 0.0545 - val_mean_absolute_percentage_error: 20182.6660 - val_root_mean_squared_error: 0.0947 - val_RMSE_P: 1111.2407 - val_RMSE_T: 15.5813
# Epoch 32/5000
# 136/136 [==============================] - 0s 3ms/step - loss: 0.0089 - mean_absolute_error: 0.0544 - mean_absolute_percentage_error: 27107.0156 - root_mean_squared_error: 0.0945 - RMSE_P: 1101.8448 - RMSE_T: 15.7226 - val_loss: 0.0092 - val_mean_absolute_error: 0.0534 - val_mean_absolute_percentage_error: 25609.2246 - val_root_mean_squared_error: 0.0961 - val_RMSE_P: 1133.3221 - val_RMSE_T: 15.5493
# Epoch 33/5000
# 136/136 [==============================] - 0s 3ms/step - loss: 0.0088 - mean_absolute_error: 0.0538 - mean_absolute_percentage_error: 27157.4590 - root_mean_squared_error: 0.0938 - RMSE_P: 1093.2419 - RMSE_T: 15.5226 - val_loss: 0.0091 - val_mean_absolute_error: 0.0529 - val_mean_absolute_percentage_error: 31247.9844 - val_root_mean_squared_error: 0.0954 - val_RMSE_P: 1121.3966 - val_RMSE_T: 15.1988
# Epoch 34/5000
# 136/136 [==============================] - 0s 3ms/step - loss: 0.0086 - mean_absolute_error: 0.0532 - mean_absolute_percentage_error: 26061.0254 - root_mean_squared_error: 0.0928 - RMSE_P: 1081.8558 - RMSE_T: 15.5243 - val_loss: 0.0091 - val_mean_absolute_error: 0.0525 - val_mean_absolute_percentage_error: 22753.8242 - val_root_mean_squared_error: 0.0955 - val_RMSE_P: 1123.6261 - val_RMSE_T: 15.3022
# Epoch 35/5000
# 136/136 [==============================] - 0s 3ms/step - loss: 0.0087 - mean_absolute_error: 0.0532 - mean_absolute_percentage_error: 26189.5078 - root_mean_squared_error: 0.0931 - RMSE_P: 1085.1218 - RMSE_T: 15.4271 - val_loss: 0.0088 - val_mean_absolute_error: 0.0515 - val_mean_absolute_percentage_error: 20728.2988 - val_root_mean_squared_error: 0.0936 - val_RMSE_P: 1099.0795 - val_RMSE_T: 15.1209
# Epoch 36/5000
# 136/136 [==============================] - 1s 4ms/step - loss: 0.0085 - mean_absolute_error: 0.0528 - mean_absolute_percentage_error: 28082.9043 - root_mean_squared_error: 0.0923 - RMSE_P: 1076.5896 - RMSE_T: 15.3405 - val_loss: 0.0089 - val_mean_absolute_error: 0.0531 - val_mean_absolute_percentage_error: 20386.0703 - val_root_mean_squared_error: 0.0943 - val_RMSE_P: 1103.5649 - val_RMSE_T: 15.5924
# Epoch 37/5000
# 136/136 [==============================] - 1s 4ms/step - loss: 0.0084 - mean_absolute_error: 0.0525 - mean_absolute_percentage_error: 26547.2598 - root_mean_squared_error: 0.0917 - RMSE_P: 1068.6366 - RMSE_T: 15.4374 - val_loss: 0.0086 - val_mean_absolute_error: 0.0533 - val_mean_absolute_percentage_error: 13351.2998 - val_root_mean_squared_error: 0.0926 - val_RMSE_P: 1086.0355 - val_RMSE_T: 15.7576
# Epoch 38/5000
# 136/136 [==============================] - 0s 3ms/step - loss: 0.0083 - mean_absolute_error: 0.0517 - mean_absolute_percentage_error: 25633.7383 - root_mean_squared_error: 0.0909 - RMSE_P: 1058.7780 - RMSE_T: 15.2537 - val_loss: 0.0086 - val_mean_absolute_error: 0.0533 - val_mean_absolute_percentage_error: 25442.2793 - val_root_mean_squared_error: 0.0930 - val_RMSE_P: 1088.2050 - val_RMSE_T: 15.4896
# Epoch 39/5000
# 136/136 [==============================] - 1s 4ms/step - loss: 0.0082 - mean_absolute_error: 0.0517 - mean_absolute_percentage_error: 25747.9668 - root_mean_squared_error: 0.0908 - RMSE_P: 1057.3984 - RMSE_T: 15.3461 - val_loss: 0.0084 - val_mean_absolute_error: 0.0521 - val_mean_absolute_percentage_error: 19347.0566 - val_root_mean_squared_error: 0.0918 - val_RMSE_P: 1073.9628 - val_RMSE_T: 15.4791
# Epoch 40/5000
# 136/136 [==============================] - 0s 3ms/step - loss: 0.0082 - mean_absolute_error: 0.0518 - mean_absolute_percentage_error: 24928.1367 - root_mean_squared_error: 0.0908 - RMSE_P: 1057.1273 - RMSE_T: 15.2720 - val_loss: 0.0083 - val_mean_absolute_error: 0.0500 - val_mean_absolute_percentage_error: 27887.7344 - val_root_mean_squared_error: 0.0912 - val_RMSE_P: 1069.9895 - val_RMSE_T: 15.1628
# Epoch 41/5000
# 136/136 [==============================] - 0s 3ms/step - loss: 0.0080 - mean_absolute_error: 0.0505 - mean_absolute_percentage_error: 25207.6191 - root_mean_squared_error: 0.0892 - RMSE_P: 1039.4045 - RMSE_T: 15.1030 - val_loss: 0.0083 - val_mean_absolute_error: 0.0510 - val_mean_absolute_percentage_error: 25542.9160 - val_root_mean_squared_error: 0.0909 - val_RMSE_P: 1064.2487 - val_RMSE_T: 15.3880
# Epoch 42/5000
# 136/136 [==============================] - 0s 3ms/step - loss: 0.0080 - mean_absolute_error: 0.0508 - mean_absolute_percentage_error: 24893.8301 - root_mean_squared_error: 0.0894 - RMSE_P: 1041.9623 - RMSE_T: 15.0657 - val_loss: 0.0082 - val_mean_absolute_error: 0.0499 - val_mean_absolute_percentage_error: 21642.9590 - val_root_mean_squared_error: 0.0907 - val_RMSE_P: 1064.4946 - val_RMSE_T: 15.0257
# Epoch 43/5000
# 136/136 [==============================] - 0s 4ms/step - loss: 0.0081 - mean_absolute_error: 0.0514 - mean_absolute_percentage_error: 23913.6953 - root_mean_squared_error: 0.0900 - RMSE_P: 1048.8982 - RMSE_T: 15.1893 - val_loss: 0.0084 - val_mean_absolute_error: 0.0517 - val_mean_absolute_percentage_error: 24347.8984 - val_root_mean_squared_error: 0.0914 - val_RMSE_P: 1069.2365 - val_RMSE_T: 15.6422
# Epoch 44/5000
# 136/136 [==============================] - 1s 5ms/step - loss: 0.0080 - mean_absolute_error: 0.0512 - mean_absolute_percentage_error: 24867.4961 - root_mean_squared_error: 0.0897 - RMSE_P: 1044.5560 - RMSE_T: 15.1355 - val_loss: 0.0086 - val_mean_absolute_error: 0.0536 - val_mean_absolute_percentage_error: 27807.1523 - val_root_mean_squared_error: 0.0926 - val_RMSE_P: 1084.0383 - val_RMSE_T: 16.4421
# Epoch 45/5000
# 136/136 [==============================] - 1s 5ms/step - loss: 0.0079 - mean_absolute_error: 0.0503 - mean_absolute_percentage_error: 26840.1699 - root_mean_squared_error: 0.0887 - RMSE_P: 1032.9736 - RMSE_T: 15.0616 - val_loss: 0.0084 - val_mean_absolute_error: 0.0515 - val_mean_absolute_percentage_error: 27894.6719 - val_root_mean_squared_error: 0.0914 - val_RMSE_P: 1067.6213 - val_RMSE_T: 15.1478
# Epoch 46/5000
# 136/136 [==============================] - 1s 6ms/step - loss: 0.0078 - mean_absolute_error: 0.0502 - mean_absolute_percentage_error: 23846.8574 - root_mean_squared_error: 0.0883 - RMSE_P: 1028.3518 - RMSE_T: 15.0178 - val_loss: 0.0082 - val_mean_absolute_error: 0.0495 - val_mean_absolute_percentage_error: 23780.5371 - val_root_mean_squared_error: 0.0904 - val_RMSE_P: 1056.3370 - val_RMSE_T: 14.8994
# Epoch 47/5000
# 136/136 [==============================] - 1s 5ms/step - loss: 0.0077 - mean_absolute_error: 0.0496 - mean_absolute_percentage_error: 23658.0352 - root_mean_squared_error: 0.0877 - RMSE_P: 1020.1199 - RMSE_T: 14.9225 - val_loss: 0.0087 - val_mean_absolute_error: 0.0525 - val_mean_absolute_percentage_error: 30624.1523 - val_root_mean_squared_error: 0.0930 - val_RMSE_P: 1088.1332 - val_RMSE_T: 15.2108
# Epoch 48/5000
# 136/136 [==============================] - 1s 4ms/step - loss: 0.0078 - mean_absolute_error: 0.0504 - mean_absolute_percentage_error: 25147.8047 - root_mean_squared_error: 0.0884 - RMSE_P: 1029.2666 - RMSE_T: 15.0614 - val_loss: 0.0082 - val_mean_absolute_error: 0.0519 - val_mean_absolute_percentage_error: 22514.3457 - val_root_mean_squared_error: 0.0906 - val_RMSE_P: 1059.6747 - val_RMSE_T: 15.4086
# Epoch 49/5000
# 136/136 [==============================] - 1s 5ms/step - loss: 0.0077 - mean_absolute_error: 0.0499 - mean_absolute_percentage_error: 24759.9180 - root_mean_squared_error: 0.0877 - RMSE_P: 1020.1622 - RMSE_T: 14.9986 - val_loss: 0.0085 - val_mean_absolute_error: 0.0513 - val_mean_absolute_percentage_error: 20189.7559 - val_root_mean_squared_error: 0.0922 - val_RMSE_P: 1080.0334 - val_RMSE_T: 14.8513
# Epoch 50/5000
# 136/136 [==============================] - 1s 5ms/step - loss: 0.0078 - mean_absolute_error: 0.0501 - mean_absolute_percentage_error: 22530.1973 - root_mean_squared_error: 0.0881 - RMSE_P: 1025.2808 - RMSE_T: 14.9774 - val_loss: 0.0084 - val_mean_absolute_error: 0.0550 - val_mean_absolute_percentage_error: 10857.1465 - val_root_mean_squared_error: 0.0917 - val_RMSE_P: 1070.9143 - val_RMSE_T: 16.1423
# Epoch 51/5000
# 136/136 [==============================] - 1s 4ms/step - loss: 0.0076 - mean_absolute_error: 0.0496 - mean_absolute_percentage_error: 25104.0098 - root_mean_squared_error: 0.0874 - RMSE_P: 1016.5530 - RMSE_T: 14.8717 - val_loss: 0.0081 - val_mean_absolute_error: 0.0489 - val_mean_absolute_percentage_error: 31912.0938 - val_root_mean_squared_error: 0.0898 - val_RMSE_P: 1049.8145 - val_RMSE_T: 15.0684
# Epoch 52/5000
# 136/136 [==============================] - 1s 4ms/step - loss: 0.0076 - mean_absolute_error: 0.0495 - mean_absolute_percentage_error: 24957.5137 - root_mean_squared_error: 0.0872 - RMSE_P: 1014.6140 - RMSE_T: 14.8580 - val_loss: 0.0077 - val_mean_absolute_error: 0.0492 - val_mean_absolute_percentage_error: 13948.0840 - val_root_mean_squared_error: 0.0877 - val_RMSE_P: 1026.0056 - val_RMSE_T: 15.3062
# Epoch 53/5000
# 136/136 [==============================] - 1s 4ms/step - loss: 0.0076 - mean_absolute_error: 0.0498 - mean_absolute_percentage_error: 22887.0352 - root_mean_squared_error: 0.0873 - RMSE_P: 1016.3688 - RMSE_T: 14.9220 - val_loss: 0.0080 - val_mean_absolute_error: 0.0493 - val_mean_absolute_percentage_error: 22941.9922 - val_root_mean_squared_error: 0.0892 - val_RMSE_P: 1041.5234 - val_RMSE_T: 14.8947
# Epoch 54/5000
# 136/136 [==============================] - 1s 4ms/step - loss: 0.0075 - mean_absolute_error: 0.0491 - mean_absolute_percentage_error: 23275.6758 - root_mean_squared_error: 0.0867 - RMSE_P: 1009.4268 - RMSE_T: 14.7995 - val_loss: 0.0080 - val_mean_absolute_error: 0.0500 - val_mean_absolute_percentage_error: 20279.8965 - val_root_mean_squared_error: 0.0893 - val_RMSE_P: 1041.5112 - val_RMSE_T: 14.8217
# Epoch 55/5000
# 136/136 [==============================] - 1s 5ms/step - loss: 0.0076 - mean_absolute_error: 0.0495 - mean_absolute_percentage_error: 23193.5703 - root_mean_squared_error: 0.0871 - RMSE_P: 1014.0507 - RMSE_T: 14.8275 - val_loss: 0.0082 - val_mean_absolute_error: 0.0513 - val_mean_absolute_percentage_error: 30690.4551 - val_root_mean_squared_error: 0.0904 - val_RMSE_P: 1055.2814 - val_RMSE_T: 15.5757
# Epoch 56/5000
# 136/136 [==============================] - 1s 5ms/step - loss: 0.0075 - mean_absolute_error: 0.0493 - mean_absolute_percentage_error: 23989.4062 - root_mean_squared_error: 0.0866 - RMSE_P: 1008.2739 - RMSE_T: 14.8575 - val_loss: 0.0079 - val_mean_absolute_error: 0.0496 - val_mean_absolute_percentage_error: 20264.3984 - val_root_mean_squared_error: 0.0886 - val_RMSE_P: 1033.0366 - val_RMSE_T: 14.9824
# Epoch 57/5000
# 136/136 [==============================] - 1s 4ms/step - loss: 0.0075 - mean_absolute_error: 0.0492 - mean_absolute_percentage_error: 23197.3262 - root_mean_squared_error: 0.0865 - RMSE_P: 1005.8702 - RMSE_T: 14.8542 - val_loss: 0.0078 - val_mean_absolute_error: 0.0502 - val_mean_absolute_percentage_error: 24363.1367 - val_root_mean_squared_error: 0.0885 - val_RMSE_P: 1035.7565 - val_RMSE_T: 15.0825
# Epoch 58/5000
# 136/136 [==============================] - 1s 4ms/step - loss: 0.0074 - mean_absolute_error: 0.0489 - mean_absolute_percentage_error: 24938.7910 - root_mean_squared_error: 0.0859 - RMSE_P: 998.6522 - RMSE_T: 14.8143 - val_loss: 0.0077 - val_mean_absolute_error: 0.0485 - val_mean_absolute_percentage_error: 29020.2988 - val_root_mean_squared_error: 0.0876 - val_RMSE_P: 1024.0470 - val_RMSE_T: 14.8135
# Epoch 59/5000
# 136/136 [==============================] - 1s 5ms/step - loss: 0.0073 - mean_absolute_error: 0.0488 - mean_absolute_percentage_error: 21706.0938 - root_mean_squared_error: 0.0857 - RMSE_P: 996.6919 - RMSE_T: 14.7426 - val_loss: 0.0079 - val_mean_absolute_error: 0.0494 - val_mean_absolute_percentage_error: 25867.2246 - val_root_mean_squared_error: 0.0889 - val_RMSE_P: 1041.7345 - val_RMSE_T: 14.6793
# Epoch 60/5000
# 136/136 [==============================] - 1s 4ms/step - loss: 0.0073 - mean_absolute_error: 0.0484 - mean_absolute_percentage_error: 22749.9375 - root_mean_squared_error: 0.0853 - RMSE_P: 992.5922 - RMSE_T: 14.6775 - val_loss: 0.0078 - val_mean_absolute_error: 0.0495 - val_mean_absolute_percentage_error: 27041.5156 - val_root_mean_squared_error: 0.0882 - val_RMSE_P: 1030.8794 - val_RMSE_T: 14.6616
# Epoch 61/5000
# 136/136 [==============================] - 1s 4ms/step - loss: 0.0072 - mean_absolute_error: 0.0481 - mean_absolute_percentage_error: 19450.5078 - root_mean_squared_error: 0.0849 - RMSE_P: 986.7156 - RMSE_T: 14.6034 - val_loss: 0.0078 - val_mean_absolute_error: 0.0487 - val_mean_absolute_percentage_error: 17864.2930 - val_root_mean_squared_error: 0.0882 - val_RMSE_P: 1022.9566 - val_RMSE_T: 14.7956
# Epoch 62/5000
# 136/136 [==============================] - 1s 4ms/step - loss: 0.0073 - mean_absolute_error: 0.0484 - mean_absolute_percentage_error: 23787.2695 - root_mean_squared_error: 0.0852 - RMSE_P: 991.1508 - RMSE_T: 14.6481 - val_loss: 0.0076 - val_mean_absolute_error: 0.0492 - val_mean_absolute_percentage_error: 15776.2588 - val_root_mean_squared_error: 0.0871 - val_RMSE_P: 1014.0712 - val_RMSE_T: 14.9387
# Epoch 63/5000
# 136/136 [==============================] - 0s 4ms/step - loss: 0.0072 - mean_absolute_error: 0.0484 - mean_absolute_percentage_error: 22885.0273 - root_mean_squared_error: 0.0851 - RMSE_P: 989.5641 - RMSE_T: 14.6719 - val_loss: 0.0079 - val_mean_absolute_error: 0.0510 - val_mean_absolute_percentage_error: 12064.5107 - val_root_mean_squared_error: 0.0887 - val_RMSE_P: 1037.1973 - val_RMSE_T: 14.8408
# Epoch 64/5000
# 136/136 [==============================] - 0s 3ms/step - loss: 0.0073 - mean_absolute_error: 0.0489 - mean_absolute_percentage_error: 22498.3809 - root_mean_squared_error: 0.0856 - RMSE_P: 995.9065 - RMSE_T: 14.6924 - val_loss: 0.0078 - val_mean_absolute_error: 0.0485 - val_mean_absolute_percentage_error: 18968.8652 - val_root_mean_squared_error: 0.0882 - val_RMSE_P: 1029.5580 - val_RMSE_T: 14.6871
# Epoch 65/5000
# 136/136 [==============================] - 1s 4ms/step - loss: 0.0070 - mean_absolute_error: 0.0475 - mean_absolute_percentage_error: 22942.2031 - root_mean_squared_error: 0.0837 - RMSE_P: 973.3613 - RMSE_T: 14.5200 - val_loss: 0.0075 - val_mean_absolute_error: 0.0475 - val_mean_absolute_percentage_error: 17116.3320 - val_root_mean_squared_error: 0.0866 - val_RMSE_P: 1011.7578 - val_RMSE_T: 14.4459
# Epoch 66/5000
# 136/136 [==============================] - 1s 4ms/step - loss: 0.0070 - mean_absolute_error: 0.0476 - mean_absolute_percentage_error: 20745.0625 - root_mean_squared_error: 0.0839 - RMSE_P: 975.5562 - RMSE_T: 14.4751 - val_loss: 0.0074 - val_mean_absolute_error: 0.0477 - val_mean_absolute_percentage_error: 21312.2871 - val_root_mean_squared_error: 0.0860 - val_RMSE_P: 1001.2914 - val_RMSE_T: 14.5924
# Epoch 67/5000
# 136/136 [==============================] - 1s 5ms/step - loss: 0.0070 - mean_absolute_error: 0.0473 - mean_absolute_percentage_error: 22144.9590 - root_mean_squared_error: 0.0836 - RMSE_P: 971.5455 - RMSE_T: 14.5023 - val_loss: 0.0082 - val_mean_absolute_error: 0.0507 - val_mean_absolute_percentage_error: 14922.7734 - val_root_mean_squared_error: 0.0906 - val_RMSE_P: 1061.6680 - val_RMSE_T: 14.8124
# Epoch 68/5000
# 136/136 [==============================] - 1s 5ms/step - loss: 0.0070 - mean_absolute_error: 0.0474 - mean_absolute_percentage_error: 22349.5977 - root_mean_squared_error: 0.0836 - RMSE_P: 972.1517 - RMSE_T: 14.5066 - val_loss: 0.0075 - val_mean_absolute_error: 0.0482 - val_mean_absolute_percentage_error: 18718.9785 - val_root_mean_squared_error: 0.0864 - val_RMSE_P: 1001.2659 - val_RMSE_T: 14.7840
# Epoch 69/5000
# 136/136 [==============================] - 1s 6ms/step - loss: 0.0070 - mean_absolute_error: 0.0478 - mean_absolute_percentage_error: 21864.7676 - root_mean_squared_error: 0.0837 - RMSE_P: 972.6373 - RMSE_T: 14.6386 - val_loss: 0.0074 - val_mean_absolute_error: 0.0470 - val_mean_absolute_percentage_error: 14257.3818 - val_root_mean_squared_error: 0.0859 - val_RMSE_P: 1000.6618 - val_RMSE_T: 14.5128
# Epoch 70/5000
# 136/136 [==============================] - 1s 5ms/step - loss: 0.0069 - mean_absolute_error: 0.0474 - mean_absolute_percentage_error: 18974.1914 - root_mean_squared_error: 0.0833 - RMSE_P: 967.7785 - RMSE_T: 14.4495 - val_loss: 0.0074 - val_mean_absolute_error: 0.0475 - val_mean_absolute_percentage_error: 18963.5586 - val_root_mean_squared_error: 0.0857 - val_RMSE_P: 1001.4683 - val_RMSE_T: 14.4853
# Epoch 71/5000
# 136/136 [==============================] - 1s 6ms/step - loss: 0.0069 - mean_absolute_error: 0.0471 - mean_absolute_percentage_error: 22064.9883 - root_mean_squared_error: 0.0831 - RMSE_P: 965.8042 - RMSE_T: 14.4152 - val_loss: 0.0071 - val_mean_absolute_error: 0.0463 - val_mean_absolute_percentage_error: 19533.1250 - val_root_mean_squared_error: 0.0844 - val_RMSE_P: 982.5205 - val_RMSE_T: 14.5026
# Epoch 72/5000
# 136/136 [==============================] - 1s 7ms/step - loss: 0.0068 - mean_absolute_error: 0.0467 - mean_absolute_percentage_error: 21093.7441 - root_mean_squared_error: 0.0823 - RMSE_P: 955.8380 - RMSE_T: 14.4124 - val_loss: 0.0074 - val_mean_absolute_error: 0.0482 - val_mean_absolute_percentage_error: 24684.7188 - val_root_mean_squared_error: 0.0861 - val_RMSE_P: 1002.2924 - val_RMSE_T: 14.6442
# Epoch 73/5000
# 136/136 [==============================] - 1s 5ms/step - loss: 0.0067 - mean_absolute_error: 0.0462 - mean_absolute_percentage_error: 22172.5996 - root_mean_squared_error: 0.0818 - RMSE_P: 950.5042 - RMSE_T: 14.2787 - val_loss: 0.0072 - val_mean_absolute_error: 0.0472 - val_mean_absolute_percentage_error: 12780.1748 - val_root_mean_squared_error: 0.0846 - val_RMSE_P: 986.2633 - val_RMSE_T: 14.6895
# Epoch 74/5000
# 136/136 [==============================] - 1s 5ms/step - loss: 0.0067 - mean_absolute_error: 0.0465 - mean_absolute_percentage_error: 23224.3984 - root_mean_squared_error: 0.0818 - RMSE_P: 950.6344 - RMSE_T: 14.3520 - val_loss: 0.0071 - val_mean_absolute_error: 0.0471 - val_mean_absolute_percentage_error: 14080.4639 - val_root_mean_squared_error: 0.0844 - val_RMSE_P: 981.5601 - val_RMSE_T: 14.5089
# Epoch 75/5000
# 136/136 [==============================] - 1s 5ms/step - loss: 0.0066 - mean_absolute_error: 0.0460 - mean_absolute_percentage_error: 19873.2676 - root_mean_squared_error: 0.0812 - RMSE_P: 943.3667 - RMSE_T: 14.2092 - val_loss: 0.0072 - val_mean_absolute_error: 0.0463 - val_mean_absolute_percentage_error: 9540.9121 - val_root_mean_squared_error: 0.0851 - val_RMSE_P: 989.1606 - val_RMSE_T: 14.5217
# Epoch 76/5000
# 136/136 [==============================] - 1s 5ms/step - loss: 0.0067 - mean_absolute_error: 0.0465 - mean_absolute_percentage_error: 21202.6113 - root_mean_squared_error: 0.0818 - RMSE_P: 949.8851 - RMSE_T: 14.3106 - val_loss: 0.0075 - val_mean_absolute_error: 0.0492 - val_mean_absolute_percentage_error: 21194.3711 - val_root_mean_squared_error: 0.0865 - val_RMSE_P: 1012.1737 - val_RMSE_T: 14.8182
# Epoch 77/5000
# 136/136 [==============================] - 1s 5ms/step - loss: 0.0066 - mean_absolute_error: 0.0463 - mean_absolute_percentage_error: 19415.0156 - root_mean_squared_error: 0.0814 - RMSE_P: 945.4641 - RMSE_T: 14.2672 - val_loss: 0.0071 - val_mean_absolute_error: 0.0474 - val_mean_absolute_percentage_error: 11767.3965 - val_root_mean_squared_error: 0.0845 - val_RMSE_P: 985.2717 - val_RMSE_T: 14.4084
# Epoch 78/5000
# 136/136 [==============================] - 1s 6ms/step - loss: 0.0064 - mean_absolute_error: 0.0454 - mean_absolute_percentage_error: 21277.8340 - root_mean_squared_error: 0.0801 - RMSE_P: 929.7283 - RMSE_T: 14.2489 - val_loss: 0.0070 - val_mean_absolute_error: 0.0466 - val_mean_absolute_percentage_error: 15416.6699 - val_root_mean_squared_error: 0.0835 - val_RMSE_P: 975.1049 - val_RMSE_T: 14.3519
# Epoch 79/5000
# 136/136 [==============================] - 1s 4ms/step - loss: 0.0065 - mean_absolute_error: 0.0458 - mean_absolute_percentage_error: 22574.3672 - root_mean_squared_error: 0.0809 - RMSE_P: 939.1559 - RMSE_T: 14.2367 - val_loss: 0.0069 - val_mean_absolute_error: 0.0451 - val_mean_absolute_percentage_error: 19819.7188 - val_root_mean_squared_error: 0.0831 - val_RMSE_P: 968.4180 - val_RMSE_T: 14.2294
# Epoch 80/5000
# 136/136 [==============================] - 1s 5ms/step - loss: 0.0064 - mean_absolute_error: 0.0455 - mean_absolute_percentage_error: 20195.8555 - root_mean_squared_error: 0.0801 - RMSE_P: 930.0852 - RMSE_T: 14.1533 - val_loss: 0.0069 - val_mean_absolute_error: 0.0457 - val_mean_absolute_percentage_error: 19104.4082 - val_root_mean_squared_error: 0.0829 - val_RMSE_P: 970.1366 - val_RMSE_T: 14.3169
# Epoch 81/5000
# 136/136 [==============================] - 1s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0452 - mean_absolute_percentage_error: 21143.8867 - root_mean_squared_error: 0.0798 - RMSE_P: 926.1022 - RMSE_T: 14.1540 - val_loss: 0.0074 - val_mean_absolute_error: 0.0475 - val_mean_absolute_percentage_error: 27405.8574 - val_root_mean_squared_error: 0.0858 - val_RMSE_P: 999.2743 - val_RMSE_T: 14.5325
# Epoch 82/5000
# 136/136 [==============================] - 1s 5ms/step - loss: 0.0065 - mean_absolute_error: 0.0456 - mean_absolute_percentage_error: 21219.4121 - root_mean_squared_error: 0.0807 - RMSE_P: 936.4714 - RMSE_T: 14.2019 - val_loss: 0.0070 - val_mean_absolute_error: 0.0473 - val_mean_absolute_percentage_error: 28531.8340 - val_root_mean_squared_error: 0.0836 - val_RMSE_P: 975.6325 - val_RMSE_T: 14.5943
# Epoch 83/5000
# 136/136 [==============================] - 1s 5ms/step - loss: 0.0063 - mean_absolute_error: 0.0452 - mean_absolute_percentage_error: 21919.5059 - root_mean_squared_error: 0.0796 - RMSE_P: 923.8868 - RMSE_T: 14.1131 - val_loss: 0.0068 - val_mean_absolute_error: 0.0454 - val_mean_absolute_percentage_error: 16453.7129 - val_root_mean_squared_error: 0.0823 - val_RMSE_P: 962.9958 - val_RMSE_T: 14.2716
# Epoch 84/5000
# 136/136 [==============================] - 1s 5ms/step - loss: 0.0063 - mean_absolute_error: 0.0446 - mean_absolute_percentage_error: 21060.0918 - root_mean_squared_error: 0.0791 - RMSE_P: 917.6923 - RMSE_T: 13.9442 - val_loss: 0.0069 - val_mean_absolute_error: 0.0452 - val_mean_absolute_percentage_error: 20498.4844 - val_root_mean_squared_error: 0.0830 - val_RMSE_P: 971.0415 - val_RMSE_T: 14.1840
# Epoch 85/5000
# 136/136 [==============================] - 1s 5ms/step - loss: 0.0061 - mean_absolute_error: 0.0441 - mean_absolute_percentage_error: 19653.5957 - root_mean_squared_error: 0.0782 - RMSE_P: 907.3752 - RMSE_T: 13.8398 - val_loss: 0.0066 - val_mean_absolute_error: 0.0450 - val_mean_absolute_percentage_error: 19556.7148 - val_root_mean_squared_error: 0.0814 - val_RMSE_P: 946.2152 - val_RMSE_T: 14.2928
# Epoch 86/5000
# 136/136 [==============================] - 1s 5ms/step - loss: 0.0063 - mean_absolute_error: 0.0449 - mean_absolute_percentage_error: 21343.4629 - root_mean_squared_error: 0.0792 - RMSE_P: 919.5499 - RMSE_T: 13.9707 - val_loss: 0.0066 - val_mean_absolute_error: 0.0451 - val_mean_absolute_percentage_error: 13167.4824 - val_root_mean_squared_error: 0.0814 - val_RMSE_P: 950.8419 - val_RMSE_T: 14.2376
# Epoch 87/5000
# 136/136 [==============================] - 1s 5ms/step - loss: 0.0061 - mean_absolute_error: 0.0443 - mean_absolute_percentage_error: 20561.7773 - root_mean_squared_error: 0.0783 - RMSE_P: 909.1079 - RMSE_T: 13.9175 - val_loss: 0.0066 - val_mean_absolute_error: 0.0449 - val_mean_absolute_percentage_error: 15084.9883 - val_root_mean_squared_error: 0.0812 - val_RMSE_P: 945.8051 - val_RMSE_T: 14.1457
# Epoch 88/5000
# 136/136 [==============================] - 1s 6ms/step - loss: 0.0061 - mean_absolute_error: 0.0441 - mean_absolute_percentage_error: 22157.2285 - root_mean_squared_error: 0.0784 - RMSE_P: 910.1616 - RMSE_T: 13.8721 - val_loss: 0.0065 - val_mean_absolute_error: 0.0448 - val_mean_absolute_percentage_error: 11899.8262 - val_root_mean_squared_error: 0.0809 - val_RMSE_P: 937.9045 - val_RMSE_T: 14.1746
# Epoch 89/5000
# 136/136 [==============================] - 1s 5ms/step - loss: 0.0062 - mean_absolute_error: 0.0444 - mean_absolute_percentage_error: 20338.5801 - root_mean_squared_error: 0.0785 - RMSE_P: 911.3627 - RMSE_T: 13.9540 - val_loss: 0.0071 - val_mean_absolute_error: 0.0476 - val_mean_absolute_percentage_error: 17086.9590 - val_root_mean_squared_error: 0.0840 - val_RMSE_P: 979.6215 - val_RMSE_T: 15.0287
# Epoch 90/5000
# 136/136 [==============================] - 1s 5ms/step - loss: 0.0062 - mean_absolute_error: 0.0447 - mean_absolute_percentage_error: 19693.8574 - root_mean_squared_error: 0.0787 - RMSE_P: 913.7866 - RMSE_T: 13.9879 - val_loss: 0.0066 - val_mean_absolute_error: 0.0449 - val_mean_absolute_percentage_error: 14139.4453 - val_root_mean_squared_error: 0.0811 - val_RMSE_P: 943.9442 - val_RMSE_T: 13.9896
# Epoch 91/5000
# 136/136 [==============================] - 1s 5ms/step - loss: 0.0061 - mean_absolute_error: 0.0442 - mean_absolute_percentage_error: 22922.0254 - root_mean_squared_error: 0.0782 - RMSE_P: 907.2589 - RMSE_T: 13.8447 - val_loss: 0.0066 - val_mean_absolute_error: 0.0442 - val_mean_absolute_percentage_error: 17827.3398 - val_root_mean_squared_error: 0.0810 - val_RMSE_P: 944.3367 - val_RMSE_T: 14.1430
# Epoch 92/5000
# 136/136 [==============================] - 1s 5ms/step - loss: 0.0061 - mean_absolute_error: 0.0443 - mean_absolute_percentage_error: 19735.3848 - root_mean_squared_error: 0.0782 - RMSE_P: 908.8143 - RMSE_T: 13.7615 - val_loss: 0.0068 - val_mean_absolute_error: 0.0460 - val_mean_absolute_percentage_error: 12357.3838 - val_root_mean_squared_error: 0.0824 - val_RMSE_P: 964.4879 - val_RMSE_T: 14.2870
# Epoch 93/5000
# 136/136 [==============================] - 1s 5ms/step - loss: 0.0061 - mean_absolute_error: 0.0439 - mean_absolute_percentage_error: 20532.5293 - root_mean_squared_error: 0.0778 - RMSE_P: 903.2967 - RMSE_T: 13.7493 - val_loss: 0.0071 - val_mean_absolute_error: 0.0476 - val_mean_absolute_percentage_error: 13929.7607 - val_root_mean_squared_error: 0.0845 - val_RMSE_P: 988.1647 - val_RMSE_T: 14.5006
# Epoch 94/5000
# 136/136 [==============================] - 1s 5ms/step - loss: 0.0058 - mean_absolute_error: 0.0428 - mean_absolute_percentage_error: 20826.4609 - root_mean_squared_error: 0.0764 - RMSE_P: 885.8818 - RMSE_T: 13.6182 - val_loss: 0.0067 - val_mean_absolute_error: 0.0447 - val_mean_absolute_percentage_error: 17793.4141 - val_root_mean_squared_error: 0.0819 - val_RMSE_P: 955.8099 - val_RMSE_T: 14.0397
# Epoch 95/5000
# 136/136 [==============================] - 1s 5ms/step - loss: 0.0059 - mean_absolute_error: 0.0436 - mean_absolute_percentage_error: 20944.3418 - root_mean_squared_error: 0.0771 - RMSE_P: 893.6989 - RMSE_T: 13.7473 - val_loss: 0.0066 - val_mean_absolute_error: 0.0450 - val_mean_absolute_percentage_error: 23624.5742 - val_root_mean_squared_error: 0.0814 - val_RMSE_P: 954.2758 - val_RMSE_T: 13.9329
# Epoch 96/5000
# 136/136 [==============================] - 1s 6ms/step - loss: 0.0059 - mean_absolute_error: 0.0434 - mean_absolute_percentage_error: 21153.1797 - root_mean_squared_error: 0.0768 - RMSE_P: 891.1324 - RMSE_T: 13.6791 - val_loss: 0.0064 - val_mean_absolute_error: 0.0438 - val_mean_absolute_percentage_error: 24024.5508 - val_root_mean_squared_error: 0.0800 - val_RMSE_P: 933.3201 - val_RMSE_T: 14.4842
# Epoch 97/5000
# 136/136 [==============================] - 1s 5ms/step - loss: 0.0060 - mean_absolute_error: 0.0439 - mean_absolute_percentage_error: 19549.9180 - root_mean_squared_error: 0.0772 - RMSE_P: 895.6232 - RMSE_T: 13.7648 - val_loss: 0.0067 - val_mean_absolute_error: 0.0459 - val_mean_absolute_percentage_error: 19166.7285 - val_root_mean_squared_error: 0.0817 - val_RMSE_P: 953.6240 - val_RMSE_T: 14.2472
# Epoch 98/5000
# 136/136 [==============================] - 1s 5ms/step - loss: 0.0059 - mean_absolute_error: 0.0437 - mean_absolute_percentage_error: 23612.0469 - root_mean_squared_error: 0.0771 - RMSE_P: 893.9598 - RMSE_T: 13.7873 - val_loss: 0.0064 - val_mean_absolute_error: 0.0448 - val_mean_absolute_percentage_error: 15418.1484 - val_root_mean_squared_error: 0.0798 - val_RMSE_P: 931.7584 - val_RMSE_T: 14.2234
# Epoch 99/5000
# 136/136 [==============================] - 1s 6ms/step - loss: 0.0059 - mean_absolute_error: 0.0432 - mean_absolute_percentage_error: 20772.4844 - root_mean_squared_error: 0.0767 - RMSE_P: 890.6190 - RMSE_T: 13.5874 - val_loss: 0.0064 - val_mean_absolute_error: 0.0446 - val_mean_absolute_percentage_error: 24454.0605 - val_root_mean_squared_error: 0.0800 - val_RMSE_P: 933.9123 - val_RMSE_T: 13.9016
# Epoch 100/5000
# 136/136 [==============================] - 1s 5ms/step - loss: 0.0058 - mean_absolute_error: 0.0430 - mean_absolute_percentage_error: 19921.4062 - root_mean_squared_error: 0.0763 - RMSE_P: 885.6583 - RMSE_T: 13.5654 - val_loss: 0.0067 - val_mean_absolute_error: 0.0447 - val_mean_absolute_percentage_error: 22697.1699 - val_root_mean_squared_error: 0.0820 - val_RMSE_P: 957.1753 - val_RMSE_T: 14.0569
# Epoch 101/5000
# 136/136 [==============================] - 1s 5ms/step - loss: 0.0058 - mean_absolute_error: 0.0431 - mean_absolute_percentage_error: 19628.2852 - root_mean_squared_error: 0.0762 - RMSE_P: 883.6205 - RMSE_T: 13.6221 - val_loss: 0.0063 - val_mean_absolute_error: 0.0433 - val_mean_absolute_percentage_error: 16405.1543 - val_root_mean_squared_error: 0.0791 - val_RMSE_P: 918.7640 - val_RMSE_T: 13.8080
# Epoch 102/5000
# 136/136 [==============================] - 1s 6ms/step - loss: 0.0058 - mean_absolute_error: 0.0429 - mean_absolute_percentage_error: 21013.4004 - root_mean_squared_error: 0.0761 - RMSE_P: 883.0762 - RMSE_T: 13.5616 - val_loss: 0.0064 - val_mean_absolute_error: 0.0452 - val_mean_absolute_percentage_error: 26417.2715 - val_root_mean_squared_error: 0.0803 - val_RMSE_P: 932.3156 - val_RMSE_T: 14.6018
# Epoch 103/5000
# 136/136 [==============================] - 1s 5ms/step - loss: 0.0059 - mean_absolute_error: 0.0435 - mean_absolute_percentage_error: 17943.5566 - root_mean_squared_error: 0.0767 - RMSE_P: 890.4245 - RMSE_T: 13.5905 - val_loss: 0.0065 - val_mean_absolute_error: 0.0454 - val_mean_absolute_percentage_error: 17996.8262 - val_root_mean_squared_error: 0.0808 - val_RMSE_P: 941.4460 - val_RMSE_T: 14.3061
# Epoch 104/5000
# 136/136 [==============================] - 1s 5ms/step - loss: 0.0057 - mean_absolute_error: 0.0427 - mean_absolute_percentage_error: 19747.0195 - root_mean_squared_error: 0.0757 - RMSE_P: 878.1556 - RMSE_T: 13.4956 - val_loss: 0.0066 - val_mean_absolute_error: 0.0455 - val_mean_absolute_percentage_error: 18021.2695 - val_root_mean_squared_error: 0.0812 - val_RMSE_P: 941.5919 - val_RMSE_T: 14.4669
# Epoch 105/5000
# 136/136 [==============================] - 1s 6ms/step - loss: 0.0059 - mean_absolute_error: 0.0432 - mean_absolute_percentage_error: 18653.5410 - root_mean_squared_error: 0.0765 - RMSE_P: 887.7489 - RMSE_T: 13.4939 - val_loss: 0.0063 - val_mean_absolute_error: 0.0436 - val_mean_absolute_percentage_error: 14575.4580 - val_root_mean_squared_error: 0.0793 - val_RMSE_P: 928.0980 - val_RMSE_T: 14.0899
# Epoch 106/5000
# 136/136 [==============================] - 1s 5ms/step - loss: 0.0059 - mean_absolute_error: 0.0434 - mean_absolute_percentage_error: 18825.3750 - root_mean_squared_error: 0.0766 - RMSE_P: 889.0553 - RMSE_T: 13.5385 - val_loss: 0.0062 - val_mean_absolute_error: 0.0433 - val_mean_absolute_percentage_error: 15324.2070 - val_root_mean_squared_error: 0.0790 - val_RMSE_P: 922.7563 - val_RMSE_T: 13.9713
# Epoch 107/5000
# 136/136 [==============================] - 1s 5ms/step - loss: 0.0057 - mean_absolute_error: 0.0424 - mean_absolute_percentage_error: 20246.3652 - root_mean_squared_error: 0.0753 - RMSE_P: 872.8791 - RMSE_T: 13.4737 - val_loss: 0.0065 - val_mean_absolute_error: 0.0455 - val_mean_absolute_percentage_error: 22426.9473 - val_root_mean_squared_error: 0.0806 - val_RMSE_P: 939.8625 - val_RMSE_T: 13.8979
# Epoch 108/5000
# 136/136 [==============================] - 1s 6ms/step - loss: 0.0058 - mean_absolute_error: 0.0430 - mean_absolute_percentage_error: 19893.3145 - root_mean_squared_error: 0.0759 - RMSE_P: 880.2345 - RMSE_T: 13.4661 - val_loss: 0.0063 - val_mean_absolute_error: 0.0437 - val_mean_absolute_percentage_error: 22501.3281 - val_root_mean_squared_error: 0.0794 - val_RMSE_P: 927.2292 - val_RMSE_T: 13.9368
# Epoch 109/5000
# 136/136 [==============================] - 1s 5ms/step - loss: 0.0058 - mean_absolute_error: 0.0430 - mean_absolute_percentage_error: 18027.8926 - root_mean_squared_error: 0.0760 - RMSE_P: 881.5551 - RMSE_T: 13.5924 - val_loss: 0.0061 - val_mean_absolute_error: 0.0428 - val_mean_absolute_percentage_error: 14585.6270 - val_root_mean_squared_error: 0.0784 - val_RMSE_P: 910.5848 - val_RMSE_T: 13.7455
# Epoch 110/5000
# 136/136 [==============================] - 1s 5ms/step - loss: 0.0056 - mean_absolute_error: 0.0424 - mean_absolute_percentage_error: 20577.8887 - root_mean_squared_error: 0.0750 - RMSE_P: 870.0639 - RMSE_T: 13.4018 - val_loss: 0.0062 - val_mean_absolute_error: 0.0434 - val_mean_absolute_percentage_error: 22142.1895 - val_root_mean_squared_error: 0.0786 - val_RMSE_P: 913.1340 - val_RMSE_T: 14.0106
# Epoch 111/5000
# 136/136 [==============================] - 1s 6ms/step - loss: 0.0056 - mean_absolute_error: 0.0422 - mean_absolute_percentage_error: 19155.8438 - root_mean_squared_error: 0.0746 - RMSE_P: 865.6998 - RMSE_T: 13.3777 - val_loss: 0.0062 - val_mean_absolute_error: 0.0433 - val_mean_absolute_percentage_error: 23018.4805 - val_root_mean_squared_error: 0.0788 - val_RMSE_P: 922.5396 - val_RMSE_T: 14.0005
# Epoch 112/5000
# 136/136 [==============================] - 1s 5ms/step - loss: 0.0057 - mean_absolute_error: 0.0425 - mean_absolute_percentage_error: 18497.3242 - root_mean_squared_error: 0.0753 - RMSE_P: 873.4642 - RMSE_T: 13.4024 - val_loss: 0.0061 - val_mean_absolute_error: 0.0437 - val_mean_absolute_percentage_error: 22011.4395 - val_root_mean_squared_error: 0.0783 - val_RMSE_P: 913.6264 - val_RMSE_T: 14.0666
# Epoch 113/5000
# 136/136 [==============================] - 1s 5ms/step - loss: 0.0056 - mean_absolute_error: 0.0418 - mean_absolute_percentage_error: 17684.1152 - root_mean_squared_error: 0.0745 - RMSE_P: 864.7435 - RMSE_T: 13.2913 - val_loss: 0.0061 - val_mean_absolute_error: 0.0432 - val_mean_absolute_percentage_error: 15730.7744 - val_root_mean_squared_error: 0.0779 - val_RMSE_P: 907.1484 - val_RMSE_T: 13.8390
# Epoch 114/5000
# 136/136 [==============================] - 1s 6ms/step - loss: 0.0058 - mean_absolute_error: 0.0428 - mean_absolute_percentage_error: 21178.4434 - root_mean_squared_error: 0.0758 - RMSE_P: 880.4566 - RMSE_T: 13.4373 - val_loss: 0.0067 - val_mean_absolute_error: 0.0446 - val_mean_absolute_percentage_error: 22104.8242 - val_root_mean_squared_error: 0.0816 - val_RMSE_P: 948.6246 - val_RMSE_T: 13.7313
# Epoch 115/5000
# 136/136 [==============================] - 1s 5ms/step - loss: 0.0056 - mean_absolute_error: 0.0423 - mean_absolute_percentage_error: 18980.4258 - root_mean_squared_error: 0.0747 - RMSE_P: 866.3341 - RMSE_T: 13.4339 - val_loss: 0.0060 - val_mean_absolute_error: 0.0426 - val_mean_absolute_percentage_error: 19860.9297 - val_root_mean_squared_error: 0.0775 - val_RMSE_P: 897.5449 - val_RMSE_T: 13.6723
# Epoch 116/5000
# 136/136 [==============================] - 1s 6ms/step - loss: 0.0055 - mean_absolute_error: 0.0417 - mean_absolute_percentage_error: 20327.8848 - root_mean_squared_error: 0.0743 - RMSE_P: 862.3859 - RMSE_T: 13.2480 - val_loss: 0.0062 - val_mean_absolute_error: 0.0442 - val_mean_absolute_percentage_error: 17303.8672 - val_root_mean_squared_error: 0.0787 - val_RMSE_P: 915.0981 - val_RMSE_T: 13.9009
# Epoch 117/5000
# 136/136 [==============================] - 1s 6ms/step - loss: 0.0056 - mean_absolute_error: 0.0423 - mean_absolute_percentage_error: 18794.3340 - root_mean_squared_error: 0.0749 - RMSE_P: 869.8438 - RMSE_T: 13.3098 - val_loss: 0.0063 - val_mean_absolute_error: 0.0446 - val_mean_absolute_percentage_error: 12519.8096 - val_root_mean_squared_error: 0.0795 - val_RMSE_P: 927.2354 - val_RMSE_T: 13.9886
# Epoch 118/5000
# 136/136 [==============================] - 1s 5ms/step - loss: 0.0055 - mean_absolute_error: 0.0420 - mean_absolute_percentage_error: 18023.5098 - root_mean_squared_error: 0.0742 - RMSE_P: 860.6009 - RMSE_T: 13.3635 - val_loss: 0.0058 - val_mean_absolute_error: 0.0418 - val_mean_absolute_percentage_error: 15917.4678 - val_root_mean_squared_error: 0.0765 - val_RMSE_P: 891.3712 - val_RMSE_T: 13.6723
# Epoch 119/5000
# 136/136 [==============================] - 1s 5ms/step - loss: 0.0054 - mean_absolute_error: 0.0416 - mean_absolute_percentage_error: 18933.3008 - root_mean_squared_error: 0.0738 - RMSE_P: 855.3843 - RMSE_T: 13.2740 - val_loss: 0.0061 - val_mean_absolute_error: 0.0444 - val_mean_absolute_percentage_error: 21377.7578 - val_root_mean_squared_error: 0.0781 - val_RMSE_P: 913.4352 - val_RMSE_T: 13.9781
# Epoch 120/5000
# 136/136 [==============================] - 1s 6ms/step - loss: 0.0055 - mean_absolute_error: 0.0415 - mean_absolute_percentage_error: 17827.5703 - root_mean_squared_error: 0.0739 - RMSE_P: 856.3205 - RMSE_T: 13.2775 - val_loss: 0.0063 - val_mean_absolute_error: 0.0442 - val_mean_absolute_percentage_error: 22490.8418 - val_root_mean_squared_error: 0.0793 - val_RMSE_P: 930.6920 - val_RMSE_T: 13.7631
# Epoch 121/5000
# 136/136 [==============================] - 1s 5ms/step - loss: 0.0054 - mean_absolute_error: 0.0415 - mean_absolute_percentage_error: 17543.6699 - root_mean_squared_error: 0.0738 - RMSE_P: 856.4911 - RMSE_T: 13.1629 - val_loss: 0.0061 - val_mean_absolute_error: 0.0436 - val_mean_absolute_percentage_error: 14916.6611 - val_root_mean_squared_error: 0.0780 - val_RMSE_P: 906.9560 - val_RMSE_T: 14.1004
# Epoch 122/5000
# 136/136 [==============================] - 1s 5ms/step - loss: 0.0055 - mean_absolute_error: 0.0417 - mean_absolute_percentage_error: 18349.8730 - root_mean_squared_error: 0.0740 - RMSE_P: 858.3699 - RMSE_T: 13.2194 - val_loss: 0.0063 - val_mean_absolute_error: 0.0453 - val_mean_absolute_percentage_error: 26394.4395 - val_root_mean_squared_error: 0.0795 - val_RMSE_P: 926.1855 - val_RMSE_T: 14.0257
# Epoch 123/5000
# 136/136 [==============================] - 1s 6ms/step - loss: 0.0054 - mean_absolute_error: 0.0416 - mean_absolute_percentage_error: 20554.3906 - root_mean_squared_error: 0.0736 - RMSE_P: 853.4592 - RMSE_T: 13.1999 - val_loss: 0.0065 - val_mean_absolute_error: 0.0442 - val_mean_absolute_percentage_error: 26527.0918 - val_root_mean_squared_error: 0.0804 - val_RMSE_P: 941.0469 - val_RMSE_T: 13.5469
# Epoch 124/5000
# 136/136 [==============================] - 1s 5ms/step - loss: 0.0055 - mean_absolute_error: 0.0420 - mean_absolute_percentage_error: 18302.8672 - root_mean_squared_error: 0.0743 - RMSE_P: 862.6467 - RMSE_T: 13.2157 - val_loss: 0.0062 - val_mean_absolute_error: 0.0428 - val_mean_absolute_percentage_error: 14979.6738 - val_root_mean_squared_error: 0.0788 - val_RMSE_P: 918.4330 - val_RMSE_T: 13.6773
# Epoch 125/5000
# 136/136 [==============================] - 1s 6ms/step - loss: 0.0055 - mean_absolute_error: 0.0418 - mean_absolute_percentage_error: 19305.8809 - root_mean_squared_error: 0.0741 - RMSE_P: 860.2356 - RMSE_T: 13.1559 - val_loss: 0.0063 - val_mean_absolute_error: 0.0441 - val_mean_absolute_percentage_error: 19319.0625 - val_root_mean_squared_error: 0.0794 - val_RMSE_P: 928.7805 - val_RMSE_T: 13.6987
# Epoch 126/5000
# 136/136 [==============================] - 1s 5ms/step - loss: 0.0055 - mean_absolute_error: 0.0418 - mean_absolute_percentage_error: 18114.1777 - root_mean_squared_error: 0.0740 - RMSE_P: 858.1918 - RMSE_T: 13.2582 - val_loss: 0.0063 - val_mean_absolute_error: 0.0453 - val_mean_absolute_percentage_error: 24054.8477 - val_root_mean_squared_error: 0.0792 - val_RMSE_P: 922.2154 - val_RMSE_T: 14.0955
# Epoch 127/5000
# 136/136 [==============================] - 1s 5ms/step - loss: 0.0053 - mean_absolute_error: 0.0412 - mean_absolute_percentage_error: 18262.5098 - root_mean_squared_error: 0.0731 - RMSE_P: 848.1613 - RMSE_T: 13.0957 - val_loss: 0.0059 - val_mean_absolute_error: 0.0424 - val_mean_absolute_percentage_error: 8874.0254 - val_root_mean_squared_error: 0.0765 - val_RMSE_P: 887.7877 - val_RMSE_T: 13.7655
# Epoch 128/5000
# 136/136 [==============================] - 1s 6ms/step - loss: 0.0056 - mean_absolute_error: 0.0424 - mean_absolute_percentage_error: 18647.1387 - root_mean_squared_error: 0.0745 - RMSE_P: 863.8495 - RMSE_T: 13.3020 - val_loss: 0.0060 - val_mean_absolute_error: 0.0433 - val_mean_absolute_percentage_error: 10817.0352 - val_root_mean_squared_error: 0.0777 - val_RMSE_P: 909.1557 - val_RMSE_T: 13.6895
# INFO:tensorflow:Assets written to: saved_models\model_ds55White2007\assets
# INFO:tensorflow:Assets written to: saved_models\model_ds55White2007\assets

# %% [markdown]
# ## Plotting of training curves

# %%
history = pd.read_csv(Path("model_ds55White2007.log"))

smooth_std = 10
color = "red"
label = "model_ds55White2007"

fig, axs = plt.subplots(1, 3, figsize=(12, 4))

axs[0].plot(history['epoch'], _smooth(history['loss'], smooth_std), color=color, label=label)
axs[0].plot(history['epoch'], _smooth(history['val_loss'], smooth_std), color=color, linestyle='--', label=label + ' (val)')

axs[1].plot(history['epoch'], _smooth(history['RMSE_T'], smooth_std), color=color, label=label)
axs[1].plot(history['epoch'], _smooth(history['val_RMSE_T'], smooth_std), color=color, linestyle='--', label=label + ' (val)')

axs[2].plot(history['epoch'], _smooth(history['RMSE_P'], smooth_std), color=color, label=label)
axs[2].plot(history['epoch'], _smooth(history['val_RMSE_P'], smooth_std), color=color, linestyle='--', label=label + ' (val)')

axs[0].set_xscale('log')
axs[1].set_xscale('log')
axs[2].set_xscale('log')


axs[0].set_xlabel('Epoch')
axs[0].set_ylabel('Loss')

axs[1].set_xlabel('Epoch')
axs[1].set_ylabel('Temperature RMSE [K]')

axs[2].set_xlabel('Epoch')
axs[2].set_ylabel('Pressure RMSE [bar]')

axs[0].legend()

fig.tight_layout()

# %%
fig, axs = plt.subplots(1, 3, figsize=(12, 4))

axs[0].plot(history['epoch'], history['loss'], color=color, label=label)
axs[0].plot(history['epoch'], history['val_loss'], color=color, linestyle='--', label=label + ' (val)')

axs[1].plot(history['epoch'], history['RMSE_T'], color=color, label=label)
axs[1].plot(history['epoch'], history['val_RMSE_T'], color=color, linestyle='--', label=label + ' (val)')

axs[2].plot(history['epoch'], history['RMSE_P'], color=color, label=label)
axs[2].plot(history['epoch'], history['val_RMSE_P'], color=color, linestyle='--', label=label + ' (val)')

# axs[0].set_xscale('log')
# axs[1].set_xscale('log')
# axs[2].set_xscale('log')


axs[0].set_xlabel('Epoch')
axs[0].set_ylabel('Loss')

axs[1].set_xlabel('Epoch')
axs[1].set_ylabel('Temperature RMSE [K]')

axs[2].set_xlabel('Epoch')
axs[2].set_ylabel('Pressure RMSE [bar]')

axs[0].legend()

fig.tight_layout()
