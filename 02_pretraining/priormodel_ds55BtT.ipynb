# %% [markdown]
# :warning:**IMPORTANT NOTICE**:warning:\
# *Since the initial parameterisation and gradient descent optimisation are stochastic processes, the training of a neural network is not fully reproducible.*
#
# *Therefore, it is not recommended to re-run this script as it will overwrite the original calibration of the neural network used in the work presented here.
# The purpose of this script is solely to document the training procedure and can be copied as a template to fit other new neural networks.*
#
# *To experiment with the models calibrated here, they can be loaded from the `saved_models` directory.*

# %% [markdown]
# # Train neural network on simulated data from **ds55** with **Tajcmanova et al. (2009)** biotite solution model
#
# Predict pressure and temperature from biotite composition.\
# The data are simulated biotite composition - pressure - temperature triples. These data were generated using phase equilibrium modelling (Theriak-Domino).
#
# Trained ANN is used as prior in transfer learning with natural data.
#
# ### Hyperparameter
# These hyperparameters were determined by tests conducted in "hyperparameter_testing.ipynb".\
# All tests were conducted on the simulated data of ds62-White2014. **It is assumed, that the same hyperparameters are optimal for ds55-Tajmanova2009.**
#
# **Performance metrics:**
# - Mean Absolute Error (MAE)
# - Mean Absolute Percentage Error (MAPE)
# - Root Mean Square Error (RMSE)
#     - RMSE inverse transformed for pressure and temperature
#
# **Last layer activation function:**
# - Linear --> Regression problem
#
# **Loss function:**
# - Mean Squared Error (MSE)
#
# **Optimizer:**
# - Adam with inverse time decay learning rate scheduler
#
# **Batch size:**
# - 500
#
# **Architecture:**
# - 4 hidden layers with 64 neurons each
#
# **Activation function:**
# - ReLU
#
# **Regularization:**
# - Small network capacity proved to be sufficient for this problem. Therefore, no regularization was used.
#
# ### Goal
# Best possible performance on the validation set.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import h5py

from pathlib import Path
from keras.models import Sequential
from keras.layers import Dense, Normalization, BatchNormalization, LayerNormalization, Dropout
from keras.losses import MeanSquaredError
from keras.optimizers import Adam, schedules
from keras.metrics import MeanAbsoluteError, RootMeanSquaredError, MeanAbsolutePercentageError
from keras.callbacks import CSVLogger, EarlyStopping
from sklearn.model_selection import train_test_split

from ml_tb.normalisation import MinMaxScaler
from ml_tb.metrics import RMSE_denormalised_P, RMSE_denormalised_T
from ml_tb.plot import _smooth
# Out:
# C:\Users\ThinkPad\AppData\Local\Temp\ipykernel_16464\3732669427.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# WARNING:tensorflow:From c:\Users\ThinkPad\miniconda3\envs\masterproject\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# ## Import data, pre-procesing and train/test split
#
# For bioitte composition only extract elements which are modelled to be present in biotite by ds55. Idel end-member added for Mn.\
# Element-idx from hdf5 file:
# ```python
# (0, 'O') (1, 'AL') (2, 'CA') (3, 'F3') (4, 'FE') (5, 'H') (6, 'K') (7, 'MN') (8, 'MG') (9, 'NA') (10, 'SI') (11, 'TI')
# ```
# Only extract: Si, Ti, Al, Fe, Mg, Mn.\
# K would be in modelled biotite, but is fixed at 1.0.
#
# Validation set is **10%** of the training set. Approx. 6000 samples.

# %%
# load hdf file
file = Path("10042024_Biotite_ds55BtT.hdf5")
with h5py.File(file, "r") as hdf_file:
    PT = np.array(hdf_file["PT"])
    full_biotite_composition = np.array(hdf_file["mineral_composition"])
    element_idx = hdf_file["mineral_composition"].attrs["element idx [apfu]"]

print(*enumerate(element_idx))

biotite_composition = full_biotite_composition[:,[10, 11, 1, 4, 7, 8]]
biotite_F3 = full_biotite_composition[:, 3]
# Consider Fe as Fe total in biotite composition, add Fe and Fe3
biotite_composition[:, 3] += biotite_F3
pt = PT

biotite_composition_train, biotite_composition_val, pt_train, pt_val = train_test_split(biotite_composition, pt, test_size=0.10, shuffle=True)

# normalise biotite composition & min-max scale PT
normalisation_biotite_composition = Normalization(axis=-1)
normalisation_biotite_composition.adapt(biotite_composition_train)

print(normalisation_biotite_composition.mean.numpy())
print(np.sqrt(normalisation_biotite_composition.variance.numpy()))

scaling_pt = MinMaxScaler(min=[1500, 400], max=[10000, 900], axis=0)
inv_scaling_pt = MinMaxScaler(min=[1500, 400], max=[10000, 900], axis=0, invert=True)
pt_train_norm = scaling_pt(pt_train)
pt_val_norm = scaling_pt(pt_val)
# Out:
# (0, 'O') (1, 'AL') (2, 'CA') (3, 'F3') (4, 'FE') (5, 'H') (6, 'K') (7, 'MN') (8, 'MG') (9, 'NA') (10, 'SI') (11, 'TI')
# WARNING:tensorflow:From c:\Users\ThinkPad\miniconda3\envs\masterproject\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# [[2.5365028  0.17007145 1.8472143  1.4520952  0.00804844 0.98606956]]
# [[0.14504048 0.0665739  0.28935492 0.27627432 0.00755797 0.25935802]]

# %% [markdown]
# ## Set-up model & training parameters
#
# Use callbacks to save the best model and to stop training if the validation loss does not decrease for 10 epochs.

# %% [markdown]
# ### Custom metrics
#
# Define a custom metric to evaluate the RMSE of temperature and pressure in meaningful units.\
# The RMSE is calculated on the inverse transformed data and therefore has the units of the original data ([bar]/[&deg;C]).

# %%
def RMSE_P(y_true, y_pred):
    return RMSE_denormalised_P(y_true, y_pred, inv_scaling_pt)


def RMSE_T(y_true, y_pred):
    return RMSE_denormalised_T(y_true, y_pred, inv_scaling_pt)

# %%
BATCH_SIZE = 500
STEPS_PER_EPOCH = len(biotite_composition_train) // BATCH_SIZE
MAX_EPOCHS = 5000

lr_schedule = schedules.InverseTimeDecay(0.001, decay_steps=STEPS_PER_EPOCH*1000, decay_rate=1, staircase=False)
OPT = Adam(lr_schedule)

LOSS = MeanSquaredError()
METRICS = [MeanAbsoluteError(), MeanAbsolutePercentageError(), RootMeanSquaredError(), RMSE_P, RMSE_T]

CALLBACKS = [EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=True), CSVLogger("model_ds55Tajcmanova2009.log", append=False)]

# %%
model = Sequential()
model.add(normalisation_biotite_composition)
model.add(Dense(64, activation="relu"))
model.add(Dense(64, activation="relu"))
model.add(Dense(64, activation="relu"))
model.add(Dense(64, activation="relu"))
model.add(Dense(2))

model.compile(optimizer=OPT, loss=LOSS, metrics=METRICS)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  normalization (Normalizati  (None, 6)                 13
#  on)
#
#  dense (Dense)               (None, 64)                448
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  dense_2 (Dense)             (None, 64)                4160
#
#  dense_3 (Dense)             (None, 64)                4160
#
#  dense_4 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 13071 (51.06 KB)
# Trainable params: 13058 (51.01 KB)
# Non-trainable params: 13 (56.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(biotite_composition_train, pt_train_norm,
                    batch_size=BATCH_SIZE, epochs=MAX_EPOCHS,
                    validation_data=[biotite_composition_val, pt_val_norm],
                    callbacks=CALLBACKS, verbose=True)

model.save(Path("saved_models", "model_ds55Tajcmanova2009"))
# Out:
# Epoch 1/5000
# WARNING:tensorflow:From c:\Users\ThinkPad\miniconda3\envs\masterproject\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\ThinkPad\miniconda3\envs\masterproject\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 139/139 [==============================] - 4s 9ms/step - loss: 0.0455 - mean_absolute_error: 0.1531 - mean_absolute_percentage_error: 89124.3047 - root_mean_squared_error: 0.2132 - RMSE_P: 2124.2778 - RMSE_T: 66.8166 - val_loss: 0.0226 - val_mean_absolute_error: 0.1065 - val_mean_absolute_percentage_error: 34083.7305 - val_root_mean_squared_error: 0.1503 - val_RMSE_P: 1649.2415 - val_RMSE_T: 42.2909
# Epoch 2/5000
# 139/139 [==============================] - 1s 5ms/step - loss: 0.0188 - mean_absolute_error: 0.0960 - mean_absolute_percentage_error: 32334.4473 - root_mean_squared_error: 0.1373 - RMSE_P: 1517.6012 - RMSE_T: 37.7986 - val_loss: 0.0183 - val_mean_absolute_error: 0.0926 - val_mean_absolute_percentage_error: 24736.9414 - val_root_mean_squared_error: 0.1352 - val_RMSE_P: 1486.3129 - val_RMSE_T: 36.8392
# Epoch 3/5000
# 139/139 [==============================] - 1s 5ms/step - loss: 0.0168 - mean_absolute_error: 0.0889 - mean_absolute_percentage_error: 29047.0430 - root_mean_squared_error: 0.1296 - RMSE_P: 1435.1627 - RMSE_T: 35.4310 - val_loss: 0.0172 - val_mean_absolute_error: 0.0883 - val_mean_absolute_percentage_error: 19706.1113 - val_root_mean_squared_error: 0.1312 - val_RMSE_P: 1442.8665 - val_RMSE_T: 35.5207
# Epoch 4/5000
# 139/139 [==============================] - 1s 5ms/step - loss: 0.0160 - mean_absolute_error: 0.0858 - mean_absolute_percentage_error: 27518.8477 - root_mean_squared_error: 0.1265 - RMSE_P: 1402.3206 - RMSE_T: 34.3624 - val_loss: 0.0164 - val_mean_absolute_error: 0.0855 - val_mean_absolute_percentage_error: 16775.9102 - val_root_mean_squared_error: 0.1281 - val_RMSE_P: 1409.6980 - val_RMSE_T: 34.5105
# Epoch 5/5000
# 139/139 [==============================] - 1s 5ms/step - loss: 0.0154 - mean_absolute_error: 0.0831 - mean_absolute_percentage_error: 28278.1992 - root_mean_squared_error: 0.1240 - RMSE_P: 1375.0635 - RMSE_T: 33.4698 - val_loss: 0.0155 - val_mean_absolute_error: 0.0828 - val_mean_absolute_percentage_error: 21726.6426 - val_root_mean_squared_error: 0.1246 - val_RMSE_P: 1371.6134 - val_RMSE_T: 33.3918
# Epoch 6/5000
# 139/139 [==============================] - 1s 5ms/step - loss: 0.0149 - mean_absolute_error: 0.0811 - mean_absolute_percentage_error: 27480.5391 - root_mean_squared_error: 0.1219 - RMSE_P: 1351.9269 - RMSE_T: 32.9470 - val_loss: 0.0154 - val_mean_absolute_error: 0.0824 - val_mean_absolute_percentage_error: 26764.1914 - val_root_mean_squared_error: 0.1241 - val_RMSE_P: 1365.7360 - val_RMSE_T: 33.2802
# Epoch 7/5000
# 139/139 [==============================] - 1s 5ms/step - loss: 0.0143 - mean_absolute_error: 0.0787 - mean_absolute_percentage_error: 25806.0566 - root_mean_squared_error: 0.1194 - RMSE_P: 1324.5322 - RMSE_T: 32.3216 - val_loss: 0.0147 - val_mean_absolute_error: 0.0794 - val_mean_absolute_percentage_error: 19375.0117 - val_root_mean_squared_error: 0.1214 - val_RMSE_P: 1333.7717 - val_RMSE_T: 32.6990
# Epoch 8/5000
# 139/139 [==============================] - 1s 6ms/step - loss: 0.0139 - mean_absolute_error: 0.0771 - mean_absolute_percentage_error: 22843.7500 - root_mean_squared_error: 0.1178 - RMSE_P: 1305.1880 - RMSE_T: 32.0056 - val_loss: 0.0145 - val_mean_absolute_error: 0.0786 - val_mean_absolute_percentage_error: 28853.6562 - val_root_mean_squared_error: 0.1204 - val_RMSE_P: 1321.7998 - val_RMSE_T: 32.6124
# Epoch 9/5000
# 139/139 [==============================] - 1s 5ms/step - loss: 0.0135 - mean_absolute_error: 0.0756 - mean_absolute_percentage_error: 25330.4707 - root_mean_squared_error: 0.1163 - RMSE_P: 1288.0303 - RMSE_T: 31.5917 - val_loss: 0.0143 - val_mean_absolute_error: 0.0790 - val_mean_absolute_percentage_error: 27186.1895 - val_root_mean_squared_error: 0.1195 - val_RMSE_P: 1313.7664 - val_RMSE_T: 32.0779
# Epoch 10/5000
# 139/139 [==============================] - 1s 5ms/step - loss: 0.0132 - mean_absolute_error: 0.0745 - mean_absolute_percentage_error: 22520.4941 - root_mean_squared_error: 0.1150 - RMSE_P: 1273.4563 - RMSE_T: 31.3519 - val_loss: 0.0139 - val_mean_absolute_error: 0.0754 - val_mean_absolute_percentage_error: 30390.4688 - val_root_mean_squared_error: 0.1177 - val_RMSE_P: 1293.1005 - val_RMSE_T: 31.6240
# Epoch 11/5000
# 139/139 [==============================] - 1s 5ms/step - loss: 0.0129 - mean_absolute_error: 0.0729 - mean_absolute_percentage_error: 25563.0742 - root_mean_squared_error: 0.1135 - RMSE_P: 1256.9027 - RMSE_T: 30.9585 - val_loss: 0.0150 - val_mean_absolute_error: 0.0806 - val_mean_absolute_percentage_error: 23681.4414 - val_root_mean_squared_error: 0.1225 - val_RMSE_P: 1354.6615 - val_RMSE_T: 31.8190
# Epoch 12/5000
# 139/139 [==============================] - 1s 5ms/step - loss: 0.0128 - mean_absolute_error: 0.0731 - mean_absolute_percentage_error: 23799.4355 - root_mean_squared_error: 0.1133 - RMSE_P: 1254.7213 - RMSE_T: 30.8731 - val_loss: 0.0136 - val_mean_absolute_error: 0.0746 - val_mean_absolute_percentage_error: 24774.8320 - val_root_mean_squared_error: 0.1164 - val_RMSE_P: 1278.2892 - val_RMSE_T: 31.2757
# Epoch 13/5000
# 139/139 [==============================] - 1s 5ms/step - loss: 0.0124 - mean_absolute_error: 0.0713 - mean_absolute_percentage_error: 22936.1992 - root_mean_squared_error: 0.1115 - RMSE_P: 1234.5665 - RMSE_T: 30.5124 - val_loss: 0.0133 - val_mean_absolute_error: 0.0717 - val_mean_absolute_percentage_error: 26420.6016 - val_root_mean_squared_error: 0.1151 - val_RMSE_P: 1263.0551 - val_RMSE_T: 30.9369
# Epoch 14/5000
# 139/139 [==============================] - 1s 5ms/step - loss: 0.0123 - mean_absolute_error: 0.0708 - mean_absolute_percentage_error: 22737.1602 - root_mean_squared_error: 0.1108 - RMSE_P: 1224.5220 - RMSE_T: 30.3957 - val_loss: 0.0133 - val_mean_absolute_error: 0.0735 - val_mean_absolute_percentage_error: 25554.9746 - val_root_mean_squared_error: 0.1155 - val_RMSE_P: 1268.4575 - val_RMSE_T: 30.9088
# Epoch 15/5000
# 139/139 [==============================] - 1s 6ms/step - loss: 0.0121 - mean_absolute_error: 0.0703 - mean_absolute_percentage_error: 22313.7383 - root_mean_squared_error: 0.1101 - RMSE_P: 1218.0935 - RMSE_T: 30.2314 - val_loss: 0.0126 - val_mean_absolute_error: 0.0705 - val_mean_absolute_percentage_error: 24682.6816 - val_root_mean_squared_error: 0.1124 - val_RMSE_P: 1232.1462 - val_RMSE_T: 30.2421
# Epoch 16/5000
# 139/139 [==============================] - 1s 5ms/step - loss: 0.0119 - mean_absolute_error: 0.0693 - mean_absolute_percentage_error: 20577.0645 - root_mean_squared_error: 0.1092 - RMSE_P: 1206.7257 - RMSE_T: 30.0026 - val_loss: 0.0128 - val_mean_absolute_error: 0.0719 - val_mean_absolute_percentage_error: 27678.2871 - val_root_mean_squared_error: 0.1131 - val_RMSE_P: 1235.8677 - val_RMSE_T: 30.9712
# Epoch 17/5000
# 139/139 [==============================] - 1s 5ms/step - loss: 0.0118 - mean_absolute_error: 0.0688 - mean_absolute_percentage_error: 23570.7129 - root_mean_squared_error: 0.1084 - RMSE_P: 1197.4821 - RMSE_T: 29.9140 - val_loss: 0.0127 - val_mean_absolute_error: 0.0711 - val_mean_absolute_percentage_error: 27715.3945 - val_root_mean_squared_error: 0.1125 - val_RMSE_P: 1229.8551 - val_RMSE_T: 30.9551
# Epoch 18/5000
# 139/139 [==============================] - 1s 5ms/step - loss: 0.0116 - mean_absolute_error: 0.0685 - mean_absolute_percentage_error: 20043.9434 - root_mean_squared_error: 0.1079 - RMSE_P: 1192.1614 - RMSE_T: 29.7407 - val_loss: 0.0124 - val_mean_absolute_error: 0.0688 - val_mean_absolute_percentage_error: 26282.5020 - val_root_mean_squared_error: 0.1113 - val_RMSE_P: 1217.8357 - val_RMSE_T: 30.2254
# Epoch 19/5000
# 139/139 [==============================] - 1s 5ms/step - loss: 0.0114 - mean_absolute_error: 0.0676 - mean_absolute_percentage_error: 21687.9902 - root_mean_squared_error: 0.1070 - RMSE_P: 1181.0061 - RMSE_T: 29.5679 - val_loss: 0.0128 - val_mean_absolute_error: 0.0718 - val_mean_absolute_percentage_error: 31899.9219 - val_root_mean_squared_error: 0.1132 - val_RMSE_P: 1242.3896 - val_RMSE_T: 30.2992
# Epoch 20/5000
# 139/139 [==============================] - 1s 5ms/step - loss: 0.0113 - mean_absolute_error: 0.0674 - mean_absolute_percentage_error: 21063.6973 - root_mean_squared_error: 0.1064 - RMSE_P: 1175.9150 - RMSE_T: 29.4032 - val_loss: 0.0120 - val_mean_absolute_error: 0.0680 - val_mean_absolute_percentage_error: 26734.0137 - val_root_mean_squared_error: 0.1094 - val_RMSE_P: 1196.0513 - val_RMSE_T: 29.8519
# Epoch 21/5000
# 139/139 [==============================] - 1s 6ms/step - loss: 0.0112 - mean_absolute_error: 0.0668 - mean_absolute_percentage_error: 20947.1680 - root_mean_squared_error: 0.1060 - RMSE_P: 1169.6617 - RMSE_T: 29.3339 - val_loss: 0.0120 - val_mean_absolute_error: 0.0684 - val_mean_absolute_percentage_error: 25080.4199 - val_root_mean_squared_error: 0.1098 - val_RMSE_P: 1197.6539 - val_RMSE_T: 30.1741
# Epoch 22/5000
# 139/139 [==============================] - 1s 5ms/step - loss: 0.0112 - mean_absolute_error: 0.0667 - mean_absolute_percentage_error: 24126.3828 - root_mean_squared_error: 0.1058 - RMSE_P: 1167.2871 - RMSE_T: 29.2587 - val_loss: 0.0118 - val_mean_absolute_error: 0.0673 - val_mean_absolute_percentage_error: 29113.8516 - val_root_mean_squared_error: 0.1085 - val_RMSE_P: 1183.7316 - val_RMSE_T: 29.7169
# Epoch 23/5000
# 139/139 [==============================] - 1s 5ms/step - loss: 0.0111 - mean_absolute_error: 0.0664 - mean_absolute_percentage_error: 22249.3223 - root_mean_squared_error: 0.1052 - RMSE_P: 1161.9628 - RMSE_T: 29.1182 - val_loss: 0.0120 - val_mean_absolute_error: 0.0691 - val_mean_absolute_percentage_error: 26573.4277 - val_root_mean_squared_error: 0.1094 - val_RMSE_P: 1196.6370 - val_RMSE_T: 30.1630
# Epoch 24/5000
# 139/139 [==============================] - 1s 6ms/step - loss: 0.0109 - mean_absolute_error: 0.0657 - mean_absolute_percentage_error: 22777.9980 - root_mean_squared_error: 0.1045 - RMSE_P: 1153.2620 - RMSE_T: 29.0394 - val_loss: 0.0115 - val_mean_absolute_error: 0.0669 - val_mean_absolute_percentage_error: 21108.5117 - val_root_mean_squared_error: 0.1074 - val_RMSE_P: 1172.4451 - val_RMSE_T: 29.5778
# Epoch 25/5000
# 139/139 [==============================] - 1s 5ms/step - loss: 0.0108 - mean_absolute_error: 0.0654 - mean_absolute_percentage_error: 18519.4355 - root_mean_squared_error: 0.1041 - RMSE_P: 1147.9904 - RMSE_T: 28.9509 - val_loss: 0.0122 - val_mean_absolute_error: 0.0682 - val_mean_absolute_percentage_error: 31865.6016 - val_root_mean_squared_error: 0.1103 - val_RMSE_P: 1211.2166 - val_RMSE_T: 29.7003
# Epoch 26/5000
# 139/139 [==============================] - 1s 5ms/step - loss: 0.0108 - mean_absolute_error: 0.0656 - mean_absolute_percentage_error: 22329.7051 - root_mean_squared_error: 0.1041 - RMSE_P: 1148.2382 - RMSE_T: 28.9866 - val_loss: 0.0116 - val_mean_absolute_error: 0.0668 - val_mean_absolute_percentage_error: 27287.1484 - val_root_mean_squared_error: 0.1076 - val_RMSE_P: 1171.4945 - val_RMSE_T: 29.7810
# Epoch 27/5000
# 139/139 [==============================] - 1s 5ms/step - loss: 0.0108 - mean_absolute_error: 0.0656 - mean_absolute_percentage_error: 22323.4844 - root_mean_squared_error: 0.1039 - RMSE_P: 1144.8949 - RMSE_T: 28.9351 - val_loss: 0.0114 - val_mean_absolute_error: 0.0656 - val_mean_absolute_percentage_error: 23989.2227 - val_root_mean_squared_error: 0.1069 - val_RMSE_P: 1164.5104 - val_RMSE_T: 29.7333
# Epoch 28/5000
# 139/139 [==============================] - 1s 6ms/step - loss: 0.0107 - mean_absolute_error: 0.0654 - mean_absolute_percentage_error: 21880.8770 - root_mean_squared_error: 0.1036 - RMSE_P: 1142.2471 - RMSE_T: 28.8529 - val_loss: 0.0115 - val_mean_absolute_error: 0.0661 - val_mean_absolute_percentage_error: 24046.6230 - val_root_mean_squared_error: 0.1070 - val_RMSE_P: 1167.1482 - val_RMSE_T: 29.4269
# Epoch 29/5000
# 139/139 [==============================] - 1s 5ms/step - loss: 0.0105 - mean_absolute_error: 0.0644 - mean_absolute_percentage_error: 19571.1152 - root_mean_squared_error: 0.1026 - RMSE_P: 1131.8654 - RMSE_T: 28.6016 - val_loss: 0.0116 - val_mean_absolute_error: 0.0673 - val_mean_absolute_percentage_error: 32782.4219 - val_root_mean_squared_error: 0.1079 - val_RMSE_P: 1178.2864 - val_RMSE_T: 29.7711
# Epoch 30/5000
# 139/139 [==============================] - 1s 5ms/step - loss: 0.0105 - mean_absolute_error: 0.0643 - mean_absolute_percentage_error: 21025.8574 - root_mean_squared_error: 0.1023 - RMSE_P: 1126.9255 - RMSE_T: 28.6476 - val_loss: 0.0116 - val_mean_absolute_error: 0.0673 - val_mean_absolute_percentage_error: 23834.3145 - val_root_mean_squared_error: 0.1079 - val_RMSE_P: 1178.1693 - val_RMSE_T: 29.6418
# Epoch 31/5000
# 139/139 [==============================] - 1s 6ms/step - loss: 0.0105 - mean_absolute_error: 0.0645 - mean_absolute_percentage_error: 21306.5430 - root_mean_squared_error: 0.1023 - RMSE_P: 1127.2777 - RMSE_T: 28.5738 - val_loss: 0.0112 - val_mean_absolute_error: 0.0641 - val_mean_absolute_percentage_error: 27249.6426 - val_root_mean_squared_error: 0.1056 - val_RMSE_P: 1151.1940 - val_RMSE_T: 29.0991
# Epoch 32/5000
# 139/139 [==============================] - 1s 5ms/step - loss: 0.0103 - mean_absolute_error: 0.0637 - mean_absolute_percentage_error: 21914.2832 - root_mean_squared_error: 0.1015 - RMSE_P: 1118.1335 - RMSE_T: 28.4562 - val_loss: 0.0112 - val_mean_absolute_error: 0.0659 - val_mean_absolute_percentage_error: 24639.9883 - val_root_mean_squared_error: 0.1060 - val_RMSE_P: 1156.7896 - val_RMSE_T: 29.3298
# Epoch 33/5000
# 139/139 [==============================] - 1s 5ms/step - loss: 0.0103 - mean_absolute_error: 0.0640 - mean_absolute_percentage_error: 19826.1445 - root_mean_squared_error: 0.1017 - RMSE_P: 1120.9707 - RMSE_T: 28.4296 - val_loss: 0.0112 - val_mean_absolute_error: 0.0654 - val_mean_absolute_percentage_error: 34653.1055 - val_root_mean_squared_error: 0.1057 - val_RMSE_P: 1151.1581 - val_RMSE_T: 29.4296
# Epoch 34/5000
# 139/139 [==============================] - 1s 6ms/step - loss: 0.0102 - mean_absolute_error: 0.0635 - mean_absolute_percentage_error: 22637.2656 - root_mean_squared_error: 0.1012 - RMSE_P: 1114.8531 - RMSE_T: 28.3486 - val_loss: 0.0112 - val_mean_absolute_error: 0.0656 - val_mean_absolute_percentage_error: 27972.0469 - val_root_mean_squared_error: 0.1057 - val_RMSE_P: 1152.3026 - val_RMSE_T: 29.1899
# Epoch 35/5000
# 139/139 [==============================] - 1s 5ms/step - loss: 0.0102 - mean_absolute_error: 0.0633 - mean_absolute_percentage_error: 20929.1367 - root_mean_squared_error: 0.1008 - RMSE_P: 1109.7598 - RMSE_T: 28.2635 - val_loss: 0.0113 - val_mean_absolute_error: 0.0648 - val_mean_absolute_percentage_error: 24930.4297 - val_root_mean_squared_error: 0.1061 - val_RMSE_P: 1158.3486 - val_RMSE_T: 29.1340
# Epoch 36/5000
# 139/139 [==============================] - 1s 6ms/step - loss: 0.0102 - mean_absolute_error: 0.0632 - mean_absolute_percentage_error: 18188.5410 - root_mean_squared_error: 0.1008 - RMSE_P: 1110.4950 - RMSE_T: 28.2067 - val_loss: 0.0110 - val_mean_absolute_error: 0.0656 - val_mean_absolute_percentage_error: 23707.9141 - val_root_mean_squared_error: 0.1047 - val_RMSE_P: 1137.7799 - val_RMSE_T: 29.2867
# Epoch 37/5000
# 139/139 [==============================] - 1s 5ms/step - loss: 0.0101 - mean_absolute_error: 0.0634 - mean_absolute_percentage_error: 20700.2988 - root_mean_squared_error: 0.1006 - RMSE_P: 1107.9716 - RMSE_T: 28.2187 - val_loss: 0.0109 - val_mean_absolute_error: 0.0638 - val_mean_absolute_percentage_error: 28386.2637 - val_root_mean_squared_error: 0.1044 - val_RMSE_P: 1138.0266 - val_RMSE_T: 28.9855
# Epoch 38/5000
# 139/139 [==============================] - 1s 5ms/step - loss: 0.0101 - mean_absolute_error: 0.0633 - mean_absolute_percentage_error: 19446.0781 - root_mean_squared_error: 0.1005 - RMSE_P: 1106.4148 - RMSE_T: 28.1700 - val_loss: 0.0108 - val_mean_absolute_error: 0.0639 - val_mean_absolute_percentage_error: 24174.8848 - val_root_mean_squared_error: 0.1040 - val_RMSE_P: 1131.2216 - val_RMSE_T: 28.9255
# Epoch 39/5000
# 139/139 [==============================] - 1s 6ms/step - loss: 0.0099 - mean_absolute_error: 0.0625 - mean_absolute_percentage_error: 18604.3340 - root_mean_squared_error: 0.0996 - RMSE_P: 1096.6431 - RMSE_T: 28.0425 - val_loss: 0.0110 - val_mean_absolute_error: 0.0652 - val_mean_absolute_percentage_error: 26434.2930 - val_root_mean_squared_error: 0.1048 - val_RMSE_P: 1142.2794 - val_RMSE_T: 29.2605
# Epoch 40/5000
# 139/139 [==============================] - 1s 5ms/step - loss: 0.0099 - mean_absolute_error: 0.0625 - mean_absolute_percentage_error: 18187.6621 - root_mean_squared_error: 0.0996 - RMSE_P: 1095.1066 - RMSE_T: 28.0720 - val_loss: 0.0107 - val_mean_absolute_error: 0.0630 - val_mean_absolute_percentage_error: 25037.0332 - val_root_mean_squared_error: 0.1035 - val_RMSE_P: 1128.0486 - val_RMSE_T: 28.7841
# Epoch 41/5000
# 139/139 [==============================] - 1s 5ms/step - loss: 0.0098 - mean_absolute_error: 0.0623 - mean_absolute_percentage_error: 18910.6680 - root_mean_squared_error: 0.0992 - RMSE_P: 1092.3501 - RMSE_T: 27.8901 - val_loss: 0.0109 - val_mean_absolute_error: 0.0641 - val_mean_absolute_percentage_error: 22514.8496 - val_root_mean_squared_error: 0.1043 - val_RMSE_P: 1136.8250 - val_RMSE_T: 28.9494
# Epoch 42/5000
# 139/139 [==============================] - 1s 6ms/step - loss: 0.0098 - mean_absolute_error: 0.0620 - mean_absolute_percentage_error: 16980.7891 - root_mean_squared_error: 0.0991 - RMSE_P: 1090.8850 - RMSE_T: 27.8151 - val_loss: 0.0109 - val_mean_absolute_error: 0.0648 - val_mean_absolute_percentage_error: 24086.1406 - val_root_mean_squared_error: 0.1043 - val_RMSE_P: 1132.4299 - val_RMSE_T: 29.6142
# Epoch 43/5000
# 139/139 [==============================] - 1s 5ms/step - loss: 0.0098 - mean_absolute_error: 0.0618 - mean_absolute_percentage_error: 21172.3730 - root_mean_squared_error: 0.0988 - RMSE_P: 1087.7423 - RMSE_T: 27.8457 - val_loss: 0.0108 - val_mean_absolute_error: 0.0640 - val_mean_absolute_percentage_error: 24035.1406 - val_root_mean_squared_error: 0.1038 - val_RMSE_P: 1131.0909 - val_RMSE_T: 28.8353
# Epoch 44/5000
# 139/139 [==============================] - 1s 6ms/step - loss: 0.0097 - mean_absolute_error: 0.0615 - mean_absolute_percentage_error: 18891.6875 - root_mean_squared_error: 0.0985 - RMSE_P: 1083.4373 - RMSE_T: 27.7217 - val_loss: 0.0107 - val_mean_absolute_error: 0.0643 - val_mean_absolute_percentage_error: 23639.4023 - val_root_mean_squared_error: 0.1036 - val_RMSE_P: 1125.1948 - val_RMSE_T: 29.3381
# Epoch 45/5000
# 139/139 [==============================] - 1s 5ms/step - loss: 0.0097 - mean_absolute_error: 0.0614 - mean_absolute_percentage_error: 17804.3691 - root_mean_squared_error: 0.0983 - RMSE_P: 1081.4613 - RMSE_T: 27.6910 - val_loss: 0.0112 - val_mean_absolute_error: 0.0668 - val_mean_absolute_percentage_error: 23833.9141 - val_root_mean_squared_error: 0.1057 - val_RMSE_P: 1152.3335 - val_RMSE_T: 29.3559
# Epoch 46/5000
# 139/139 [==============================] - 1s 4ms/step - loss: 0.0096 - mean_absolute_error: 0.0612 - mean_absolute_percentage_error: 18252.1582 - root_mean_squared_error: 0.0980 - RMSE_P: 1077.9817 - RMSE_T: 27.6351 - val_loss: 0.0106 - val_mean_absolute_error: 0.0630 - val_mean_absolute_percentage_error: 19683.6855 - val_root_mean_squared_error: 0.1029 - val_RMSE_P: 1119.4730 - val_RMSE_T: 28.8112
# Epoch 47/5000
# 139/139 [==============================] - 1s 4ms/step - loss: 0.0096 - mean_absolute_error: 0.0615 - mean_absolute_percentage_error: 18352.7695 - root_mean_squared_error: 0.0981 - RMSE_P: 1079.2032 - RMSE_T: 27.6880 - val_loss: 0.0106 - val_mean_absolute_error: 0.0632 - val_mean_absolute_percentage_error: 26692.1152 - val_root_mean_squared_error: 0.1028 - val_RMSE_P: 1118.1495 - val_RMSE_T: 28.9595
# Epoch 48/5000
# 139/139 [==============================] - 1s 5ms/step - loss: 0.0096 - mean_absolute_error: 0.0612 - mean_absolute_percentage_error: 19572.9336 - root_mean_squared_error: 0.0979 - RMSE_P: 1077.6555 - RMSE_T: 27.6161 - val_loss: 0.0108 - val_mean_absolute_error: 0.0641 - val_mean_absolute_percentage_error: 28395.4512 - val_root_mean_squared_error: 0.1039 - val_RMSE_P: 1132.7535 - val_RMSE_T: 28.8923
# Epoch 49/5000
# 139/139 [==============================] - 1s 4ms/step - loss: 0.0095 - mean_absolute_error: 0.0609 - mean_absolute_percentage_error: 17109.1562 - root_mean_squared_error: 0.0975 - RMSE_P: 1071.3224 - RMSE_T: 27.5365 - val_loss: 0.0108 - val_mean_absolute_error: 0.0635 - val_mean_absolute_percentage_error: 28404.7617 - val_root_mean_squared_error: 0.1041 - val_RMSE_P: 1132.7484 - val_RMSE_T: 29.1762
# Epoch 50/5000
# 139/139 [==============================] - 1s 4ms/step - loss: 0.0095 - mean_absolute_error: 0.0608 - mean_absolute_percentage_error: 19818.4355 - root_mean_squared_error: 0.0972 - RMSE_P: 1068.9076 - RMSE_T: 27.5185 - val_loss: 0.0105 - val_mean_absolute_error: 0.0641 - val_mean_absolute_percentage_error: 18613.7812 - val_root_mean_squared_error: 0.1026 - val_RMSE_P: 1118.2223 - val_RMSE_T: 28.5470
# Epoch 51/5000
# 139/139 [==============================] - 1s 4ms/step - loss: 0.0094 - mean_absolute_error: 0.0608 - mean_absolute_percentage_error: 17820.9551 - root_mean_squared_error: 0.0972 - RMSE_P: 1068.3789 - RMSE_T: 27.4967 - val_loss: 0.0104 - val_mean_absolute_error: 0.0612 - val_mean_absolute_percentage_error: 21481.5527 - val_root_mean_squared_error: 0.1020 - val_RMSE_P: 1112.3851 - val_RMSE_T: 28.3989
# Epoch 52/5000
# 139/139 [==============================] - 1s 6ms/step - loss: 0.0094 - mean_absolute_error: 0.0606 - mean_absolute_percentage_error: 18532.6309 - root_mean_squared_error: 0.0970 - RMSE_P: 1066.6241 - RMSE_T: 27.4195 - val_loss: 0.0105 - val_mean_absolute_error: 0.0628 - val_mean_absolute_percentage_error: 29242.4609 - val_root_mean_squared_error: 0.1023 - val_RMSE_P: 1110.6056 - val_RMSE_T: 29.0789
# Epoch 53/5000
# 139/139 [==============================] - 1s 4ms/step - loss: 0.0094 - mean_absolute_error: 0.0607 - mean_absolute_percentage_error: 18849.4609 - root_mean_squared_error: 0.0970 - RMSE_P: 1065.4420 - RMSE_T: 27.4753 - val_loss: 0.0103 - val_mean_absolute_error: 0.0626 - val_mean_absolute_percentage_error: 21722.4180 - val_root_mean_squared_error: 0.1016 - val_RMSE_P: 1105.3472 - val_RMSE_T: 28.5737
# Epoch 54/5000
# 139/139 [==============================] - 1s 4ms/step - loss: 0.0093 - mean_absolute_error: 0.0603 - mean_absolute_percentage_error: 17772.1133 - root_mean_squared_error: 0.0966 - RMSE_P: 1062.0432 - RMSE_T: 27.4438 - val_loss: 0.0104 - val_mean_absolute_error: 0.0617 - val_mean_absolute_percentage_error: 33509.8477 - val_root_mean_squared_error: 0.1021 - val_RMSE_P: 1112.3082 - val_RMSE_T: 28.5031
# Epoch 55/5000
# 139/139 [==============================] - 1s 4ms/step - loss: 0.0093 - mean_absolute_error: 0.0604 - mean_absolute_percentage_error: 16497.8672 - root_mean_squared_error: 0.0966 - RMSE_P: 1061.0009 - RMSE_T: 27.5187 - val_loss: 0.0104 - val_mean_absolute_error: 0.0631 - val_mean_absolute_percentage_error: 20053.3867 - val_root_mean_squared_error: 0.1021 - val_RMSE_P: 1111.8217 - val_RMSE_T: 28.4263
# Epoch 56/5000
# 139/139 [==============================] - 0s 3ms/step - loss: 0.0093 - mean_absolute_error: 0.0601 - mean_absolute_percentage_error: 18490.5781 - root_mean_squared_error: 0.0962 - RMSE_P: 1056.9083 - RMSE_T: 27.3486 - val_loss: 0.0107 - val_mean_absolute_error: 0.0651 - val_mean_absolute_percentage_error: 30199.0020 - val_root_mean_squared_error: 0.1033 - val_RMSE_P: 1124.8164 - val_RMSE_T: 28.8894
# Epoch 57/5000
# 139/139 [==============================] - 0s 3ms/step - loss: 0.0092 - mean_absolute_error: 0.0600 - mean_absolute_percentage_error: 18276.6504 - root_mean_squared_error: 0.0960 - RMSE_P: 1054.4811 - RMSE_T: 27.3095 - val_loss: 0.0104 - val_mean_absolute_error: 0.0630 - val_mean_absolute_percentage_error: 25376.4590 - val_root_mean_squared_error: 0.1018 - val_RMSE_P: 1107.1555 - val_RMSE_T: 28.5820
# Epoch 58/5000
# 139/139 [==============================] - 0s 3ms/step - loss: 0.0093 - mean_absolute_error: 0.0601 - mean_absolute_percentage_error: 17989.2031 - root_mean_squared_error: 0.0963 - RMSE_P: 1057.4462 - RMSE_T: 27.3347 - val_loss: 0.0104 - val_mean_absolute_error: 0.0624 - val_mean_absolute_percentage_error: 21845.3320 - val_root_mean_squared_error: 0.1018 - val_RMSE_P: 1105.7292 - val_RMSE_T: 28.6557
# Epoch 59/5000
# 139/139 [==============================] - 0s 3ms/step - loss: 0.0092 - mean_absolute_error: 0.0600 - mean_absolute_percentage_error: 17532.5234 - root_mean_squared_error: 0.0960 - RMSE_P: 1055.2710 - RMSE_T: 27.1984 - val_loss: 0.0103 - val_mean_absolute_error: 0.0627 - val_mean_absolute_percentage_error: 25644.4316 - val_root_mean_squared_error: 0.1017 - val_RMSE_P: 1106.3412 - val_RMSE_T: 28.4616
# Epoch 60/5000
# 139/139 [==============================] - 0s 3ms/step - loss: 0.0092 - mean_absolute_error: 0.0599 - mean_absolute_percentage_error: 18206.8574 - root_mean_squared_error: 0.0958 - RMSE_P: 1052.3285 - RMSE_T: 27.2088 - val_loss: 0.0105 - val_mean_absolute_error: 0.0629 - val_mean_absolute_percentage_error: 19921.7227 - val_root_mean_squared_error: 0.1025 - val_RMSE_P: 1114.6953 - val_RMSE_T: 28.7449
# Epoch 61/5000
# 139/139 [==============================] - 0s 4ms/step - loss: 0.0091 - mean_absolute_error: 0.0595 - mean_absolute_percentage_error: 17657.1484 - root_mean_squared_error: 0.0954 - RMSE_P: 1047.9724 - RMSE_T: 27.1452 - val_loss: 0.0101 - val_mean_absolute_error: 0.0616 - val_mean_absolute_percentage_error: 20955.6543 - val_root_mean_squared_error: 0.1005 - val_RMSE_P: 1094.7450 - val_RMSE_T: 28.2446
# Epoch 62/5000
# 139/139 [==============================] - 0s 3ms/step - loss: 0.0091 - mean_absolute_error: 0.0597 - mean_absolute_percentage_error: 17908.6895 - root_mean_squared_error: 0.0954 - RMSE_P: 1046.8105 - RMSE_T: 27.2562 - val_loss: 0.0103 - val_mean_absolute_error: 0.0617 - val_mean_absolute_percentage_error: 21834.0156 - val_root_mean_squared_error: 0.1015 - val_RMSE_P: 1107.1615 - val_RMSE_T: 28.2392
# Epoch 63/5000
# 139/139 [==============================] - 0s 3ms/step - loss: 0.0091 - mean_absolute_error: 0.0596 - mean_absolute_percentage_error: 16645.7090 - root_mean_squared_error: 0.0954 - RMSE_P: 1047.5022 - RMSE_T: 27.2116 - val_loss: 0.0104 - val_mean_absolute_error: 0.0636 - val_mean_absolute_percentage_error: 19071.2949 - val_root_mean_squared_error: 0.1018 - val_RMSE_P: 1108.5072 - val_RMSE_T: 28.5516
# Epoch 64/5000
# 139/139 [==============================] - 0s 3ms/step - loss: 0.0091 - mean_absolute_error: 0.0598 - mean_absolute_percentage_error: 16272.3389 - root_mean_squared_error: 0.0953 - RMSE_P: 1047.0612 - RMSE_T: 27.1404 - val_loss: 0.0102 - val_mean_absolute_error: 0.0619 - val_mean_absolute_percentage_error: 26033.9844 - val_root_mean_squared_error: 0.1009 - val_RMSE_P: 1095.6586 - val_RMSE_T: 28.6787
# Epoch 65/5000
# 139/139 [==============================] - 0s 3ms/step - loss: 0.0090 - mean_absolute_error: 0.0592 - mean_absolute_percentage_error: 16150.3955 - root_mean_squared_error: 0.0949 - RMSE_P: 1041.8260 - RMSE_T: 27.0901 - val_loss: 0.0100 - val_mean_absolute_error: 0.0612 - val_mean_absolute_percentage_error: 22887.6426 - val_root_mean_squared_error: 0.1000 - val_RMSE_P: 1087.1969 - val_RMSE_T: 28.2466
# Epoch 66/5000
# 139/139 [==============================] - 0s 3ms/step - loss: 0.0090 - mean_absolute_error: 0.0594 - mean_absolute_percentage_error: 18255.9980 - root_mean_squared_error: 0.0949 - RMSE_P: 1040.6333 - RMSE_T: 27.1626 - val_loss: 0.0105 - val_mean_absolute_error: 0.0628 - val_mean_absolute_percentage_error: 24754.6465 - val_root_mean_squared_error: 0.1023 - val_RMSE_P: 1116.0142 - val_RMSE_T: 28.3027
# Epoch 67/5000
# 139/139 [==============================] - 0s 3ms/step - loss: 0.0090 - mean_absolute_error: 0.0591 - mean_absolute_percentage_error: 15975.5215 - root_mean_squared_error: 0.0947 - RMSE_P: 1040.3452 - RMSE_T: 26.9834 - val_loss: 0.0100 - val_mean_absolute_error: 0.0608 - val_mean_absolute_percentage_error: 22667.2617 - val_root_mean_squared_error: 0.1000 - val_RMSE_P: 1088.8074 - val_RMSE_T: 28.1796
# Epoch 68/5000
# 139/139 [==============================] - 1s 4ms/step - loss: 0.0089 - mean_absolute_error: 0.0590 - mean_absolute_percentage_error: 14788.4092 - root_mean_squared_error: 0.0946 - RMSE_P: 1037.9506 - RMSE_T: 26.9531 - val_loss: 0.0100 - val_mean_absolute_error: 0.0610 - val_mean_absolute_percentage_error: 22392.3633 - val_root_mean_squared_error: 0.1000 - val_RMSE_P: 1085.3168 - val_RMSE_T: 28.2366
# Epoch 69/5000
# 139/139 [==============================] - 0s 3ms/step - loss: 0.0089 - mean_absolute_error: 0.0588 - mean_absolute_percentage_error: 16296.9248 - root_mean_squared_error: 0.0943 - RMSE_P: 1035.3430 - RMSE_T: 26.8796 - val_loss: 0.0100 - val_mean_absolute_error: 0.0618 - val_mean_absolute_percentage_error: 24529.9375 - val_root_mean_squared_error: 0.1002 - val_RMSE_P: 1086.2174 - val_RMSE_T: 28.4770
# Epoch 70/5000
# 139/139 [==============================] - 0s 3ms/step - loss: 0.0089 - mean_absolute_error: 0.0588 - mean_absolute_percentage_error: 17350.4297 - root_mean_squared_error: 0.0942 - RMSE_P: 1032.3083 - RMSE_T: 27.0281 - val_loss: 0.0099 - val_mean_absolute_error: 0.0601 - val_mean_absolute_percentage_error: 24264.1641 - val_root_mean_squared_error: 0.0996 - val_RMSE_P: 1081.6942 - val_RMSE_T: 28.2633
# Epoch 71/5000
# 139/139 [==============================] - 0s 3ms/step - loss: 0.0088 - mean_absolute_error: 0.0585 - mean_absolute_percentage_error: 15964.9590 - root_mean_squared_error: 0.0938 - RMSE_P: 1028.9269 - RMSE_T: 26.8179 - val_loss: 0.0098 - val_mean_absolute_error: 0.0604 - val_mean_absolute_percentage_error: 24576.0977 - val_root_mean_squared_error: 0.0992 - val_RMSE_P: 1077.3457 - val_RMSE_T: 28.0856
# Epoch 72/5000
# 139/139 [==============================] - 0s 3ms/step - loss: 0.0088 - mean_absolute_error: 0.0591 - mean_absolute_percentage_error: 16694.1914 - root_mean_squared_error: 0.0940 - RMSE_P: 1030.5673 - RMSE_T: 27.0403 - val_loss: 0.0101 - val_mean_absolute_error: 0.0621 - val_mean_absolute_percentage_error: 20233.2324 - val_root_mean_squared_error: 0.1005 - val_RMSE_P: 1093.3643 - val_RMSE_T: 28.1239
# Epoch 73/5000
# 139/139 [==============================] - 1s 4ms/step - loss: 0.0088 - mean_absolute_error: 0.0585 - mean_absolute_percentage_error: 16907.6992 - root_mean_squared_error: 0.0938 - RMSE_P: 1028.4847 - RMSE_T: 26.8760 - val_loss: 0.0103 - val_mean_absolute_error: 0.0618 - val_mean_absolute_percentage_error: 23769.6445 - val_root_mean_squared_error: 0.1013 - val_RMSE_P: 1102.5168 - val_RMSE_T: 28.5374
# Epoch 74/5000
# 139/139 [==============================] - 0s 3ms/step - loss: 0.0088 - mean_absolute_error: 0.0588 - mean_absolute_percentage_error: 15171.5361 - root_mean_squared_error: 0.0940 - RMSE_P: 1031.2529 - RMSE_T: 26.8805 - val_loss: 0.0100 - val_mean_absolute_error: 0.0610 - val_mean_absolute_percentage_error: 18663.2031 - val_root_mean_squared_error: 0.0999 - val_RMSE_P: 1086.0972 - val_RMSE_T: 28.3195
# Epoch 75/5000
# 139/139 [==============================] - 0s 3ms/step - loss: 0.0088 - mean_absolute_error: 0.0591 - mean_absolute_percentage_error: 15802.8457 - root_mean_squared_error: 0.0940 - RMSE_P: 1031.7279 - RMSE_T: 26.8786 - val_loss: 0.0099 - val_mean_absolute_error: 0.0614 - val_mean_absolute_percentage_error: 27269.7559 - val_root_mean_squared_error: 0.0994 - val_RMSE_P: 1080.2174 - val_RMSE_T: 28.2828
# Epoch 76/5000
# 139/139 [==============================] - 0s 3ms/step - loss: 0.0087 - mean_absolute_error: 0.0584 - mean_absolute_percentage_error: 17458.7910 - root_mean_squared_error: 0.0934 - RMSE_P: 1024.9565 - RMSE_T: 26.7660 - val_loss: 0.0098 - val_mean_absolute_error: 0.0598 - val_mean_absolute_percentage_error: 22100.5000 - val_root_mean_squared_error: 0.0990 - val_RMSE_P: 1072.8214 - val_RMSE_T: 28.2803
# Epoch 77/5000
# 139/139 [==============================] - 0s 3ms/step - loss: 0.0087 - mean_absolute_error: 0.0584 - mean_absolute_percentage_error: 17731.0137 - root_mean_squared_error: 0.0935 - RMSE_P: 1025.1327 - RMSE_T: 26.7585 - val_loss: 0.0100 - val_mean_absolute_error: 0.0611 - val_mean_absolute_percentage_error: 17923.0488 - val_root_mean_squared_error: 0.1000 - val_RMSE_P: 1086.6713 - val_RMSE_T: 28.5503
# Epoch 78/5000
# 139/139 [==============================] - 0s 3ms/step - loss: 0.0087 - mean_absolute_error: 0.0581 - mean_absolute_percentage_error: 17355.7246 - root_mean_squared_error: 0.0931 - RMSE_P: 1019.9041 - RMSE_T: 26.8305 - val_loss: 0.0098 - val_mean_absolute_error: 0.0596 - val_mean_absolute_percentage_error: 25680.4629 - val_root_mean_squared_error: 0.0991 - val_RMSE_P: 1076.2269 - val_RMSE_T: 28.0907
# Epoch 79/5000
# 139/139 [==============================] - 1s 4ms/step - loss: 0.0087 - mean_absolute_error: 0.0580 - mean_absolute_percentage_error: 16243.4727 - root_mean_squared_error: 0.0930 - RMSE_P: 1019.3519 - RMSE_T: 26.7434 - val_loss: 0.0099 - val_mean_absolute_error: 0.0605 - val_mean_absolute_percentage_error: 22834.0684 - val_root_mean_squared_error: 0.0995 - val_RMSE_P: 1082.2744 - val_RMSE_T: 28.1536
# Epoch 80/5000
# 139/139 [==============================] - 0s 3ms/step - loss: 0.0086 - mean_absolute_error: 0.0582 - mean_absolute_percentage_error: 15332.5859 - root_mean_squared_error: 0.0930 - RMSE_P: 1018.7554 - RMSE_T: 26.7688 - val_loss: 0.0097 - val_mean_absolute_error: 0.0605 - val_mean_absolute_percentage_error: 26578.0039 - val_root_mean_squared_error: 0.0987 - val_RMSE_P: 1071.5500 - val_RMSE_T: 28.0896
# Epoch 81/5000
# 139/139 [==============================] - 0s 3ms/step - loss: 0.0086 - mean_absolute_error: 0.0579 - mean_absolute_percentage_error: 14511.7461 - root_mean_squared_error: 0.0927 - RMSE_P: 1016.3093 - RMSE_T: 26.6643 - val_loss: 0.0100 - val_mean_absolute_error: 0.0613 - val_mean_absolute_percentage_error: 19849.8320 - val_root_mean_squared_error: 0.0998 - val_RMSE_P: 1086.0615 - val_RMSE_T: 28.0291
# Epoch 82/5000
# 139/139 [==============================] - 0s 3ms/step - loss: 0.0086 - mean_absolute_error: 0.0582 - mean_absolute_percentage_error: 17229.2227 - root_mean_squared_error: 0.0928 - RMSE_P: 1016.8587 - RMSE_T: 26.7268 - val_loss: 0.0100 - val_mean_absolute_error: 0.0609 - val_mean_absolute_percentage_error: 22909.7910 - val_root_mean_squared_error: 0.0999 - val_RMSE_P: 1088.3492 - val_RMSE_T: 28.1742
# Epoch 83/5000
# 139/139 [==============================] - 0s 3ms/step - loss: 0.0086 - mean_absolute_error: 0.0579 - mean_absolute_percentage_error: 14745.0244 - root_mean_squared_error: 0.0928 - RMSE_P: 1016.6229 - RMSE_T: 26.6611 - val_loss: 0.0098 - val_mean_absolute_error: 0.0601 - val_mean_absolute_percentage_error: 25434.7129 - val_root_mean_squared_error: 0.0988 - val_RMSE_P: 1074.8986 - val_RMSE_T: 27.9304
# Epoch 84/5000
# 139/139 [==============================] - 0s 3ms/step - loss: 0.0086 - mean_absolute_error: 0.0578 - mean_absolute_percentage_error: 15441.9717 - root_mean_squared_error: 0.0925 - RMSE_P: 1013.9884 - RMSE_T: 26.6105 - val_loss: 0.0099 - val_mean_absolute_error: 0.0614 - val_mean_absolute_percentage_error: 22409.1719 - val_root_mean_squared_error: 0.0995 - val_RMSE_P: 1079.1343 - val_RMSE_T: 28.4202
# Epoch 85/5000
# 139/139 [==============================] - 0s 4ms/step - loss: 0.0086 - mean_absolute_error: 0.0580 - mean_absolute_percentage_error: 14715.7920 - root_mean_squared_error: 0.0925 - RMSE_P: 1013.2412 - RMSE_T: 26.6730 - val_loss: 0.0099 - val_mean_absolute_error: 0.0604 - val_mean_absolute_percentage_error: 26879.2246 - val_root_mean_squared_error: 0.0995 - val_RMSE_P: 1084.9305 - val_RMSE_T: 27.9501
# Epoch 86/5000
# 139/139 [==============================] - 0s 3ms/step - loss: 0.0085 - mean_absolute_error: 0.0577 - mean_absolute_percentage_error: 13945.1475 - root_mean_squared_error: 0.0924 - RMSE_P: 1012.1121 - RMSE_T: 26.5704 - val_loss: 0.0098 - val_mean_absolute_error: 0.0602 - val_mean_absolute_percentage_error: 21957.7656 - val_root_mean_squared_error: 0.0990 - val_RMSE_P: 1073.1102 - val_RMSE_T: 28.1297
# Epoch 87/5000
# 139/139 [==============================] - 0s 3ms/step - loss: 0.0085 - mean_absolute_error: 0.0578 - mean_absolute_percentage_error: 15240.5771 - root_mean_squared_error: 0.0923 - RMSE_P: 1011.0714 - RMSE_T: 26.6018 - val_loss: 0.0099 - val_mean_absolute_error: 0.0597 - val_mean_absolute_percentage_error: 25667.3691 - val_root_mean_squared_error: 0.0996 - val_RMSE_P: 1083.4341 - val_RMSE_T: 28.0855
# Epoch 88/5000
# 139/139 [==============================] - 0s 3ms/step - loss: 0.0084 - mean_absolute_error: 0.0572 - mean_absolute_percentage_error: 14596.7705 - root_mean_squared_error: 0.0919 - RMSE_P: 1005.7175 - RMSE_T: 26.4720 - val_loss: 0.0098 - val_mean_absolute_error: 0.0596 - val_mean_absolute_percentage_error: 19374.8340 - val_root_mean_squared_error: 0.0988 - val_RMSE_P: 1076.9183 - val_RMSE_T: 27.6813
# Epoch 89/5000
# 139/139 [==============================] - 0s 3ms/step - loss: 0.0085 - mean_absolute_error: 0.0575 - mean_absolute_percentage_error: 13876.5244 - root_mean_squared_error: 0.0920 - RMSE_P: 1007.9137 - RMSE_T: 26.5160 - val_loss: 0.0097 - val_mean_absolute_error: 0.0603 - val_mean_absolute_percentage_error: 20774.6055 - val_root_mean_squared_error: 0.0983 - val_RMSE_P: 1067.6641 - val_RMSE_T: 27.9117
# Epoch 90/5000
# 139/139 [==============================] - 0s 3ms/step - loss: 0.0085 - mean_absolute_error: 0.0577 - mean_absolute_percentage_error: 13903.4961 - root_mean_squared_error: 0.0922 - RMSE_P: 1008.8415 - RMSE_T: 26.7163 - val_loss: 0.0098 - val_mean_absolute_error: 0.0607 - val_mean_absolute_percentage_error: 22504.8125 - val_root_mean_squared_error: 0.0989 - val_RMSE_P: 1073.2052 - val_RMSE_T: 28.2799
# Epoch 91/5000
# 139/139 [==============================] - 0s 4ms/step - loss: 0.0085 - mean_absolute_error: 0.0579 - mean_absolute_percentage_error: 14216.5869 - root_mean_squared_error: 0.0924 - RMSE_P: 1011.4698 - RMSE_T: 26.6512 - val_loss: 0.0098 - val_mean_absolute_error: 0.0616 - val_mean_absolute_percentage_error: 13869.5527 - val_root_mean_squared_error: 0.0992 - val_RMSE_P: 1073.5382 - val_RMSE_T: 28.5617
# Epoch 92/5000
# 139/139 [==============================] - 0s 3ms/step - loss: 0.0084 - mean_absolute_error: 0.0571 - mean_absolute_percentage_error: 15785.4561 - root_mean_squared_error: 0.0917 - RMSE_P: 1003.3153 - RMSE_T: 26.5114 - val_loss: 0.0099 - val_mean_absolute_error: 0.0609 - val_mean_absolute_percentage_error: 23348.8516 - val_root_mean_squared_error: 0.0993 - val_RMSE_P: 1081.9436 - val_RMSE_T: 28.0908
# Epoch 93/5000
# 139/139 [==============================] - 0s 3ms/step - loss: 0.0084 - mean_absolute_error: 0.0570 - mean_absolute_percentage_error: 14056.2451 - root_mean_squared_error: 0.0915 - RMSE_P: 1001.5375 - RMSE_T: 26.4161 - val_loss: 0.0096 - val_mean_absolute_error: 0.0601 - val_mean_absolute_percentage_error: 22349.6816 - val_root_mean_squared_error: 0.0979 - val_RMSE_P: 1060.4424 - val_RMSE_T: 28.1898
# Epoch 94/5000
# 139/139 [==============================] - 0s 3ms/step - loss: 0.0084 - mean_absolute_error: 0.0571 - mean_absolute_percentage_error: 12167.6572 - root_mean_squared_error: 0.0914 - RMSE_P: 1000.7073 - RMSE_T: 26.5386 - val_loss: 0.0097 - val_mean_absolute_error: 0.0594 - val_mean_absolute_percentage_error: 23921.4551 - val_root_mean_squared_error: 0.0984 - val_RMSE_P: 1067.4771 - val_RMSE_T: 28.0446
# Epoch 95/5000
# 139/139 [==============================] - 0s 3ms/step - loss: 0.0084 - mean_absolute_error: 0.0571 - mean_absolute_percentage_error: 15294.9121 - root_mean_squared_error: 0.0915 - RMSE_P: 1002.3682 - RMSE_T: 26.4618 - val_loss: 0.0097 - val_mean_absolute_error: 0.0604 - val_mean_absolute_percentage_error: 20060.0605 - val_root_mean_squared_error: 0.0985 - val_RMSE_P: 1070.8624 - val_RMSE_T: 27.9108
# Epoch 96/5000
# 139/139 [==============================] - 0s 3ms/step - loss: 0.0084 - mean_absolute_error: 0.0575 - mean_absolute_percentage_error: 14274.2197 - root_mean_squared_error: 0.0916 - RMSE_P: 1002.5923 - RMSE_T: 26.4935 - val_loss: 0.0099 - val_mean_absolute_error: 0.0601 - val_mean_absolute_percentage_error: 20630.0273 - val_root_mean_squared_error: 0.0996 - val_RMSE_P: 1081.4512 - val_RMSE_T: 28.6925
# Epoch 97/5000
# 139/139 [==============================] - 0s 3ms/step - loss: 0.0083 - mean_absolute_error: 0.0568 - mean_absolute_percentage_error: 12901.8545 - root_mean_squared_error: 0.0911 - RMSE_P: 997.8508 - RMSE_T: 26.3416 - val_loss: 0.0095 - val_mean_absolute_error: 0.0595 - val_mean_absolute_percentage_error: 24874.9941 - val_root_mean_squared_error: 0.0977 - val_RMSE_P: 1058.1096 - val_RMSE_T: 28.0623
# Epoch 98/5000
# 139/139 [==============================] - 0s 3ms/step - loss: 0.0084 - mean_absolute_error: 0.0571 - mean_absolute_percentage_error: 15117.9912 - root_mean_squared_error: 0.0914 - RMSE_P: 1000.6901 - RMSE_T: 26.3990 - val_loss: 0.0097 - val_mean_absolute_error: 0.0596 - val_mean_absolute_percentage_error: 20860.9551 - val_root_mean_squared_error: 0.0987 - val_RMSE_P: 1073.4866 - val_RMSE_T: 27.8108
# Epoch 99/5000
# 139/139 [==============================] - 0s 3ms/step - loss: 0.0083 - mean_absolute_error: 0.0570 - mean_absolute_percentage_error: 12526.5459 - root_mean_squared_error: 0.0911 - RMSE_P: 996.1713 - RMSE_T: 26.4299 - val_loss: 0.0098 - val_mean_absolute_error: 0.0615 - val_mean_absolute_percentage_error: 16142.3291 - val_root_mean_squared_error: 0.0992 - val_RMSE_P: 1075.6906 - val_RMSE_T: 28.3976
# Epoch 100/5000
# 139/139 [==============================] - 0s 3ms/step - loss: 0.0084 - mean_absolute_error: 0.0576 - mean_absolute_percentage_error: 13465.0156 - root_mean_squared_error: 0.0917 - RMSE_P: 1004.3813 - RMSE_T: 26.4931 - val_loss: 0.0096 - val_mean_absolute_error: 0.0598 - val_mean_absolute_percentage_error: 20061.2676 - val_root_mean_squared_error: 0.0982 - val_RMSE_P: 1065.0637 - val_RMSE_T: 28.1622
# Epoch 101/5000
# 139/139 [==============================] - 0s 3ms/step - loss: 0.0082 - mean_absolute_error: 0.0567 - mean_absolute_percentage_error: 14932.0146 - root_mean_squared_error: 0.0908 - RMSE_P: 993.0151 - RMSE_T: 26.3999 - val_loss: 0.0097 - val_mean_absolute_error: 0.0611 - val_mean_absolute_percentage_error: 21911.1055 - val_root_mean_squared_error: 0.0983 - val_RMSE_P: 1063.7609 - val_RMSE_T: 28.3934
# Epoch 102/5000
# 139/139 [==============================] - 0s 3ms/step - loss: 0.0082 - mean_absolute_error: 0.0567 - mean_absolute_percentage_error: 14755.4434 - root_mean_squared_error: 0.0908 - RMSE_P: 992.8918 - RMSE_T: 26.3381 - val_loss: 0.0095 - val_mean_absolute_error: 0.0585 - val_mean_absolute_percentage_error: 15349.2246 - val_root_mean_squared_error: 0.0973 - val_RMSE_P: 1053.6091 - val_RMSE_T: 27.7011
# Epoch 103/5000
# 139/139 [==============================] - 0s 3ms/step - loss: 0.0083 - mean_absolute_error: 0.0570 - mean_absolute_percentage_error: 12839.9111 - root_mean_squared_error: 0.0910 - RMSE_P: 995.9648 - RMSE_T: 26.3313 - val_loss: 0.0099 - val_mean_absolute_error: 0.0619 - val_mean_absolute_percentage_error: 12491.4482 - val_root_mean_squared_error: 0.0996 - val_RMSE_P: 1085.3547 - val_RMSE_T: 28.2446
# Epoch 104/5000
# 139/139 [==============================] - 0s 3ms/step - loss: 0.0083 - mean_absolute_error: 0.0574 - mean_absolute_percentage_error: 14712.7725 - root_mean_squared_error: 0.0913 - RMSE_P: 999.4517 - RMSE_T: 26.3948 - val_loss: 0.0095 - val_mean_absolute_error: 0.0600 - val_mean_absolute_percentage_error: 19428.2676 - val_root_mean_squared_error: 0.0974 - val_RMSE_P: 1054.4258 - val_RMSE_T: 28.0520
# Epoch 105/5000
# 139/139 [==============================] - 0s 3ms/step - loss: 0.0082 - mean_absolute_error: 0.0567 - mean_absolute_percentage_error: 13506.5059 - root_mean_squared_error: 0.0907 - RMSE_P: 992.1306 - RMSE_T: 26.3088 - val_loss: 0.0097 - val_mean_absolute_error: 0.0602 - val_mean_absolute_percentage_error: 18708.5918 - val_root_mean_squared_error: 0.0984 - val_RMSE_P: 1068.9888 - val_RMSE_T: 28.0721
# Epoch 106/5000
# 139/139 [==============================] - 0s 4ms/step - loss: 0.0083 - mean_absolute_error: 0.0569 - mean_absolute_percentage_error: 13256.3389 - root_mean_squared_error: 0.0909 - RMSE_P: 994.2774 - RMSE_T: 26.3415 - val_loss: 0.0098 - val_mean_absolute_error: 0.0610 - val_mean_absolute_percentage_error: 18370.3730 - val_root_mean_squared_error: 0.0989 - val_RMSE_P: 1076.3749 - val_RMSE_T: 27.8593
# Epoch 107/5000
# 139/139 [==============================] - 0s 3ms/step - loss: 0.0082 - mean_absolute_error: 0.0567 - mean_absolute_percentage_error: 13073.3984 - root_mean_squared_error: 0.0906 - RMSE_P: 991.8231 - RMSE_T: 26.2225 - val_loss: 0.0096 - val_mean_absolute_error: 0.0595 - val_mean_absolute_percentage_error: 17752.6270 - val_root_mean_squared_error: 0.0979 - val_RMSE_P: 1064.3674 - val_RMSE_T: 27.8732
# Epoch 108/5000
# 139/139 [==============================] - 0s 3ms/step - loss: 0.0082 - mean_absolute_error: 0.0566 - mean_absolute_percentage_error: 12159.2490 - root_mean_squared_error: 0.0905 - RMSE_P: 989.9085 - RMSE_T: 26.2345 - val_loss: 0.0096 - val_mean_absolute_error: 0.0606 - val_mean_absolute_percentage_error: 20020.6719 - val_root_mean_squared_error: 0.0978 - val_RMSE_P: 1059.2959 - val_RMSE_T: 28.2916
# Epoch 109/5000
# 139/139 [==============================] - 0s 3ms/step - loss: 0.0082 - mean_absolute_error: 0.0567 - mean_absolute_percentage_error: 14059.7939 - root_mean_squared_error: 0.0905 - RMSE_P: 990.2078 - RMSE_T: 26.2849 - val_loss: 0.0095 - val_mean_absolute_error: 0.0595 - val_mean_absolute_percentage_error: 21712.7324 - val_root_mean_squared_error: 0.0977 - val_RMSE_P: 1061.1082 - val_RMSE_T: 27.8079
# Epoch 110/5000
# 139/139 [==============================] - 0s 3ms/step - loss: 0.0081 - mean_absolute_error: 0.0561 - mean_absolute_percentage_error: 14413.6357 - root_mean_squared_error: 0.0900 - RMSE_P: 983.5000 - RMSE_T: 26.1685 - val_loss: 0.0094 - val_mean_absolute_error: 0.0588 - val_mean_absolute_percentage_error: 15978.1855 - val_root_mean_squared_error: 0.0972 - val_RMSE_P: 1057.5197 - val_RMSE_T: 27.5981
# Epoch 111/5000
# 139/139 [==============================] - 0s 4ms/step - loss: 0.0082 - mean_absolute_error: 0.0566 - mean_absolute_percentage_error: 13717.7031 - root_mean_squared_error: 0.0905 - RMSE_P: 989.3152 - RMSE_T: 26.3699 - val_loss: 0.0095 - val_mean_absolute_error: 0.0600 - val_mean_absolute_percentage_error: 17348.1953 - val_root_mean_squared_error: 0.0977 - val_RMSE_P: 1056.8402 - val_RMSE_T: 28.2267
# Epoch 112/5000
# 139/139 [==============================] - 0s 3ms/step - loss: 0.0081 - mean_absolute_error: 0.0563 - mean_absolute_percentage_error: 14304.7695 - root_mean_squared_error: 0.0898 - RMSE_P: 981.1453 - RMSE_T: 26.2032 - val_loss: 0.0094 - val_mean_absolute_error: 0.0596 - val_mean_absolute_percentage_error: 20958.2168 - val_root_mean_squared_error: 0.0972 - val_RMSE_P: 1053.6447 - val_RMSE_T: 27.7090
# Epoch 113/5000
# 139/139 [==============================] - 0s 3ms/step - loss: 0.0081 - mean_absolute_error: 0.0564 - mean_absolute_percentage_error: 13088.0225 - root_mean_squared_error: 0.0901 - RMSE_P: 986.0598 - RMSE_T: 26.1711 - val_loss: 0.0096 - val_mean_absolute_error: 0.0610 - val_mean_absolute_percentage_error: 18441.0684 - val_root_mean_squared_error: 0.0981 - val_RMSE_P: 1067.7925 - val_RMSE_T: 27.6043
# Epoch 114/5000
# 139/139 [==============================] - 0s 3ms/step - loss: 0.0081 - mean_absolute_error: 0.0566 - mean_absolute_percentage_error: 11977.7900 - root_mean_squared_error: 0.0902 - RMSE_P: 986.2781 - RMSE_T: 26.2656 - val_loss: 0.0095 - val_mean_absolute_error: 0.0589 - val_mean_absolute_percentage_error: 18742.4121 - val_root_mean_squared_error: 0.0973 - val_RMSE_P: 1056.2739 - val_RMSE_T: 27.6529
# Epoch 115/5000
# 139/139 [==============================] - 1s 4ms/step - loss: 0.0080 - mean_absolute_error: 0.0558 - mean_absolute_percentage_error: 13641.0625 - root_mean_squared_error: 0.0896 - RMSE_P: 979.6672 - RMSE_T: 26.0709 - val_loss: 0.0094 - val_mean_absolute_error: 0.0585 - val_mean_absolute_percentage_error: 16870.1426 - val_root_mean_squared_error: 0.0967 - val_RMSE_P: 1049.6627 - val_RMSE_T: 27.6202
# Epoch 116/5000
# 139/139 [==============================] - 0s 3ms/step - loss: 0.0081 - mean_absolute_error: 0.0561 - mean_absolute_percentage_error: 12477.2842 - root_mean_squared_error: 0.0898 - RMSE_P: 981.9056 - RMSE_T: 26.1249 - val_loss: 0.0098 - val_mean_absolute_error: 0.0625 - val_mean_absolute_percentage_error: 24426.3359 - val_root_mean_squared_error: 0.0992 - val_RMSE_P: 1076.7793 - val_RMSE_T: 28.3206
# Epoch 117/5000
# 139/139 [==============================] - 0s 3ms/step - loss: 0.0081 - mean_absolute_error: 0.0567 - mean_absolute_percentage_error: 11293.2021 - root_mean_squared_error: 0.0900 - RMSE_P: 982.8781 - RMSE_T: 26.3361 - val_loss: 0.0093 - val_mean_absolute_error: 0.0586 - val_mean_absolute_percentage_error: 16178.8428 - val_root_mean_squared_error: 0.0963 - val_RMSE_P: 1043.6534 - val_RMSE_T: 27.4381
# Epoch 118/5000
# 139/139 [==============================] - 0s 3ms/step - loss: 0.0081 - mean_absolute_error: 0.0563 - mean_absolute_percentage_error: 13729.3633 - root_mean_squared_error: 0.0898 - RMSE_P: 980.4489 - RMSE_T: 26.2035 - val_loss: 0.0094 - val_mean_absolute_error: 0.0595 - val_mean_absolute_percentage_error: 15079.7812 - val_root_mean_squared_error: 0.0971 - val_RMSE_P: 1052.1150 - val_RMSE_T: 27.8628
# Epoch 119/5000
# 139/139 [==============================] - 0s 4ms/step - loss: 0.0081 - mean_absolute_error: 0.0564 - mean_absolute_percentage_error: 12445.1035 - root_mean_squared_error: 0.0899 - RMSE_P: 982.4065 - RMSE_T: 26.0967 - val_loss: 0.0096 - val_mean_absolute_error: 0.0608 - val_mean_absolute_percentage_error: 17960.0020 - val_root_mean_squared_error: 0.0981 - val_RMSE_P: 1069.6191 - val_RMSE_T: 27.3455
# Epoch 120/5000
# 139/139 [==============================] - 0s 3ms/step - loss: 0.0081 - mean_absolute_error: 0.0566 - mean_absolute_percentage_error: 13794.1895 - root_mean_squared_error: 0.0899 - RMSE_P: 983.0797 - RMSE_T: 26.2226 - val_loss: 0.0092 - val_mean_absolute_error: 0.0580 - val_mean_absolute_percentage_error: 23877.4922 - val_root_mean_squared_error: 0.0962 - val_RMSE_P: 1043.3519 - val_RMSE_T: 27.3865
# Epoch 121/5000
# 139/139 [==============================] - 0s 3ms/step - loss: 0.0080 - mean_absolute_error: 0.0561 - mean_absolute_percentage_error: 12458.1709 - root_mean_squared_error: 0.0896 - RMSE_P: 979.4022 - RMSE_T: 26.1307 - val_loss: 0.0095 - val_mean_absolute_error: 0.0603 - val_mean_absolute_percentage_error: 26261.6719 - val_root_mean_squared_error: 0.0977 - val_RMSE_P: 1058.4663 - val_RMSE_T: 28.2002
# Epoch 122/5000
# 139/139 [==============================] - 0s 3ms/step - loss: 0.0080 - mean_absolute_error: 0.0560 - mean_absolute_percentage_error: 13499.4121 - root_mean_squared_error: 0.0894 - RMSE_P: 976.7267 - RMSE_T: 26.0895 - val_loss: 0.0095 - val_mean_absolute_error: 0.0599 - val_mean_absolute_percentage_error: 20233.3164 - val_root_mean_squared_error: 0.0974 - val_RMSE_P: 1054.3666 - val_RMSE_T: 28.0158
# Epoch 123/5000
# 139/139 [==============================] - 0s 4ms/step - loss: 0.0080 - mean_absolute_error: 0.0557 - mean_absolute_percentage_error: 11948.6602 - root_mean_squared_error: 0.0892 - RMSE_P: 973.7079 - RMSE_T: 26.0445 - val_loss: 0.0094 - val_mean_absolute_error: 0.0589 - val_mean_absolute_percentage_error: 18125.5684 - val_root_mean_squared_error: 0.0972 - val_RMSE_P: 1052.7045 - val_RMSE_T: 27.7651
# Epoch 124/5000
# 139/139 [==============================] - 0s 3ms/step - loss: 0.0080 - mean_absolute_error: 0.0561 - mean_absolute_percentage_error: 12180.7158 - root_mean_squared_error: 0.0895 - RMSE_P: 978.4697 - RMSE_T: 26.0479 - val_loss: 0.0093 - val_mean_absolute_error: 0.0585 - val_mean_absolute_percentage_error: 18149.5195 - val_root_mean_squared_error: 0.0965 - val_RMSE_P: 1047.2163 - val_RMSE_T: 27.4346
# Epoch 125/5000
# 139/139 [==============================] - 0s 3ms/step - loss: 0.0080 - mean_absolute_error: 0.0560 - mean_absolute_percentage_error: 12915.2275 - root_mean_squared_error: 0.0893 - RMSE_P: 975.5884 - RMSE_T: 26.1232 - val_loss: 0.0093 - val_mean_absolute_error: 0.0587 - val_mean_absolute_percentage_error: 16312.0596 - val_root_mean_squared_error: 0.0966 - val_RMSE_P: 1048.0985 - val_RMSE_T: 27.7038
# Epoch 126/5000
# 139/139 [==============================] - 0s 3ms/step - loss: 0.0079 - mean_absolute_error: 0.0558 - mean_absolute_percentage_error: 13365.8340 - root_mean_squared_error: 0.0892 - RMSE_P: 973.6831 - RMSE_T: 26.0249 - val_loss: 0.0094 - val_mean_absolute_error: 0.0595 - val_mean_absolute_percentage_error: 15888.6133 - val_root_mean_squared_error: 0.0972 - val_RMSE_P: 1053.4011 - val_RMSE_T: 28.1277
# Epoch 127/5000
# 139/139 [==============================] - 0s 3ms/step - loss: 0.0080 - mean_absolute_error: 0.0559 - mean_absolute_percentage_error: 13054.4609 - root_mean_squared_error: 0.0892 - RMSE_P: 974.2267 - RMSE_T: 26.1284 - val_loss: 0.0095 - val_mean_absolute_error: 0.0589 - val_mean_absolute_percentage_error: 13747.3750 - val_root_mean_squared_error: 0.0975 - val_RMSE_P: 1058.7816 - val_RMSE_T: 27.7779
# Epoch 128/5000
# 139/139 [==============================] - 0s 3ms/step - loss: 0.0079 - mean_absolute_error: 0.0554 - mean_absolute_percentage_error: 11585.1133 - root_mean_squared_error: 0.0887 - RMSE_P: 969.3781 - RMSE_T: 25.9014 - val_loss: 0.0097 - val_mean_absolute_error: 0.0611 - val_mean_absolute_percentage_error: 16855.2148 - val_root_mean_squared_error: 0.0986 - val_RMSE_P: 1071.6368 - val_RMSE_T: 27.9791
# Epoch 129/5000
# 139/139 [==============================] - 0s 3ms/step - loss: 0.0079 - mean_absolute_error: 0.0560 - mean_absolute_percentage_error: 12697.0547 - root_mean_squared_error: 0.0891 - RMSE_P: 972.5052 - RMSE_T: 26.1412 - val_loss: 0.0094 - val_mean_absolute_error: 0.0594 - val_mean_absolute_percentage_error: 19979.4609 - val_root_mean_squared_error: 0.0969 - val_RMSE_P: 1049.0994 - val_RMSE_T: 27.7192
# Epoch 130/5000
# 139/139 [==============================] - 0s 3ms/step - loss: 0.0079 - mean_absolute_error: 0.0559 - mean_absolute_percentage_error: 13785.1299 - root_mean_squared_error: 0.0891 - RMSE_P: 973.5188 - RMSE_T: 26.0145 - val_loss: 0.0094 - val_mean_absolute_error: 0.0590 - val_mean_absolute_percentage_error: 12564.1484 - val_root_mean_squared_error: 0.0970 - val_RMSE_P: 1051.2257 - val_RMSE_T: 27.8278
# INFO:tensorflow:Assets written to: saved_models\model_ds55Tajcmanova2009\assets
# INFO:tensorflow:Assets written to: saved_models\model_ds55Tajcmanova2009\assets

# %% [markdown]
# ## Plotting of training curves

# %%
history = pd.read_csv(Path("model_ds55Tajcmanova2009.log"))

smooth_std = 10
color = "red"
label = "model_ds55Tajcmanova2009"

fig, axs = plt.subplots(1, 3, figsize=(12, 4))

axs[0].plot(history['epoch'], _smooth(history['loss'], smooth_std), color=color, label=label)
axs[0].plot(history['epoch'], _smooth(history['val_loss'], smooth_std), color=color, linestyle='--', label=label + ' (val)')

axs[1].plot(history['epoch'], _smooth(history['RMSE_T'], smooth_std), color=color, label=label)
axs[1].plot(history['epoch'], _smooth(history['val_RMSE_T'], smooth_std), color=color, linestyle='--', label=label + ' (val)')

axs[2].plot(history['epoch'], _smooth(history['RMSE_P'], smooth_std), color=color, label=label)
axs[2].plot(history['epoch'], _smooth(history['val_RMSE_P'], smooth_std), color=color, linestyle='--', label=label + ' (val)')

axs[0].set_xscale('log')
axs[1].set_xscale('log')
axs[2].set_xscale('log')


axs[0].set_xlabel('Epoch')
axs[0].set_ylabel('Loss')

axs[1].set_xlabel('Epoch')
axs[1].set_ylabel('Temperature RMSE [K]')

axs[2].set_xlabel('Epoch')
axs[2].set_ylabel('Pressure RMSE [bar]')

axs[0].legend()

fig.tight_layout()

# %%
fig, axs = plt.subplots(1, 3, figsize=(12, 4))

axs[0].plot(history['epoch'], history['loss'], color=color, label=label)
axs[0].plot(history['epoch'], history['val_loss'], color=color, linestyle='--', label=label + ' (val)')

axs[1].plot(history['epoch'], history['RMSE_T'], color=color, label=label)
axs[1].plot(history['epoch'], history['val_RMSE_T'], color=color, linestyle='--', label=label + ' (val)')

axs[2].plot(history['epoch'], history['RMSE_P'], color=color, label=label)
axs[2].plot(history['epoch'], history['val_RMSE_P'], color=color, linestyle='--', label=label + ' (val)')

# axs[0].set_xscale('log')
# axs[1].set_xscale('log')
# axs[2].set_xscale('log')


axs[0].set_xlabel('Epoch')
axs[0].set_ylabel('Loss')

axs[1].set_xlabel('Epoch')
axs[1].set_ylabel('Temperature RMSE [K]')

axs[2].set_xlabel('Epoch')
axs[2].set_ylabel('Pressure RMSE [bar]')

axs[0].legend()

fig.tight_layout()
