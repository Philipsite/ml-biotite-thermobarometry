# %%
import seaborn as sns

from ml_tb.plot import plot_hyperparameter_test

# %%
fig, axs = plot_hyperparameter_test(log_files=["logs/baseline_small.log", "logs/baseline_medium.log", "logs/baseline_mediumdeep.log", "logs/baseline_large.log", "logs/baseline_largedeep.log"],
                                    colors=sns.color_palette("deep", 5),
                                    labels=["Small", "Medium", "MediumDeep", "Large", "LargeDeep"],
                                    ylims=[None, (5, 25), (50, 1500)])

# fig.savefig(Path("exported_figs", "ds62_model_architecture.pdf"), dpi=300)

# %%
fig, axs = plot_hyperparameter_test(log_files=["logs/baseline_elu.log", "logs/baseline_relu.log", "logs/baseline_leaky_relu.log"],
                                    colors=sns.color_palette("deep", 3),
                                    labels=["ELU", "ReLU", "LeakyReLU"],
                                    ylims=[None, (5, 25), (50, 1500)])

# fig.savefig(Path("exported_figs", "ds62_lr.pdf"), dpi=300)

# %%
fig, axs = plot_hyperparameter_test(log_files=["logs/baseline_noReg.log", "logs/baseline_L2.log","logs/baseline_dropout.log", "logs/baseline_BatchNorm.log", "logs/baseline_LayerNorm.log", "logs/baseline_L2_dropout.log"],
                                    colors=sns.color_palette("deep", 6),
                                    labels=["NoReg", "L2", "Dropout", "BatchNorm", "LayerNorm", "L2+Dropout"],
                                    ylims=[None, None, None])

# fig.savefig(Path("exported_figs", "ds62_regularisation.pdf"), dpi=300)
